# %% [markdown]
# # Import libraries

# %%
import os
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.cm as cm

import seaborn as sns

import math

import json

import re

import shap

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import label_binarize

from sklearn.model_selection import cross_validate
from sklearn.model_selection import StratifiedKFold

from sklearn.utils import resample

from sklearn.multiclass import OneVsRestClassifier

from sklearn.linear_model import LogisticRegression

from sklearn.pipeline import Pipeline

from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn.metrics import make_scorer
from sklearn.metrics import confusion_matrix

from scipy.stats import t

from joblib import Parallel
from joblib import delayed
from tqdm_joblib import tqdm_joblib

from itertools import combinations

from collections import defaultdict

from tqdm.notebook import tqdm

# %%
warnings.filterwarnings("ignore")

np.seterr(all='ignore')

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', None)

# %%
path_to_save = './../results/04b_modeling_lr'

# %% [markdown]
# # Loading data

# %%
path_to_ftir_data = './../data/processed_data/dataset_1900_800_engineered.csv'
path_to_features_description = './../data/processed_data/features_description_1900_800.json'

# %% [markdown]
# ## FTIR-features (*long-list*)

# %%
dataset = pd.read_csv(path_to_ftir_data, sep=';', index_col=0)

print(dataset.shape)
dataset.head(3)
# Out:
# (74, 249)
#                       $I_{872}$  $I_{1085}$  $I_{1182}$  $I_{1241}$  \
# division_1_size_bulk   0.047800    0.681294    0.388923    0.455066
# division_1_size_5      0.091438    0.606138    0.416593    0.427988
# division_1_size_3      0.108127    0.836176    0.514367    0.400950
#
#                       $I_{1394}$  $I_{1612}$  $I_{1725}$  \
# division_1_size_bulk    0.760582         1.0    0.423273
# division_1_size_5       0.687458         1.0    0.384475
# division_1_size_3       0.696553         1.0    0.368753
#
#                       $\overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                          0.424162
# division_1_size_5                             0.378730
# division_1_size_3                             0.436266
#
#                       $\Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                          3.756938
# division_1_size_5                             3.614090
# division_1_size_3                             3.924926
#
#                       $\overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                           0.426619
# division_1_size_5                              0.378004
# division_1_size_3                              0.429362
#
#                       $\Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                           1.423273
# division_1_size_5                              1.384475
# division_1_size_3                              1.368753
#
#                       $\overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                           0.571735
# division_1_size_5                              0.502368
# division_1_size_3                              0.523513
#
#                       $\Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                           0.760582
# division_1_size_5                              0.687458
# division_1_size_3                              0.696553
#
#                       $\overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                          0.363338
# division_1_size_5                             0.329999
# division_1_size_3                             0.406988
#
#                       $\Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                          1.573083
# division_1_size_5                             1.542157
# division_1_size_3                             1.859620
#
#                       $\overline{I}_{872 \pm 25}$  \
# division_1_size_bulk                     0.047238
# division_1_size_5                        0.092933
# division_1_size_3                        0.111725
#
#                       $\overline{I}_{1085 \pm 25}$  \
# division_1_size_bulk                      0.658256
# division_1_size_5                         0.571531
# division_1_size_3                         0.776148
#
#                       $\overline{I}_{1182 \pm 25}$  \
# division_1_size_bulk                      0.399497
# division_1_size_5                         0.426105
# division_1_size_3                         0.526741
#
#                       $\overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                      0.447733
# division_1_size_5                         0.424918
# division_1_size_3                         0.401435
#
#                       $\overline{I}_{1394 \pm 25}$  \
# division_1_size_bulk                      0.738860
# division_1_size_5                         0.667947
# division_1_size_3                         0.678774
#
#                       $\overline{I}_{1612 \pm 25}$  \
# division_1_size_bulk                      0.936425
# division_1_size_5                         0.926718
# division_1_size_3                         0.951396
#
#                       $\overline{I}_{1725 \pm 25}$  $\log I_{872}$  \
# division_1_size_bulk                      0.417470       -3.040727
# division_1_size_5                         0.378463       -2.392093
# division_1_size_3                         0.369746       -2.224448
#
#                       $(I_{872})^{-1}$  $\log I_{1085}$  $(I_{1085})^{-1}$  \
# division_1_size_bulk         20.920439        -0.383761           1.467794
# division_1_size_5            10.936364        -0.500648           1.649790
# division_1_size_3             9.248376        -0.178917           1.195921
#
#                       $\log I_{1182}$  $(I_{1182})^{-1}$  $\log I_{1241}$  \
# division_1_size_bulk        -0.944375           2.571206        -0.787312
# division_1_size_5           -0.875645           2.400424        -0.848660
# division_1_size_3           -0.664819           1.944138        -0.913918
#
#                       $(I_{1241})^{-1}$  $\log I_{1394}$  $(I_{1394})^{-1}$  \
# division_1_size_bulk           2.197482        -0.273672           1.314783
# division_1_size_5              2.336514        -0.374754           1.454634
# division_1_size_3              2.494076        -0.361611           1.435640
#
#                       $\log I_{1612}$  $(I_{1612})^{-1}$  $\log I_{1725}$  \
# division_1_size_bulk              0.0                1.0        -0.859739
# division_1_size_5                 0.0                1.0        -0.955877
# division_1_size_3                 0.0                1.0        -0.997629
#
#                       $(I_{1725})^{-1}$  \
# division_1_size_bulk           2.362543
# division_1_size_5              2.600952
# division_1_size_3              2.711845
#
#                       $\log \overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                              -0.857641
# division_1_size_5                                 -0.970931
# division_1_size_3                                 -0.829504
#
#                       $(\overline{I}_{1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.357591
# division_1_size_5                                    2.640400
# division_1_size_3                                    2.292181
#
#                       $\log \Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                               1.323604
# division_1_size_5                                  1.284840
# division_1_size_3                                  1.367347
#
#                       $(\Sigma I_{p,\ 1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.266174
# division_1_size_5                                    0.276695
# division_1_size_3                                    0.254782
#
#                       $\log \overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                               -0.851863
# division_1_size_5                                  -0.972851
# division_1_size_3                                  -0.845455
#
#                       $(\overline{I}_{1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  2.344010
# division_1_size_5                                     2.645477
# division_1_size_3                                     2.329038
#
#                       $\log \Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                                0.352959
# division_1_size_5                                   0.325321
# division_1_size_3                                   0.313900
#
#                       $(\Sigma I_{p,\ 1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  0.702606
# division_1_size_5                                     0.722296
# division_1_size_3                                     0.730592
#
#                       $\log \overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                               -0.559080
# division_1_size_5                                  -0.688422
# division_1_size_3                                  -0.647194
#
#                       $(\overline{I}_{1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.749062
# division_1_size_5                                     1.990572
# division_1_size_3                                     1.910173
#
#                       $\log \Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                               -0.273672
# division_1_size_5                                  -0.374754
# division_1_size_3                                  -0.361611
#
#                       $(\Sigma I_{p,\ 1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.314783
# division_1_size_5                                     1.454634
# division_1_size_3                                     1.435640
#
#                       $\log \overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                              -1.012422
# division_1_size_5                                 -1.108665
# division_1_size_3                                 -0.898970
#
#                       $(\overline{I}_{1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.752259
# division_1_size_5                                    3.030309
# division_1_size_3                                    2.457072
#
#                       $\log \Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                               0.453038
# division_1_size_5                                  0.433182
# division_1_size_3                                  0.620372
#
#                       $(\Sigma I_{p,\ 1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.635694
# division_1_size_5                                    0.648442
# division_1_size_3                                    0.537744
#
#                       $\log \overline{I}_{872 \pm 25}$  \
# division_1_size_bulk                         -3.052551
# division_1_size_5                            -2.375877
# division_1_size_3                            -2.191715
#
#                       $(\overline{I}_{872 \pm 25})^{-1}$  \
# division_1_size_bulk                           21.169287
# division_1_size_5                              10.760443
# division_1_size_3                               8.950554
#
#                       $\log \overline{I}_{1085 \pm 25}$  \
# division_1_size_bulk                          -0.418161
# division_1_size_5                             -0.559437
# division_1_size_3                             -0.253412
#
#                       $(\overline{I}_{1085 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.519165
# division_1_size_5                                1.749686
# division_1_size_3                                1.288414
#
#                       $\log \overline{I}_{1182 \pm 25}$  \
# division_1_size_bulk                          -0.917549
# division_1_size_5                             -0.853069
# division_1_size_3                             -0.641046
#
#                       $(\overline{I}_{1182 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.503146
# division_1_size_5                                2.346839
# division_1_size_3                                1.898465
#
#                       $\log \overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                          -0.803558
# division_1_size_5                             -0.855859
# division_1_size_3                             -0.912710
#
#                       $(\overline{I}_{1241 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.233473
# division_1_size_5                                2.353396
# division_1_size_3                                2.491063
#
#                       $\log \overline{I}_{1394 \pm 25}$  \
# division_1_size_bulk                          -0.302647
# division_1_size_5                             -0.403547
# division_1_size_3                             -0.387466
#
#                       $(\overline{I}_{1394 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.353436
# division_1_size_5                                1.497126
# division_1_size_3                                1.473243
#
#                       $\log \overline{I}_{1612 \pm 25}$  \
# division_1_size_bulk                          -0.065686
# division_1_size_5                             -0.076106
# division_1_size_3                             -0.049825
#
#                       $(\overline{I}_{1612 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.067891
# division_1_size_5                                1.079077
# division_1_size_3                                1.051087
#
#                       $\log \overline{I}_{1725 \pm 25}$  \
# division_1_size_bulk                          -0.873542
# division_1_size_5                             -0.971638
# division_1_size_3                             -0.994938
#
#                       $(\overline{I}_{1725 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.395381
# division_1_size_5                                2.642268
# division_1_size_3                                2.704557
#
#                       $\frac{I_{872}}{I_{1085}}$  $\frac{I_{872}}{I_{1182}}$  \
# division_1_size_bulk                    0.070161                    0.122904
# division_1_size_5                       0.150854                    0.219490
# division_1_size_3                       0.129311                    0.210214
#
#                       $\frac{I_{872}}{I_{1241}}$  $\frac{I_{872}}{I_{1394}}$  \
# division_1_size_bulk                    0.105040                    0.062847
# division_1_size_5                       0.213646                    0.133009
# division_1_size_3                       0.269677                    0.155232
#
#                       $\frac{I_{872}}{I_{1612}}$  $\frac{I_{872}}{I_{1725}}$  \
# division_1_size_bulk                    0.047800                    0.112930
# division_1_size_5                       0.091438                    0.237826
# division_1_size_3                       0.108127                    0.293224
#
#                       $\frac{I_{872}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                          0.112693
# division_1_size_5                                             0.241433
# division_1_size_3                                             0.247847
#
#                       $\frac{I_{872}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                          0.012723
# division_1_size_5                                             0.025300
# division_1_size_3                                             0.027549
#
#                       $\frac{I_{872}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.112044
# division_1_size_5                                              0.241897
# division_1_size_3                                              0.251832
#
#                       $\frac{I_{872}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.033585
# division_1_size_5                                              0.066045
# division_1_size_3                                              0.078997
#
#                       $\frac{I_{872}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.083605
# division_1_size_5                                              0.182014
# division_1_size_3                                              0.206541
#
#                       $\frac{I_{872}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.062847
# division_1_size_5                                              0.133009
# division_1_size_3                                              0.155232
#
#                       $\frac{I_{872}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                          0.131558
# division_1_size_5                                             0.277086
# division_1_size_3                                             0.265676
#
#                       $\frac{I_{872}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                          0.030386
# division_1_size_5                                             0.059292
# division_1_size_3                                             0.058145
#
#                       $\frac{I_{872}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                      0.072616
# division_1_size_5                                         0.159988
# division_1_size_3                                         0.139312
#
#                       $\frac{I_{872}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                      0.119651
# division_1_size_5                                         0.214590
# division_1_size_3                                         0.205276
#
#                       $\frac{I_{872}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                      0.106760
# division_1_size_5                                         0.215190
# division_1_size_3                                         0.269351
#
#                       $\frac{I_{872}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                      0.064694
# division_1_size_5                                         0.136894
# division_1_size_3                                         0.159298
#
#                       $\frac{I_{872}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                      0.051045
# division_1_size_5                                         0.098669
# division_1_size_3                                         0.113651
#
#                       $\frac{I_{872}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                      0.114500
# division_1_size_5                                         0.241604
# division_1_size_3                                         0.292436
#
#                       $\frac{I_{1085}}{I_{1182}}$  \
# division_1_size_bulk                     1.751748
# division_1_size_5                        1.454988
# division_1_size_3                        1.625641
#
#                       $\frac{I_{1085}}{I_{1241}}$  \
# division_1_size_bulk                     1.497132
# division_1_size_5                        1.416250
# division_1_size_3                        2.085485
#
#                       $\frac{I_{1085}}{I_{1394}}$  \
# division_1_size_bulk                     0.895754
# division_1_size_5                        0.881708
# division_1_size_3                        1.200447
#
#                       $\frac{I_{1085}}{I_{1612}}$  \
# division_1_size_bulk                     0.681294
# division_1_size_5                        0.606138
# division_1_size_3                        0.836176
#
#                       $\frac{I_{1085}}{I_{1725}}$  \
# division_1_size_bulk                     1.609587
# division_1_size_5                        1.576535
# division_1_size_3                        2.267579
#
#                       $\frac{I_{1085}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.606214
# division_1_size_5                                              1.600446
# division_1_size_3                                              1.916666
#
#                       $\frac{I_{1085}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.181343
# division_1_size_5                                              0.167715
# division_1_size_3                                              0.213042
#
#                       $\frac{I_{1085}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.596961
# division_1_size_5                                               1.603523
# division_1_size_3                                               1.947485
#
#                       $\frac{I_{1085}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.478681
# division_1_size_5                                               0.437811
# division_1_size_3                                               0.610903
#
#                       $\frac{I_{1085}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.191626
# division_1_size_5                                               1.206561
# division_1_size_3                                               1.597240
#
#                       $\frac{I_{1085}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.895754
# division_1_size_5                                               0.881708
# division_1_size_3                                               1.200447
#
#                       $\frac{I_{1085}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.875098
# division_1_size_5                                              1.836785
# division_1_size_3                                              2.054544
#
#                       $\frac{I_{1085}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.433095
# division_1_size_5                                              0.393045
# division_1_size_3                                              0.449649
#
#                       $\frac{I_{1085}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                     14.422514
# division_1_size_5                                         6.522311
# division_1_size_3                                         7.484235
#
#                       $\frac{I_{1085}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                       1.705379
# division_1_size_5                                          1.422508
# division_1_size_3                                          1.587450
#
#                       $\frac{I_{1085}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.521652
# division_1_size_5                                          1.426482
# division_1_size_3                                          2.082966
#
#                       $\frac{I_{1085}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.922089
# division_1_size_5                                          0.907465
# division_1_size_3                                          1.231890
#
#                       $\frac{I_{1085}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                       0.727548
# division_1_size_5                                          0.654069
# division_1_size_3                                          0.878893
#
#                       $\frac{I_{1085}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.631959
# division_1_size_5                                          1.601578
# division_1_size_3                                          2.261485
#
#                       $\frac{I_{1182}}{I_{1241}}$  \
# division_1_size_bulk                     0.854650
# division_1_size_5                        0.973376
# division_1_size_3                        1.282869
#
#                       $\frac{I_{1182}}{I_{1394}}$  \
# division_1_size_bulk                     0.511349
# division_1_size_5                        0.605990
# division_1_size_3                        0.738445
#
#                       $\frac{I_{1182}}{I_{1612}}$  \
# division_1_size_bulk                     0.388923
# division_1_size_5                        0.416593
# division_1_size_3                        0.514367
#
#                       $\frac{I_{1182}}{I_{1725}}$  \
# division_1_size_bulk                     0.918847
# division_1_size_5                        1.083538
# division_1_size_3                        1.394883
#
#                       $\frac{I_{1182}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           0.916921
# division_1_size_5                                              1.099973
# division_1_size_3                                              1.179021
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.103521
# division_1_size_5                                              0.115269
# division_1_size_3                                              0.131051
#
#                       $\frac{I_{1182}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.911639
# division_1_size_5                                               1.102087
# division_1_size_3                                               1.197980
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.273259
# division_1_size_5                                               0.300903
# division_1_size_3                                               0.375792
#
#                       $\frac{I_{1182}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.680250
# division_1_size_5                                               0.829258
# division_1_size_3                                               0.982530
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.511349
# division_1_size_5                                               0.605990
# division_1_size_3                                               0.738445
#
#                       $\frac{I_{1182}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.070416
# division_1_size_5                                              1.262406
# division_1_size_3                                              1.263836
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.247236
# division_1_size_5                                              0.270137
# division_1_size_3                                              0.276598
#
#                       $\frac{I_{1182}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                      8.233214
# division_1_size_5                                         4.482726
# division_1_size_3                                         4.603867
#
#                       $\frac{I_{1182}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                       0.590838
# division_1_size_5                                          0.728907
# division_1_size_3                                          0.662717
#
#                       $\frac{I_{1182}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       0.868648
# division_1_size_5                                          0.980408
# division_1_size_3                                          1.281320
#
#                       $\frac{I_{1182}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.526382
# division_1_size_5                                          0.623692
# division_1_size_3                                          0.757787
#
#                       $\frac{I_{1182}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                       0.415327
# division_1_size_5                                          0.449536
# division_1_size_3                                          0.540644
#
#                       $\frac{I_{1182}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       0.931618
# division_1_size_5                                          1.100751
# division_1_size_3                                          1.391134
#
#                       $\frac{I_{1241}}{I_{1394}}$  \
# division_1_size_bulk                     0.598314
# division_1_size_5                        0.622566
# division_1_size_3                        0.575620
#
#                       $\frac{I_{1241}}{I_{1612}}$  \
# division_1_size_bulk                     0.455066
# division_1_size_5                        0.427988
# division_1_size_3                        0.400950
#
#                       $\frac{I_{1241}}{I_{1725}}$  \
# division_1_size_bulk                     1.075114
# division_1_size_5                        1.113176
# division_1_size_3                        1.087315
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.072861
# division_1_size_5                                              1.130060
# division_1_size_3                                              0.919050
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.121127
# division_1_size_5                                              0.118422
# division_1_size_3                                              0.102155
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.066680
# division_1_size_5                                               1.132232
# division_1_size_3                                               0.933828
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.319732
# division_1_size_5                                               0.309134
# division_1_size_3                                               0.292931
#
#                       $\frac{I_{1241}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.795939
# division_1_size_5                                               0.851941
# division_1_size_3                                               0.765884
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.598314
# division_1_size_5                                               0.622566
# division_1_size_3                                               0.575620
#
#                       $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.252460
# division_1_size_5                                              1.296936
# division_1_size_3                                              0.985163
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.289283
# division_1_size_5                                              0.277526
# division_1_size_3                                              0.215609
#
#                       $\frac{I_{1241}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                      9.633431
# division_1_size_5                                         4.605340
# division_1_size_3                                         3.588726
#
#                       $\frac{I_{1241}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                       0.691321
# division_1_size_5                                          0.748845
# division_1_size_3                                          0.516590
#
#                       $\frac{I_{1241}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                       1.139098
# division_1_size_5                                          1.004419
# division_1_size_3                                          0.761190
#
#                       $\frac{I_{1241}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.615903
# division_1_size_5                                          0.640752
# division_1_size_3                                          0.590697
#
#                       $\frac{I_{1241}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                       0.485961
# division_1_size_5                                          0.461832
# division_1_size_3                                          0.421433
#
#                       $\frac{I_{1241}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.090057
# division_1_size_5                                          1.130859
# division_1_size_3                                          1.084393
#
#                       $\frac{I_{1394}}{I_{1612}}$  \
# division_1_size_bulk                     0.760582
# division_1_size_5                        0.687458
# division_1_size_3                        0.696553
#
#                       $\frac{I_{1394}}{I_{1725}}$  \
# division_1_size_bulk                     1.796907
# division_1_size_5                        1.788046
# division_1_size_3                        1.888945
#
#                       $\frac{I_{1394}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.793141
# division_1_size_5                                              1.815165
# division_1_size_3                                              1.596626
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.202447
# division_1_size_5                                              0.190216
# division_1_size_3                                              0.177469
#
#                       $\frac{I_{1394}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.782811
# division_1_size_5                                               1.818655
# division_1_size_3                                               1.622300
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.534389
# division_1_size_5                                               0.496548
# division_1_size_3                                               0.508897
#
#                       $\frac{I_{1394}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.330305
# division_1_size_5                                               1.368435
# division_1_size_3                                               1.330538
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                 1.0
# division_1_size_5                                                    1.0
# division_1_size_3                                                    1.0
#
#                       $\frac{I_{1394}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.093317
# division_1_size_5                                              2.083211
# division_1_size_3                                              1.711482
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.483497
# division_1_size_5                                              0.445777
# division_1_size_3                                              0.374568
#
#                       $\frac{I_{1394}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                     16.100969
# division_1_size_5                                         7.397356
# division_1_size_3                                         6.234539
#
#                       $\frac{I_{1394}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                       1.155449
# division_1_size_5                                          1.202836
# division_1_size_3                                          0.897449
#
#                       $\frac{I_{1394}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                       1.903847
# division_1_size_5                                          1.613354
# division_1_size_3                                          1.322383
#
#                       $\frac{I_{1394}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.698738
# division_1_size_5                                          1.617862
# division_1_size_3                                          1.735159
#
#                       $\frac{I_{1394}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                       0.812218
# division_1_size_5                                          0.741820
# division_1_size_3                                          0.732138
#
#                       $\frac{I_{1394}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.821882
# division_1_size_5                                          1.816449
# division_1_size_3                                          1.883869
#
#                       $\frac{I_{1612}}{I_{1725}}$  \
# division_1_size_bulk                     2.362543
# division_1_size_5                        2.600952
# division_1_size_3                        2.711845
#
#                       $\frac{I_{1612}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           2.357591
# division_1_size_5                                              2.640400
# division_1_size_3                                              2.292181
#
#                       $\frac{I_{1612}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.266174
# division_1_size_5                                              0.276695
# division_1_size_3                                              0.254782
#
#                       $\frac{I_{1612}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            2.344010
# division_1_size_5                                               2.645477
# division_1_size_3                                               2.329038
#
#                       $\frac{I_{1612}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.702606
# division_1_size_5                                               0.722296
# division_1_size_3                                               0.730592
#
#                       $\frac{I_{1612}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.749062
# division_1_size_5                                               1.990572
# division_1_size_3                                               1.910173
#
#                       $\frac{I_{1612}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.314783
# division_1_size_5                                               1.454634
# division_1_size_3                                               1.435640
#
#                       $\frac{I_{1612}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.752259
# division_1_size_5                                              3.030309
# division_1_size_3                                              2.457072
#
#                       $\frac{I_{1612}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.635694
# division_1_size_5                                              0.648442
# division_1_size_3                                              0.537744
#
#                       $\frac{I_{1612}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                     21.169287
# division_1_size_5                                        10.760443
# division_1_size_3                                         8.950554
#
#                       $\frac{I_{1612}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                       1.519165
# division_1_size_5                                          1.749686
# division_1_size_3                                          1.288414
#
#                       $\frac{I_{1612}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                       2.503146
# division_1_size_5                                          2.346839
# division_1_size_3                                          1.898465
#
#                       $\frac{I_{1612}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       2.233473
# division_1_size_5                                          2.353396
# division_1_size_3                                          2.491063
#
#                       $\frac{I_{1612}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       1.353436
# division_1_size_5                                          1.497126
# division_1_size_3                                          1.473243
#
#                       $\frac{I_{1612}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       2.395381
# division_1_size_5                                          2.642268
# division_1_size_3                                          2.704557
#
#                       $\frac{I_{1725}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           0.997904
# division_1_size_5                                              1.015167
# division_1_size_3                                              0.845248
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.112664
# division_1_size_5                                              0.106382
# division_1_size_3                                              0.093951
#
#                       $\frac{I_{1725}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.992156
# division_1_size_5                                               1.017119
# division_1_size_3                                               0.858839
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.297394
# division_1_size_5                                               0.277704
# division_1_size_3                                               0.269408
#
#                       $\frac{I_{1725}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.740330
# division_1_size_5                                               0.765324
# division_1_size_3                                               0.704381
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.556512
# division_1_size_5                                               0.559270
# division_1_size_3                                               0.529396
#
#                       $\frac{I_{1725}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.164956
# division_1_size_5                                              1.165077
# division_1_size_3                                              0.906052
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.269072
# division_1_size_5                                              0.249310
# division_1_size_3                                              0.198295
#
#                       $\frac{I_{1725}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                      8.960381
# division_1_size_5                                         4.137118
# division_1_size_3                                         3.300540
#
#                       $\frac{I_{1725}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                       0.643021
# division_1_size_5                                          0.672710
# division_1_size_3                                          0.475106
#
#                       $\frac{I_{1725}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                       1.059513
# division_1_size_5                                          0.902300
# division_1_size_3                                          0.700064
#
#                       $\frac{I_{1725}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       0.945368
# division_1_size_5                                          0.904821
# division_1_size_3                                          0.918586
#
#                       $\frac{I_{1725}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.572873
# division_1_size_5                                          0.575607
# division_1_size_3                                          0.543262
#
#                       $\frac{I_{1725}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                       0.452009
# division_1_size_5                                          0.414878
# division_1_size_3                                          0.387591
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                                                  0.741885
# division_1_size_5                                                                     0.753890
# division_1_size_3                                                                     0.833343
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                                                 1.167403
# division_1_size_5                                                                    1.147670
# division_1_size_3                                                                    1.071937
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                                            8.979201
# division_1_size_5                                                               4.075307
# division_1_size_3                                                               3.904821
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                                             0.644372
# division_1_size_5                                                                0.662659
# division_1_size_3                                                                0.562091
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                                             1.061739
# division_1_size_5                                                                0.888819
# division_1_size_3                                                                0.828236
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# ...
# division_1_size_bulk                                                              0.952843
# division_1_size_5                                                                 0.889592
# division_1_size_3                                                                 1.069567
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                              0.577402
# division_1_size_5                                                                 0.565919
# division_1_size_3                                                                 0.632554
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                              0.455583
# division_1_size_5                                                                 0.407895
# division_1_size_3                                                                 0.451297
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                              1.021916
# division_1_size_5                                                                 0.998787
# division_1_size_3                                                                 1.161234
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}1500}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                                   1.871295
# division_1_size_5                                                                      2.013903
# division_1_size_3                                                                      1.965036
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}1500}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                                                  0.904766
# division_1_size_5                                                                     0.897752
# division_1_size_3                                                                     0.736039
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                                                  1.573562
# division_1_size_5                                                                     1.522331
# division_1_size_3                                                                     1.286309
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                                            12.103221
# division_1_size_5                                                                5.405705
# division_1_size_3                                                                4.685729
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                                              0.868560
# division_1_size_5                                                                 0.878987
# division_1_size_3                                                                 0.674501
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                                              1.431136
# division_1_size_5                                                                 1.178978
# division_1_size_3                                                                 0.993871
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                              1.276955
# division_1_size_5                                                                 1.182272
# division_1_size_3                                                                 1.304103
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                              0.773807
# division_1_size_5                                                                 0.752109
# division_1_size_3                                                                 0.771262
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                              0.610551
# division_1_size_5                                                                 0.542094
# division_1_size_3                                                                 0.550257
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                              1.369523
# division_1_size_5                                                                 1.327392
# division_1_size_3                                                                 1.415870
#
#                       $\frac{\Sigma I_{p,\ 1500\text{–}1300}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                                                  0.483497
# division_1_size_5                                                                     0.445777
# division_1_size_3                                                                     0.374568
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                                            7.691605
# division_1_size_5                                                               3.550939
# division_1_size_3                                                               3.642772
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                                             0.551970
# division_1_size_5                                                                0.577395
# division_1_size_3                                                                0.524370
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                                             0.909488
# division_1_size_5                                                                0.774455
# division_1_size_3                                                                0.772653
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                             0.811505
# division_1_size_5                                                                0.776619
# division_1_size_3                                                                1.013834
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                             0.491755
# division_1_size_5                                                                0.494051
# division_1_size_3                                                                0.599593
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                             0.388005
# division_1_size_5                                                                0.356095
# division_1_size_3                                                                0.427780
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                             0.870333
# division_1_size_5                                                                0.871947
# division_1_size_3                                                                1.100724
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                                        0.071763
# division_1_size_5                                                           0.162604
# division_1_size_3                                                           0.143948
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                                        0.118244
# division_1_size_5                                                           0.218099
# division_1_size_3                                                           0.212106
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                        0.105505
# division_1_size_5                                                           0.218708
# division_1_size_3                                                           0.278314
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                        0.063934
# division_1_size_5                                                           0.139132
# division_1_size_3                                                           0.164598
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                        0.050445
# division_1_size_5                                                           0.100282
# division_1_size_3                                                           0.117433
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                        0.113154
# division_1_size_5                                                           0.245554
# division_1_size_3                                                           0.302166
#
#                       $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                                         1.647712
# division_1_size_5                                                            1.341291
# division_1_size_3                                                            1.473490
#
#                       $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                         1.470198
# division_1_size_5                                                            1.345039
# division_1_size_3                                                            1.933434
#
#                       $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.890908
# division_1_size_5                                                            0.855654
# division_1_size_3                                                            1.143455
#
#                       $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                         0.702946
# division_1_size_5                                                            0.616726
# division_1_size_3                                                            0.815799
#
#                       $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.576774
# division_1_size_5                                                            1.510138
# division_1_size_3                                                            2.099137
#
#                       $\frac{\overline{I}_{1182 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                         0.892266
# division_1_size_5                                                            1.002794
# division_1_size_3                                                            1.312146
#
#                       $\frac{\overline{I}_{1182 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.540694
# division_1_size_5                                                            0.637933
# division_1_size_3                                                            0.776018
#
#                       $\frac{\overline{I}_{1182 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                         0.426620
# division_1_size_5                                                            0.459800
# division_1_size_3                                                            0.553651
#
#                       $\frac{\overline{I}_{1182 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         0.956948
# division_1_size_5                                                            1.125884
# division_1_size_3                                                            1.424602
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.605978
# division_1_size_5                                                            0.636156
# division_1_size_3                                                            0.591411
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                         0.478130
# division_1_size_5                                                            0.458519
# division_1_size_3                                                            0.421943
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.072491
# division_1_size_5                                                            1.122747
# division_1_size_3                                                            1.085704
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                         0.789022
# division_1_size_5                                                            0.720766
# division_1_size_3                                                            0.713451
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.769851
# division_1_size_5                                                            1.764894
# division_1_size_3                                                            1.835784
#
#                       $\frac{\overline{I}_{1612 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         2.243094
# division_1_size_5                                                            2.448637
# division_1_size_3                                                            2.573105
#
#                       Split Fraction_hue Fraction_grouped_hue  Class
# division_1_size_bulk  Train        $> 0$              $d > 5$      2
# division_1_size_5     Train        $< 5$       $2 < d \leq 5$      1
# division_1_size_3     Train        $< 3$       $2 < d \leq 5$      1

# %% [markdown]
# ## Features description

# %%
with open(path_to_features_description, 'r', encoding='utf-8') as f:
    features_description = json.load(f)

# %% [markdown]
# # Data wrangling

# %% [markdown]
# ## Data wrangling

# %%
dataset_train = dataset.loc[dataset['Split'] == 'Train']

X_train = dataset_train.loc[:, ~dataset_train.columns.isin(['Split', 'Fraction_hue', 'Fraction_grouped_hue', 'Class'])]
y_train = dataset_train['Class']

print(
    f'(*) X_train: {X_train.shape}',
    f'(*) y_train: {y_train.shape}',
    sep='\n'
)
X_train.head(3)
# Out:
# (*) X_train: (59, 245)
# (*) y_train: (59,)
#                       $I_{872}$  $I_{1085}$  $I_{1182}$  $I_{1241}$  \
# division_1_size_bulk   0.047800    0.681294    0.388923    0.455066
# division_1_size_5      0.091438    0.606138    0.416593    0.427988
# division_1_size_3      0.108127    0.836176    0.514367    0.400950
#
#                       $I_{1394}$  $I_{1612}$  $I_{1725}$  \
# division_1_size_bulk    0.760582         1.0    0.423273
# division_1_size_5       0.687458         1.0    0.384475
# division_1_size_3       0.696553         1.0    0.368753
#
#                       $\overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                          0.424162
# division_1_size_5                             0.378730
# division_1_size_3                             0.436266
#
#                       $\Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                          3.756938
# division_1_size_5                             3.614090
# division_1_size_3                             3.924926
#
#                       $\overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                           0.426619
# division_1_size_5                              0.378004
# division_1_size_3                              0.429362
#
#                       $\Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                           1.423273
# division_1_size_5                              1.384475
# division_1_size_3                              1.368753
#
#                       $\overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                           0.571735
# division_1_size_5                              0.502368
# division_1_size_3                              0.523513
#
#                       $\Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                           0.760582
# division_1_size_5                              0.687458
# division_1_size_3                              0.696553
#
#                       $\overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                          0.363338
# division_1_size_5                             0.329999
# division_1_size_3                             0.406988
#
#                       $\Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                          1.573083
# division_1_size_5                             1.542157
# division_1_size_3                             1.859620
#
#                       $\overline{I}_{872 \pm 25}$  \
# division_1_size_bulk                     0.047238
# division_1_size_5                        0.092933
# division_1_size_3                        0.111725
#
#                       $\overline{I}_{1085 \pm 25}$  \
# division_1_size_bulk                      0.658256
# division_1_size_5                         0.571531
# division_1_size_3                         0.776148
#
#                       $\overline{I}_{1182 \pm 25}$  \
# division_1_size_bulk                      0.399497
# division_1_size_5                         0.426105
# division_1_size_3                         0.526741
#
#                       $\overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                      0.447733
# division_1_size_5                         0.424918
# division_1_size_3                         0.401435
#
#                       $\overline{I}_{1394 \pm 25}$  \
# division_1_size_bulk                      0.738860
# division_1_size_5                         0.667947
# division_1_size_3                         0.678774
#
#                       $\overline{I}_{1612 \pm 25}$  \
# division_1_size_bulk                      0.936425
# division_1_size_5                         0.926718
# division_1_size_3                         0.951396
#
#                       $\overline{I}_{1725 \pm 25}$  $\log I_{872}$  \
# division_1_size_bulk                      0.417470       -3.040727
# division_1_size_5                         0.378463       -2.392093
# division_1_size_3                         0.369746       -2.224448
#
#                       $(I_{872})^{-1}$  $\log I_{1085}$  $(I_{1085})^{-1}$  \
# division_1_size_bulk         20.920439        -0.383761           1.467794
# division_1_size_5            10.936364        -0.500648           1.649790
# division_1_size_3             9.248376        -0.178917           1.195921
#
#                       $\log I_{1182}$  $(I_{1182})^{-1}$  $\log I_{1241}$  \
# division_1_size_bulk        -0.944375           2.571206        -0.787312
# division_1_size_5           -0.875645           2.400424        -0.848660
# division_1_size_3           -0.664819           1.944138        -0.913918
#
#                       $(I_{1241})^{-1}$  $\log I_{1394}$  $(I_{1394})^{-1}$  \
# division_1_size_bulk           2.197482        -0.273672           1.314783
# division_1_size_5              2.336514        -0.374754           1.454634
# division_1_size_3              2.494076        -0.361611           1.435640
#
#                       $\log I_{1612}$  $(I_{1612})^{-1}$  $\log I_{1725}$  \
# division_1_size_bulk              0.0                1.0        -0.859739
# division_1_size_5                 0.0                1.0        -0.955877
# division_1_size_3                 0.0                1.0        -0.997629
#
#                       $(I_{1725})^{-1}$  \
# division_1_size_bulk           2.362543
# division_1_size_5              2.600952
# division_1_size_3              2.711845
#
#                       $\log \overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                              -0.857641
# division_1_size_5                                 -0.970931
# division_1_size_3                                 -0.829504
#
#                       $(\overline{I}_{1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.357591
# division_1_size_5                                    2.640400
# division_1_size_3                                    2.292181
#
#                       $\log \Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                               1.323604
# division_1_size_5                                  1.284840
# division_1_size_3                                  1.367347
#
#                       $(\Sigma I_{p,\ 1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.266174
# division_1_size_5                                    0.276695
# division_1_size_3                                    0.254782
#
#                       $\log \overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                               -0.851863
# division_1_size_5                                  -0.972851
# division_1_size_3                                  -0.845455
#
#                       $(\overline{I}_{1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  2.344010
# division_1_size_5                                     2.645477
# division_1_size_3                                     2.329038
#
#                       $\log \Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                                0.352959
# division_1_size_5                                   0.325321
# division_1_size_3                                   0.313900
#
#                       $(\Sigma I_{p,\ 1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  0.702606
# division_1_size_5                                     0.722296
# division_1_size_3                                     0.730592
#
#                       $\log \overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                               -0.559080
# division_1_size_5                                  -0.688422
# division_1_size_3                                  -0.647194
#
#                       $(\overline{I}_{1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.749062
# division_1_size_5                                     1.990572
# division_1_size_3                                     1.910173
#
#                       $\log \Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                               -0.273672
# division_1_size_5                                  -0.374754
# division_1_size_3                                  -0.361611
#
#                       $(\Sigma I_{p,\ 1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.314783
# division_1_size_5                                     1.454634
# division_1_size_3                                     1.435640
#
#                       $\log \overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                              -1.012422
# division_1_size_5                                 -1.108665
# division_1_size_3                                 -0.898970
#
#                       $(\overline{I}_{1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.752259
# division_1_size_5                                    3.030309
# division_1_size_3                                    2.457072
#
#                       $\log \Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                               0.453038
# division_1_size_5                                  0.433182
# division_1_size_3                                  0.620372
#
#                       $(\Sigma I_{p,\ 1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.635694
# division_1_size_5                                    0.648442
# division_1_size_3                                    0.537744
#
#                       $\log \overline{I}_{872 \pm 25}$  \
# division_1_size_bulk                         -3.052551
# division_1_size_5                            -2.375877
# division_1_size_3                            -2.191715
#
#                       $(\overline{I}_{872 \pm 25})^{-1}$  \
# division_1_size_bulk                           21.169287
# division_1_size_5                              10.760443
# division_1_size_3                               8.950554
#
#                       $\log \overline{I}_{1085 \pm 25}$  \
# division_1_size_bulk                          -0.418161
# division_1_size_5                             -0.559437
# division_1_size_3                             -0.253412
#
#                       $(\overline{I}_{1085 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.519165
# division_1_size_5                                1.749686
# division_1_size_3                                1.288414
#
#                       $\log \overline{I}_{1182 \pm 25}$  \
# division_1_size_bulk                          -0.917549
# division_1_size_5                             -0.853069
# division_1_size_3                             -0.641046
#
#                       $(\overline{I}_{1182 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.503146
# division_1_size_5                                2.346839
# division_1_size_3                                1.898465
#
#                       $\log \overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                          -0.803558
# division_1_size_5                             -0.855859
# division_1_size_3                             -0.912710
#
#                       $(\overline{I}_{1241 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.233473
# division_1_size_5                                2.353396
# division_1_size_3                                2.491063
#
#                       $\log \overline{I}_{1394 \pm 25}$  \
# division_1_size_bulk                          -0.302647
# division_1_size_5                             -0.403547
# division_1_size_3                             -0.387466
#
#                       $(\overline{I}_{1394 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.353436
# division_1_size_5                                1.497126
# division_1_size_3                                1.473243
#
#                       $\log \overline{I}_{1612 \pm 25}$  \
# division_1_size_bulk                          -0.065686
# division_1_size_5                             -0.076106
# division_1_size_3                             -0.049825
#
#                       $(\overline{I}_{1612 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.067891
# division_1_size_5                                1.079077
# division_1_size_3                                1.051087
#
#                       $\log \overline{I}_{1725 \pm 25}$  \
# division_1_size_bulk                          -0.873542
# division_1_size_5                             -0.971638
# division_1_size_3                             -0.994938
#
#                       $(\overline{I}_{1725 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.395381
# division_1_size_5                                2.642268
# division_1_size_3                                2.704557
#
#                       $\frac{I_{872}}{I_{1085}}$  $\frac{I_{872}}{I_{1182}}$  \
# division_1_size_bulk                    0.070161                    0.122904
# division_1_size_5                       0.150854                    0.219490
# division_1_size_3                       0.129311                    0.210214
#
#                       $\frac{I_{872}}{I_{1241}}$  $\frac{I_{872}}{I_{1394}}$  \
# division_1_size_bulk                    0.105040                    0.062847
# division_1_size_5                       0.213646                    0.133009
# division_1_size_3                       0.269677                    0.155232
#
#                       $\frac{I_{872}}{I_{1612}}$  $\frac{I_{872}}{I_{1725}}$  \
# division_1_size_bulk                    0.047800                    0.112930
# division_1_size_5                       0.091438                    0.237826
# division_1_size_3                       0.108127                    0.293224
#
#                       $\frac{I_{872}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                          0.112693
# division_1_size_5                                             0.241433
# division_1_size_3                                             0.247847
#
#                       $\frac{I_{872}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                          0.012723
# division_1_size_5                                             0.025300
# division_1_size_3                                             0.027549
#
#                       $\frac{I_{872}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.112044
# division_1_size_5                                              0.241897
# division_1_size_3                                              0.251832
#
#                       $\frac{I_{872}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.033585
# division_1_size_5                                              0.066045
# division_1_size_3                                              0.078997
#
#                       $\frac{I_{872}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.083605
# division_1_size_5                                              0.182014
# division_1_size_3                                              0.206541
#
#                       $\frac{I_{872}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.062847
# division_1_size_5                                              0.133009
# division_1_size_3                                              0.155232
#
#                       $\frac{I_{872}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                          0.131558
# division_1_size_5                                             0.277086
# division_1_size_3                                             0.265676
#
#                       $\frac{I_{872}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                          0.030386
# division_1_size_5                                             0.059292
# division_1_size_3                                             0.058145
#
#                       $\frac{I_{872}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                      0.072616
# division_1_size_5                                         0.159988
# division_1_size_3                                         0.139312
#
#                       $\frac{I_{872}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                      0.119651
# division_1_size_5                                         0.214590
# division_1_size_3                                         0.205276
#
#                       $\frac{I_{872}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                      0.106760
# division_1_size_5                                         0.215190
# division_1_size_3                                         0.269351
#
#                       $\frac{I_{872}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                      0.064694
# division_1_size_5                                         0.136894
# division_1_size_3                                         0.159298
#
#                       $\frac{I_{872}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                      0.051045
# division_1_size_5                                         0.098669
# division_1_size_3                                         0.113651
#
#                       $\frac{I_{872}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                      0.114500
# division_1_size_5                                         0.241604
# division_1_size_3                                         0.292436
#
#                       $\frac{I_{1085}}{I_{1182}}$  \
# division_1_size_bulk                     1.751748
# division_1_size_5                        1.454988
# division_1_size_3                        1.625641
#
#                       $\frac{I_{1085}}{I_{1241}}$  \
# division_1_size_bulk                     1.497132
# division_1_size_5                        1.416250
# division_1_size_3                        2.085485
#
#                       $\frac{I_{1085}}{I_{1394}}$  \
# division_1_size_bulk                     0.895754
# division_1_size_5                        0.881708
# division_1_size_3                        1.200447
#
#                       $\frac{I_{1085}}{I_{1612}}$  \
# division_1_size_bulk                     0.681294
# division_1_size_5                        0.606138
# division_1_size_3                        0.836176
#
#                       $\frac{I_{1085}}{I_{1725}}$  \
# division_1_size_bulk                     1.609587
# division_1_size_5                        1.576535
# division_1_size_3                        2.267579
#
#                       $\frac{I_{1085}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.606214
# division_1_size_5                                              1.600446
# division_1_size_3                                              1.916666
#
#                       $\frac{I_{1085}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.181343
# division_1_size_5                                              0.167715
# division_1_size_3                                              0.213042
#
#                       $\frac{I_{1085}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.596961
# division_1_size_5                                               1.603523
# division_1_size_3                                               1.947485
#
#                       $\frac{I_{1085}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.478681
# division_1_size_5                                               0.437811
# division_1_size_3                                               0.610903
#
#                       $\frac{I_{1085}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.191626
# division_1_size_5                                               1.206561
# division_1_size_3                                               1.597240
#
#                       $\frac{I_{1085}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.895754
# division_1_size_5                                               0.881708
# division_1_size_3                                               1.200447
#
#                       $\frac{I_{1085}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.875098
# division_1_size_5                                              1.836785
# division_1_size_3                                              2.054544
#
#                       $\frac{I_{1085}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.433095
# division_1_size_5                                              0.393045
# division_1_size_3                                              0.449649
#
#                       $\frac{I_{1085}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                     14.422514
# division_1_size_5                                         6.522311
# division_1_size_3                                         7.484235
#
#                       $\frac{I_{1085}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                       1.705379
# division_1_size_5                                          1.422508
# division_1_size_3                                          1.587450
#
#                       $\frac{I_{1085}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.521652
# division_1_size_5                                          1.426482
# division_1_size_3                                          2.082966
#
#                       $\frac{I_{1085}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.922089
# division_1_size_5                                          0.907465
# division_1_size_3                                          1.231890
#
#                       $\frac{I_{1085}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                       0.727548
# division_1_size_5                                          0.654069
# division_1_size_3                                          0.878893
#
#                       $\frac{I_{1085}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.631959
# division_1_size_5                                          1.601578
# division_1_size_3                                          2.261485
#
#                       $\frac{I_{1182}}{I_{1241}}$  \
# division_1_size_bulk                     0.854650
# division_1_size_5                        0.973376
# division_1_size_3                        1.282869
#
#                       $\frac{I_{1182}}{I_{1394}}$  \
# division_1_size_bulk                     0.511349
# division_1_size_5                        0.605990
# division_1_size_3                        0.738445
#
#                       $\frac{I_{1182}}{I_{1612}}$  \
# division_1_size_bulk                     0.388923
# division_1_size_5                        0.416593
# division_1_size_3                        0.514367
#
#                       $\frac{I_{1182}}{I_{1725}}$  \
# division_1_size_bulk                     0.918847
# division_1_size_5                        1.083538
# division_1_size_3                        1.394883
#
#                       $\frac{I_{1182}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           0.916921
# division_1_size_5                                              1.099973
# division_1_size_3                                              1.179021
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.103521
# division_1_size_5                                              0.115269
# division_1_size_3                                              0.131051
#
#                       $\frac{I_{1182}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.911639
# division_1_size_5                                               1.102087
# division_1_size_3                                               1.197980
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.273259
# division_1_size_5                                               0.300903
# division_1_size_3                                               0.375792
#
#                       $\frac{I_{1182}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.680250
# division_1_size_5                                               0.829258
# division_1_size_3                                               0.982530
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.511349
# division_1_size_5                                               0.605990
# division_1_size_3                                               0.738445
#
#                       $\frac{I_{1182}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.070416
# division_1_size_5                                              1.262406
# division_1_size_3                                              1.263836
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.247236
# division_1_size_5                                              0.270137
# division_1_size_3                                              0.276598
#
#                       $\frac{I_{1182}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                      8.233214
# division_1_size_5                                         4.482726
# division_1_size_3                                         4.603867
#
#                       $\frac{I_{1182}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                       0.590838
# division_1_size_5                                          0.728907
# division_1_size_3                                          0.662717
#
#                       $\frac{I_{1182}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       0.868648
# division_1_size_5                                          0.980408
# division_1_size_3                                          1.281320
#
#                       $\frac{I_{1182}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.526382
# division_1_size_5                                          0.623692
# division_1_size_3                                          0.757787
#
#                       $\frac{I_{1182}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                       0.415327
# division_1_size_5                                          0.449536
# division_1_size_3                                          0.540644
#
#                       $\frac{I_{1182}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       0.931618
# division_1_size_5                                          1.100751
# division_1_size_3                                          1.391134
#
#                       $\frac{I_{1241}}{I_{1394}}$  \
# division_1_size_bulk                     0.598314
# division_1_size_5                        0.622566
# division_1_size_3                        0.575620
#
#                       $\frac{I_{1241}}{I_{1612}}$  \
# division_1_size_bulk                     0.455066
# division_1_size_5                        0.427988
# division_1_size_3                        0.400950
#
#                       $\frac{I_{1241}}{I_{1725}}$  \
# division_1_size_bulk                     1.075114
# division_1_size_5                        1.113176
# division_1_size_3                        1.087315
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.072861
# division_1_size_5                                              1.130060
# division_1_size_3                                              0.919050
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.121127
# division_1_size_5                                              0.118422
# division_1_size_3                                              0.102155
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.066680
# division_1_size_5                                               1.132232
# division_1_size_3                                               0.933828
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.319732
# division_1_size_5                                               0.309134
# division_1_size_3                                               0.292931
#
#                       $\frac{I_{1241}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.795939
# division_1_size_5                                               0.851941
# division_1_size_3                                               0.765884
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.598314
# division_1_size_5                                               0.622566
# division_1_size_3                                               0.575620
#
#                       $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.252460
# division_1_size_5                                              1.296936
# division_1_size_3                                              0.985163
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.289283
# division_1_size_5                                              0.277526
# division_1_size_3                                              0.215609
#
#                       $\frac{I_{1241}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                      9.633431
# division_1_size_5                                         4.605340
# division_1_size_3                                         3.588726
#
#                       $\frac{I_{1241}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                       0.691321
# division_1_size_5                                          0.748845
# division_1_size_3                                          0.516590
#
#                       $\frac{I_{1241}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                       1.139098
# division_1_size_5                                          1.004419
# division_1_size_3                                          0.761190
#
#                       $\frac{I_{1241}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.615903
# division_1_size_5                                          0.640752
# division_1_size_3                                          0.590697
#
#                       $\frac{I_{1241}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                       0.485961
# division_1_size_5                                          0.461832
# division_1_size_3                                          0.421433
#
#                       $\frac{I_{1241}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.090057
# division_1_size_5                                          1.130859
# division_1_size_3                                          1.084393
#
#                       $\frac{I_{1394}}{I_{1612}}$  \
# division_1_size_bulk                     0.760582
# division_1_size_5                        0.687458
# division_1_size_3                        0.696553
#
#                       $\frac{I_{1394}}{I_{1725}}$  \
# division_1_size_bulk                     1.796907
# division_1_size_5                        1.788046
# division_1_size_3                        1.888945
#
#                       $\frac{I_{1394}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.793141
# division_1_size_5                                              1.815165
# division_1_size_3                                              1.596626
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.202447
# division_1_size_5                                              0.190216
# division_1_size_3                                              0.177469
#
#                       $\frac{I_{1394}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.782811
# division_1_size_5                                               1.818655
# division_1_size_3                                               1.622300
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.534389
# division_1_size_5                                               0.496548
# division_1_size_3                                               0.508897
#
#                       $\frac{I_{1394}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.330305
# division_1_size_5                                               1.368435
# division_1_size_3                                               1.330538
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                 1.0
# division_1_size_5                                                    1.0
# division_1_size_3                                                    1.0
#
#                       $\frac{I_{1394}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.093317
# division_1_size_5                                              2.083211
# division_1_size_3                                              1.711482
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.483497
# division_1_size_5                                              0.445777
# division_1_size_3                                              0.374568
#
#                       $\frac{I_{1394}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                     16.100969
# division_1_size_5                                         7.397356
# division_1_size_3                                         6.234539
#
#                       $\frac{I_{1394}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                       1.155449
# division_1_size_5                                          1.202836
# division_1_size_3                                          0.897449
#
#                       $\frac{I_{1394}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                       1.903847
# division_1_size_5                                          1.613354
# division_1_size_3                                          1.322383
#
#                       $\frac{I_{1394}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.698738
# division_1_size_5                                          1.617862
# division_1_size_3                                          1.735159
#
#                       $\frac{I_{1394}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                       0.812218
# division_1_size_5                                          0.741820
# division_1_size_3                                          0.732138
#
#                       $\frac{I_{1394}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.821882
# division_1_size_5                                          1.816449
# division_1_size_3                                          1.883869
#
#                       $\frac{I_{1612}}{I_{1725}}$  \
# division_1_size_bulk                     2.362543
# division_1_size_5                        2.600952
# division_1_size_3                        2.711845
#
#                       $\frac{I_{1612}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           2.357591
# division_1_size_5                                              2.640400
# division_1_size_3                                              2.292181
#
#                       $\frac{I_{1612}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.266174
# division_1_size_5                                              0.276695
# division_1_size_3                                              0.254782
#
#                       $\frac{I_{1612}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            2.344010
# division_1_size_5                                               2.645477
# division_1_size_3                                               2.329038
#
#                       $\frac{I_{1612}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.702606
# division_1_size_5                                               0.722296
# division_1_size_3                                               0.730592
#
#                       $\frac{I_{1612}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.749062
# division_1_size_5                                               1.990572
# division_1_size_3                                               1.910173
#
#                       $\frac{I_{1612}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.314783
# division_1_size_5                                               1.454634
# division_1_size_3                                               1.435640
#
#                       $\frac{I_{1612}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.752259
# division_1_size_5                                              3.030309
# division_1_size_3                                              2.457072
#
#                       $\frac{I_{1612}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.635694
# division_1_size_5                                              0.648442
# division_1_size_3                                              0.537744
#
#                       $\frac{I_{1612}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                     21.169287
# division_1_size_5                                        10.760443
# division_1_size_3                                         8.950554
#
#                       $\frac{I_{1612}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                       1.519165
# division_1_size_5                                          1.749686
# division_1_size_3                                          1.288414
#
#                       $\frac{I_{1612}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                       2.503146
# division_1_size_5                                          2.346839
# division_1_size_3                                          1.898465
#
#                       $\frac{I_{1612}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       2.233473
# division_1_size_5                                          2.353396
# division_1_size_3                                          2.491063
#
#                       $\frac{I_{1612}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       1.353436
# division_1_size_5                                          1.497126
# division_1_size_3                                          1.473243
#
#                       $\frac{I_{1612}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       2.395381
# division_1_size_5                                          2.642268
# division_1_size_3                                          2.704557
#
#                       $\frac{I_{1725}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           0.997904
# division_1_size_5                                              1.015167
# division_1_size_3                                              0.845248
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.112664
# division_1_size_5                                              0.106382
# division_1_size_3                                              0.093951
#
#                       $\frac{I_{1725}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.992156
# division_1_size_5                                               1.017119
# division_1_size_3                                               0.858839
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.297394
# division_1_size_5                                               0.277704
# division_1_size_3                                               0.269408
#
#                       $\frac{I_{1725}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.740330
# division_1_size_5                                               0.765324
# division_1_size_3                                               0.704381
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.556512
# division_1_size_5                                               0.559270
# division_1_size_3                                               0.529396
#
#                       $\frac{I_{1725}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.164956
# division_1_size_5                                              1.165077
# division_1_size_3                                              0.906052
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.269072
# division_1_size_5                                              0.249310
# division_1_size_3                                              0.198295
#
#                       $\frac{I_{1725}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                      8.960381
# division_1_size_5                                         4.137118
# division_1_size_3                                         3.300540
#
#                       $\frac{I_{1725}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                       0.643021
# division_1_size_5                                          0.672710
# division_1_size_3                                          0.475106
#
#                       $\frac{I_{1725}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                       1.059513
# division_1_size_5                                          0.902300
# division_1_size_3                                          0.700064
#
#                       $\frac{I_{1725}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       0.945368
# division_1_size_5                                          0.904821
# division_1_size_3                                          0.918586
#
#                       $\frac{I_{1725}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.572873
# division_1_size_5                                          0.575607
# division_1_size_3                                          0.543262
#
#                       $\frac{I_{1725}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                       0.452009
# division_1_size_5                                          0.414878
# division_1_size_3                                          0.387591
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                                                  0.741885
# division_1_size_5                                                                     0.753890
# division_1_size_3                                                                     0.833343
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                                                 1.167403
# division_1_size_5                                                                    1.147670
# division_1_size_3                                                                    1.071937
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                                            8.979201
# division_1_size_5                                                               4.075307
# division_1_size_3                                                               3.904821
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                                             0.644372
# division_1_size_5                                                                0.662659
# division_1_size_3                                                                0.562091
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                                             1.061739
# division_1_size_5                                                                0.888819
# division_1_size_3                                                                0.828236
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# ...
# division_1_size_5                                                                 0.887114
# division_1_size_3                                                                 0.815128
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                              0.952843
# division_1_size_5                                                                 0.889592
# division_1_size_3                                                                 1.069567
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                              0.577402
# division_1_size_5                                                                 0.565919
# division_1_size_3                                                                 0.632554
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                              0.455583
# division_1_size_5                                                                 0.407895
# division_1_size_3                                                                 0.451297
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                              1.021916
# division_1_size_5                                                                 0.998787
# division_1_size_3                                                                 1.161234
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}1500}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                                   1.871295
# division_1_size_5                                                                      2.013903
# division_1_size_3                                                                      1.965036
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}1500}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                                                  0.904766
# division_1_size_5                                                                     0.897752
# division_1_size_3                                                                     0.736039
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                                                  1.573562
# division_1_size_5                                                                     1.522331
# division_1_size_3                                                                     1.286309
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                                            12.103221
# division_1_size_5                                                                5.405705
# division_1_size_3                                                                4.685729
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                                              0.868560
# division_1_size_5                                                                 0.878987
# division_1_size_3                                                                 0.674501
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                                              1.431136
# division_1_size_5                                                                 1.178978
# division_1_size_3                                                                 0.993871
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                              1.276955
# division_1_size_5                                                                 1.182272
# division_1_size_3                                                                 1.304103
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                              0.773807
# division_1_size_5                                                                 0.752109
# division_1_size_3                                                                 0.771262
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                              0.610551
# division_1_size_5                                                                 0.542094
# division_1_size_3                                                                 0.550257
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                              1.369523
# division_1_size_5                                                                 1.327392
# division_1_size_3                                                                 1.415870
#
#                       $\frac{\Sigma I_{p,\ 1500\text{–}1300}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                                                  0.483497
# division_1_size_5                                                                     0.445777
# division_1_size_3                                                                     0.374568
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                                            7.691605
# division_1_size_5                                                               3.550939
# division_1_size_3                                                               3.642772
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                                             0.551970
# division_1_size_5                                                                0.577395
# division_1_size_3                                                                0.524370
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                                             0.909488
# division_1_size_5                                                                0.774455
# division_1_size_3                                                                0.772653
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                             0.811505
# division_1_size_5                                                                0.776619
# division_1_size_3                                                                1.013834
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                             0.491755
# division_1_size_5                                                                0.494051
# division_1_size_3                                                                0.599593
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                             0.388005
# division_1_size_5                                                                0.356095
# division_1_size_3                                                                0.427780
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                             0.870333
# division_1_size_5                                                                0.871947
# division_1_size_3                                                                1.100724
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                                        0.071763
# division_1_size_5                                                           0.162604
# division_1_size_3                                                           0.143948
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                                        0.118244
# division_1_size_5                                                           0.218099
# division_1_size_3                                                           0.212106
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                        0.105505
# division_1_size_5                                                           0.218708
# division_1_size_3                                                           0.278314
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                        0.063934
# division_1_size_5                                                           0.139132
# division_1_size_3                                                           0.164598
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                        0.050445
# division_1_size_5                                                           0.100282
# division_1_size_3                                                           0.117433
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                        0.113154
# division_1_size_5                                                           0.245554
# division_1_size_3                                                           0.302166
#
#                       $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                                         1.647712
# division_1_size_5                                                            1.341291
# division_1_size_3                                                            1.473490
#
#                       $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                         1.470198
# division_1_size_5                                                            1.345039
# division_1_size_3                                                            1.933434
#
#                       $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.890908
# division_1_size_5                                                            0.855654
# division_1_size_3                                                            1.143455
#
#                       $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                         0.702946
# division_1_size_5                                                            0.616726
# division_1_size_3                                                            0.815799
#
#                       $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.576774
# division_1_size_5                                                            1.510138
# division_1_size_3                                                            2.099137
#
#                       $\frac{\overline{I}_{1182 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                         0.892266
# division_1_size_5                                                            1.002794
# division_1_size_3                                                            1.312146
#
#                       $\frac{\overline{I}_{1182 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.540694
# division_1_size_5                                                            0.637933
# division_1_size_3                                                            0.776018
#
#                       $\frac{\overline{I}_{1182 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                         0.426620
# division_1_size_5                                                            0.459800
# division_1_size_3                                                            0.553651
#
#                       $\frac{\overline{I}_{1182 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         0.956948
# division_1_size_5                                                            1.125884
# division_1_size_3                                                            1.424602
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.605978
# division_1_size_5                                                            0.636156
# division_1_size_3                                                            0.591411
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                         0.478130
# division_1_size_5                                                            0.458519
# division_1_size_3                                                            0.421943
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.072491
# division_1_size_5                                                            1.122747
# division_1_size_3                                                            1.085704
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                         0.789022
# division_1_size_5                                                            0.720766
# division_1_size_3                                                            0.713451
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.769851
# division_1_size_5                                                            1.764894
# division_1_size_3                                                            1.835784
#
#                       $\frac{\overline{I}_{1612 \pm 25}}{\overline{I}_{1725 \pm 25}}$
# division_1_size_bulk                                                         2.243094
# division_1_size_5                                                            2.448637
# division_1_size_3                                                            2.573105

# %%
dataset_test = dataset.loc[dataset['Split'] == 'Test']

X_test = dataset_test.loc[:, ~dataset_test.columns.isin(['Split', 'Fraction_hue', 'Fraction_grouped_hue', 'Class'])]
y_test = dataset_test['Class']

hue_train = dataset_test['Fraction_grouped_hue'].tolist()

print(
    f'(*) X_train: {X_test.shape}',
    f'(*) y_train: {y_test.shape}',
    sep='\n'
)
X_test.head(3)
# Out:
# (*) X_train: (15, 245)
# (*) y_train: (15,)
#                      $I_{872}$  $I_{1085}$  $I_{1182}$  $I_{1241}$  \
# division_1_size_0.2   0.032618    0.612132    0.402979    0.361602
# division_2_size_3     0.490661    1.000000    0.714745    0.552366
# division_2_size_2.5   0.624211    1.000000    0.762920    0.564824
#
#                      $I_{1394}$  $I_{1612}$  $I_{1725}$  \
# division_1_size_0.2    1.000000    0.971316    0.398831
# division_2_size_3      0.632884    0.653723    0.348920
# division_2_size_2.5    0.656644    0.708563    0.323891
#
#                      $\overline{I}_{1900\text{–}800}$  \
# division_1_size_0.2                          0.461139
# division_2_size_3                            0.512811
# division_2_size_2.5                          0.560094
#
#                      $\Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_0.2                          3.779479
# division_2_size_3                            4.393298
# division_2_size_2.5                          4.641051
#
#                      $\overline{I}_{1900\text{–}1500}$  \
# division_1_size_0.2                           0.478522
# division_2_size_3                             0.325820
# division_2_size_2.5                           0.350883
#
#                      $\Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_0.2                           1.370147
# division_2_size_3                             1.002642
# division_2_size_2.5                           1.032453
#
#                      $\overline{I}_{1500\text{–}1300}$  \
# division_1_size_0.2                           0.743613
# division_2_size_3                             0.530136
# division_2_size_2.5                           0.547801
#
#                      $\Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_0.2                           1.000000
# division_2_size_3                             0.632884
# division_2_size_2.5                           0.656644
#
#                      $\overline{I}_{1300\text{–}800}$  \
# division_1_size_0.2                          0.334577
# division_2_size_3                            0.655421
# division_2_size_2.5                          0.732284
#
#                      $\Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_0.2                          1.409332
# division_2_size_3                            2.757772
# division_2_size_2.5                          2.951954
#
#                      $\overline{I}_{872 \pm 25}$  \
# division_1_size_0.2                     0.038623
# division_2_size_3                       0.496831
# division_2_size_2.5                     0.629900
#
#                      $\overline{I}_{1085 \pm 25}$  \
# division_1_size_0.2                      0.611228
# division_2_size_3                        0.976368
# division_2_size_2.5                      0.990777
#
#                      $\overline{I}_{1182 \pm 25}$  \
# division_1_size_0.2                      0.414732
# division_2_size_3                        0.714591
# division_2_size_2.5                      0.764326
#
#                      $\overline{I}_{1241 \pm 25}$  \
# division_1_size_0.2                      0.358081
# division_2_size_3                        0.556256
# division_2_size_2.5                      0.570112
#
#                      $\overline{I}_{1394 \pm 25}$  \
# division_1_size_0.2                      0.973721
# division_2_size_3                        0.620091
# division_2_size_2.5                      0.642213
#
#                      $\overline{I}_{1612 \pm 25}$  \
# division_1_size_0.2                      0.954251
# division_2_size_3                        0.629724
# division_2_size_2.5                      0.681320
#
#                      $\overline{I}_{1725 \pm 25}$  $\log I_{872}$  \
# division_1_size_0.2                      0.409373       -3.422887
# division_2_size_3                        0.343312       -0.712002
# division_2_size_2.5                      0.326359       -0.471267
#
#                      $(I_{872})^{-1}$  $\log I_{1085}$  $(I_{1085})^{-1}$  \
# division_1_size_0.2         30.657797        -0.490807           1.633634
# division_2_size_3            2.038068         0.000000           1.000000
# division_2_size_2.5          1.602023         0.000000           1.000000
#
#                      $\log I_{1182}$  $(I_{1182})^{-1}$  $\log I_{1241}$  \
# division_1_size_0.2        -0.908871           2.481519        -1.017211
# division_2_size_3          -0.335829           1.399100        -0.593544
# division_2_size_2.5        -0.270603           1.310754        -0.571241
#
#                      $(I_{1241})^{-1}$  $\log I_{1394}$  $(I_{1394})^{-1}$  \
# division_1_size_0.2           2.765471         0.000000           1.000000
# division_2_size_3             1.810394        -0.457469           1.580070
# division_2_size_2.5           1.770464        -0.420613           1.522895
#
#                      $\log I_{1612}$  $(I_{1612})^{-1}$  $\log I_{1725}$  \
# division_1_size_0.2        -0.029103           1.029531        -0.919217
# division_2_size_3          -0.425072           1.529701        -1.052914
# division_2_size_2.5        -0.344517           1.411308        -1.127349
#
#                      $(I_{1725})^{-1}$  $\log \overline{I}_{1900\text{–}800}$  \
# division_1_size_0.2           2.507326                              -0.774056
# division_2_size_3             2.865991                              -0.667849
# division_2_size_2.5           3.087461                              -0.579651
#
#                      $(\overline{I}_{1900\text{–}800})^{-1}$  \
# division_1_size_0.2                                 2.168543
# division_2_size_3                                   1.950038
# division_2_size_2.5                                 1.785416
#
#                      $\log \Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_0.2                               1.329586
# division_2_size_3                                 1.480080
# division_2_size_2.5                               1.534941
#
#                      $(\Sigma I_{p,\ 1900\text{–}800})^{-1}$  \
# division_1_size_0.2                                 0.264587
# division_2_size_3                                   0.227619
# division_2_size_2.5                                 0.215468
#
#                      $\log \overline{I}_{1900\text{–}1500}$  \
# division_1_size_0.2                               -0.737054
# division_2_size_3                                 -1.121410
# division_2_size_2.5                               -1.047302
#
#                      $(\overline{I}_{1900\text{–}1500})^{-1}$  \
# division_1_size_0.2                                  2.089770
# division_2_size_3                                    3.069178
# division_2_size_2.5                                  2.849953
#
#                      $\log \Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_0.2                                0.314918
# division_2_size_3                                  0.002639
# division_2_size_2.5                                0.031938
#
#                      $(\Sigma I_{p,\ 1900\text{–}1500})^{-1}$  \
# division_1_size_0.2                                  0.729849
# division_2_size_3                                    0.997365
# division_2_size_2.5                                  0.968567
#
#                      $\log \overline{I}_{1500\text{–}1300}$  \
# division_1_size_0.2                               -0.296234
# division_2_size_3                                 -0.634621
# division_2_size_2.5                               -0.601843
#
#                      $(\overline{I}_{1500\text{–}1300})^{-1}$  \
# division_1_size_0.2                                  1.344785
# division_2_size_3                                    1.886308
# division_2_size_2.5                                  1.825480
#
#                      $\log \Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_0.2                                0.000000
# division_2_size_3                                 -0.457469
# division_2_size_2.5                               -0.420613
#
#                      $(\Sigma I_{p,\ 1500\text{–}1300})^{-1}$  \
# division_1_size_0.2                                  1.000000
# division_2_size_3                                    1.580070
# division_2_size_2.5                                  1.522895
#
#                      $\log \overline{I}_{1300\text{–}800}$  \
# division_1_size_0.2                              -1.094889
# division_2_size_3                                -0.422478
# division_2_size_2.5                              -0.311587
#
#                      $(\overline{I}_{1300\text{–}800})^{-1}$  \
# division_1_size_0.2                                 2.988851
# division_2_size_3                                   1.525737
# division_2_size_2.5                                 1.365590
#
#                      $\log \Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_0.2                               0.343116
# division_2_size_3                                 1.014423
# division_2_size_2.5                               1.082467
#
#                      $(\Sigma I_{p,\ 1300\text{–}800})^{-1}$  \
# division_1_size_0.2                                 0.709556
# division_2_size_3                                   0.362612
# division_2_size_2.5                                 0.338759
#
#                      $\log \overline{I}_{872 \pm 25}$  \
# division_1_size_0.2                         -3.253918
# division_2_size_3                           -0.699506
# division_2_size_2.5                         -0.462193
#
#                      $(\overline{I}_{872 \pm 25})^{-1}$  \
# division_1_size_0.2                           25.891588
# division_2_size_3                              2.012758
# division_2_size_2.5                            1.587552
#
#                      $\log \overline{I}_{1085 \pm 25}$  \
# division_1_size_0.2                          -0.492286
# division_2_size_3                            -0.023915
# division_2_size_2.5                          -0.009266
#
#                      $(\overline{I}_{1085 \pm 25})^{-1}$  \
# division_1_size_0.2                             1.636051
# division_2_size_3                               1.024204
# division_2_size_2.5                             1.009309
#
#                      $\log \overline{I}_{1182 \pm 25}$  \
# division_1_size_0.2                          -0.880122
# division_2_size_3                            -0.336045
# division_2_size_2.5                          -0.268761
#
#                      $(\overline{I}_{1182 \pm 25})^{-1}$  \
# division_1_size_0.2                             2.411195
# division_2_size_3                               1.399401
# division_2_size_2.5                             1.308343
#
#                      $\log \overline{I}_{1241 \pm 25}$  \
# division_1_size_0.2                          -1.026996
# division_2_size_3                            -0.586526
# division_2_size_2.5                          -0.561923
#
#                      $(\overline{I}_{1241 \pm 25})^{-1}$  \
# division_1_size_0.2                             2.792665
# division_2_size_3                               1.797733
# division_2_size_2.5                             1.754042
#
#                      $\log \overline{I}_{1394 \pm 25}$  \
# division_1_size_0.2                          -0.026630
# division_2_size_3                            -0.477889
# division_2_size_2.5                          -0.442835
#
#                      $(\overline{I}_{1394 \pm 25})^{-1}$  \
# division_1_size_0.2                             1.026988
# division_2_size_3                               1.612666
# division_2_size_2.5                             1.557115
#
#                      $\log \overline{I}_{1612 \pm 25}$  \
# division_1_size_0.2                          -0.046828
# division_2_size_3                            -0.462474
# division_2_size_2.5                          -0.383723
#
#                      $(\overline{I}_{1612 \pm 25})^{-1}$  \
# division_1_size_0.2                             1.047942
# division_2_size_3                               1.587998
# division_2_size_2.5                             1.467739
#
#                      $\log \overline{I}_{1725 \pm 25}$  \
# division_1_size_0.2                          -0.893129
# division_2_size_3                            -1.069114
# division_2_size_2.5                          -1.119756
#
#                      $(\overline{I}_{1725 \pm 25})^{-1}$  \
# division_1_size_0.2                             2.442762
# division_2_size_3                               2.912798
# division_2_size_2.5                             3.064107
#
#                      $\frac{I_{872}}{I_{1085}}$  $\frac{I_{872}}{I_{1182}}$  \
# division_1_size_0.2                    0.053286                    0.080943
# division_2_size_3                      0.490661                    0.686483
# division_2_size_2.5                    0.624211                    0.818187
#
#                      $\frac{I_{872}}{I_{1241}}$  $\frac{I_{872}}{I_{1394}}$  \
# division_1_size_0.2                    0.090204                    0.032618
# division_2_size_3                      0.888289                    0.775278
# division_2_size_2.5                    1.105142                    0.950608
#
#                      $\frac{I_{872}}{I_{1612}}$  $\frac{I_{872}}{I_{1725}}$  \
# division_1_size_0.2                    0.033581                    0.081784
# division_2_size_3                      0.750564                    1.406229
# division_2_size_2.5                    0.880953                    1.927226
#
#                      $\frac{I_{872}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_0.2                                          0.070734
# division_2_size_3                                            0.956807
# division_2_size_2.5                                          1.114476
#
#                      $\frac{I_{872}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_0.2                                          0.008630
# division_2_size_3                                            0.111684
# division_2_size_2.5                                          0.134498
#
#                      $\frac{I_{872}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_0.2                                           0.068164
# division_2_size_3                                             1.505925
# division_2_size_2.5                                           1.778971
#
#                      $\frac{I_{872}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_0.2                                           0.023806
# division_2_size_3                                             0.489368
# division_2_size_2.5                                           0.604590
#
#                      $\frac{I_{872}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_0.2                                           0.043864
# division_2_size_3                                             0.925537
# division_2_size_2.5                                           1.139484
#
#                      $\frac{I_{872}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_0.2                                           0.032618
# division_2_size_3                                             0.775278
# division_2_size_2.5                                           0.950608
#
#                      $\frac{I_{872}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_0.2                                          0.097491
# division_2_size_3                                            0.748620
# division_2_size_2.5                                          0.852416
#
#                      $\frac{I_{872}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_0.2                                          0.023144
# division_2_size_3                                            0.177919
# division_2_size_2.5                                          0.211457
#
#                      $\frac{I_{872}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_0.2                                      0.053365
# division_2_size_3                                        0.502537
# division_2_size_2.5                                      0.630021
#
#                      $\frac{I_{872}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_0.2                                      0.078649
# division_2_size_3                                        0.686631
# division_2_size_2.5                                      0.816682
#
#                      $\frac{I_{872}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.2                                      0.091092
# division_2_size_3                                        0.882077
# division_2_size_2.5                                      1.094892
#
#                      $\frac{I_{872}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.2                                      0.033498
# division_2_size_3                                        0.791272
# division_2_size_2.5                                      0.971968
#
#                      $\frac{I_{872}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_0.2                                      0.034182
# division_2_size_3                                        0.779168
# division_2_size_2.5                                      0.916178
#
#                      $\frac{I_{872}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_0.2                                      0.079678
# division_2_size_3                                        1.429196
# division_2_size_2.5                                      1.912648
#
#                      $\frac{I_{1085}}{I_{1182}}$  $\frac{I_{1085}}{I_{1241}}$  \
# division_1_size_0.2                     1.519018                     1.692834
# division_2_size_3                       1.399100                     1.810394
# division_2_size_2.5                     1.310754                     1.770464
#
#                      $\frac{I_{1085}}{I_{1394}}$  $\frac{I_{1085}}{I_{1612}}$  \
# division_1_size_0.2                     0.612132                     0.630209
# division_2_size_3                       1.580070                     1.529701
# division_2_size_2.5                     1.522895                     1.411308
#
#                      $\frac{I_{1085}}{I_{1725}}$  \
# division_1_size_0.2                     1.534815
# division_2_size_3                       2.865991
# division_2_size_2.5                     3.087461
#
#                      $\frac{I_{1085}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_0.2                                           1.327436
# division_2_size_3                                             1.950038
# division_2_size_2.5                                           1.785416
#
#                      $\frac{I_{1085}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_0.2                                           0.161962
# division_2_size_3                                             0.227619
# division_2_size_2.5                                           0.215468
#
#                      $\frac{I_{1085}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_0.2                                            1.279216
# division_2_size_3                                              3.069178
# division_2_size_2.5                                            2.849953
#
#                      $\frac{I_{1085}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_0.2                                            0.446764
# division_2_size_3                                              0.997365
# division_2_size_2.5                                            0.968567
#
#                      $\frac{I_{1085}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_0.2                                            0.823187
# division_2_size_3                                              1.886308
# division_2_size_2.5                                            1.825480
#
#                      $\frac{I_{1085}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_0.2                                            0.612132
# division_2_size_3                                              1.580070
# division_2_size_2.5                                            1.522895
#
#                      $\frac{I_{1085}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_0.2                                           1.829572
# division_2_size_3                                             1.525737
# division_2_size_2.5                                           1.365590
#
#                      $\frac{I_{1085}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_0.2                                           0.434342
# division_2_size_3                                             0.362612
# division_2_size_2.5                                           0.338759
#
#                      $\frac{I_{1085}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_0.2                                     15.849079
# division_2_size_3                                        2.012758
# division_2_size_2.5                                      1.587552
#
#                      $\frac{I_{1085}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_0.2                                       1.475970
# division_2_size_3                                         1.399401
# division_2_size_2.5                                       1.308343
#
#                      $\frac{I_{1085}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.2                                       1.709481
# division_2_size_3                                         1.797733
# division_2_size_2.5                                       1.754042
#
#                      $\frac{I_{1085}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.2                                       0.628653
# division_2_size_3                                         1.612666
# division_2_size_2.5                                       1.557115
#
#                      $\frac{I_{1085}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_0.2                                       0.641479
# division_2_size_3                                         1.587998
# division_2_size_2.5                                       1.467739
#
#                      $\frac{I_{1085}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_0.2                                       1.495294
# division_2_size_3                                         2.912798
# division_2_size_2.5                                       3.064107
#
#                      $\frac{I_{1182}}{I_{1241}}$  $\frac{I_{1182}}{I_{1394}}$  \
# division_1_size_0.2                     1.114427                     0.402979
# division_2_size_3                       1.293970                     1.129347
# division_2_size_2.5                     1.350721                     1.161847
#
#                      $\frac{I_{1182}}{I_{1612}}$  $\frac{I_{1182}}{I_{1725}}$  \
# division_1_size_0.2                     0.414879                     1.010400
# division_2_size_3                       1.093346                     2.048454
# division_2_size_2.5                     1.076714                     2.355484
#
#                      $\frac{I_{1182}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_0.2                                           0.873877
# division_2_size_3                                             1.393780
# division_2_size_2.5                                           1.362129
#
#                      $\frac{I_{1182}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_0.2                                           0.106623
# division_2_size_3                                             0.162690
# division_2_size_2.5                                           0.164385
#
#                      $\frac{I_{1182}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_0.2                                            0.842134
# division_2_size_3                                              2.193681
# division_2_size_2.5                                            2.174285
#
#                      $\frac{I_{1182}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_0.2                                            0.294114
# division_2_size_3                                              0.712862
# division_2_size_2.5                                            0.738938
#
#                      $\frac{I_{1182}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_0.2                                            0.541920
# division_2_size_3                                              1.348230
# division_2_size_2.5                                            1.392694
#
#                      $\frac{I_{1182}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_0.2                                            0.402979
# division_2_size_3                                              1.129347
# division_2_size_2.5                                            1.161847
#
#                      $\frac{I_{1182}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_0.2                                           1.204444
# division_2_size_3                                             1.090514
# division_2_size_2.5                                           1.041835
#
#                      $\frac{I_{1182}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_0.2                                           0.285936
# division_2_size_3                                             0.259175
# division_2_size_2.5                                           0.258446
#
#                      $\frac{I_{1182}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_0.2                                     10.433766
# division_2_size_3                                        1.438610
# division_2_size_2.5                                      1.211175
#
#                      $\frac{I_{1182}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_0.2                                       0.659294
# division_2_size_3                                         0.732045
# division_2_size_2.5                                       0.770021
#
#                      $\frac{I_{1182}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.2                                       1.125385
# division_2_size_3                                         1.284921
# division_2_size_2.5                                       1.338193
#
#                      $\frac{I_{1182}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.2                                       0.413855
# division_2_size_3                                         1.152646
# division_2_size_2.5                                       1.187953
#
#                      $\frac{I_{1182}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_0.2                                       0.422299
# division_2_size_3                                         1.135014
# division_2_size_2.5                                       1.119767
#
#                      $\frac{I_{1182}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_0.2                                       0.984382
# division_2_size_3                                         2.081909
# division_2_size_2.5                                       2.337667
#
#                      $\frac{I_{1241}}{I_{1394}}$  $\frac{I_{1241}}{I_{1612}}$  \
# division_1_size_0.2                     0.361602                     0.372281
# division_2_size_3                       0.872777                     0.844955
# division_2_size_2.5                     0.860168                     0.797140
#
#                      $\frac{I_{1241}}{I_{1725}}$  \
# division_1_size_0.2                     0.906654
# division_2_size_3                       1.583076
# division_2_size_2.5                     1.743871
#
#                      $\frac{I_{1241}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_0.2                                           0.784150
# division_2_size_3                                             1.077135
# division_2_size_2.5                                           1.008446
#
#                      $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_0.2                                           0.095675
# division_2_size_3                                             0.125729
# division_2_size_2.5                                           0.121702
#
#                      $\frac{I_{1241}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_0.2                                            0.755665
# division_2_size_3                                              1.695310
# division_2_size_2.5                                            1.609721
#
#                      $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_0.2                                            0.263915
# division_2_size_3                                              0.550910
# division_2_size_2.5                                            0.547070
#
#                      $\frac{I_{1241}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_0.2                                            0.486277
# division_2_size_3                                              1.041932
# division_2_size_2.5                                            1.031074
#
#                      $\frac{I_{1241}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_0.2                                            0.361602
# division_2_size_3                                              0.872777
# division_2_size_2.5                                            0.860168
#
#                      $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_0.2                                           1.080775
# division_2_size_3                                             0.842766
# division_2_size_2.5                                           0.771318
#
#                      $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_0.2                                           0.256577
# division_2_size_3                                             0.200294
# division_2_size_2.5                                           0.191339
#
#                      $\frac{I_{1241}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_0.2                                      9.362451
# division_2_size_3                                        1.111779
# division_2_size_2.5                                      0.896687
#
#                      $\frac{I_{1241}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_0.2                                       0.591600
# division_2_size_3                                         0.565735
# division_2_size_2.5                                       0.570082
#
#                      $\frac{I_{1241}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_0.2                                       0.871893
# division_2_size_3                                         0.772982
# division_2_size_2.5                                       0.738983
#
#                      $\frac{I_{1241}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.2                                       0.371361
# division_2_size_3                                         0.890782
# division_2_size_2.5                                       0.879495
#
#                      $\frac{I_{1241}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_0.2                                       0.378938
# division_2_size_3                                         0.877156
# division_2_size_2.5                                       0.829014
#
#                      $\frac{I_{1241}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_0.2                                       0.883308
# division_2_size_3                                         1.608931
# division_2_size_2.5                                       1.730681
#
#                      $\frac{I_{1394}}{I_{1612}}$  $\frac{I_{1394}}{I_{1725}}$  \
# division_1_size_0.2                     1.029531                     2.507326
# division_2_size_3                       0.968122                     1.813838
# division_2_size_2.5                     0.926727                     2.027362
#
#                      $\frac{I_{1394}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_0.2                                           2.168543
# division_2_size_3                                             1.234147
# division_2_size_2.5                                           1.172383
#
#                      $\frac{I_{1394}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_0.2                                           0.264587
# division_2_size_3                                             0.144057
# division_2_size_2.5                                           0.141486
#
#                      $\frac{I_{1394}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_0.2                                            2.089770
# division_2_size_3                                              1.942432
# division_2_size_2.5                                            1.871404
#
#                      $\frac{I_{1394}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_0.2                                            0.729849
# division_2_size_3                                              0.631216
# division_2_size_2.5                                            0.636003
#
#                      $\frac{I_{1394}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_0.2                                            1.344785
# division_2_size_3                                              1.193813
# division_2_size_2.5                                            1.198690
#
#                      $\frac{I_{1394}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_0.2                                                 1.0
# division_2_size_3                                                   1.0
# division_2_size_2.5                                                 1.0
#
#                      $\frac{I_{1394}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_0.2                                           2.988851
# division_2_size_3                                             0.965614
# division_2_size_2.5                                           0.896707
#
#                      $\frac{I_{1394}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_0.2                                           0.709556
# division_2_size_3                                             0.229491
# division_2_size_2.5                                           0.222444
#
#                      $\frac{I_{1394}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_0.2                                     25.891588
# division_2_size_3                                        1.273842
# division_2_size_2.5                                      1.042457
#
#                      $\frac{I_{1394}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_0.2                                       1.636051
# division_2_size_3                                         0.648202
# division_2_size_2.5                                       0.662756
#
#                      $\frac{I_{1394}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_0.2                                       2.411195
# division_2_size_3                                         0.885658
# division_2_size_2.5                                       0.859115
#
#                      $\frac{I_{1394}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.2                                       2.792665
# division_2_size_3                                         1.137755
# division_2_size_2.5                                       1.151781
#
#                      $\frac{I_{1394}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_0.2                                       1.047942
# division_2_size_3                                         1.005017
# division_2_size_2.5                                       0.963782
#
#                      $\frac{I_{1394}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_0.2                                       2.442762
# division_2_size_3                                         1.843462
# division_2_size_2.5                                       2.012027
#
#                      $\frac{I_{1612}}{I_{1725}}$  \
# division_1_size_0.2                     2.435406
# division_2_size_3                       1.873563
# division_2_size_2.5                     2.187659
#
#                      $\frac{I_{1612}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_0.2                                           2.106341
# division_2_size_3                                             1.274784
# division_2_size_2.5                                           1.265079
#
#                      $\frac{I_{1612}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_0.2                                           0.256997
# division_2_size_3                                             0.148800
# division_2_size_2.5                                           0.152673
#
#                      $\frac{I_{1612}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_0.2                                            2.029827
# division_2_size_3                                              2.006392
# division_2_size_2.5                                            2.019370
#
#                      $\frac{I_{1612}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_0.2                                            0.708914
# division_2_size_3                                              0.652000
# division_2_size_2.5                                            0.686290
#
#                      $\frac{I_{1612}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_0.2                                            1.306212
# division_2_size_3                                              1.233122
# division_2_size_2.5                                            1.293467
#
#                      $\frac{I_{1612}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_0.2                                            0.971316
# division_2_size_3                                              1.032927
# division_2_size_2.5                                            1.079067
#
#                      $\frac{I_{1612}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_0.2                                           2.903119
# division_2_size_3                                             0.997409
# division_2_size_2.5                                           0.967606
#
#                      $\frac{I_{1612}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_0.2                                           0.689203
# division_2_size_3                                             0.237047
# division_2_size_2.5                                           0.240032
#
#                      $\frac{I_{1612}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_0.2                                     25.148914
# division_2_size_3                                        1.315786
# division_2_size_2.5                                      1.124880
#
#                      $\frac{I_{1612}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_0.2                                       1.589123
# division_2_size_3                                         0.669545
# division_2_size_2.5                                       0.715159
#
#                      $\frac{I_{1612}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_0.2                                       2.342032
# division_2_size_3                                         0.914820
# division_2_size_2.5                                       0.927043
#
#                      $\frac{I_{1612}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.2                                       2.712560
# division_2_size_3                                         1.175219
# division_2_size_2.5                                       1.242849
#
#                      $\frac{I_{1612}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.2                                       0.997530
# division_2_size_3                                         1.054237
# division_2_size_2.5                                       1.103313
#
#                      $\frac{I_{1612}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_0.2                                       2.372694
# division_2_size_3                                         1.904162
# division_2_size_2.5                                       2.171112
#
#                      $\frac{I_{1725}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_0.2                                           0.864883
# division_2_size_3                                             0.680406
# division_2_size_2.5                                           0.578280
#
#                      $\frac{I_{1725}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_0.2                                           0.105525
# division_2_size_3                                             0.079421
# division_2_size_2.5                                           0.069788
#
#                      $\frac{I_{1725}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_0.2                                            0.833466
# division_2_size_3                                              1.070896
# division_2_size_2.5                                            0.923073
#
#                      $\frac{I_{1725}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_0.2                                            0.291086
# division_2_size_3                                              0.348000
# division_2_size_2.5                                            0.313710
#
#                      $\frac{I_{1725}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_0.2                                            0.536342
# division_2_size_3                                              0.658170
# division_2_size_2.5                                            0.591256
#
#                      $\frac{I_{1725}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_0.2                                            0.398831
# division_2_size_3                                              0.551317
# division_2_size_2.5                                            0.493252
#
#                      $\frac{I_{1725}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_0.2                                           1.192047
# division_2_size_3                                             0.532360
# division_2_size_2.5                                           0.442302
#
#                      $\frac{I_{1725}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_0.2                                           0.282993
# division_2_size_3                                             0.126522
# division_2_size_2.5                                           0.109721
#
#                      $\frac{I_{1725}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_0.2                                     10.326374
# division_2_size_3                                        0.702291
# division_2_size_2.5                                      0.514194
#
#                      $\frac{I_{1725}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_0.2                                       0.652508
# division_2_size_3                                         0.357365
# division_2_size_2.5                                       0.326906
#
#                      $\frac{I_{1725}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_0.2                                       0.961660
# division_2_size_3                                         0.488278
# division_2_size_2.5                                       0.423760
#
#                      $\frac{I_{1725}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.2                                       1.113802
# division_2_size_3                                         0.627264
# division_2_size_2.5                                       0.568118
#
#                      $\frac{I_{1725}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.2                                       0.409595
# division_2_size_3                                         0.562691
# division_2_size_2.5                                       0.504335
#
#                      $\frac{I_{1725}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_0.2                                       0.417952
# division_2_size_3                                         0.554083
# division_2_size_2.5                                       0.475387
#
#                      $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_0.2                                                                  0.620133
# division_2_size_3                                                                    0.967319
# division_2_size_2.5                                                                  1.022439
#
#                      $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_0.2                                                                 1.378276
# division_2_size_3                                                                   0.782414
# division_2_size_2.5                                                                 0.764858
#
#                      $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_0.2                                                           11.939623
# division_2_size_3                                                              1.032164
# division_2_size_2.5                                                            0.889178
#
#                      $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_0.2                                                             0.754447
# division_2_size_3                                                               0.525222
# division_2_size_2.5                                                             0.565307
#
#                      $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_0.2                                                             1.111896
# division_2_size_3                                                               0.717628
# division_2_size_2.5                                                             0.732794
#
#                      $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.2                                                             1.287807
# division_2_size_3                                                               0.921896
# division_2_size_2.5                                                             0.982428
#
#                      $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.2                                                             0.473584
# division_2_size_3                                                               0.826992
# division_2_size_2.5                                                             0.872130
#
#                      $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_0.2                                                             0.483247
# division_2_size_3                                                               0.814342
# division_2_size_2.5                                                             0.822071
#
#                      $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_0.2                                                             1.126453
# division_2_size_3                                                               1.493714
# ...
#
#                      $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_0.2                                                              1.153809
# division_2_size_3                                                                0.455953
# division_2_size_2.5                                                              0.459075
#
#                      $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.2                                                              1.336350
# division_2_size_3                                                                0.585738
# division_2_size_2.5                                                              0.615464
#
#                      $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.2                                                              0.491436
# division_2_size_3                                                                0.525439
# division_2_size_2.5                                                              0.546365
#
#                      $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_0.2                                                              0.501463
# division_2_size_3                                                                0.517402
# division_2_size_2.5                                                              0.515005
#
#                      $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_0.2                                                              1.168914
# division_2_size_3                                                                0.949048
# division_2_size_2.5                                                              1.075143
#
#                      $\frac{\Sigma I_{p,\ 1900\text{–}1500}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_0.2                                                                   1.370147
# division_2_size_3                                                                     1.584244
# division_2_size_2.5                                                                   1.572319
#
#                      $\frac{\Sigma I_{p,\ 1900\text{–}1500}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_0.2                                                                  0.972197
# division_2_size_3                                                                    0.363570
# division_2_size_2.5                                                                  0.349753
#
#                      $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_0.2                                                                  2.222549
# division_2_size_3                                                                    0.808849
# division_2_size_2.5                                                                  0.748072
#
#                      $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_0.2                                                            19.253324
# division_2_size_3                                                               1.067036
# division_2_size_2.5                                                             0.869663
#
#                      $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_0.2                                                              1.216589
# division_2_size_3                                                                0.542967
# division_2_size_2.5                                                              0.552901
#
#                      $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_0.2                                                              1.792996
# division_2_size_3                                                                0.741873
# division_2_size_2.5                                                              0.716712
#
#                      $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.2                                                              2.076662
# division_2_size_3                                                                0.953043
# division_2_size_2.5                                                              0.960866
#
#                      $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.2                                                              0.763682
# division_2_size_3                                                                0.854933
# division_2_size_2.5                                                              0.852989
#
#                      $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_0.2                                                              0.779263
# division_2_size_3                                                                0.841855
# division_2_size_2.5                                                              0.804029
#
#                      $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_0.2                                                              1.816470
# division_2_size_3                                                                1.544180
# division_2_size_2.5                                                              1.678521
#
#                      $\frac{\Sigma I_{p,\ 1500\text{–}1300}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_0.2                                                                  0.709556
# division_2_size_3                                                                    0.229491
# division_2_size_2.5                                                                  0.222444
#
#                      $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_0.2                                                            8.662723
# division_2_size_3                                                              1.319204
# division_2_size_2.5                                                            1.162539
#
#                      $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_0.2                                                             0.547385
# division_2_size_3                                                               0.671284
# division_2_size_2.5                                                             0.739101
#
#                      $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_0.2                                                             0.806730
# division_2_size_3                                                               0.917197
# division_2_size_2.5                                                             0.958079
#
#                      $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.2                                                             0.934361
# division_2_size_3                                                               1.178271
# division_2_size_2.5                                                             1.284457
#
#                      $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.2                                                             0.343606
# division_2_size_3                                                               1.056975
# division_2_size_2.5                                                             1.140250
#
#                      $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_0.2                                                             0.350617
# division_2_size_3                                                               1.040807
# division_2_size_2.5                                                             1.074802
#
#                      $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_0.2                                                             0.817291
# division_2_size_3                                                               1.909109
# division_2_size_2.5                                                             2.243797
#
#                      $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_0.2                                                        0.063189
# division_2_size_3                                                          0.508856
# division_2_size_2.5                                                        0.635764
#
#                      $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_0.2                                                        0.093127
# division_2_size_3                                                          0.695266
# division_2_size_2.5                                                        0.824126
#
#                      $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.2                                                        0.107860
# division_2_size_3                                                          0.893169
# division_2_size_2.5                                                        1.104872
#
#                      $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.2                                                        0.039665
# division_2_size_3                                                          0.801222
# division_2_size_2.5                                                        0.980827
#
#                      $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_0.2                                                        0.040474
# division_2_size_3                                                          0.788966
# division_2_size_2.5                                                        0.924529
#
#                      $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_0.2                                                        0.094346
# division_2_size_3                                                          1.447167
# division_2_size_2.5                                                        1.930082
#
#                      $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_0.2                                                         1.473789
# division_2_size_3                                                           1.366331
# division_2_size_2.5                                                         1.296276
#
#                      $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.2                                                         1.706954
# division_2_size_3                                                           1.755250
# division_2_size_2.5                                                         1.737865
#
#                      $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.2                                                         0.627724
# division_2_size_3                                                           1.574557
# division_2_size_2.5                                                         1.542753
#
#                      $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_0.2                                                         0.640531
# division_2_size_3                                                           1.550471
# division_2_size_2.5                                                         1.454202
#
#                      $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_0.2                                                         1.493084
# division_2_size_3                                                           2.843964
# division_2_size_2.5                                                         3.035847
#
#                      $\frac{\overline{I}_{1182 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.2                                                         1.158208
# division_2_size_3                                                           1.284644
# division_2_size_2.5                                                         1.340660
#
#                      $\frac{\overline{I}_{1182 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.2                                                         0.425925
# division_2_size_3                                                           1.152397
# division_2_size_2.5                                                         1.190143
#
#                      $\frac{\overline{I}_{1182 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_0.2                                                         0.434615
# division_2_size_3                                                           1.134769
# division_2_size_2.5                                                         1.121831
#
#                      $\frac{\overline{I}_{1182 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_0.2                                                         1.013092
# division_2_size_3                                                           2.081460
# division_2_size_2.5                                                         2.341976
#
#                      $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.2                                                         0.367745
# division_2_size_3                                                           0.897056
# division_2_size_2.5                                                         0.887729
#
#                      $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_0.2                                                         0.375248
# division_2_size_3                                                           0.883333
# division_2_size_2.5                                                         0.836775
#
#                      $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_0.2                                                         0.874706
# division_2_size_3                                                           1.620262
# division_2_size_2.5                                                         1.746883
#
#                      $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_0.2                                                         1.020403
# division_2_size_3                                                           0.984703
# division_2_size_2.5                                                         0.942602
#
#                      $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_0.2                                                         2.378569
# division_2_size_3                                                           1.806200
# division_2_size_2.5                                                         1.967811
#
#                      $\frac{\overline{I}_{1612 \pm 25}}{\overline{I}_{1725 \pm 25}}$
# division_1_size_0.2                                                         2.331009
# division_2_size_3                                                           1.834259
# division_2_size_2.5                                                         2.087638

# %%
dataset = pd.concat([dataset_train, dataset_test], axis=0)

print(dataset.shape)
dataset.head(3)
# Out:
# (74, 249)
#                       $I_{872}$  $I_{1085}$  $I_{1182}$  $I_{1241}$  \
# division_1_size_bulk   0.047800    0.681294    0.388923    0.455066
# division_1_size_5      0.091438    0.606138    0.416593    0.427988
# division_1_size_3      0.108127    0.836176    0.514367    0.400950
#
#                       $I_{1394}$  $I_{1612}$  $I_{1725}$  \
# division_1_size_bulk    0.760582         1.0    0.423273
# division_1_size_5       0.687458         1.0    0.384475
# division_1_size_3       0.696553         1.0    0.368753
#
#                       $\overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                          0.424162
# division_1_size_5                             0.378730
# division_1_size_3                             0.436266
#
#                       $\Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                          3.756938
# division_1_size_5                             3.614090
# division_1_size_3                             3.924926
#
#                       $\overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                           0.426619
# division_1_size_5                              0.378004
# division_1_size_3                              0.429362
#
#                       $\Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                           1.423273
# division_1_size_5                              1.384475
# division_1_size_3                              1.368753
#
#                       $\overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                           0.571735
# division_1_size_5                              0.502368
# division_1_size_3                              0.523513
#
#                       $\Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                           0.760582
# division_1_size_5                              0.687458
# division_1_size_3                              0.696553
#
#                       $\overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                          0.363338
# division_1_size_5                             0.329999
# division_1_size_3                             0.406988
#
#                       $\Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                          1.573083
# division_1_size_5                             1.542157
# division_1_size_3                             1.859620
#
#                       $\overline{I}_{872 \pm 25}$  \
# division_1_size_bulk                     0.047238
# division_1_size_5                        0.092933
# division_1_size_3                        0.111725
#
#                       $\overline{I}_{1085 \pm 25}$  \
# division_1_size_bulk                      0.658256
# division_1_size_5                         0.571531
# division_1_size_3                         0.776148
#
#                       $\overline{I}_{1182 \pm 25}$  \
# division_1_size_bulk                      0.399497
# division_1_size_5                         0.426105
# division_1_size_3                         0.526741
#
#                       $\overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                      0.447733
# division_1_size_5                         0.424918
# division_1_size_3                         0.401435
#
#                       $\overline{I}_{1394 \pm 25}$  \
# division_1_size_bulk                      0.738860
# division_1_size_5                         0.667947
# division_1_size_3                         0.678774
#
#                       $\overline{I}_{1612 \pm 25}$  \
# division_1_size_bulk                      0.936425
# division_1_size_5                         0.926718
# division_1_size_3                         0.951396
#
#                       $\overline{I}_{1725 \pm 25}$  $\log I_{872}$  \
# division_1_size_bulk                      0.417470       -3.040727
# division_1_size_5                         0.378463       -2.392093
# division_1_size_3                         0.369746       -2.224448
#
#                       $(I_{872})^{-1}$  $\log I_{1085}$  $(I_{1085})^{-1}$  \
# division_1_size_bulk         20.920439        -0.383761           1.467794
# division_1_size_5            10.936364        -0.500648           1.649790
# division_1_size_3             9.248376        -0.178917           1.195921
#
#                       $\log I_{1182}$  $(I_{1182})^{-1}$  $\log I_{1241}$  \
# division_1_size_bulk        -0.944375           2.571206        -0.787312
# division_1_size_5           -0.875645           2.400424        -0.848660
# division_1_size_3           -0.664819           1.944138        -0.913918
#
#                       $(I_{1241})^{-1}$  $\log I_{1394}$  $(I_{1394})^{-1}$  \
# division_1_size_bulk           2.197482        -0.273672           1.314783
# division_1_size_5              2.336514        -0.374754           1.454634
# division_1_size_3              2.494076        -0.361611           1.435640
#
#                       $\log I_{1612}$  $(I_{1612})^{-1}$  $\log I_{1725}$  \
# division_1_size_bulk              0.0                1.0        -0.859739
# division_1_size_5                 0.0                1.0        -0.955877
# division_1_size_3                 0.0                1.0        -0.997629
#
#                       $(I_{1725})^{-1}$  \
# division_1_size_bulk           2.362543
# division_1_size_5              2.600952
# division_1_size_3              2.711845
#
#                       $\log \overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                              -0.857641
# division_1_size_5                                 -0.970931
# division_1_size_3                                 -0.829504
#
#                       $(\overline{I}_{1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.357591
# division_1_size_5                                    2.640400
# division_1_size_3                                    2.292181
#
#                       $\log \Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                               1.323604
# division_1_size_5                                  1.284840
# division_1_size_3                                  1.367347
#
#                       $(\Sigma I_{p,\ 1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.266174
# division_1_size_5                                    0.276695
# division_1_size_3                                    0.254782
#
#                       $\log \overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                               -0.851863
# division_1_size_5                                  -0.972851
# division_1_size_3                                  -0.845455
#
#                       $(\overline{I}_{1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  2.344010
# division_1_size_5                                     2.645477
# division_1_size_3                                     2.329038
#
#                       $\log \Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                                0.352959
# division_1_size_5                                   0.325321
# division_1_size_3                                   0.313900
#
#                       $(\Sigma I_{p,\ 1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  0.702606
# division_1_size_5                                     0.722296
# division_1_size_3                                     0.730592
#
#                       $\log \overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                               -0.559080
# division_1_size_5                                  -0.688422
# division_1_size_3                                  -0.647194
#
#                       $(\overline{I}_{1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.749062
# division_1_size_5                                     1.990572
# division_1_size_3                                     1.910173
#
#                       $\log \Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                               -0.273672
# division_1_size_5                                  -0.374754
# division_1_size_3                                  -0.361611
#
#                       $(\Sigma I_{p,\ 1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.314783
# division_1_size_5                                     1.454634
# division_1_size_3                                     1.435640
#
#                       $\log \overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                              -1.012422
# division_1_size_5                                 -1.108665
# division_1_size_3                                 -0.898970
#
#                       $(\overline{I}_{1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.752259
# division_1_size_5                                    3.030309
# division_1_size_3                                    2.457072
#
#                       $\log \Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                               0.453038
# division_1_size_5                                  0.433182
# division_1_size_3                                  0.620372
#
#                       $(\Sigma I_{p,\ 1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.635694
# division_1_size_5                                    0.648442
# division_1_size_3                                    0.537744
#
#                       $\log \overline{I}_{872 \pm 25}$  \
# division_1_size_bulk                         -3.052551
# division_1_size_5                            -2.375877
# division_1_size_3                            -2.191715
#
#                       $(\overline{I}_{872 \pm 25})^{-1}$  \
# division_1_size_bulk                           21.169287
# division_1_size_5                              10.760443
# division_1_size_3                               8.950554
#
#                       $\log \overline{I}_{1085 \pm 25}$  \
# division_1_size_bulk                          -0.418161
# division_1_size_5                             -0.559437
# division_1_size_3                             -0.253412
#
#                       $(\overline{I}_{1085 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.519165
# division_1_size_5                                1.749686
# division_1_size_3                                1.288414
#
#                       $\log \overline{I}_{1182 \pm 25}$  \
# division_1_size_bulk                          -0.917549
# division_1_size_5                             -0.853069
# division_1_size_3                             -0.641046
#
#                       $(\overline{I}_{1182 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.503146
# division_1_size_5                                2.346839
# division_1_size_3                                1.898465
#
#                       $\log \overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                          -0.803558
# division_1_size_5                             -0.855859
# division_1_size_3                             -0.912710
#
#                       $(\overline{I}_{1241 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.233473
# division_1_size_5                                2.353396
# division_1_size_3                                2.491063
#
#                       $\log \overline{I}_{1394 \pm 25}$  \
# division_1_size_bulk                          -0.302647
# division_1_size_5                             -0.403547
# division_1_size_3                             -0.387466
#
#                       $(\overline{I}_{1394 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.353436
# division_1_size_5                                1.497126
# division_1_size_3                                1.473243
#
#                       $\log \overline{I}_{1612 \pm 25}$  \
# division_1_size_bulk                          -0.065686
# division_1_size_5                             -0.076106
# division_1_size_3                             -0.049825
#
#                       $(\overline{I}_{1612 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.067891
# division_1_size_5                                1.079077
# division_1_size_3                                1.051087
#
#                       $\log \overline{I}_{1725 \pm 25}$  \
# division_1_size_bulk                          -0.873542
# division_1_size_5                             -0.971638
# division_1_size_3                             -0.994938
#
#                       $(\overline{I}_{1725 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.395381
# division_1_size_5                                2.642268
# division_1_size_3                                2.704557
#
#                       $\frac{I_{872}}{I_{1085}}$  $\frac{I_{872}}{I_{1182}}$  \
# division_1_size_bulk                    0.070161                    0.122904
# division_1_size_5                       0.150854                    0.219490
# division_1_size_3                       0.129311                    0.210214
#
#                       $\frac{I_{872}}{I_{1241}}$  $\frac{I_{872}}{I_{1394}}$  \
# division_1_size_bulk                    0.105040                    0.062847
# division_1_size_5                       0.213646                    0.133009
# division_1_size_3                       0.269677                    0.155232
#
#                       $\frac{I_{872}}{I_{1612}}$  $\frac{I_{872}}{I_{1725}}$  \
# division_1_size_bulk                    0.047800                    0.112930
# division_1_size_5                       0.091438                    0.237826
# division_1_size_3                       0.108127                    0.293224
#
#                       $\frac{I_{872}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                          0.112693
# division_1_size_5                                             0.241433
# division_1_size_3                                             0.247847
#
#                       $\frac{I_{872}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                          0.012723
# division_1_size_5                                             0.025300
# division_1_size_3                                             0.027549
#
#                       $\frac{I_{872}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.112044
# division_1_size_5                                              0.241897
# division_1_size_3                                              0.251832
#
#                       $\frac{I_{872}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.033585
# division_1_size_5                                              0.066045
# division_1_size_3                                              0.078997
#
#                       $\frac{I_{872}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.083605
# division_1_size_5                                              0.182014
# division_1_size_3                                              0.206541
#
#                       $\frac{I_{872}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.062847
# division_1_size_5                                              0.133009
# division_1_size_3                                              0.155232
#
#                       $\frac{I_{872}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                          0.131558
# division_1_size_5                                             0.277086
# division_1_size_3                                             0.265676
#
#                       $\frac{I_{872}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                          0.030386
# division_1_size_5                                             0.059292
# division_1_size_3                                             0.058145
#
#                       $\frac{I_{872}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                      0.072616
# division_1_size_5                                         0.159988
# division_1_size_3                                         0.139312
#
#                       $\frac{I_{872}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                      0.119651
# division_1_size_5                                         0.214590
# division_1_size_3                                         0.205276
#
#                       $\frac{I_{872}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                      0.106760
# division_1_size_5                                         0.215190
# division_1_size_3                                         0.269351
#
#                       $\frac{I_{872}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                      0.064694
# division_1_size_5                                         0.136894
# division_1_size_3                                         0.159298
#
#                       $\frac{I_{872}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                      0.051045
# division_1_size_5                                         0.098669
# division_1_size_3                                         0.113651
#
#                       $\frac{I_{872}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                      0.114500
# division_1_size_5                                         0.241604
# division_1_size_3                                         0.292436
#
#                       $\frac{I_{1085}}{I_{1182}}$  \
# division_1_size_bulk                     1.751748
# division_1_size_5                        1.454988
# division_1_size_3                        1.625641
#
#                       $\frac{I_{1085}}{I_{1241}}$  \
# division_1_size_bulk                     1.497132
# division_1_size_5                        1.416250
# division_1_size_3                        2.085485
#
#                       $\frac{I_{1085}}{I_{1394}}$  \
# division_1_size_bulk                     0.895754
# division_1_size_5                        0.881708
# division_1_size_3                        1.200447
#
#                       $\frac{I_{1085}}{I_{1612}}$  \
# division_1_size_bulk                     0.681294
# division_1_size_5                        0.606138
# division_1_size_3                        0.836176
#
#                       $\frac{I_{1085}}{I_{1725}}$  \
# division_1_size_bulk                     1.609587
# division_1_size_5                        1.576535
# division_1_size_3                        2.267579
#
#                       $\frac{I_{1085}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.606214
# division_1_size_5                                              1.600446
# division_1_size_3                                              1.916666
#
#                       $\frac{I_{1085}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.181343
# division_1_size_5                                              0.167715
# division_1_size_3                                              0.213042
#
#                       $\frac{I_{1085}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.596961
# division_1_size_5                                               1.603523
# division_1_size_3                                               1.947485
#
#                       $\frac{I_{1085}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.478681
# division_1_size_5                                               0.437811
# division_1_size_3                                               0.610903
#
#                       $\frac{I_{1085}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.191626
# division_1_size_5                                               1.206561
# division_1_size_3                                               1.597240
#
#                       $\frac{I_{1085}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.895754
# division_1_size_5                                               0.881708
# division_1_size_3                                               1.200447
#
#                       $\frac{I_{1085}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.875098
# division_1_size_5                                              1.836785
# division_1_size_3                                              2.054544
#
#                       $\frac{I_{1085}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.433095
# division_1_size_5                                              0.393045
# division_1_size_3                                              0.449649
#
#                       $\frac{I_{1085}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                     14.422514
# division_1_size_5                                         6.522311
# division_1_size_3                                         7.484235
#
#                       $\frac{I_{1085}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                       1.705379
# division_1_size_5                                          1.422508
# division_1_size_3                                          1.587450
#
#                       $\frac{I_{1085}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.521652
# division_1_size_5                                          1.426482
# division_1_size_3                                          2.082966
#
#                       $\frac{I_{1085}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.922089
# division_1_size_5                                          0.907465
# division_1_size_3                                          1.231890
#
#                       $\frac{I_{1085}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                       0.727548
# division_1_size_5                                          0.654069
# division_1_size_3                                          0.878893
#
#                       $\frac{I_{1085}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.631959
# division_1_size_5                                          1.601578
# division_1_size_3                                          2.261485
#
#                       $\frac{I_{1182}}{I_{1241}}$  \
# division_1_size_bulk                     0.854650
# division_1_size_5                        0.973376
# division_1_size_3                        1.282869
#
#                       $\frac{I_{1182}}{I_{1394}}$  \
# division_1_size_bulk                     0.511349
# division_1_size_5                        0.605990
# division_1_size_3                        0.738445
#
#                       $\frac{I_{1182}}{I_{1612}}$  \
# division_1_size_bulk                     0.388923
# division_1_size_5                        0.416593
# division_1_size_3                        0.514367
#
#                       $\frac{I_{1182}}{I_{1725}}$  \
# division_1_size_bulk                     0.918847
# division_1_size_5                        1.083538
# division_1_size_3                        1.394883
#
#                       $\frac{I_{1182}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           0.916921
# division_1_size_5                                              1.099973
# division_1_size_3                                              1.179021
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.103521
# division_1_size_5                                              0.115269
# division_1_size_3                                              0.131051
#
#                       $\frac{I_{1182}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.911639
# division_1_size_5                                               1.102087
# division_1_size_3                                               1.197980
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.273259
# division_1_size_5                                               0.300903
# division_1_size_3                                               0.375792
#
#                       $\frac{I_{1182}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.680250
# division_1_size_5                                               0.829258
# division_1_size_3                                               0.982530
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.511349
# division_1_size_5                                               0.605990
# division_1_size_3                                               0.738445
#
#                       $\frac{I_{1182}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.070416
# division_1_size_5                                              1.262406
# division_1_size_3                                              1.263836
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.247236
# division_1_size_5                                              0.270137
# division_1_size_3                                              0.276598
#
#                       $\frac{I_{1182}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                      8.233214
# division_1_size_5                                         4.482726
# division_1_size_3                                         4.603867
#
#                       $\frac{I_{1182}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                       0.590838
# division_1_size_5                                          0.728907
# division_1_size_3                                          0.662717
#
#                       $\frac{I_{1182}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       0.868648
# division_1_size_5                                          0.980408
# division_1_size_3                                          1.281320
#
#                       $\frac{I_{1182}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.526382
# division_1_size_5                                          0.623692
# division_1_size_3                                          0.757787
#
#                       $\frac{I_{1182}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                       0.415327
# division_1_size_5                                          0.449536
# division_1_size_3                                          0.540644
#
#                       $\frac{I_{1182}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       0.931618
# division_1_size_5                                          1.100751
# division_1_size_3                                          1.391134
#
#                       $\frac{I_{1241}}{I_{1394}}$  \
# division_1_size_bulk                     0.598314
# division_1_size_5                        0.622566
# division_1_size_3                        0.575620
#
#                       $\frac{I_{1241}}{I_{1612}}$  \
# division_1_size_bulk                     0.455066
# division_1_size_5                        0.427988
# division_1_size_3                        0.400950
#
#                       $\frac{I_{1241}}{I_{1725}}$  \
# division_1_size_bulk                     1.075114
# division_1_size_5                        1.113176
# division_1_size_3                        1.087315
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.072861
# division_1_size_5                                              1.130060
# division_1_size_3                                              0.919050
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.121127
# division_1_size_5                                              0.118422
# division_1_size_3                                              0.102155
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.066680
# division_1_size_5                                               1.132232
# division_1_size_3                                               0.933828
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.319732
# division_1_size_5                                               0.309134
# division_1_size_3                                               0.292931
#
#                       $\frac{I_{1241}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.795939
# division_1_size_5                                               0.851941
# division_1_size_3                                               0.765884
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.598314
# division_1_size_5                                               0.622566
# division_1_size_3                                               0.575620
#
#                       $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.252460
# division_1_size_5                                              1.296936
# division_1_size_3                                              0.985163
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.289283
# division_1_size_5                                              0.277526
# division_1_size_3                                              0.215609
#
#                       $\frac{I_{1241}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                      9.633431
# division_1_size_5                                         4.605340
# division_1_size_3                                         3.588726
#
#                       $\frac{I_{1241}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                       0.691321
# division_1_size_5                                          0.748845
# division_1_size_3                                          0.516590
#
#                       $\frac{I_{1241}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                       1.139098
# division_1_size_5                                          1.004419
# division_1_size_3                                          0.761190
#
#                       $\frac{I_{1241}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.615903
# division_1_size_5                                          0.640752
# division_1_size_3                                          0.590697
#
#                       $\frac{I_{1241}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                       0.485961
# division_1_size_5                                          0.461832
# division_1_size_3                                          0.421433
#
#                       $\frac{I_{1241}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.090057
# division_1_size_5                                          1.130859
# division_1_size_3                                          1.084393
#
#                       $\frac{I_{1394}}{I_{1612}}$  \
# division_1_size_bulk                     0.760582
# division_1_size_5                        0.687458
# division_1_size_3                        0.696553
#
#                       $\frac{I_{1394}}{I_{1725}}$  \
# division_1_size_bulk                     1.796907
# division_1_size_5                        1.788046
# division_1_size_3                        1.888945
#
#                       $\frac{I_{1394}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.793141
# division_1_size_5                                              1.815165
# division_1_size_3                                              1.596626
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.202447
# division_1_size_5                                              0.190216
# division_1_size_3                                              0.177469
#
#                       $\frac{I_{1394}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.782811
# division_1_size_5                                               1.818655
# division_1_size_3                                               1.622300
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.534389
# division_1_size_5                                               0.496548
# division_1_size_3                                               0.508897
#
#                       $\frac{I_{1394}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.330305
# division_1_size_5                                               1.368435
# division_1_size_3                                               1.330538
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                 1.0
# division_1_size_5                                                    1.0
# division_1_size_3                                                    1.0
#
#                       $\frac{I_{1394}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.093317
# division_1_size_5                                              2.083211
# division_1_size_3                                              1.711482
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.483497
# division_1_size_5                                              0.445777
# division_1_size_3                                              0.374568
#
#                       $\frac{I_{1394}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                     16.100969
# division_1_size_5                                         7.397356
# division_1_size_3                                         6.234539
#
#                       $\frac{I_{1394}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                       1.155449
# division_1_size_5                                          1.202836
# division_1_size_3                                          0.897449
#
#                       $\frac{I_{1394}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                       1.903847
# division_1_size_5                                          1.613354
# division_1_size_3                                          1.322383
#
#                       $\frac{I_{1394}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.698738
# division_1_size_5                                          1.617862
# division_1_size_3                                          1.735159
#
#                       $\frac{I_{1394}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                       0.812218
# division_1_size_5                                          0.741820
# division_1_size_3                                          0.732138
#
#                       $\frac{I_{1394}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.821882
# division_1_size_5                                          1.816449
# division_1_size_3                                          1.883869
#
#                       $\frac{I_{1612}}{I_{1725}}$  \
# division_1_size_bulk                     2.362543
# division_1_size_5                        2.600952
# division_1_size_3                        2.711845
#
#                       $\frac{I_{1612}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           2.357591
# division_1_size_5                                              2.640400
# division_1_size_3                                              2.292181
#
#                       $\frac{I_{1612}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.266174
# division_1_size_5                                              0.276695
# division_1_size_3                                              0.254782
#
#                       $\frac{I_{1612}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            2.344010
# division_1_size_5                                               2.645477
# division_1_size_3                                               2.329038
#
#                       $\frac{I_{1612}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.702606
# division_1_size_5                                               0.722296
# division_1_size_3                                               0.730592
#
#                       $\frac{I_{1612}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.749062
# division_1_size_5                                               1.990572
# division_1_size_3                                               1.910173
#
#                       $\frac{I_{1612}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.314783
# division_1_size_5                                               1.454634
# division_1_size_3                                               1.435640
#
#                       $\frac{I_{1612}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.752259
# division_1_size_5                                              3.030309
# division_1_size_3                                              2.457072
#
#                       $\frac{I_{1612}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.635694
# division_1_size_5                                              0.648442
# division_1_size_3                                              0.537744
#
#                       $\frac{I_{1612}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                     21.169287
# division_1_size_5                                        10.760443
# division_1_size_3                                         8.950554
#
#                       $\frac{I_{1612}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                       1.519165
# division_1_size_5                                          1.749686
# division_1_size_3                                          1.288414
#
#                       $\frac{I_{1612}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                       2.503146
# division_1_size_5                                          2.346839
# division_1_size_3                                          1.898465
#
#                       $\frac{I_{1612}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       2.233473
# division_1_size_5                                          2.353396
# division_1_size_3                                          2.491063
#
#                       $\frac{I_{1612}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       1.353436
# division_1_size_5                                          1.497126
# division_1_size_3                                          1.473243
#
#                       $\frac{I_{1612}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       2.395381
# division_1_size_5                                          2.642268
# division_1_size_3                                          2.704557
#
#                       $\frac{I_{1725}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           0.997904
# division_1_size_5                                              1.015167
# division_1_size_3                                              0.845248
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.112664
# division_1_size_5                                              0.106382
# division_1_size_3                                              0.093951
#
#                       $\frac{I_{1725}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.992156
# division_1_size_5                                               1.017119
# division_1_size_3                                               0.858839
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.297394
# division_1_size_5                                               0.277704
# division_1_size_3                                               0.269408
#
#                       $\frac{I_{1725}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.740330
# division_1_size_5                                               0.765324
# division_1_size_3                                               0.704381
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.556512
# division_1_size_5                                               0.559270
# division_1_size_3                                               0.529396
#
#                       $\frac{I_{1725}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.164956
# division_1_size_5                                              1.165077
# division_1_size_3                                              0.906052
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.269072
# division_1_size_5                                              0.249310
# division_1_size_3                                              0.198295
#
#                       $\frac{I_{1725}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                      8.960381
# division_1_size_5                                         4.137118
# division_1_size_3                                         3.300540
#
#                       $\frac{I_{1725}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                       0.643021
# division_1_size_5                                          0.672710
# division_1_size_3                                          0.475106
#
#                       $\frac{I_{1725}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                       1.059513
# division_1_size_5                                          0.902300
# division_1_size_3                                          0.700064
#
#                       $\frac{I_{1725}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       0.945368
# division_1_size_5                                          0.904821
# division_1_size_3                                          0.918586
#
#                       $\frac{I_{1725}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.572873
# division_1_size_5                                          0.575607
# division_1_size_3                                          0.543262
#
#                       $\frac{I_{1725}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                       0.452009
# division_1_size_5                                          0.414878
# division_1_size_3                                          0.387591
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                                                  0.741885
# division_1_size_5                                                                     0.753890
# division_1_size_3                                                                     0.833343
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                                                 1.167403
# division_1_size_5                                                                    1.147670
# division_1_size_3                                                                    1.071937
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                                            8.979201
# division_1_size_5                                                               4.075307
# division_1_size_3                                                               3.904821
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                                             0.644372
# division_1_size_5                                                                0.662659
# division_1_size_3                                                                0.562091
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                                             1.061739
# division_1_size_5                                                                0.888819
# division_1_size_3                                                                0.828236
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# ...
# division_1_size_bulk                                                              0.952843
# division_1_size_5                                                                 0.889592
# division_1_size_3                                                                 1.069567
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                              0.577402
# division_1_size_5                                                                 0.565919
# division_1_size_3                                                                 0.632554
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                              0.455583
# division_1_size_5                                                                 0.407895
# division_1_size_3                                                                 0.451297
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                              1.021916
# division_1_size_5                                                                 0.998787
# division_1_size_3                                                                 1.161234
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}1500}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                                   1.871295
# division_1_size_5                                                                      2.013903
# division_1_size_3                                                                      1.965036
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}1500}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                                                  0.904766
# division_1_size_5                                                                     0.897752
# division_1_size_3                                                                     0.736039
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                                                  1.573562
# division_1_size_5                                                                     1.522331
# division_1_size_3                                                                     1.286309
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                                            12.103221
# division_1_size_5                                                                5.405705
# division_1_size_3                                                                4.685729
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                                              0.868560
# division_1_size_5                                                                 0.878987
# division_1_size_3                                                                 0.674501
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                                              1.431136
# division_1_size_5                                                                 1.178978
# division_1_size_3                                                                 0.993871
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                              1.276955
# division_1_size_5                                                                 1.182272
# division_1_size_3                                                                 1.304103
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                              0.773807
# division_1_size_5                                                                 0.752109
# division_1_size_3                                                                 0.771262
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                              0.610551
# division_1_size_5                                                                 0.542094
# division_1_size_3                                                                 0.550257
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                              1.369523
# division_1_size_5                                                                 1.327392
# division_1_size_3                                                                 1.415870
#
#                       $\frac{\Sigma I_{p,\ 1500\text{–}1300}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                                                  0.483497
# division_1_size_5                                                                     0.445777
# division_1_size_3                                                                     0.374568
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{872 \pm 25}}$  \
# division_1_size_bulk                                                            7.691605
# division_1_size_5                                                               3.550939
# division_1_size_3                                                               3.642772
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                                             0.551970
# division_1_size_5                                                                0.577395
# division_1_size_3                                                                0.524370
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                                             0.909488
# division_1_size_5                                                                0.774455
# division_1_size_3                                                                0.772653
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                             0.811505
# division_1_size_5                                                                0.776619
# division_1_size_3                                                                1.013834
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                             0.491755
# division_1_size_5                                                                0.494051
# division_1_size_3                                                                0.599593
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                             0.388005
# division_1_size_5                                                                0.356095
# division_1_size_3                                                                0.427780
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                             0.870333
# division_1_size_5                                                                0.871947
# division_1_size_3                                                                1.100724
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1085 \pm 25}}$  \
# division_1_size_bulk                                                        0.071763
# division_1_size_5                                                           0.162604
# division_1_size_3                                                           0.143948
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                                        0.118244
# division_1_size_5                                                           0.218099
# division_1_size_3                                                           0.212106
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                        0.105505
# division_1_size_5                                                           0.218708
# division_1_size_3                                                           0.278314
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                        0.063934
# division_1_size_5                                                           0.139132
# division_1_size_3                                                           0.164598
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                        0.050445
# division_1_size_5                                                           0.100282
# division_1_size_3                                                           0.117433
#
#                       $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                        0.113154
# division_1_size_5                                                           0.245554
# division_1_size_3                                                           0.302166
#
#                       $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1182 \pm 25}}$  \
# division_1_size_bulk                                                         1.647712
# division_1_size_5                                                            1.341291
# division_1_size_3                                                            1.473490
#
#                       $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                         1.470198
# division_1_size_5                                                            1.345039
# division_1_size_3                                                            1.933434
#
#                       $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.890908
# division_1_size_5                                                            0.855654
# division_1_size_3                                                            1.143455
#
#                       $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                         0.702946
# division_1_size_5                                                            0.616726
# division_1_size_3                                                            0.815799
#
#                       $\frac{\overline{I}_{1085 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.576774
# division_1_size_5                                                            1.510138
# division_1_size_3                                                            2.099137
#
#                       $\frac{\overline{I}_{1182 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                         0.892266
# division_1_size_5                                                            1.002794
# division_1_size_3                                                            1.312146
#
#                       $\frac{\overline{I}_{1182 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.540694
# division_1_size_5                                                            0.637933
# division_1_size_3                                                            0.776018
#
#                       $\frac{\overline{I}_{1182 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                         0.426620
# division_1_size_5                                                            0.459800
# division_1_size_3                                                            0.553651
#
#                       $\frac{\overline{I}_{1182 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         0.956948
# division_1_size_5                                                            1.125884
# division_1_size_3                                                            1.424602
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.605978
# division_1_size_5                                                            0.636156
# division_1_size_3                                                            0.591411
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                         0.478130
# division_1_size_5                                                            0.458519
# division_1_size_3                                                            0.421943
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.072491
# division_1_size_5                                                            1.122747
# division_1_size_3                                                            1.085704
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1612 \pm 25}}$  \
# division_1_size_bulk                                                         0.789022
# division_1_size_5                                                            0.720766
# division_1_size_3                                                            0.713451
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.769851
# division_1_size_5                                                            1.764894
# division_1_size_3                                                            1.835784
#
#                       $\frac{\overline{I}_{1612 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         2.243094
# division_1_size_5                                                            2.448637
# division_1_size_3                                                            2.573105
#
#                       Split Fraction_hue Fraction_grouped_hue  Class
# division_1_size_bulk  Train        $> 0$              $d > 5$      2
# division_1_size_5     Train        $< 5$       $2 < d \leq 5$      1
# division_1_size_3     Train        $< 3$       $2 < d \leq 5$      1

# %% [markdown]
# ## Base parameters

# %%
type_color_dict = {
    '$d \leq 2$': '#2166AC',
    '$2 < d \leq 5$': '#67A9CF',
    '$d > 5$': '#B2182B'
}

# %%
groups = list(type_color_dict.keys())

# %%
sns.set_theme()

# %% [markdown]
# ## Dictionary for features mapping to type

# %%
feature_to_types = defaultdict(list)

for feature_type, features in features_description.items():
    for feature in features:
        feature_to_types[feature].append(feature_type)

# %% [markdown]
# ## Dictionary for mapping *class* to *size group*

# %%
class_fraction_group_dict = {
    0: r'$d \leq 2$',
    1: r'$2 < d \leq 5$',
    2: r'$d > 5$'
}

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Target rate analysis

# %% [markdown]
# Mapping hue ~ group:
# * Class 0 — $0< d \leq 2$
# * Class 1 — $2 < d \leq 5$
# * Class 2 — $d > 5$

# %%
fractions_hue_train_df = pd.DataFrame(dataset_train['Fraction_hue'].value_counts()).sort_values(by='Fraction_hue')
fractions_hue_test_df = pd.DataFrame(dataset_test['Fraction_hue'].value_counts()).sort_values(by='Fraction_hue')

display(fractions_hue_train_df.T, fractions_hue_test_df.T)
# Out:
# Fraction_hue  $< 0.2$  $< 0.4$  $< 2$  $< 2.5$  $< 25$  $< 3$  $< 4$  $< 5$  \
# count               6        6      7        6       6      9      1      6
#
# Fraction_hue  $< 50$  $< 70$  $< 75$  $> 0$
# count              1       2       1      8
# Fraction_hue  $< 0.2$  $< 0.4$  $< 2$  $< 2.5$  $< 3$  $< 5$  $< 70$  $< 75$  \
# count               1        2      1        2      1      3       1       2
#
# Fraction_hue  $> 0$
# count             2

# %%
target_rate_train_df = pd.DataFrame(dataset_train['Fraction_grouped_hue'].value_counts()).sort_values(by='Fraction_grouped_hue')
target_rate_test_df = pd.DataFrame(dataset_test['Fraction_grouped_hue'].value_counts()).sort_values(by='Fraction_grouped_hue')

display(target_rate_train_df.T, target_rate_test_df.T)
# Out:
# Fraction_grouped_hue  $2 < d \leq 5$  $d > 5$  $d \leq 2$
# count                             22       18          19
# Fraction_grouped_hue  $2 < d \leq 5$  $d > 5$  $d \leq 2$
# count                              6        5           4

# %% [markdown]
# ### Data wrangling

# %%
train = target_rate_train_df.copy()
test  = target_rate_test_df.copy()

train = train["count"].reset_index()
test  = test["count"].reset_index()
train.columns = ["bin", "count_train"]
test.columns  = ["bin", "count_test"]

bins_order = list(train["bin"])
bins_order += [b for b in test["bin"] if b not in bins_order]

df = (pd.DataFrame({"bin": bins_order})
      .merge(train, on="bin", how="left")
      .merge(test,  on="bin", how="left"))
df[["count_train", "count_test"]] = df[["count_train", "count_test"]].fillna(0).astype(int)

sum_tr, sum_te = df["count_train"].sum(), df["count_test"].sum()
df["freq_train"] = df["count_train"] * 100 / sum_tr if sum_tr else 0
df["freq_test"]  = df["count_test"] * 100  / sum_te if sum_te else 0

# %% [markdown]
# ### Visualization

# %%
fontsize = 14

train_color = "#08519c"
test_color  = "#1f77b4"
edge_color = "white"

# %%
fig, ax = plt.subplots(figsize=(10, 4), dpi=300)

x = np.arange(len(df))

width = 0.35

bars_train = ax.bar(x - width/2, df["freq_train"].values, width=width, label="Train", color=train_color, alpha=0.7, edgecolor=edge_color, linewidth=0.6)
bars_test  = ax.bar(x + width/2, df["freq_test"].values,  width=width, label="Test",  color=test_color, alpha=0.7,  edgecolor=edge_color, linewidth=0.6)

ax.set_xlabel("")
ax.set_ylabel("Relative frequency", fontsize=fontsize, labelpad=5)

ax.set_xticks(x, df["bin"])
ax.tick_params(axis='x', labelsize=fontsize)
ax.tick_params(axis='y', labelsize=fontsize-2)

# ax.yaxis.set_major_formatter(PercentFormatter(1.0))
ax.yaxis.set_major_locator(ticker.MaxNLocator(nbins=10))

# ax.legend(frameon=True, fontsize=fontsize-2, title_fontsize=fontsize, title='Dataset split')
ax.legend(frameon=True, fontsize=fontsize-2)

def annotate(container, values):
    for rect, val in zip(container, values):
        h = rect.get_height()
        ax.annotate(f"{int(val)}",
                    xy=(rect.get_x() + rect.get_width()/2, h),
                    xytext=(0, 0), textcoords="offset points",
                    ha="center", va="bottom", fontsize=fontsize-2, fontweight='normal')

annotate(bars_train, df["count_train"].values)
annotate(bars_test, df["count_test"].values)

plt.tight_layout()

plt.savefig(f"{path_to_save}/target_rate_barplot.svg", dpi=600)

plt.show()

# %% [markdown]
# ## *One-factor (OF)* analysis

# %% [markdown]
# ### *OF*-statictics calculation

# %%
def of_analysis(feature, features_df_train, target_train, features_df_test, target_test, n_bootstrap=50, C=1.0, random_state=42, n_splits=3, cv_shuffle=True):

    def safe_auc(y_true, proba):
        try:
            return roc_auc_score(y_true, proba, multi_class="ovr")
        except ValueError:
            return np.nan

    def fit_logreg_and_auc(X_tr, y_tr, X_te, y_te, C=1.0, rs=42, return_scale=False):
        scaler = StandardScaler().fit(X_tr)
        X_tr_s = scaler.transform(X_tr)
        X_te_s = scaler.transform(X_te)

        clf = OneVsRestClassifier(
            LogisticRegression(
                penalty="l2", C=C, solver="lbfgs", max_iter=10_000, random_state=rs
            )
        )
        clf.fit(X_tr_s, y_tr)

        auc_train = safe_auc(y_tr, clf.predict_proba(X_tr_s))
        auc_test  = safe_auc(y_te, clf.predict_proba(X_te_s))

        if return_scale:
            return auc_train, auc_test, float(scaler.mean_[0]), float(scaler.scale_[0])
        return auc_train, auc_test

    def bootstrap_block(X_source, y_train, X_test_raw, y_test, n_bs, C, rs=42):
        aucs_train, aucs_test = [], []
        for seed in range(n_bs):
            X_bs, y_bs = resample(X_source, y_train, replace=True, random_state=seed)
            a_tr, a_te = fit_logreg_and_auc(X_bs, y_bs, X_test_raw, y_test, C=C, rs=rs)
            aucs_train.append(a_tr)
            aucs_test.append(a_te)
        return np.asarray(aucs_train, float), np.asarray(aucs_test, float)

    def cv_block(X_train_raw, y_train, n_splits, shuffle, rs, C):
        skf = StratifiedKFold(n_splits=n_splits, shuffle=shuffle, random_state=rs)
        oof_scores = []
        for tr_idx, val_idx in skf.split(X_train_raw, y_train):
            X_tr, X_val = X_train_raw[tr_idx], X_train_raw[val_idx]
            y_tr, y_val = y_train[tr_idx], y_train[val_idx]

            scaler = StandardScaler().fit(X_tr)
            X_tr_s  = scaler.transform(X_tr)
            X_val_s = scaler.transform(X_val)

            clf = OneVsRestClassifier(
                LogisticRegression(
                    penalty="l2", C=C, solver="lbfgs", max_iter=10_000, random_state=rs
                )
            )
            clf.fit(X_tr_s, y_tr)
            proba_val = clf.predict_proba(X_val_s)
            oof_scores.append(safe_auc(y_val, proba_val))

        return np.asarray(oof_scores, float)

    def summarize(arr):
        arr = np.asarray(arr, float)
        if arr.size == 0:
            return np.nan, np.nan, np.nan
        return float(np.nanmean(arr)), float(np.nanpercentile(arr, 5)), float(np.nanpercentile(arr, 95))

    rng = np.random.default_rng(random_state)

    X_train_raw = features_df_train[[feature]].values
    y_train     = target_train.values
    X_test_raw  = features_df_test[[feature]].values
    y_test      = target_test.values

    # Глобальные (единственная подгонка на всём трейне)
    auc_global_train, auc_global_test, mean_val, std_val = fit_logreg_and_auc(
        X_train_raw, y_train, X_test_raw, y_test, C=C, rs=random_state, return_scale=True
    )

    # Бутстрэп
    bs_train, bs_test = bootstrap_block(
        X_train_raw, y_train, X_test_raw, y_test, n_bs=n_bootstrap, C=C, rs=random_state
    )
    bs_mean_train, bs_ci5_train, bs_ci95_train = summarize(bs_train)
    bs_mean_test,  bs_ci5_test,  bs_ci95_test  = summarize(bs_test)

    # Нoise baseline (перемешанный train)
    shuffled_train = rng.permutation(X_train_raw.ravel()).reshape(-1, 1)
    noise_train, noise_test = bootstrap_block(
        shuffled_train, y_train, X_test_raw, y_test, n_bs=n_bootstrap, C=C, rs=random_state
    )
    noise_mean_train, noise_ci5_train, noise_ci95_train = summarize(noise_train)
    noise_mean_test,  noise_ci5_test,  noise_ci95_test  = summarize(noise_test)

    # Δ и z-score
    delta_auc_train = bs_mean_train - noise_mean_train
    delta_auc_test  = bs_mean_test  - noise_mean_test
    std_noise_train = np.nanstd(noise_train)
    std_noise_test  = np.nanstd(noise_test)
    z_score_train = (delta_auc_train / std_noise_train) if std_noise_train > 0 else np.nan
    z_score_test  = (delta_auc_test  / std_noise_test)  if std_noise_test  > 0 else np.nan

    # CV-OOF
    cv_scores = cv_block(X_train_raw, y_train, n_splits=n_splits, shuffle=cv_shuffle, rs=random_state, C=C)
    cv_mean_train, cv_ci5_train, cv_ci95_train = summarize(cv_scores)

    return {
        "Feature": feature,
        "$scale-mean$": mean_val,
        "$scale-std$": std_val,
        "$C$": C,

        "$ROC-AUC_{ovr}^{global,train}$": auc_global_train,
        "$ROC-AUC_{ovr}^{global,test}$":  auc_global_test,

        "$ROC-AUC_{ovr}^{BS,train}$": bs_mean_train,
        "$CI_{5\\%}^{BS,train}$":     bs_ci5_train,
        "$CI_{95\\%}^{BS,train}$":    bs_ci95_train,
        "$ROC-AUC_{ovr}^{BS,test}$":  bs_mean_test,
        "$CI_{5\\%}^{BS,test}$":      bs_ci5_test,
        "$CI_{95\\%}^{BS,test}$":     bs_ci95_test,

        "$ROC-AUC_{ovr}^{CV,train}$": cv_mean_train,
        "$CI_{5\\%}^{CV,train}$":     cv_ci5_train,
        "$CI_{95\\%}^{CV,train}$":    cv_ci95_train,
        "$n_{folds}^{CV}$":           int(np.isfinite(cv_scores).sum()),

        "$ROC-AUC_{ovr}^{noise,train}$": noise_mean_train,
        "$CI_{5\\%}^{noise,train}$":     noise_ci5_train,
        "$CI_{95\\%}^{noise,train}$":    noise_ci95_train,
        "$ROC-AUC_{ovr}^{noise,test}$":  noise_mean_test,
        "$CI_{5\\%}^{noise,test}$":      noise_ci5_test,
        "$CI_{95\\%}^{noise,test}$":     noise_ci95_test,

        "$ΔROC-AUC^{train}$": delta_auc_train,
        "$ΔROC-AUC^{test}$":  delta_auc_test,
        "$z-score^{train}$":  z_score_train,
        "$z-score^{test}$":   z_score_test,

        "$n_{valid}^{BS,train}$":      int(np.isfinite(bs_train).sum()),
        "$n_{valid}^{BS,test}$":       int(np.isfinite(bs_test).sum()),
        "$n_{valid}^{noise,train}$":   int(np.isfinite(noise_train).sum()),
        "$n_{valid}^{noise,test}$":    int(np.isfinite(noise_test).sum()),
    }

# %%
# %%time

features_list = X_train.columns.tolist()

with tqdm_joblib(desc="Calculation progress", total=len(features_list)):
    results = Parallel(n_jobs=-1, backend="loky")(
        delayed(of_analysis)(
            feature,
            X_train,
            y_train,
            X_test,
            y_test,
            n_bootstrap=50,
            C=1.0,
        )
        for feature in features_list
    )
# Out:
# Calculation progress:   0%|          | 0/245 [00:00<?, ?it/s]
# CPU times: user 489 ms, sys: 148 ms, total: 637 ms
# Wall time: 11.9 s

# %%
of_metrics_df = pd.DataFrame(results).sort_values(
    by=[
        "$CI_{5\%}^{BS,train}$",
        "$ROC-AUC_{ovr}^{BS,train}$",
        "$ROC-AUC_{ovr}^{global,train}$"
    ],
    ascending=[
        False,
        False,
        False
    ]
)
print(of_metrics_df.shape)
of_metrics_df.head(3)
# Out:
# (245, 30)
#                                                                  Feature  \
# 220  $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1241 \pm 25}}$
# 132                    $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$
# 68                                            $\frac{I_{872}}{I_{1241}}$
#
#      $scale-mean$  $scale-std$  $C$  $ROC-AUC_{ovr}^{global,train}$  \
# 220      0.910113     0.390297  1.0                        0.797614
# 132      1.258344     0.425168  1.0                        0.786452
# 68       0.419326     0.342203  1.0                        0.806589
#
#      $ROC-AUC_{ovr}^{global,test}$  $ROC-AUC_{ovr}^{BS,train}$  \
# 220                       0.501156                    0.794698
# 132                       0.525847                    0.799362
# 68                        0.701302                    0.797397
#
#      $CI_{5\%}^{BS,train}$  $CI_{95\%}^{BS,train}$  $ROC-AUC_{ovr}^{BS,test}$  \
# 220               0.718063                0.887894                   0.536465
# 132               0.714820                0.882826                   0.537699
# 68                0.712352                0.875928                   0.659080
#
#      $CI_{5\%}^{BS,test}$  $CI_{95\%}^{BS,test}$  $ROC-AUC_{ovr}^{CV,train}$  \
# 220              0.488810               0.643131                    0.741695
# 132              0.485415               0.618440                    0.773593
# 68               0.525067               0.732783                    0.801498
#
#      $CI_{5\%}^{CV,train}$  $CI_{95\%}^{CV,train}$  $n_{folds}^{CV}$  \
# 220               0.714572                0.782875                 3
# 132               0.743678                0.816205                 3
# 68                0.744444                0.870028                 3
#
#      $ROC-AUC_{ovr}^{noise,train}$  $CI_{5\%}^{noise,train}$  \
# 220                       0.582307                  0.494984
# 132                       0.591690                  0.508063
# 68                        0.621656                  0.525851
#
#      $CI_{95\%}^{noise,train}$  $ROC-AUC_{ovr}^{noise,test}$  \
# 220                   0.708049                      0.480482
# 132                   0.688083                      0.415422
# 68                    0.726621                      0.318001
#
#      $CI_{5\%}^{noise,test}$  $CI_{95\%}^{noise,test}$  $ΔROC-AUC^{train}$  \
# 220                 0.359675                  0.610033            0.212391
# 132                 0.344523                  0.597600            0.207672
# 68                  0.201055                  0.461722            0.175741
#
#      $ΔROC-AUC^{test}$  $z-score^{train}$  $z-score^{test}$  \
# 220           0.055983           3.171596          0.700527
# 132           0.122278           3.872331          1.390960
# 68            0.341079           2.791657          2.610054
#
#      $n_{valid}^{BS,train}$  $n_{valid}^{BS,test}$  $n_{valid}^{noise,train}$  \
# 220                      50                     50                         50
# 132                      50                     50                         50
# 68                       50                     50                         50
#
#      $n_{valid}^{noise,test}$
# 220                        50
# 132                        50
# 68                         50

# %% [markdown]
# ### *Hard-check* factor selection

# %%
of_features_to_save = (
    of_metrics_df
    .loc[
        (of_metrics_df['$CI_{5\%}^{BS,train}$'] >= 0.60)
        # & (of_metrics_df['$CI_{5\%}^{CV,train}$'] >= 0.55)
        & (of_metrics_df['$ROC-AUC_{ovr}^{global,train}$'] >= 0.60)
    ]['Feature']
).tolist()

print(
    f'Число фичей',
    f'(*) до отбора: {len(of_metrics_df["Feature"].unique())}',
    f'(*) после отбора: {len(of_features_to_save)}',
    f'Доля фичей, прошедших однофакторный отбор: {round(len(of_features_to_save) / len(of_metrics_df["Feature"].unique()) * 100, 2)}%',
    sep='\n'
)
# Out:
# Число фичей
# (*) до отбора: 245
# (*) после отбора: 34
# Доля фичей, прошедших однофакторный отбор: 13.88%

# %%
of_metrics_df = of_metrics_df.loc[of_metrics_df['Feature'].isin(of_features_to_save)]

print(of_metrics_df.shape)
of_metrics_df.head(3)
# Out:
# (34, 30)
#                                                                  Feature  \
# 220  $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1241 \pm 25}}$
# 132                    $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$
# 68                                            $\frac{I_{872}}{I_{1241}}$
#
#      $scale-mean$  $scale-std$  $C$  $ROC-AUC_{ovr}^{global,train}$  \
# 220      0.910113     0.390297  1.0                        0.797614
# 132      1.258344     0.425168  1.0                        0.786452
# 68       0.419326     0.342203  1.0                        0.806589
#
#      $ROC-AUC_{ovr}^{global,test}$  $ROC-AUC_{ovr}^{BS,train}$  \
# 220                       0.501156                    0.794698
# 132                       0.525847                    0.799362
# 68                        0.701302                    0.797397
#
#      $CI_{5\%}^{BS,train}$  $CI_{95\%}^{BS,train}$  $ROC-AUC_{ovr}^{BS,test}$  \
# 220               0.718063                0.887894                   0.536465
# 132               0.714820                0.882826                   0.537699
# 68                0.712352                0.875928                   0.659080
#
#      $CI_{5\%}^{BS,test}$  $CI_{95\%}^{BS,test}$  $ROC-AUC_{ovr}^{CV,train}$  \
# 220              0.488810               0.643131                    0.741695
# 132              0.485415               0.618440                    0.773593
# 68               0.525067               0.732783                    0.801498
#
#      $CI_{5\%}^{CV,train}$  $CI_{95\%}^{CV,train}$  $n_{folds}^{CV}$  \
# 220               0.714572                0.782875                 3
# 132               0.743678                0.816205                 3
# 68                0.744444                0.870028                 3
#
#      $ROC-AUC_{ovr}^{noise,train}$  $CI_{5\%}^{noise,train}$  \
# 220                       0.582307                  0.494984
# 132                       0.591690                  0.508063
# 68                        0.621656                  0.525851
#
#      $CI_{95\%}^{noise,train}$  $ROC-AUC_{ovr}^{noise,test}$  \
# 220                   0.708049                      0.480482
# 132                   0.688083                      0.415422
# 68                    0.726621                      0.318001
#
#      $CI_{5\%}^{noise,test}$  $CI_{95\%}^{noise,test}$  $ΔROC-AUC^{train}$  \
# 220                 0.359675                  0.610033            0.212391
# 132                 0.344523                  0.597600            0.207672
# 68                  0.201055                  0.461722            0.175741
#
#      $ΔROC-AUC^{test}$  $z-score^{train}$  $z-score^{test}$  \
# 220           0.055983           3.171596          0.700527
# 132           0.122278           3.872331          1.390960
# 68            0.341079           2.791657          2.610054
#
#      $n_{valid}^{BS,train}$  $n_{valid}^{BS,test}$  $n_{valid}^{noise,train}$  \
# 220                      50                     50                         50
# 132                      50                     50                         50
# 68                       50                     50                         50
#
#      $n_{valid}^{noise,test}$
# 220                        50
# 132                        50
# 68                         50

# %% [markdown]
# ### Mapping features with their types

# %%
rows = []

for _, row in of_metrics_df.iterrows():
    feature = row['Feature']
    feature_types = feature_to_types.get(feature, [])

    for feature_type in feature_types:
        row_copy = row.copy()
        row_copy['Feature_Type'] = feature_type
        rows.append(row_copy)

of_metrics_expanded_df = pd.DataFrame(rows)

print(of_metrics_expanded_df.shape)
of_metrics_expanded_df.head(3)
# Out:
# (68, 31)
#                                                                  Feature  \
# 220  $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1241 \pm 25}}$
# 220  $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1241 \pm 25}}$
# 132                    $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$
#
#      $scale-mean$  $scale-std$  $C$  $ROC-AUC_{ovr}^{global,train}$  \
# 220      0.910113     0.390297  1.0                        0.797614
# 220      0.910113     0.390297  1.0                        0.797614
# 132      1.258344     0.425168  1.0                        0.786452
#
#      $ROC-AUC_{ovr}^{global,test}$  $ROC-AUC_{ovr}^{BS,train}$  \
# 220                       0.501156                    0.794698
# 220                       0.501156                    0.794698
# 132                       0.525847                    0.799362
#
#      $CI_{5\%}^{BS,train}$  $CI_{95\%}^{BS,train}$  $ROC-AUC_{ovr}^{BS,test}$  \
# 220               0.718063                0.887894                   0.536465
# 220               0.718063                0.887894                   0.536465
# 132               0.714820                0.882826                   0.537699
#
#      $CI_{5\%}^{BS,test}$  $CI_{95\%}^{BS,test}$  $ROC-AUC_{ovr}^{CV,train}$  \
# 220              0.488810               0.643131                    0.741695
# 220              0.488810               0.643131                    0.741695
# 132              0.485415               0.618440                    0.773593
#
#      $CI_{5\%}^{CV,train}$  $CI_{95\%}^{CV,train}$  $n_{folds}^{CV}$  \
# 220               0.714572                0.782875                 3
# 220               0.714572                0.782875                 3
# 132               0.743678                0.816205                 3
#
#      $ROC-AUC_{ovr}^{noise,train}$  $CI_{5\%}^{noise,train}$  \
# 220                       0.582307                  0.494984
# 220                       0.582307                  0.494984
# 132                       0.591690                  0.508063
#
#      $CI_{95\%}^{noise,train}$  $ROC-AUC_{ovr}^{noise,test}$  \
# 220                   0.708049                      0.480482
# 220                   0.708049                      0.480482
# 132                   0.688083                      0.415422
#
#      $CI_{5\%}^{noise,test}$  $CI_{95\%}^{noise,test}$  $ΔROC-AUC^{train}$  \
# 220                 0.359675                  0.610033            0.212391
# 220                 0.359675                  0.610033            0.212391
# 132                 0.344523                  0.597600            0.207672
#
#      $ΔROC-AUC^{test}$  $z-score^{train}$  $z-score^{test}$  \
# 220           0.055983           3.171596          0.700527
# 220           0.055983           3.171596          0.700527
# 132           0.122278           3.872331          1.390960
#
#      $n_{valid}^{BS,train}$  $n_{valid}^{BS,test}$  $n_{valid}^{noise,train}$  \
# 220                      50                     50                         50
# 220                      50                     50                         50
# 132                      50                     50                         50
#
#      $n_{valid}^{noise,test}$                            Feature_Type
# 220                        50  engineered_features_intervals_1900_800
# 220                        50                     engineered_features
# 132                        50  engineered_features_intervals_1900_800

# %% [markdown]
# ### Visualization

# %%
train_color = "#08519c"
test_color  = "#1f77b4"

PLOT_STYLE = {
    'TITLE_FONT_SIZE': 18, 'TITLE_FONTSTYLE': 'normal',
    'X_LABEL_FONT_SIZE': 14, 'Y_TICK_LABEL_FONT_SIZE': 14,
    'X_LABELPAD': 8, 'X_NBINS': 8,
    'BAR_HEIGHT': 0.34, 'BAR_ALPHA': 0.7,
    'FIG_DPI': 300, 'SUBPLOT_WIDTH': 6, 'SUBPLOT_HEIGHT': 4.2,
    'TOP_N': 5, 'LEGEND_FONT_SIZE': 12, 'ERR_CAPSIZE': 3, 'ERR_LINEWIDTH': 1.4,
    'HUE_COLORS': {'train': train_color, 'test': test_color}
}

KEYS = {
    'bs_train': "$ROC-AUC_{ovr}^{BS,train}$",     'glob_train': "$ROC-AUC_{ovr}^{global,train}$",
    'bs_test': "$ROC-AUC_{ovr}^{BS,test}$",       'glob_test': "$ROC-AUC_{ovr}^{global,test}$",
    'ci5_train': "$CI_{5\\%}^{BS,train}$",        'ci95_train': "$CI_{95\\%}^{BS,train}$",
    'ci5_test': "$CI_{5\\%}^{BS,test}$",          'ci95_test': "$CI_{95\\%}^{BS,test}$",
    'cv_train': '$ROC-AUC_{ovr}^{CV,train}$',     'ci5_cv_train': '$CI_{5\%}^{CV,train}$',
    'ci95_cv_train': '$CI_{95\%}^{CV,train}$'
}

VISUAL_TYPE_LABELS = {'peaks': 'Peak-based', 'intervals': 'Region-based'}

# %%
def extract_base_and_range(feature_type: str):
    if not isinstance(feature_type, str):
        return None, None

    parts = feature_type.lower().split('_')

    # база (тип)
    if 'peaks' in parts:
        base = 'peaks'
    elif 'intervals' in parts:
        base = 'intervals'
    else:
        base = None

    # диапазон — две последние числовые части
    nums = [p for p in parts if re.fullmatch(r'\d+(?:\.\d+)?', p)]
    rng = None
    if len(nums) >= 2:
        a, b = float(nums[-2]), float(nums[-1])
        hi, lo = (max(a, b), min(a, b))
        def _fmt(x):
            xi = int(round(x))
            return str(xi) if abs(x - xi) < 1e-9 else f"{x:g}"
        rng = f"{_fmt(hi)}–{_fmt(lo)}"

    # валидируем базу по словарю визуальных меток
    if base not in VISUAL_TYPE_LABELS:
        base = None

    return base, rng


def group_sort_key(gr):
    base, rng = gr
    base_order = list(VISUAL_TYPE_LABELS.keys())
    base_idx = base_order.index(base) if base in base_order else len(base_order)

    hi = lo = None
    if isinstance(rng, str):
        m = re.findall(r'\d+(?:\.\d+)?', rng)
        if len(m) >= 2:
            a, b = float(m[0]), float(m[1])
            hi, lo = (max(a, b), min(a, b))

    # hi -> сортируем по убыванию (поэтому минус), lo -> по возрастанию
    return (base_idx, -(hi if hi is not None else -1e9), (lo if lo is not None else 1e9))


def panel_title_from_group(gr):
    base, rng = gr
    base_label = VISUAL_TYPE_LABELS.get(base, base or "")
    return f"{base_label} | {rng} cm$^{{-1}}$" if rng else base_label


def build_plot_df(subset: pd.DataFrame, top_n: int = 5):
    rows = []
    for _, row in subset.iterrows():
        feat = row.get('Feature')
        if pd.isna(feat):
            continue

        for split in ('train', 'test'):
            mean_col_bs = KEYS[f'bs_{split}']
            mean_col_glob = KEYS[f'glob_{split}']
            ci5_col = KEYS[f'ci5_{split}']
            ci95_col = KEYS[f'ci95_{split}']

            mean = row.get(mean_col_bs)
            ci5  = row.get(ci5_col)
            ci95 = row.get(ci95_col)

            # если bootstrap-метрик нет — используем global без ошибок
            if pd.isna(mean):
                mean = row.get(mean_col_glob)
                ci5, ci95 = np.nan, np.nan

            if pd.isna(mean):
                continue

            err_left  = float(mean - ci5)  if (ci5  is not None and not pd.isna(ci5))  else 0.0
            err_right = float(ci95 - mean) if (ci95 is not None and not pd.isna(ci95)) else 0.0

            rows.append({
                'Feature': feat,
                'Split': split,
                'mean': float(mean),
                'err_left': err_left,
                'err_right': err_right
            })

    plot_df = pd.DataFrame(rows)
    if plot_df.empty:
        return plot_df, []

    order_feats = (
        plot_df.groupby('Feature')['mean']
        .mean()
        .sort_values(ascending=False)
        .head(top_n)
        .index.tolist()
    )
    plot_df = plot_df[plot_df['Feature'].isin(order_feats)].copy()
    return plot_df, order_feats

# %%
tmp = of_metrics_expanded_df.copy()

tmp[['viz_base','viz_range']] = tmp['Feature_Type'].apply(lambda s: pd.Series(extract_base_and_range(s)))
tmp = tmp[tmp['viz_base'].isin(VISUAL_TYPE_LABELS) & tmp['viz_range'].notna()]

present_groups = sorted(tmp[['viz_base','viz_range']].drop_duplicates().itertuples(index=False, name=None), key=group_sort_key)

# %%
# --- layout ---
n = len(present_groups)
ncols = 2 if n > 1 else 1
nrows = math.ceil(n / ncols)
fig, axes = plt.subplots(nrows=nrows, ncols=ncols,
                         figsize=(ncols*PLOT_STYLE['SUBPLOT_WIDTH'], nrows*PLOT_STYLE['SUBPLOT_HEIGHT']),
                         dpi=PLOT_STYLE['FIG_DPI'])
axes = np.atleast_1d(axes).ravel()

# --- panels ---
for i, g in enumerate(present_groups):
    ax = axes[i]
    base, rng = g
    subset = tmp[(tmp['viz_base']==base) & (tmp['viz_range']==rng)].copy()
    plot_df, order_feats = build_plot_df(subset, PLOT_STYLE['TOP_N'])
    if plot_df.empty:
        ax.set_title(panel_title_from_group(g), fontsize=PLOT_STYLE['TITLE_FONT_SIZE'],
                     fontstyle=PLOT_STYLE['TITLE_FONTSTYLE'])
        ax.text(0.5,0.5,'no data',ha='center',va='center',fontsize=12,alpha=0.7)
        ax.set_axis_off()
        continue

    plot_df['Feature'] = pd.Categorical(plot_df['Feature'], categories=order_feats, ordered=True)
    y0 = np.arange(len(order_feats)); off = PLOT_STYLE['BAR_HEIGHT']/2

    for split, sign in (('train',-1),('test',+1)):
        sub = plot_df[plot_df['Split']==split].sort_values('Feature')
        y = y0 + sign*off
        xerr = np.vstack([sub['err_left'].to_numpy(), sub['err_right'].to_numpy()])
        ax.barh(y, sub['mean'], height=PLOT_STYLE['BAR_HEIGHT'], alpha=PLOT_STYLE['BAR_ALPHA'],
                label=split.capitalize(), color=PLOT_STYLE['HUE_COLORS'][split],
                xerr=xerr, error_kw={'capsize':PLOT_STYLE['ERR_CAPSIZE'], 'lw':PLOT_STYLE['ERR_LINEWIDTH']})

    ax.set_yticks(y0, labels=order_feats, fontsize=PLOT_STYLE['Y_TICK_LABEL_FONT_SIZE'])
    ax.invert_yaxis()
    ax.set_xlabel('$ROC\\!-\\!AUC_{ovr}$', fontsize=PLOT_STYLE['X_LABEL_FONT_SIZE'],
                  labelpad=PLOT_STYLE['X_LABELPAD'])
    ax.set_xlim(0,1)
    ax.set_title(panel_title_from_group(g), fontsize=PLOT_STYLE['TITLE_FONT_SIZE'],
                 fontstyle=PLOT_STYLE['TITLE_FONTSTYLE'])
    ax.xaxis.set_major_locator(ticker.MaxNLocator(nbins=PLOT_STYLE['X_NBINS']))
    ax.legend(loc='upper left', fontsize=PLOT_STYLE['LEGEND_FONT_SIZE'], frameon=True)

# hide unused axes
for j in range(len(present_groups), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()

plt.savefig(f'{path_to_save}/roc_auc_barplots.svg', dpi=600)

plt.show()

# %% [markdown]
# ## *Multi-factor* analysis

# %% [markdown]
# ### Functions for processing & config-parameters

# %% [markdown]
# #### Forward selection

# %%
def forward_selection_bootstrap(
    X_train: pd.DataFrame,
    y_train: pd.Series | np.ndarray,
    X_test: pd.DataFrame,
    y_test: pd.Series | np.ndarray,
    candidate_features: list[str],
    scoring: str = "roc_auc_ovr",          # 'roc_auc_ovr' | 'pr_auc'
    min_uplift: float | None = None,
    max_features: int | None = None,
    n_bootstrap: int = 50,
    n_jobs: int = -1,
    use_tqdm: bool = True,
    uplift_type: str = "mean",             # 'mean' | 'low' | 'high' — USED ONLY WHEN selection_mode='bootstrap'
    return_ci: bool = True,                # kept for compatibility; CI is always calculated in bootstrap mode
    random_state: int = 42,
    selection_mode: str = "bootstrap",     # 'bootstrap' | 'train'
):
    rng = np.random.RandomState(random_state)

    # convert targets to arrays/indices
    y_tr = np.asarray(y_train).ravel() if isinstance(y_train, (pd.Series, pd.DataFrame)) else np.asarray(y_train).ravel()
    y_te = np.asarray(y_test).ravel() if isinstance(y_test, (pd.Series, pd.DataFrame)) else np.asarray(y_test).ravel()

    # fix the set of classes (important for PR AUC / aligning probability column order)
    classes = np.unique(np.concatenate([y_tr, y_te]))

    def _score_metric(y_true, proba):
        try:
            if scoring == "roc_auc_ovr":
                return roc_auc_score(y_true, proba, multi_class="ovr", labels=classes)
            elif scoring == "pr_auc":
                y_bin = label_binarize(y_true, classes=classes)
                return average_precision_score(y_bin, proba, average="macro")
            else:
                raise ValueError(f"Unsupported metric: {scoring}")
        except Exception:
            return np.nan

    # Общий пайплайн обучение→прогноз→метрика
    def _fit_and_score(Xtr, ytr, Xte, seed):
        est = Pipeline([
            ("scaler", StandardScaler()),
            ("clf", OneVsRestClassifier(
                LogisticRegression(
                    penalty="l2",
                    C=1.0,
                    solver="lbfgs",
                    max_iter=10_000,
                    random_state=seed
                ),
                n_jobs=None
            ))
        ])
        est.fit(Xtr, ytr)
        proba_tr = est.predict_proba(Xtr)
        proba_te = est.predict_proba(Xte)
        if hasattr(est, "classes_"):
            order = [int(np.where(est.classes_ == c)[0][0]) for c in classes]
            proba_tr = proba_tr[:, order]
            proba_te = proba_te[:, order]
        train_metric = _score_metric(ytr, proba_tr)
        test_metric  = _score_metric(y_te, proba_te)
        return train_metric, test_metric

    selected: list[str] = []
    best_train_score = -np.inf
    history: list[dict] = []
    remain = list(candidate_features)

    # --- режим 1: bootstrap (как было) ---
    def bootstrap_scores(feature_set: list[str]):
        Xtr = X_train[feature_set].values
        Xte = X_test[feature_set].values

        def single_bootstrap(seed: int):
            idx = resample(np.arange(len(y_tr)), replace=True, random_state=seed)
            X_bs = Xtr[idx]
            y_bs = y_tr[idx]
            if np.unique(y_bs).size < 2:
                return np.nan, np.nan
            try:
                return _fit_and_score(X_bs, y_bs, Xte, seed)
            except Exception:
                return np.nan, np.nan

        seeds = rng.randint(0, 10**9, size=n_bootstrap)
        pairs = Parallel(n_jobs=n_jobs)(
            delayed(single_bootstrap)(int(s)) for s in seeds
        )
        pairs = np.asarray(pairs, dtype=float)
        train_scores = pairs[:, 0]
        test_scores  = pairs[:, 1]

        def _agg(x):
            return (np.nanmean(x), np.nanpercentile(x, 5), np.nanpercentile(x, 95))

        tr_mean, tr_low, tr_high = _agg(train_scores)
        te_mean, te_low, te_high = _agg(test_scores)
        return (tr_mean, tr_low, tr_high), (te_mean, te_low, te_high)

    # --- режим 2: plain train (без бутстрапа) ---
    def plain_train_scores(feature_set: list[str]):
        Xtr = X_train[feature_set].values
        Xte = X_test[feature_set].values
        try:
            tr, te = _fit_and_score(Xtr, y_tr, Xte, random_state)
        except Exception:
            tr, te = np.nan, np.nan
        # совместимость с полями *_mean/low/high
        return (tr, tr, tr), (te, te, te)

    step = 0
    while remain:
        step += 1
        iterator = tqdm(remain, desc=f"Step {step}") if use_tqdm else remain

        if selection_mode not in ("bootstrap", "train"):
            raise ValueError("selection_mode must be 'bootstrap' or 'train'")

        scorer = bootstrap_scores if selection_mode == "bootstrap" else plain_train_scores

        results = Parallel(n_jobs=n_jobs)(
            delayed(scorer)(selected + [feat]) for feat in iterator
        )

        candidates_info = []
        for feat, ((tr_m, tr_l, tr_h), (te_m, te_l, te_h)) in zip(remain, results):
            candidates_info.append({
                "feature":   feat,
                "train_mean": float(tr_m),
                "train_low":  float(tr_l),
                "train_high": float(tr_h),
                "test_mean":  float(te_m),
                "test_low":   float(te_l),
                "test_high":  float(te_h),
            })

        # ключ выбора
        if selection_mode == "bootstrap":
            if uplift_type == "mean":
                key = "train_mean"
            elif uplift_type == "low":
                key = "train_low"
            elif uplift_type == "high":
                key = "train_high"
            else:
                raise ValueError("uplift_type must be one of: 'mean', 'low', 'high'")
        else:
            # в train-режиме берем train_mean (он же = low = high)
            key = "train_mean"

        best_candidate = max(candidates_info, key=lambda x: (x[key], -np.inf if np.isnan(x[key]) else 0))

        uplift = best_candidate[key] - best_train_score
        if (min_uplift is not None) and (uplift < min_uplift):
            break

        selected.append(best_candidate["feature"])
        remain.remove(best_candidate["feature"])
        best_train_score = best_candidate[key]

        history.append({
            "feature":     best_candidate["feature"],
            "train_mean":  best_candidate["train_mean"],
            "train_low":   best_candidate["train_low"],
            "train_high":  best_candidate["train_high"],
            "test_mean":   best_candidate["test_mean"],
            "test_low":    best_candidate["test_low"],
            "test_high":   best_candidate["test_high"],
            "uplift_train": float(uplift),
            "n_selected":  len(selected),
            "selection_mode": selection_mode,   # NEW: для прозрачности в логе
        })

        if (max_features is not None) and (len(selected) >= max_features):
            break

    return selected, history

# %% [markdown]
# #### *Metric-uplift* line plot

# %%
def plot_cumulative_score_line_bootstrap(
    selection_log,
    ax=None,
    show_ci=True,
    show_test=True,
    annotate=True,
):
    # Prepare data
    df_log = pd.DataFrame(selection_log).copy()
    if df_log.empty:
        raise ValueError("selection_log is empty.")

    # Backward compatibility with old keys
    if {"score_mean", "score_low", "score_high"}.issubset(df_log.columns):
        df_log["train_mean"] = df_log["score_mean"]
        df_log["train_low"]  = df_log["score_low"]
        df_log["train_high"] = df_log["score_high"]

    req_train = {"train_mean", "train_low", "train_high"}
    if not req_train.issubset(df_log.columns):
        missing = req_train - set(df_log.columns)
        raise ValueError(f"Missing train columns: {missing}")

    df_log["Step"] = np.arange(1, len(df_log) + 1)

    created_fig = False
    if ax is None:
        fig, ax = plt.subplots(figsize=(max(6, len(df_log) * 1.2), 5), dpi=150)
        created_fig = True

    # Style from PLOT_STYLE (direct access)
    title           = PLOT_STYLE["TITLE"]
    title_fs        = PLOT_STYLE["TITLE_FONT_SIZE"]
    title_fs_style  = PLOT_STYLE["TITLE_FONTSTYLE"]
    x_label         = PLOT_STYLE["X_LABEL"]
    x_label_fs      = PLOT_STYLE["X_LABEL_FONT_SIZE"]
    x_labelpad      = PLOT_STYLE["X_LABELPAD"]
    y_label         = PLOT_STYLE["Y_LABEL"]
    y_label_fs      = PLOT_STYLE["Y_LABEL_FONT_SIZE"]
    y_labelpad      = PLOT_STYLE["Y_LABELPAD"]
    x_tick_fs       = PLOT_STYLE["X_TICK_LABEL_FONT_SIZE"]
    y_tick_fs       = PLOT_STYLE["Y_TICK_LABEL_FONT_SIZE"]
    metric_value_fs = PLOT_STYLE["METRIC_VALUE_FONT_SIZE"]

    # Fixed colors
    train_color = "#08519c"
    test_color  = "#1f77b4"

    # Train line
    line_train, = ax.plot(
        df_log["Step"],
        df_log["train_mean"],
        marker="o",
        linewidth=2,
        alpha=0.7,
        linestyle="-",
        label="Train",
        color=train_color,
    )
    if show_ci:
        ax.fill_between(
            df_log["Step"],
            df_log["train_low"],
            df_log["train_high"],
            alpha=0.20,
            color=train_color,
        )

    # Test line (nominal)
    line_test = None
    if show_test and {"test_mean","test_low","test_high"}.issubset(df_log.columns):
        line_test, = ax.plot(
            df_log["Step"],
            df_log["test_mean"],
            marker="s",
            linewidth=2,
            alpha=0.7,
            linestyle="-",
            label="Test",
            color=test_color,
        )
        if show_ci:
            ax.fill_between(
                df_log["Step"],
                df_log["test_low"],
                df_log["test_high"],
                alpha=0.20,
                color=test_color,
            )

    # Point annotations
    if annotate:
        for _, row in df_log.iterrows():
            ax.text(
                row["Step"],
                row["train_mean"] + 0.005,
                f'{row["train_mean"]:.3f}',
                ha="center",
                va="bottom",
                fontsize=metric_value_fs,
                color='black',
            )
        if line_test is not None:
            for _, row in df_log.iterrows():
                ax.text(
                    row["Step"],
                    row["test_mean"] - 0.020,
                    f'{row["test_mean"]:.3f}',
                    ha="center",
                    va="bottom",
                    fontsize=metric_value_fs,
                    color='black',
                )

    # Axes formatting
    ax.set_title(title, fontsize=title_fs, fontstyle=title_fs_style)
    ax.set_xlabel(x_label, fontsize=x_label_fs, labelpad=x_labelpad)
    ax.set_ylabel(y_label, fontsize=y_label_fs, labelpad=y_labelpad)
    ax.tick_params(axis="x", labelsize=x_tick_fs)
    ax.tick_params(axis="y", labelsize=y_tick_fs)

    # Exactly 10 ticks on Y
    ax.yaxis.set_major_locator(ticker.MaxNLocator(10))

    # Steps and labels
    ax.set_xticks(df_log["Step"])
    if "feature" in df_log.columns:
        ax.set_xticklabels(df_log["feature"], rotation=0)

    # Legend with only two line entries
    handles = [line_train] + ([line_test] if line_test is not None else [])
    labels = ["Train"] + (["Test"] if line_test is not None else [])
    ax.legend(handles, labels, loc="upper left", frameon=True)

    # Y limits padding
    y_candidates = [df_log["train_low"], df_log["train_high"], df_log["train_mean"]]
    if line_test is not None:
        y_candidates += [df_log["test_low"], df_log["test_high"], df_log["test_mean"]]
    y_min = np.nanmin([c.min() for c in y_candidates])
    y_max = np.nanmax([c.max() for c in y_candidates])
    if np.isfinite(y_min) and np.isfinite(y_max):
        pad = (y_max - y_min) * 0.06 if y_max > y_min else 0.02
        ax.set_ylim(y_min - pad, y_max + pad)

    if created_fig:
        plt.tight_layout()
        plt.show()

    return ax

# %% [markdown]
# ### Feature selection

# %%
candidate_features = []

for feature in of_features_to_save:
    feature_types_lst = feature_to_types[feature]
    for feature_type in feature_types_lst:
        candidate_features.append(feature)

print(f'Число фичей для многофакторного анализа: {len(candidate_features)}')
# Out:
# Число фичей для многофакторного анализа: 68

# %%
# %%time

selected_feats, selection_log = forward_selection_bootstrap(
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    candidate_features=candidate_features,
    scoring='roc_auc_ovr',
    min_uplift=0.005,
    max_features=4,
    n_bootstrap=50,
    uplift_type='low',  # 'mean', 'low', 'high'
    n_jobs=-1
)
# Out:
# Step 1:   0%|          | 0/68 [00:00<?, ?it/s]
# Step 2:   0%|          | 0/67 [00:00<?, ?it/s]
# Step 3:   0%|          | 0/66 [00:00<?, ?it/s]
# Step 4:   0%|          | 0/65 [00:00<?, ?it/s]
# Step 5:   0%|          | 0/64 [00:00<?, ?it/s]
# CPU times: user 553 ms, sys: 101 ms, total: 654 ms
# Wall time: 10.4 s

# %%
PLOT_STYLE = {
    'TITLE': '',
    'TITLE_FONT_SIZE': 12,
    'TITLE_FONTSTYLE': 'normal',
    'X_LABEL': '',
    'Y_LABEL': '$ROC-AUC_{ovr}$',
    'X_LABEL_FONT_SIZE': 12,
    'Y_LABEL_FONT_SIZE': 12,
    'X_TICK_LABEL_FONT_SIZE': 16,
    'Y_TICK_LABEL_FONT_SIZE': 10,
    'X_LABELPAD': 10,
    'Y_LABELPAD': 10,
    'METRIC_VALUE_FONT_SIZE': 8,
    'Y_NBINS': 10
}

# %%
fig, ax = plt.subplots(figsize=(8, 4), dpi=300)

plot_cumulative_score_line_bootstrap(
    selection_log=selection_log,
    ax=ax,
    show_ci=True
)

plt.tight_layout()
plt.savefig(f'{path_to_save}/fs_uplift_lineplot_bootstrap.svg', dpi=600)
plt.show()

# %% [markdown]
# ## Models analysis

# %% [markdown]
# ### Functions for processing

# %% [markdown]
# #### Modeling process (*scaling, `lr` fitting, cross-validation, metrics calculation*)

# %%
def logreg_bootstrap_train_test(
    X_train: pd.DataFrame,
    y_train: pd.Series,
    X_test: pd.DataFrame,
    y_test: pd.Series,
    feature_list=None,
    C_values=None,
    n_bootstrap: int = 50,
    random_state: int = 42,
    reoptimize_C_on_bootstrap: bool = True,
    solver: str = "lbfgs",
    max_iter: int = 10_000,
):
    # ---- feature selection & alignment ----
    if feature_list is not None:
        feature_list = list(feature_list)
        missing_train = [f for f in feature_list if f not in X_train.columns]
        missing_test  = [f for f in feature_list if f not in X_test.columns]
        if missing_train or missing_test:
            raise ValueError(
                f"Selected features missing:\n"
                f"- in X_train: {missing_train}\n"
                f"- in X_test : {missing_test}"
            )
        X_train_use = X_train.loc[:, feature_list].copy()
        X_test_use  = X_test.loc[:, feature_list].copy()
    else:
        # If not provided, use the intersection to be safe and keep consistent order from X_train
        common = [c for c in X_train.columns if c in X_test.columns]
        if not common:
            raise ValueError("No common features between X_train and X_test.")
        feature_list = common
        X_train_use = X_train.loc[:, feature_list].copy()
        X_test_use  = X_test.loc[:, feature_list].copy()

    # ---- grids and classes ----
    if C_values is None:
        C_values = np.logspace(-4, 4, 30)

    classes = np.unique(y_train)

    def optimize_C(X_tr_scaled, y_tr, C_grid, scoring='roc_auc'):
        """Tune C by maximizing macro ROC-AUC on the (scaled) training set."""
        scores = []
        for C in C_grid:
            clf = OneVsRestClassifier(
                LogisticRegression(C=C, solver=solver, max_iter=max_iter)
            )
            clf.fit(X_tr_scaled, y_tr)
            proba = clf.predict_proba(X_tr_scaled)
            score = roc_auc_score(y_tr, proba, multi_class='ovr', average='macro')
            scores.append(score)
        c_metric_df_ = pd.DataFrame({'C': C_grid, scoring: scores})
        best_C_ = c_metric_df_.loc[c_metric_df_[scoring].idxmax(), 'C']
        return best_C_, c_metric_df_

    def compute_metrics(y_true, proba, classes_):
        """Return macro ROC-AUC (OvR) and macro PR-AUC for multiclass."""
        roc = roc_auc_score(y_true, proba, multi_class='ovr', average='macro')
        Y_bin = label_binarize(y_true, classes=classes_)
        pr = average_precision_score(Y_bin, proba, average='macro')
        return roc, pr

    def ci_percentile(data, lower=5, upper=95):
        """Percentile-based confidence interval."""
        return float(np.percentile(data, lower)), float(np.percentile(data, upper))

    # ---- final model (tune C on full train, fit once) ----
    scaler = StandardScaler().fit(X_train_use.values)
    X_tr_scaled = scaler.transform(X_train_use.values)
    X_te_scaled = scaler.transform(X_test_use.values)

    best_C_full, c_metric_df = optimize_C(X_tr_scaled, y_train.values, C_values)

    clf_full = OneVsRestClassifier(
        LogisticRegression(C=best_C_full, solver=solver, max_iter=max_iter)
    )
    clf_full.fit(X_tr_scaled, y_train.values)

    proba_tr = clf_full.predict_proba(X_tr_scaled)
    proba_te = clf_full.predict_proba(X_te_scaled)

    roc_train_point, pr_train_point = compute_metrics(y_train.values, proba_tr, classes)
    roc_test_point,  pr_test_point  = compute_metrics(y_test.values,  proba_te, classes)

    # ---- coefficients & scaler summary ----
    coef_df = pd.DataFrame(
        [est.coef_.flatten() for est in clf_full.estimators_],
        columns=feature_list,
        index=[f'Class {c}' for c in clf_full.classes_]
    )
    coef_df['Intercept'] = [float(est.intercept_[0]) for est in clf_full.estimators_]

    scaler_df = pd.DataFrame({'Feature': feature_list, 'Mean': scaler.mean_, 'Std': scaler.scale_})

    # ---- bootstrap: CIs for train and test ----
    rng = np.random.RandomState(random_state)
    roc_train_boot, pr_train_boot = [], []
    roc_test_boot,  pr_test_boot  = [], []

    n = len(X_train_use)
    X_te_np = X_test_use.values
    y_te_np = y_test.values

    for _ in tqdm(range(n_bootstrap), desc="Calculation progress"):
        # resample indices with replacement from training set
        idx = rng.choice(n, size=n, replace=True)
        Xb = X_train_use.values[idx]
        yb = y_train.values[idx]

        # fit scaler on bootstrap sample to avoid leakage
        scaler_b = StandardScaler().fit(Xb)
        Xb_scaled = scaler_b.transform(Xb)
        Xte_scaled_b = scaler_b.transform(X_te_np)

        # optionally re-tune C inside bootstrap
        if reoptimize_C_on_bootstrap:
            C_b, _ = optimize_C(Xb_scaled, yb, C_values)
        else:
            C_b = best_C_full

        clf_b = OneVsRestClassifier(
            LogisticRegression(C=C_b, solver=solver, max_iter=max_iter)
        )
        clf_b.fit(Xb_scaled, yb)

        proba_b_tr = clf_b.predict_proba(Xb_scaled)
        proba_b_te = clf_b.predict_proba(Xte_scaled_b)

        roc_tr_b, pr_tr_b = compute_metrics(yb, proba_b_tr, classes)
        roc_te_b, pr_te_b = compute_metrics(y_te_np, proba_b_te, classes)

        roc_train_boot.append(roc_tr_b)
        pr_train_boot.append(pr_tr_b)
        roc_test_boot.append(roc_te_b)
        pr_test_boot.append(pr_te_b)

    metrics_df = pd.DataFrame({
        'ROC-AUC (macro, OvR)': {
            'Train point': round(roc_train_point, 6),
            'Test point' : round(roc_test_point,  6),
            'Train CI 5–95%': [round(x, 6) for x in ci_percentile(roc_train_boot)],
            'Test  CI 5–95%': [round(x, 6) for x in ci_percentile(roc_test_boot)],
        },
        'PR-AUC (macro)': {
            'Train point': round(pr_train_point, 6),
            'Test point' : round(pr_test_point,  6),
            'Train CI 5–95%': [round(x, 6) for x in ci_percentile(pr_train_boot)],
            'Test  CI 5–95%': [round(x, 6) for x in ci_percentile(pr_test_boot)],
        }
    })

    return clf_full, X_tr_scaled, X_te_scaled, scaler, coef_df, scaler_df, metrics_df, best_C_full, c_metric_df

# %% [markdown]
# #### `C` optimaztion visualization

# %%
def plot_c_metric_curve(c_metric_df, metric_name='roc_auc', best_C=None, ax=None):
    external_ax = ax is not None
    fig, ax = plt.subplots(figsize=PLOT_STYLE['FIGSIZE'], dpi=300) if not external_ax else (None, ax)

    sns.lineplot(
        data=c_metric_df,
        x='C',
        y=metric_name,
        color='teal',
        linewidth=3.5,
        ax=ax
    )

    ax.set_xscale('log')

    if best_C is not None:
        best_y = c_metric_df.loc[c_metric_df['C'] == best_C, metric_name].values
        if len(best_y):
            ax.axvline(x=best_C, color='darkred', linestyle='--', linewidth=1.8)
            ax.scatter(best_C, best_y[0], color='darkred', s=50, zorder=5)

    ax.set_title(PLOT_STYLE['TITLE'], fontsize=PLOT_STYLE['TITLE_FONT_SIZE'], fontstyle=PLOT_STYLE['TITLE_FONTSTYLE'])
    
    ax.set_xlabel(PLOT_STYLE['X_LABEL'], fontsize=PLOT_STYLE['X_LABEL_FONT_SIZE'], labelpad=PLOT_STYLE['X_LABELPAD'])
    ax.set_ylabel(PLOT_STYLE['Y_LABEL'], fontsize=PLOT_STYLE['Y_LABEL_FONT_SIZE'], labelpad=PLOT_STYLE['Y_LABELPAD'])
    
    ax.tick_params(axis='x', labelsize=PLOT_STYLE['X_TICK_LABEL_FONT_SIZE'])
    ax.tick_params(axis='y', labelsize=PLOT_STYLE['Y_TICK_LABEL_FONT_SIZE'])

    if not external_ax:
        plt.tight_layout()
        plt.show()

# %% [markdown]
# #### *ROC*-curves visualization

# %%
def plot_roc_curve_per_class(
    model, 
    X_train, y_train, 
    X_test, y_test, 
    class_index, ax
):
    classes = model.classes_
    y_train_bin = label_binarize(y_train, classes=classes)
    y_test_bin  = label_binarize(y_test,  classes=classes)

    # predict probabilities
    y_score_train = model.predict_proba(X_train)
    y_score_test  = model.predict_proba(X_test)

    # compute ROC curve
    fpr_tr, tpr_tr, _ = roc_curve(y_train_bin[:, class_index], y_score_train[:, class_index])
    fpr_te, tpr_te, _ = roc_curve(y_test_bin[:, class_index],  y_score_test[:,  class_index])

    # compute AUC
    auc_tr = auc(fpr_tr, tpr_tr)
    auc_te = auc(fpr_te, tpr_te)

    class_label = class_fraction_group_dict[class_index]
    class_color = type_color_dict[class_label]

    # plot train curve
    ax.plot(
        fpr_tr, tpr_tr,
        color=class_color,
        linewidth=PLOT_STYLE['LINE_WIDTH'],
        linestyle='-',
        label=fr'$ROC\text{{-}}AUC^{{train}} = {auc_tr:.2f}$'
    )

    # plot test curve
    ax.plot(
        fpr_te, tpr_te,
        color=class_color,
        linewidth=PLOT_STYLE['LINE_WIDTH'],
        linestyle='--',
        label=fr'$ROC\text{{-}}AUC^{{test}} = {auc_te:.2f}$'
    )

    # random baseline
    ax.plot([0, 1], [0, 1], linestyle=':', color='gray', linewidth=1, label='')

    # formatting
    ax.set_title(class_label, fontsize=PLOT_STYLE['TITLE_FONT_SIZE'], fontstyle=PLOT_STYLE['TITLE_FONTSTYLE'])
    ax.set_xlabel(PLOT_STYLE['X_LABEL'], fontsize=PLOT_STYLE['X_LABEL_FONT_SIZE'], labelpad=PLOT_STYLE['X_LABELPAD'])
    ax.set_ylabel(PLOT_STYLE['Y_LABEL'], fontsize=PLOT_STYLE['Y_LABEL_FONT_SIZE'], labelpad=PLOT_STYLE['Y_LABELPAD'])

    ax.tick_params(axis='x', labelsize=PLOT_STYLE['X_TICK_LABEL_FONT_SIZE'])
    ax.tick_params(axis='y', labelsize=PLOT_STYLE['Y_TICK_LABEL_FONT_SIZE'])

    if 'X_NBINS' in PLOT_STYLE:
        ax.xaxis.set_major_locator(ticker.MaxNLocator(nbins=PLOT_STYLE['X_NBINS']))
    if 'Y_NBINS' in PLOT_STYLE:
        ax.yaxis.set_major_locator(ticker.MaxNLocator(nbins=PLOT_STYLE['Y_NBINS']))

    ax.legend(loc='lower right', fontsize=PLOT_STYLE['LEGEND_FONT_SIZE'])

# %% [markdown]
# #### *SHAP*-values visualization (*beeswarm*)

# %%
def plot_shap_summary_logreg(
    model,
    X_train_scaled: pd.DataFrame,
    X_test_scaled: pd.DataFrame,
    features_lst: list[str],
    class_index: int = 0,
    max_display: int = 20,
    show_colorbar: bool = True,
    ax=None
):
    """
    Build a SHAP summary (beeswarm) for a multinomial One-vs-Rest LogisticRegression (or plain LogisticRegression)
    using a merged dataset of train + test.

    Parameters
    ----------
    model : fitted estimator
        Either OneVsRestClassifier(LogisticRegression) or LogisticRegression.
    X_train_scaled : pd.DataFrame
        Scaled train features. Must have the same columns and order as test.
    X_test_scaled : pd.DataFrame
        Scaled test features. Must have the same columns and order as train.
    features_lst : list[str]
        Feature names in the order matching columns of X_*_scaled.
    class_index : int
        Index of the class to explain when model is OneVsRestClassifier.
    max_display : int
        Max number of features to display in the beeswarm.
    show_colorbar : bool
        Whether to show SHAP colorbar.
    ax : matplotlib.axes.Axes | None
        Axis to draw on. If None, a new figure/axis is created.

    Notes
    -----
    - We merge X_train and X_test vertically and compute SHAP values on the merged matrix.
    - Color encodes feature values (default SHAP behavior).
    - If your model is OVR, we pick `estimators_[class_index]`.
    """

    # pick base binary logistic regression if it is OneVsRestClassifier
    base_model = model.estimators_[class_index] if hasattr(model, 'estimators_') else model

    # sanity checks on columns
    if list(X_train_scaled.columns) != list(X_test_scaled.columns):
        raise ValueError("Train/Test columns (order) must match exactly.")
    if features_lst and list(X_train_scaled.columns) != list(features_lst):
        # keep behavior predictable: columns should match features_lst
        raise ValueError("features_lst must match X_*_scaled columns order.")

    # merge train + test by rows
    X_merged = pd.concat([X_train_scaled, X_test_scaled], axis=0, ignore_index=True)

    # build explainer on merged data (interventional background = merged)
    explainer = shap.LinearExplainer(base_model, X_merged, feature_perturbation='interventional')

    # compute SHAP values for merged matrix
    shap_values = explainer(X_merged)
    shap_values.feature_names = list(features_lst)

    # figure/axis handling
    external_ax = ax is not None
    fig, ax = plt.subplots(figsize=PLOT_STYLE['FIGSIZE']) if ax is None else (plt.gcf(), ax)

    # draw beeswarm for merged data
    shap.plots.beeswarm(
        shap_values,
        max_display=max_display,
        show=False,
        color_bar=show_colorbar,
        ax=ax,
        s=PLOT_STYLE.get('DOT_SIZE', 12),
        plot_size=None
    )

    # titles/labels/ticks styling
    ax.set_title(
        PLOT_STYLE['TITLE'],
        fontsize=PLOT_STYLE['TITLE_FONT_SIZE'],
        fontstyle=PLOT_STYLE['TITLE_FONTSTYLE']
    )
    ax.set_xlabel(
        PLOT_STYLE['X_LABEL'],
        fontsize=PLOT_STYLE['X_LABEL_FONT_SIZE'],
        labelpad=PLOT_STYLE['X_LABELPAD']
    )
    ax.set_ylabel(
        PLOT_STYLE['Y_LABEL'],
        fontsize=PLOT_STYLE['Y_LABEL_FONT_SIZE'],
        labelpad=PLOT_STYLE['Y_LABELPAD']
    )
    ax.tick_params(axis='x', labelsize=PLOT_STYLE['X_TICK_LABEL_FONT_SIZE'])
    ax.tick_params(axis='y', labelsize=PLOT_STYLE['Y_TICK_LABEL_FONT_SIZE'])

    if 'X_NBINS' in PLOT_STYLE:
        ax.xaxis.set_major_locator(ticker.MaxNLocator(nbins=PLOT_STYLE['X_NBINS']))

    # style SHAP colorbar (which SHAP draws as a separate axis) if present
    if show_colorbar:
        current_fig = plt.gcf()
        for other_ax in current_fig.axes:
            # heuristic: SHAP colorbar axis has no xticks and has yticks
            if other_ax is not ax and len(other_ax.get_xticks()) == 0 and len(other_ax.get_yticks()) > 0:
                other_ax.set_ylabel(PLOT_STYLE['LEGEND_TITLE'], fontsize=PLOT_STYLE['LEGEND_FONT_SIZE'])
                other_ax.tick_params(labelsize=PLOT_STYLE['LEGEND_FONT_SIZE'])
                if 'COLORBAR_TICKS' in PLOT_STYLE:
                    other_ax.set_yticklabels(PLOT_STYLE['COLORBAR_TICKS'])

    if not external_ax:
        plt.tight_layout()
        plt.show()

# %% [markdown]
# ### Model investigation

# %% [markdown]
# #### Model fitting

# %%
model, X_tr_scaled, X_te_scaled, scaler, coef_df, scaler_df, metrics_df, best_C_full, c_metric_df = logreg_bootstrap_train_test(
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    feature_list=selected_feats,
    C_values=np.logspace(-8, 8, 50),
    n_bootstrap=50,
    random_state=42
)
# Out:
# Calculation progress:   0%|          | 0/50 [00:00<?, ?it/s]

# %%
X_tr_scaled = pd.DataFrame(X_tr_scaled, columns=selected_feats)

print(X_tr_scaled.shape)
X_tr_scaled.head(3)
# Out:
# (59, 4)
#    $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# 0                                                       -0.937540
# 1                                                       -0.596159
# 2                                                       -0.416408
#
#    $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# 0                                                             0.167934
# 1                                                             0.028365
# 2                                                             0.515073
#
#    $\frac{I_{1241}}{\overline{I}_{1182 \pm 25}}$  $\frac{I_{872}}{I_{1085}}$
# 0                                       0.628137                   -1.015564
# 1                                       0.214383                   -0.696349
# 2                                      -0.532854                   -0.781568

# %%
X_te_scaled = pd.DataFrame(X_te_scaled, columns=selected_feats)

print(X_te_scaled.shape)
X_te_scaled.head(3)
# Out:
# (15, 4)
#    $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# 0                                                       -0.930439
# 1                                                        1.437785
# 2                                                        2.076210
#
#    $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# 0                                                             1.015670
# 1                                                             0.104545
# 2                                                             0.255269
#
#    $\frac{I_{1241}}{\overline{I}_{1182 \pm 25}}$  $\frac{I_{872}}{I_{1085}}$
# 0                                      -0.192757                   -1.082319
# 1                                      -0.496627                    0.647904
# 2                                      -0.601077                    1.176218

# %% [markdown]
# *Parameters for scaling*

# %%
display(scaler_df.T)
# Out:
#                                                                       0  \
# Feature  $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1241 \pm 25}}$
# Mean                                                           0.416396
# Std                                                            0.331602
#
#                                                                            1  \
# Feature  $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1241 \pm 25}}$
# Mean                                                                0.879911
# Std                                                                 0.401603
#
#                                                      2  \
# Feature  $\frac{I_{1241}}{\overline{I}_{1182 \pm 25}}$
# Mean                                          0.934636
# Std                                           0.325505
#
#                                   3
# Feature  $\frac{I_{872}}{I_{1085}}$
# Mean                        0.32688
# Std                        0.252785

# %% [markdown]
# *Model parameters (weights & intercept)*

# %%
display(coef_df)
# Out:
#          $\frac{\overline{I}_{872 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# Class 0                                                        1.091597
# Class 1                                                       -1.078578
# Class 2                                                      -34.614522
#
#          $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# Class 0                                                             1.556751
# Class 1                                                             0.187339
# Class 2                                                           -69.401947
#
#          $\frac{I_{1241}}{\overline{I}_{1182 \pm 25}}$  \
# Class 0                                      -1.106477
# Class 1                                      -0.530552
# Class 2                                      34.610726
#
#          $\frac{I_{872}}{I_{1085}}$  Intercept
# Class 0                    0.712826  -1.641749
# Class 1                    1.373964  -0.581256
# Class 2                  -19.743505 -47.307773

# %% [markdown]
# *Model metrics*

# %%
display(metrics_df)
# Out:
#                 ROC-AUC (macro, OvR)        PR-AUC (macro)
# Train point                 0.935193              0.886766
# Test point                  0.738215              0.641777
# Train CI 5–95%  [0.911475, 0.977622]  [0.841112, 0.961581]
# Test  CI 5–95%   [0.65853, 0.814212]  [0.579957, 0.729854]

# %% [markdown]
# *Optimal inverse of regulation strength value*

# %% [markdown]
# #### Visualization of `C` optimization

# %%
print(f'Optimal value of regularization coefficient (C): {round(best_C_full, 4)}')
# Out:
# Optimal value of regularization coefficient (C): 54286.7544

# %%
PLOT_STYLE = {
    'FIGSIZE': (10, 3.3),
    'TITLE': '',
    'TITLE_FONT_SIZE': 14,
    'TITLE_FONTSTYLE': 'normal',
    'X_LABEL': 'Обратный коэффициент регуляризации ($C$)',
    'Y_LABEL': '$ROC-AUC_{ovr}$',
    'X_LABEL_FONT_SIZE': 12,
    'Y_LABEL_FONT_SIZE': 12,
    'X_LABELPAD': 6,
    'Y_LABELPAD': 6,
    'X_TICK_LABEL_FONT_SIZE': 12,
    'Y_TICK_LABEL_FONT_SIZE': 11
}

# %%
fig, ax = plt.subplots(figsize=PLOT_STYLE['FIGSIZE'], dpi=300)

plot_c_metric_curve(
    c_metric_df=c_metric_df,
    metric_name='roc_auc',
    best_C=best_C_full,
    ax=ax
)

plt.tight_layout()

plt.savefig(f'{path_to_save}/c_optimization_curve.svg', dpi=600)

plt.show()

# %% [markdown]
# #### *ROC*-curves visualization

# %%
PLOT_STYLE = {
    'FIGSIZE': (10, 4),
    'TITLE_FONT_SIZE': 16,
    'TITLE_FONTSTYLE': 'normal',
    'X_LABEL': 'False Positive Rate',
    'Y_LABEL': 'True Positive Rate',
    'X_LABEL_FONT_SIZE': 14,
    'Y_LABEL_FONT_SIZE': 14,
    'X_TICK_LABEL_FONT_SIZE': 12,
    'Y_TICK_LABEL_FONT_SIZE': 12,
    'X_LABELPAD': 6,
    'Y_LABELPAD': 6,
    'LEGEND_FONT_SIZE': 10,
    'X_NBINS': 6,
    'Y_NBINS': 6,
    'LINE_WIDTH': 2.5
}

# %%
fig, axes = plt.subplots(1, 3, figsize=PLOT_STYLE['FIGSIZE'], dpi=300)
axes = axes.flat

for i, ax in enumerate(axes):
    plot_roc_curve_per_class(
        model=model,
        X_train=X_tr_scaled,
        y_train=y_train,
        X_test=X_te_scaled,
        y_test=y_test,
        class_index=i,
        ax=ax
    )

plt.tight_layout()
plt.savefig(f'{path_to_save}/roc_curves_train_test.svg')
plt.show()

# %% [markdown]
# #### *SHAP-values* diagram

# %%
PLOT_STYLE = {
    'FIGSIZE': (14, 5),
    'TITLE': '',
    'TITLE_FONT_SIZE': 16,
    'TITLE_FONTSTYLE': 'normal',
    'X_LABEL': '$SHAP$ value',
    'Y_LABEL': '',
    'X_LABEL_FONT_SIZE': 14,
    'Y_LABEL_FONT_SIZE': 12,
    'X_TICK_LABEL_FONT_SIZE': 12,
    'Y_TICK_LABEL_FONT_SIZE': 20,
    'X_LABELPAD': 8,
    'Y_LABELPAD': 20,
    'DOT_SIZE': 64,
    'LEGEND_TITLE': 'Значение признака',
    'LEGEND_FONT_SIZE': 14,
    'X_NBINS': 6,
    'COLORBAR_TICKS': ['Низкое', 'Высокое']
}

# %%
nrows, ncols = 1, 3
fig, axes = plt.subplots(nrows, ncols, figsize=PLOT_STYLE['FIGSIZE'], dpi=300)
axes = axes.flat

for i, ax in enumerate(axes):
    show_colorbar = (i == ncols - 1)  # show only on the last subplot
    PLOT_STYLE['TITLE'] = class_fraction_group_dict[i]  # заголовок как раньше

    plot_shap_summary_logreg(
        model=model,
        X_train_scaled=X_tr_scaled,
        X_test_scaled=X_te_scaled,
        features_lst=X_tr_scaled.columns.tolist(),
        class_index=i,
        max_display=20,
        show_colorbar=show_colorbar,
        ax=ax
    )

plt.tight_layout()
plt.savefig(f'{path_to_save}/shap_3_subplots.svg')
plt.show()
