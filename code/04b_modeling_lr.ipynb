# %% [markdown]
# # Import libraries

# %%
import os
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.cm as cm

import seaborn as sns

import math

import json

import re

import shap

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import label_binarize

from sklearn.model_selection import cross_validate
from sklearn.model_selection import StratifiedKFold

from sklearn.utils import resample

from sklearn.multiclass import OneVsRestClassifier

from sklearn.linear_model import LogisticRegression

from sklearn.pipeline import Pipeline

from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn.metrics import make_scorer
from sklearn.metrics import confusion_matrix

from scipy.stats import t

from joblib import Parallel
from joblib import delayed
from tqdm_joblib import tqdm_joblib

from itertools import combinations

from collections import defaultdict

from tqdm.notebook import tqdm

# %%
warnings.filterwarnings("ignore")

np.seterr(all='ignore')

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', None)

# %%
path_to_save = './../results/04b_modeling_lr'

# %% [markdown]
# # Loading data

# %%
path_to_ftir_data = './../data/processed_data/dataset_1900_800_engineered.csv'
path_to_features_description = './../data/processed_data/features_description_1900_800.json'

# %% [markdown]
# ## FTIR-features (*long-list*)

# %%
dataset = pd.read_csv(path_to_ftir_data, sep=';', index_col=0)

print(dataset.shape)
dataset.head(3)
# Out:
# (75, 491)
#                       $I_{874}$  $I_{1084}$  $I_{1182}$  $I_{1241}$  \
# division_1_size_bulk   0.048493    0.681294    0.388923    0.455066
# division_1_size_5      0.092297    0.578199    0.416593    0.427988
# division_1_size_3      0.112416    0.836176    0.514367    0.400950
#
#                       $I_{1393}$  $I_{1541}$  $I_{1625}$  $I_{1725}$  \
# division_1_size_bulk    0.760582    0.367672         1.0    0.423273
# division_1_size_5       0.687458    0.297496         1.0    0.384475
# division_1_size_3       0.696553    0.461156         1.0    0.368753
#
#                       $\overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                          0.424162
# division_1_size_5                             0.378730
# division_1_size_3                             0.436266
#
#                       $\Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                          4.125303
# division_1_size_5                             3.884505
# division_1_size_3                             4.390371
#
#                       $\overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                           0.426619
# division_1_size_5                              0.378004
# division_1_size_3                              0.429362
#
#                       $\Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                           1.790945
# division_1_size_5                              1.681970
# division_1_size_3                              1.829909
#
#                       $\overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                           0.571735
# division_1_size_5                              0.502368
# division_1_size_3                              0.523513
#
#                       $\Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                           0.760582
# division_1_size_5                              0.687458
# division_1_size_3                              0.696553
#
#                       $\overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                          0.363338
# division_1_size_5                             0.329999
# division_1_size_3                             0.406988
#
#                       $\Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                          1.573776
# division_1_size_5                             1.515076
# division_1_size_3                             1.863909
#
#                       $\overline{I}_{874 \pm 16}$  \
# division_1_size_bulk                     0.047265
# division_1_size_5                        0.092791
# division_1_size_3                        0.112733
#
#                       $\overline{I}_{874 \pm 32}$  \
# division_1_size_bulk                     0.048014
# division_1_size_5                        0.094425
# division_1_size_3                        0.115579
#
#                       $\overline{I}_{1084 \pm 16}$  \
# division_1_size_bulk                      0.662496
# division_1_size_5                         0.574190
# division_1_size_3                         0.776369
#
#                       $\overline{I}_{1084 \pm 32}$  \
# division_1_size_bulk                      0.657082
# division_1_size_5                         0.561949
# division_1_size_3                         0.765984
#
#                       $\overline{I}_{1182 \pm 16}$  \
# division_1_size_bulk                      0.392509
# division_1_size_5                         0.420000
# division_1_size_3                         0.518442
#
#                       $\overline{I}_{1182 \pm 32}$  \
# division_1_size_bulk                      0.405814
# division_1_size_5                         0.431030
# division_1_size_3                         0.532188
#
#                       $\overline{I}_{1241 \pm 16}$  \
# division_1_size_bulk                      0.452149
# division_1_size_5                         0.426729
# division_1_size_3                         0.400848
#
#                       $\overline{I}_{1241 \pm 32}$  \
# division_1_size_bulk                      0.446270
# division_1_size_5                         0.424209
# division_1_size_3                         0.402630
#
#                       $\overline{I}_{1393 \pm 16}$  \
# division_1_size_bulk                      0.750393
# division_1_size_5                         0.678639
# division_1_size_3                         0.688316
#
#                       $\overline{I}_{1393 \pm 32}$  \
# division_1_size_bulk                      0.728337
# division_1_size_5                         0.657626
# division_1_size_3                         0.668191
#
#                       $\overline{I}_{1541 \pm 16}$  \
# division_1_size_bulk                      0.375020
# division_1_size_5                         0.305844
# division_1_size_3                         0.466881
#
#                       $\overline{I}_{1541 \pm 32}$  \
# division_1_size_bulk                      0.398300
# division_1_size_5                         0.331232
# division_1_size_3                         0.484095
#
#                       $\overline{I}_{1625 \pm 16}$  \
# division_1_size_bulk                      0.977345
# division_1_size_5                         0.978445
# division_1_size_3                         0.980602
#
#                       $\overline{I}_{1625 \pm 32}$  \
# division_1_size_bulk                      0.926084
# division_1_size_5                         0.923387
# division_1_size_3                         0.939339
#
#                       $\overline{I}_{1725 \pm 16}$  \
# division_1_size_bulk                      0.419742
# division_1_size_5                         0.381089
# division_1_size_3                         0.367814
#
#                       $\overline{I}_{1725 \pm 32}$  $\log I_{874}$  \
# division_1_size_bulk                      0.415811       -3.026334
# division_1_size_5                         0.376149       -2.382747
# division_1_size_3                         0.371003       -2.185546
#
#                       $(I_{874})^{-1}$  $\log I_{1084}$  $(I_{1084})^{-1}$  \
# division_1_size_bulk         20.621489        -0.383761           1.467794
# division_1_size_5            10.834628        -0.547838           1.729510
# division_1_size_3             8.895503        -0.178917           1.195921
#
#                       $\log I_{1182}$  $(I_{1182})^{-1}$  $\log I_{1241}$  \
# division_1_size_bulk        -0.944375           2.571206        -0.787312
# division_1_size_5           -0.875645           2.400424        -0.848660
# division_1_size_3           -0.664819           1.944138        -0.913918
#
#                       $(I_{1241})^{-1}$  $\log I_{1393}$  $(I_{1393})^{-1}$  \
# division_1_size_bulk           2.197482        -0.273672           1.314783
# division_1_size_5              2.336514        -0.374754           1.454634
# division_1_size_3              2.494076        -0.361611           1.435640
#
#                       $\log I_{1541}$  $(I_{1541})^{-1}$  $\log I_{1625}$  \
# division_1_size_bulk        -1.000564           2.719814              0.0
# division_1_size_5           -1.212356           3.361394              0.0
# division_1_size_3           -0.774019           2.168463              0.0
#
#                       $(I_{1625})^{-1}$  $\log I_{1725}$  $(I_{1725})^{-1}$  \
# division_1_size_bulk                1.0        -0.859739           2.362543
# division_1_size_5                   1.0        -0.955877           2.600952
# division_1_size_3                   1.0        -0.997629           2.711845
#
#                       $\log \overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                              -0.857641
# division_1_size_5                                 -0.970931
# division_1_size_3                                 -0.829504
#
#                       $(\overline{I}_{1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.357591
# division_1_size_5                                    2.640400
# division_1_size_3                                    2.292181
#
#                       $\log \Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                               1.417139
# division_1_size_5                                  1.356996
# division_1_size_3                                  1.479414
#
#                       $(\Sigma I_{p,\ 1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.242406
# division_1_size_5                                    0.257433
# division_1_size_3                                    0.227771
#
#                       $\log \overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                               -0.851863
# division_1_size_5                                  -0.972851
# division_1_size_3                                  -0.845455
#
#                       $(\overline{I}_{1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  2.344010
# division_1_size_5                                     2.645477
# division_1_size_3                                     2.329038
#
#                       $\log \Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                                0.582743
# division_1_size_5                                   0.519966
# division_1_size_3                                   0.604266
#
#                       $(\Sigma I_{p,\ 1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  0.558364
# division_1_size_5                                     0.594541
# division_1_size_3                                     0.546475
#
#                       $\log \overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                               -0.559080
# division_1_size_5                                  -0.688422
# division_1_size_3                                  -0.647194
#
#                       $(\overline{I}_{1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.749062
# division_1_size_5                                     1.990572
# division_1_size_3                                     1.910173
#
#                       $\log \Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                               -0.273672
# division_1_size_5                                  -0.374754
# division_1_size_3                                  -0.361611
#
#                       $(\Sigma I_{p,\ 1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.314783
# division_1_size_5                                     1.454634
# division_1_size_3                                     1.435640
#
#                       $\log \overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                              -1.012422
# division_1_size_5                                 -1.108665
# division_1_size_3                                 -0.898970
#
#                       $(\overline{I}_{1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.752259
# division_1_size_5                                    3.030309
# division_1_size_3                                    2.457072
#
#                       $\log \Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                               0.453478
# division_1_size_5                                  0.415466
# division_1_size_3                                  0.622676
#
#                       $(\Sigma I_{p,\ 1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.635414
# division_1_size_5                                    0.660033
# division_1_size_3                                    0.536507
#
#                       $\log \overline{I}_{874 \pm 16}$  \
# division_1_size_bulk                         -3.051984
# division_1_size_5                            -2.377410
# division_1_size_3                            -2.182731
#
#                       $(\overline{I}_{874 \pm 16})^{-1}$  \
# division_1_size_bulk                           21.157274
# division_1_size_5                              10.776958
# division_1_size_3                               8.870495
#
#                       $\log \overline{I}_{874 \pm 32}$  \
# division_1_size_bulk                         -3.036257
# division_1_size_5                            -2.359950
# division_1_size_3                            -2.157802
#
#                       $(\overline{I}_{874 \pm 32})^{-1}$  \
# division_1_size_bulk                           20.827141
# division_1_size_5                              10.590420
# division_1_size_3                               8.652097
#
#                       $\log \overline{I}_{1084 \pm 16}$  \
# division_1_size_bulk                          -0.411741
# division_1_size_5                             -0.554795
# division_1_size_3                             -0.253127
#
#                       $(\overline{I}_{1084 \pm 16})^{-1}$  \
# division_1_size_bulk                             1.509444
# division_1_size_5                                1.741583
# division_1_size_3                                1.288047
#
#                       $\log \overline{I}_{1084 \pm 32}$  \
# division_1_size_bulk                          -0.419947
# division_1_size_5                             -0.576345
# division_1_size_3                             -0.266595
#
#                       $(\overline{I}_{1084 \pm 32})^{-1}$  \
# division_1_size_bulk                             1.521881
# division_1_size_5                                1.779522
# division_1_size_3                                1.305511
#
#                       $\log \overline{I}_{1182 \pm 16}$  \
# division_1_size_bulk                          -0.935195
# division_1_size_5                             -0.867500
# division_1_size_3                             -0.656926
#
#                       $(\overline{I}_{1182 \pm 16})^{-1}$  \
# division_1_size_bulk                             2.547710
# division_1_size_5                                2.380950
# division_1_size_3                                1.928854
#
#                       $\log \overline{I}_{1182 \pm 32}$  \
# division_1_size_bulk                          -0.901862
# division_1_size_5                             -0.841577
# division_1_size_3                             -0.630758
#
#                       $(\overline{I}_{1182 \pm 32})^{-1}$  \
# division_1_size_bulk                             2.464186
# division_1_size_5                                2.320023
# division_1_size_3                                1.879034
#
#                       $\log \overline{I}_{1241 \pm 16}$  \
# division_1_size_bulk                          -0.793744
# division_1_size_5                             -0.851606
# division_1_size_3                             -0.914173
#
#                       $(\overline{I}_{1241 \pm 16})^{-1}$  \
# division_1_size_bulk                             2.211661
# division_1_size_5                                2.343408
# division_1_size_3                                2.494711
#
#                       $\log \overline{I}_{1241 \pm 32}$  \
# division_1_size_bulk                          -0.806831
# division_1_size_5                             -0.857530
# division_1_size_3                             -0.909738
#
#                       $(\overline{I}_{1241 \pm 32})^{-1}$  \
# division_1_size_bulk                             2.240797
# division_1_size_5                                2.357331
# division_1_size_3                                2.483671
#
#                       $\log \overline{I}_{1393 \pm 16}$  \
# division_1_size_bulk                          -0.287159
# division_1_size_5                             -0.387665
# division_1_size_3                             -0.373508
#
#                       $(\overline{I}_{1393 \pm 16})^{-1}$  \
# division_1_size_bulk                             1.332636
# division_1_size_5                                1.473537
# division_1_size_3                                1.452822
#
#                       $\log \overline{I}_{1393 \pm 32}$  \
# division_1_size_bulk                          -0.316992
# division_1_size_5                             -0.419119
# division_1_size_3                             -0.403181
#
#                       $(\overline{I}_{1393 \pm 32})^{-1}$  \
# division_1_size_bulk                             1.372991
# division_1_size_5                                1.520621
# division_1_size_3                                1.496578
#
#                       $\log \overline{I}_{1541 \pm 16}$  \
# division_1_size_bulk                          -0.980775
# division_1_size_5                             -1.184680
# division_1_size_3                             -0.761681
#
#                       $(\overline{I}_{1541 \pm 16})^{-1}$  \
# division_1_size_bulk                             2.666523
# division_1_size_5                                3.269642
# division_1_size_3                                2.141873
#
#                       $\log \overline{I}_{1541 \pm 32}$  \
# division_1_size_bulk                          -0.920549
# division_1_size_5                             -1.104936
# division_1_size_3                             -0.725474
#
#                       $(\overline{I}_{1541 \pm 32})^{-1}$  \
# division_1_size_bulk                             2.510669
# division_1_size_5                                3.019031
# division_1_size_3                                2.065710
#
#                       $\log \overline{I}_{1625 \pm 16}$  \
# division_1_size_bulk                          -0.022916
# division_1_size_5                             -0.021791
# division_1_size_3                             -0.019589
#
#                       $(\overline{I}_{1625 \pm 16})^{-1}$  \
# division_1_size_bulk                             1.023181
# division_1_size_5                                1.022030
# division_1_size_3                                1.019782
#
#                       $\log \overline{I}_{1625 \pm 32}$  \
# division_1_size_bulk                          -0.076790
# division_1_size_5                             -0.079707
# division_1_size_3                             -0.062579
#
#                       $(\overline{I}_{1625 \pm 32})^{-1}$  \
# division_1_size_bulk                             1.079816
# division_1_size_5                                1.082970
# division_1_size_3                                1.064578
#
#                       $\log \overline{I}_{1725 \pm 16}$  \
# division_1_size_bulk                          -0.868116
# division_1_size_5                             -0.964723
# division_1_size_3                             -1.000179
#
#                       $(\overline{I}_{1725 \pm 16})^{-1}$  \
# division_1_size_bulk                             2.382418
# division_1_size_5                                2.624062
# division_1_size_3                                2.718768
#
#                       $\log \overline{I}_{1725 \pm 32}$  \
# division_1_size_bulk                          -0.877525
# division_1_size_5                             -0.977770
# division_1_size_3                             -0.991544
#
#                       $(\overline{I}_{1725 \pm 32})^{-1}$  \
# division_1_size_bulk                             2.404941
# division_1_size_5                                2.658520
# division_1_size_3                                2.695394
#
#                       $\frac{I_{874}}{I_{1084}}$  $\frac{I_{874}}{I_{1182}}$  \
# division_1_size_bulk                    0.071178                    0.124686
# division_1_size_5                       0.159628                    0.221551
# division_1_size_3                       0.134441                    0.218553
#
#                       $\frac{I_{874}}{I_{1241}}$  $\frac{I_{874}}{I_{1393}}$  \
# division_1_size_bulk                    0.106563                    0.063758
# division_1_size_5                       0.215652                    0.134258
# division_1_size_3                       0.280375                    0.161389
#
#                       $\frac{I_{874}}{I_{1541}}$  $\frac{I_{874}}{I_{1625}}$  \
# division_1_size_bulk                    0.131892                    0.048493
# division_1_size_5                       0.310245                    0.092297
# division_1_size_3                       0.243771                    0.112416
#
#                       $\frac{I_{874}}{I_{1725}}$  \
# division_1_size_bulk                    0.114567
# division_1_size_5                       0.240059
# division_1_size_3                       0.304856
#
#                       $\frac{I_{874}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                          0.114327
# division_1_size_5                                             0.243700
# division_1_size_3                                             0.257679
#
#                       $\frac{I_{874}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                          0.011755
# division_1_size_5                                             0.023760
# division_1_size_3                                             0.025605
#
#                       $\frac{I_{874}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.113668
# division_1_size_5                                              0.244169
# division_1_size_3                                              0.261822
#
#                       $\frac{I_{874}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.027077
# division_1_size_5                                              0.054874
# division_1_size_3                                              0.061433
#
#                       $\frac{I_{874}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.084817
# division_1_size_5                                              0.183723
# division_1_size_3                                              0.214735
#
#                       $\frac{I_{874}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.063758
# division_1_size_5                                              0.134258
# division_1_size_3                                              0.161389
#
#                       $\frac{I_{874}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                          0.133466
# division_1_size_5                                             0.279687
# division_1_size_3                                             0.276215
#
#                       $\frac{I_{874}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                          0.030813
# division_1_size_5                                             0.060919
# division_1_size_3                                             0.060312
#
#                       $\frac{I_{874}}{\overline{I}_{1084 \pm 16}}$  \
# division_1_size_bulk                                      0.073198
# division_1_size_5                                         0.160742
# division_1_size_3                                         0.144798
#
#                       $\frac{I_{874}}{\overline{I}_{1084 \pm 32}}$  \
# division_1_size_bulk                                      0.073801
# division_1_size_5                                         0.164244
# division_1_size_3                                         0.146761
#
#                       $\frac{I_{874}}{\overline{I}_{1182 \pm 16}}$  \
# division_1_size_bulk                                      0.123546
# division_1_size_5                                         0.219754
# division_1_size_3                                         0.216835
#
#                       $\frac{I_{874}}{\overline{I}_{1182 \pm 32}}$  \
# division_1_size_bulk                                      0.119496
# division_1_size_5                                         0.214130
# division_1_size_3                                         0.211234
#
#                       $\frac{I_{874}}{\overline{I}_{1241 \pm 16}}$  \
# division_1_size_bulk                                      0.107250
# division_1_size_5                                         0.216289
# division_1_size_3                                         0.280446
#
#                       $\frac{I_{874}}{\overline{I}_{1241 \pm 32}}$  \
# division_1_size_bulk                                      0.108663
# division_1_size_5                                         0.217574
# division_1_size_3                                         0.279205
#
#                       $\frac{I_{874}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                      0.064624
# division_1_size_5                                         0.136003
# division_1_size_3                                         0.163321
#
#                       $\frac{I_{874}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                      0.066581
# division_1_size_5                                         0.140348
# division_1_size_3                                         0.168240
#
#                       $\frac{I_{874}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                      0.129308
# division_1_size_5                                         0.301777
# division_1_size_3                                         0.240782
#
#                       $\frac{I_{874}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                      0.121750
# division_1_size_5                                         0.278646
# division_1_size_3                                         0.232220
#
#                       $\frac{I_{874}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                      0.049617
# division_1_size_5                                         0.094330
# division_1_size_3                                         0.114640
#
#                       $\frac{I_{874}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                      0.052364
# division_1_size_5                                         0.099955
# division_1_size_3                                         0.119676
#
#                       $\frac{I_{874}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                      0.115531
# division_1_size_5                                         0.242192
# division_1_size_3                                         0.305634
#
#                       $\frac{I_{874}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                      0.116623
# division_1_size_5                                         0.245373
# division_1_size_3                                         0.303006
#
#                       $\frac{I_{1084}}{I_{1182}}$  \
# division_1_size_bulk                     1.751748
# division_1_size_5                        1.387922
# division_1_size_3                        1.625641
#
#                       $\frac{I_{1084}}{I_{1241}}$  \
# division_1_size_bulk                     1.497132
# division_1_size_5                        1.350969
# division_1_size_3                        2.085485
#
#                       $\frac{I_{1084}}{I_{1393}}$  \
# division_1_size_bulk                     0.895754
# division_1_size_5                        0.841067
# division_1_size_3                        1.200447
#
#                       $\frac{I_{1084}}{I_{1541}}$  \
# division_1_size_bulk                     1.852994
# division_1_size_5                        1.943553
# division_1_size_3                        1.813216
#
#                       $\frac{I_{1084}}{I_{1625}}$  \
# division_1_size_bulk                     0.681294
# division_1_size_5                        0.578199
# division_1_size_3                        0.836176
#
#                       $\frac{I_{1084}}{I_{1725}}$  \
# division_1_size_bulk                     1.609587
# division_1_size_5                        1.503866
# division_1_size_3                        2.267579
#
#                       $\frac{I_{1084}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.606214
# division_1_size_5                                              1.526676
# division_1_size_3                                              1.916666
#
#                       $\frac{I_{1084}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.165150
# division_1_size_5                                              0.148847
# division_1_size_3                                              0.190457
#
#                       $\frac{I_{1084}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.596961
# division_1_size_5                                               1.529611
# division_1_size_3                                               1.947485
#
#                       $\frac{I_{1084}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.380411
# division_1_size_5                                               0.343763
# division_1_size_3                                               0.456949
#
#                       $\frac{I_{1084}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.191626
# division_1_size_5                                               1.150946
# division_1_size_3                                               1.597240
#
#                       $\frac{I_{1084}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.895754
# division_1_size_5                                               0.841067
# division_1_size_3                                               1.200447
#
#                       $\frac{I_{1084}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.875098
# division_1_size_5                                              1.752120
# division_1_size_3                                              2.054544
#
#                       $\frac{I_{1084}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.432904
# division_1_size_5                                              0.381630
# division_1_size_3                                              0.448614
#
#                       $\frac{I_{1084}}{\overline{I}_{874 \pm 16}}$  \
# division_1_size_bulk                                     14.414330
# division_1_size_5                                         6.231222
# division_1_size_3                                         7.417292
#
#                       $\frac{I_{1084}}{\overline{I}_{874 \pm 32}}$  \
# division_1_size_bulk                                     14.189412
# division_1_size_5                                         6.123365
# division_1_size_3                                         7.234673
#
#                       $\frac{I_{1084}}{\overline{I}_{1182 \pm 16}}$  \
# division_1_size_bulk                                       1.735740
# division_1_size_5                                          1.376662
# division_1_size_3                                          1.612861
#
#                       $\frac{I_{1084}}{\overline{I}_{1182 \pm 32}}$  \
# division_1_size_bulk                                       1.678836
# division_1_size_5                                          1.341434
# division_1_size_3                                          1.571203
#
#                       $\frac{I_{1084}}{\overline{I}_{1241 \pm 16}}$  \
# division_1_size_bulk                                       1.506792
# division_1_size_5                                          1.354955
# division_1_size_3                                          2.086017
#
#                       $\frac{I_{1084}}{\overline{I}_{1241 \pm 32}}$  \
# division_1_size_bulk                                       1.526642
# division_1_size_5                                          1.363005
# division_1_size_3                                          2.076785
#
#                       $\frac{I_{1084}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                       0.907917
# division_1_size_5                                          0.851997
# division_1_size_3                                          1.214814
#
#                       $\frac{I_{1084}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                       0.935411
# division_1_size_5                                          0.879221
# division_1_size_3                                          1.251402
#
#                       $\frac{I_{1084}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                       1.816687
# division_1_size_5                                          1.890502
# division_1_size_3                                          1.790982
#
#                       $\frac{I_{1084}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                       1.710504
# division_1_size_5                                          1.745599
# division_1_size_3                                          1.727296
#
#                       $\frac{I_{1084}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                       0.697087
# division_1_size_5                                          0.590936
# division_1_size_3                                          0.852717
#
#                       $\frac{I_{1084}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                       0.735672
# division_1_size_5                                          0.626172
# division_1_size_3                                          0.890175
#
#                       $\frac{I_{1084}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                       1.623128
# division_1_size_5                                          1.517229
# division_1_size_3                                          2.273368
#
#                       $\frac{I_{1084}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                       1.638473
# division_1_size_5                                          1.537153
# division_1_size_3                                          2.253823
#
#                       $\frac{I_{1182}}{I_{1241}}$  \
# division_1_size_bulk                     0.854650
# division_1_size_5                        0.973376
# division_1_size_3                        1.282869
#
#                       $\frac{I_{1182}}{I_{1393}}$  \
# division_1_size_bulk                     0.511349
# division_1_size_5                        0.605990
# division_1_size_3                        0.738445
#
#                       $\frac{I_{1182}}{I_{1541}}$  \
# division_1_size_bulk                     1.057797
# division_1_size_5                        1.400333
# division_1_size_3                        1.115385
#
#                       $\frac{I_{1182}}{I_{1625}}$  \
# division_1_size_bulk                     0.388923
# division_1_size_5                        0.416593
# division_1_size_3                        0.514367
#
#                       $\frac{I_{1182}}{I_{1725}}$  \
# division_1_size_bulk                     0.918847
# division_1_size_5                        1.083538
# division_1_size_3                        1.394883
#
#                       $\frac{I_{1182}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           0.916921
# division_1_size_5                                              1.099973
# division_1_size_3                                              1.179021
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.094277
# division_1_size_5                                              0.107245
# division_1_size_3                                              0.117158
#
#                       $\frac{I_{1182}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.911639
# division_1_size_5                                               1.102087
# division_1_size_3                                               1.197980
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.217161
# division_1_size_5                                               0.247682
# division_1_size_3                                               0.281089
#
#                       $\frac{I_{1182}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.680250
# division_1_size_5                                               0.829258
# division_1_size_3                                               0.982530
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.511349
# division_1_size_5                                               0.605990
# division_1_size_3                                               0.738445
#
#                       $\frac{I_{1182}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.070416
# division_1_size_5                                              1.262406
# division_1_size_3                                              1.263836
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.247127
# division_1_size_5                                              0.274965
# division_1_size_3                                              0.275961
#
#                       $\frac{I_{1182}}{\overline{I}_{874 \pm 16}}$  \
# division_1_size_bulk                                      8.228542
# division_1_size_5                                         4.489606
# division_1_size_3                                         4.562687
#
#                       $\frac{I_{1182}}{\overline{I}_{874 \pm 32}}$  \
# division_1_size_bulk                                      8.100146
# division_1_size_5                                         4.411895
# division_1_size_3                                         4.450351
#
#                       $\frac{I_{1182}}{\overline{I}_{1084 \pm 16}}$  \
# division_1_size_bulk                                       0.587057
# division_1_size_5                                          0.725532
# division_1_size_3                                          0.662529
#
#                       $\frac{I_{1182}}{\overline{I}_{1084 \pm 32}}$  \
# division_1_size_bulk                                       0.591894
# division_1_size_5                                          0.741336
# division_1_size_3                                          0.671511
#
#                       $\frac{I_{1182}}{\overline{I}_{1241 \pm 16}}$  \
# division_1_size_bulk                                       0.860165
# division_1_size_5                                          0.976248
# division_1_size_3                                          1.283196
#
#                       $\frac{I_{1182}}{\overline{I}_{1241 \pm 32}}$  \
# division_1_size_bulk                                       0.871497
# division_1_size_5                                          0.982048
# division_1_size_3                                          1.277518
#
#                       $\frac{I_{1182}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                       0.518292
# division_1_size_5                                          0.613865
# division_1_size_3                                          0.747283
#
#                       $\frac{I_{1182}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                       0.533987
# division_1_size_5                                          0.633480
# division_1_size_3                                          0.769790
#
#                       $\frac{I_{1182}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                       1.037071
# division_1_size_5                                          1.362110
# division_1_size_3                                          1.101708
#
#                       $\frac{I_{1182}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                       0.976456
# division_1_size_5                                          1.257707
# division_1_size_3                                          1.062532
#
#                       $\frac{I_{1182}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                       0.397938
# division_1_size_5                                          0.425771
# division_1_size_3                                          0.524542
#
#                       $\frac{I_{1182}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                       0.419965
# division_1_size_5                                          0.451158
# division_1_size_3                                          0.547584
#
#                       $\frac{I_{1182}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                       0.926576
# division_1_size_5                                          1.093166
# division_1_size_3                                          1.398444
#
#                       $\frac{I_{1182}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                       0.935336
# division_1_size_5                                          1.107521
# division_1_size_3                                          1.386421
#
#                       $\frac{I_{1241}}{I_{1393}}$  \
# division_1_size_bulk                     0.598314
# division_1_size_5                        0.622566
# division_1_size_3                        0.575620
#
#                       $\frac{I_{1241}}{I_{1541}}$  \
# division_1_size_bulk                     1.237696
# division_1_size_5                        1.438636
# division_1_size_3                        0.869446
#
#                       $\frac{I_{1241}}{I_{1625}}$  \
# division_1_size_bulk                     0.455066
# division_1_size_5                        0.427988
# division_1_size_3                        0.400950
#
#                       $\frac{I_{1241}}{I_{1725}}$  \
# division_1_size_bulk                     1.075114
# division_1_size_5                        1.113176
# division_1_size_3                        1.087315
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.072861
# division_1_size_5                                              1.130060
# division_1_size_3                                              0.919050
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.110311
# division_1_size_5                                              0.110178
# division_1_size_3                                              0.091325
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.066680
# division_1_size_5                                               1.132232
# division_1_size_3                                               0.933828
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.254093
# division_1_size_5                                               0.254456
# division_1_size_3                                               0.219109
#
#                       $\frac{I_{1241}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.795939
# division_1_size_5                                               0.851941
# division_1_size_3                                               0.765884
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.598314
# division_1_size_5                                               0.622566
# division_1_size_3                                               0.575620
#
#                       $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.252460
# division_1_size_5                                              1.296936
# division_1_size_3                                              0.985163
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.289156
# division_1_size_5                                              0.282486
# division_1_size_3                                              0.215113
#
#                       $\frac{I_{1241}}{\overline{I}_{874 \pm 16}}$  \
# division_1_size_bulk                                      9.627964
# division_1_size_5                                         4.612409
# division_1_size_3                                         3.556626
#
#                       $\frac{I_{1241}}{\overline{I}_{874 \pm 32}}$  \
# division_1_size_bulk                                      9.477732
# division_1_size_5                                         4.532572
# division_1_size_3                                         3.469060
#
#                       $\frac{I_{1241}}{\overline{I}_{1084 \pm 16}}$  \
# division_1_size_bulk                                       0.686897
# division_1_size_5                                          0.745377
# division_1_size_3                                          0.516443
#
#                       $\frac{I_{1241}}{\overline{I}_{1084 \pm 32}}$  \
# division_1_size_bulk                                       0.692557
# division_1_size_5                                          0.761614
# division_1_size_3                                          0.523445
#
#                       $\frac{I_{1241}}{\overline{I}_{1182 \pm 16}}$  \
# division_1_size_bulk                                       1.159377
# division_1_size_5                                          1.019018
# division_1_size_3                                          0.773374
#
#                       $\frac{I_{1241}}{\overline{I}_{1182 \pm 32}}$  \
# division_1_size_bulk                                       1.121368
# division_1_size_5                                          0.992942
# division_1_size_3                                          0.753399
#
#                       $\frac{I_{1241}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                       0.606438
# division_1_size_5                                          0.630656
# division_1_size_3                                          0.582509
#
#                       $\frac{I_{1241}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                       0.624802
# division_1_size_5                                          0.650807
# division_1_size_3                                          0.600053
#
#                       $\frac{I_{1241}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                       1.213445
# division_1_size_5                                          1.399367
# division_1_size_3                                          0.858784
#
#                       $\frac{I_{1241}}{\overline{I}_{1541 \pm 32}}$  \
# ...
#
#                       $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.415220
# division_1_size_5                                                            0.440526
# division_1_size_3                                                            0.542716
#
#                       $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.438204
# division_1_size_5                                                            0.466793
# division_1_size_3                                                            0.566556
#
#                       $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         0.966818
# division_1_size_5                                                            1.131050
# division_1_size_3                                                            1.446897
#
#                       $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         0.975958
# division_1_size_5                                                            1.145903
# division_1_size_3                                                            1.434457
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                                         0.602550
# division_1_size_5                                                            0.628801
# division_1_size_3                                                            0.582361
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                                         0.620796
# division_1_size_5                                                            0.648893
# division_1_size_3                                                            0.599900
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                                         1.205665
# division_1_size_5                                                            1.395251
# division_1_size_3                                                            0.858566
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                                         1.135196
# division_1_size_5                                                            1.288308
# division_1_size_3                                                            0.828036
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.462630
# division_1_size_5                                                            0.436130
# division_1_size_3                                                            0.408778
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.488237
# division_1_size_5                                                            0.462135
# division_1_size_3                                                            0.426734
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         1.077208
# division_1_size_5                                                            1.119763
# division_1_size_3                                                            1.089813
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         1.087391
# division_1_size_5                                                            1.134468
# division_1_size_3                                                            1.080443
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                                         0.594715
# division_1_size_5                                                            0.625087
# division_1_size_3                                                            0.584949
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                                         0.612725
# division_1_size_5                                                            0.645060
# division_1_size_3                                                            0.602567
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                                         1.189989
# division_1_size_5                                                            1.387010
# division_1_size_3                                                            0.862382
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                                         1.120436
# division_1_size_5                                                            1.280699
# division_1_size_3                                                            0.831716
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.456615
# division_1_size_5                                                            0.433554
# division_1_size_3                                                            0.410595
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.481889
# division_1_size_5                                                            0.459405
# division_1_size_3                                                            0.428631
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         1.063201
# division_1_size_5                                                            1.113150
# division_1_size_3                                                            1.094657
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         1.073253
# division_1_size_5                                                            1.127767
# division_1_size_3                                                            1.085246
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                                         2.000939
# division_1_size_5                                                            2.218907
# division_1_size_3                                                            1.474285
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                                         1.883987
# division_1_size_5                                                            2.048833
# division_1_size_3                                                            1.421860
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.767787
# division_1_size_5                                                            0.693590
# division_1_size_3                                                            0.701932
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.810286
# division_1_size_5                                                            0.734946
# division_1_size_3                                                            0.732766
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         1.787749
# division_1_size_5                                                            1.780791
# division_1_size_3                                                            1.871371
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         1.804650
# division_1_size_5                                                            1.804177
# division_1_size_3                                                            1.855282
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                                         1.942127
# division_1_size_5                                                            2.150202
# division_1_size_3                                                            1.431180
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                                         1.828613
# division_1_size_5                                                            1.985394
# division_1_size_3                                                            1.380289
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.745220
# division_1_size_5                                                            0.672114
# division_1_size_3                                                            0.681409
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.786470
# division_1_size_5                                                            0.712189
# division_1_size_3                                                            0.711342
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         1.735203
# division_1_size_5                                                            1.725652
# division_1_size_3                                                            1.816657
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         1.751607
# division_1_size_5                                                            1.748313
# division_1_size_3                                                            1.801038
#
#                       $\frac{\overline{I}_{1541 \pm 16}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.383713
# division_1_size_5                                                            0.312582
# division_1_size_3                                                            0.476117
#
#                       $\frac{\overline{I}_{1541 \pm 16}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.404953
# division_1_size_5                                                            0.331220
# division_1_size_3                                                            0.497032
#
#                       $\frac{\overline{I}_{1541 \pm 16}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         0.893455
# division_1_size_5                                                            0.802553
# division_1_size_3                                                            1.269341
#
#                       $\frac{\overline{I}_{1541 \pm 16}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         0.901901
# division_1_size_5                                                            0.813092
# division_1_size_3                                                            1.258428
#
#                       $\frac{\overline{I}_{1541 \pm 32}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.407533
# division_1_size_5                                                            0.338529
# division_1_size_3                                                            0.493671
#
#                       $\frac{\overline{I}_{1541 \pm 32}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.430091
# division_1_size_5                                                            0.358714
# division_1_size_3                                                            0.515357
#
#                       $\frac{\overline{I}_{1541 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         0.948918
# division_1_size_5                                                            0.869173
# division_1_size_3                                                            1.316143
#
#                       $\frac{\overline{I}_{1541 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         0.957889
# division_1_size_5                                                            0.880587
# division_1_size_3                                                            1.304827
#
#                       $\frac{\overline{I}_{1625 \pm 16}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         2.328444
# division_1_size_5                                                            2.567499
# division_1_size_3                                                            2.666030
#
#                       $\frac{\overline{I}_{1625 \pm 16}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         2.350456
# division_1_size_5                                                            2.601215
# division_1_size_3                                                            2.643108
#
#                       $\frac{\overline{I}_{1625 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         2.206319
# division_1_size_5                                                            2.423024
# division_1_size_3                                                            2.553845
#
#                       $\frac{\overline{I}_{1625 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         2.227177
# division_1_size_5                                                            2.454842
# division_1_size_3                                                            2.531888
#
#                       Split Fraction_hue Fraction_grouped_hue  Class
# division_1_size_bulk  Train        $> 0$              $d > 5$      2
# division_1_size_5      Test        $< 5$       $2 < d \leq 5$      1
# division_1_size_3     Train        $< 3$       $2 < d \leq 5$      1

# %% [markdown]
# ## Features description

# %%
with open(path_to_features_description, 'r', encoding='utf-8') as f:
    features_description = json.load(f)

# %% [markdown]
# # Data wrangling

# %% [markdown]
# ## Data wrangling

# %%
dataset_train = dataset.loc[dataset['Split'] == 'Train']

X_train = dataset_train.loc[:, ~dataset_train.columns.isin(['Split', 'Fraction_hue', 'Fraction_grouped_hue', 'Class'])]
y_train = dataset_train['Class']

print(
    f'(*) X_train: {X_train.shape}',
    f'(*) y_train: {y_train.shape}',
    sep='\n'
)
X_train.head(3)
# Out:
# (*) X_train: (50, 487)
# (*) y_train: (50,)
#                       $I_{874}$  $I_{1084}$  $I_{1182}$  $I_{1241}$  \
# division_1_size_bulk   0.048493    0.681294    0.388923    0.455066
# division_1_size_3      0.112416    0.836176    0.514367    0.400950
# division_1_size_2.5    0.113965    0.642576    0.406665    0.416118
#
#                       $I_{1393}$  $I_{1541}$  $I_{1625}$  $I_{1725}$  \
# division_1_size_bulk    0.760582    0.367672         1.0    0.423273
# division_1_size_3       0.696553    0.461156         1.0    0.368753
# division_1_size_2.5     0.801299    0.842757         1.0    0.543270
#
#                       $\overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                          0.424162
# division_1_size_3                             0.436266
# division_1_size_2.5                           0.525971
#
#                       $\Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                          4.125303
# division_1_size_3                             4.390371
# division_1_size_2.5                           4.766650
#
#                       $\overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                           0.426619
# division_1_size_3                              0.429362
# division_1_size_2.5                            0.647458
#
#                       $\Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                           1.790945
# division_1_size_3                              1.829909
# division_1_size_2.5                            2.386027
#
#                       $\overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                           0.571735
# division_1_size_3                              0.523513
# division_1_size_2.5                            0.676532
#
#                       $\Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                           0.760582
# division_1_size_3                              0.696553
# division_1_size_2.5                            0.801299
#
#                       $\overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                          0.363338
# division_1_size_3                             0.406988
# division_1_size_2.5                           0.368779
#
#                       $\Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                          1.573776
# division_1_size_3                             1.863909
# division_1_size_2.5                           1.579324
#
#                       $\overline{I}_{874 \pm 16}$  \
# division_1_size_bulk                     0.047265
# division_1_size_3                        0.112733
# division_1_size_2.5                      0.109038
#
#                       $\overline{I}_{874 \pm 32}$  \
# division_1_size_bulk                     0.048014
# division_1_size_3                        0.115579
# division_1_size_2.5                      0.107469
#
#                       $\overline{I}_{1084 \pm 16}$  \
# division_1_size_bulk                      0.662496
# division_1_size_3                         0.776369
# division_1_size_2.5                       0.612194
#
#                       $\overline{I}_{1084 \pm 32}$  \
# division_1_size_bulk                      0.657082
# division_1_size_3                         0.765984
# division_1_size_2.5                       0.612489
#
#                       $\overline{I}_{1182 \pm 16}$  \
# division_1_size_bulk                      0.392509
# division_1_size_3                         0.518442
# division_1_size_2.5                       0.408719
#
#                       $\overline{I}_{1182 \pm 32}$  \
# division_1_size_bulk                      0.405814
# division_1_size_3                         0.532188
# division_1_size_2.5                       0.418879
#
#                       $\overline{I}_{1241 \pm 16}$  \
# division_1_size_bulk                      0.452149
# division_1_size_3                         0.400848
# division_1_size_2.5                       0.414206
#
#                       $\overline{I}_{1241 \pm 32}$  \
# division_1_size_bulk                      0.446270
# division_1_size_3                         0.402630
# division_1_size_2.5                       0.412569
#
#                       $\overline{I}_{1393 \pm 16}$  \
# division_1_size_bulk                      0.750393
# division_1_size_3                         0.688316
# division_1_size_2.5                       0.789455
#
#                       $\overline{I}_{1393 \pm 32}$  \
# division_1_size_bulk                      0.728337
# division_1_size_3                         0.668191
# division_1_size_2.5                       0.776950
#
#                       $\overline{I}_{1541 \pm 16}$  \
# division_1_size_bulk                      0.375020
# division_1_size_3                         0.466881
# division_1_size_2.5                       0.835396
#
#                       $\overline{I}_{1541 \pm 32}$  \
# division_1_size_bulk                      0.398300
# division_1_size_3                         0.484095
# division_1_size_2.5                       0.818229
#
#                       $\overline{I}_{1625 \pm 16}$  \
# division_1_size_bulk                      0.977345
# division_1_size_3                         0.980602
# division_1_size_2.5                       0.960529
#
#                       $\overline{I}_{1625 \pm 32}$  \
# division_1_size_bulk                      0.926084
# division_1_size_3                         0.939339
# division_1_size_2.5                       0.953859
#
#                       $\overline{I}_{1725 \pm 16}$  \
# division_1_size_bulk                      0.419742
# division_1_size_3                         0.367814
# division_1_size_2.5                       0.546926
#
#                       $\overline{I}_{1725 \pm 32}$  $\log I_{874}$  \
# division_1_size_bulk                      0.415811       -3.026334
# division_1_size_3                         0.371003       -2.185546
# division_1_size_2.5                       0.562146       -2.171866
#
#                       $(I_{874})^{-1}$  $\log I_{1084}$  $(I_{1084})^{-1}$  \
# division_1_size_bulk         20.621489        -0.383761           1.467794
# division_1_size_3             8.895503        -0.178917           1.195921
# division_1_size_2.5           8.774639        -0.442270           1.556235
#
#                       $\log I_{1182}$  $(I_{1182})^{-1}$  $\log I_{1241}$  \
# division_1_size_bulk        -0.944375           2.571206        -0.787312
# division_1_size_3           -0.664819           1.944138        -0.913918
# division_1_size_2.5         -0.899766           2.459028        -0.876787
#
#                       $(I_{1241})^{-1}$  $\log I_{1393}$  $(I_{1393})^{-1}$  \
# division_1_size_bulk           2.197482        -0.273672           1.314783
# division_1_size_3              2.494076        -0.361611           1.435640
# division_1_size_2.5            2.403166        -0.221521           1.247973
#
#                       $\log I_{1541}$  $(I_{1541})^{-1}$  $\log I_{1625}$  \
# division_1_size_bulk        -1.000564           2.719814              0.0
# division_1_size_3           -0.774019           2.168463              0.0
# division_1_size_2.5         -0.171077           1.186582              0.0
#
#                       $(I_{1625})^{-1}$  $\log I_{1725}$  $(I_{1725})^{-1}$  \
# division_1_size_bulk                1.0        -0.859739           2.362543
# division_1_size_3                   1.0        -0.997629           2.711845
# division_1_size_2.5                 1.0        -0.610149           1.840705
#
#                       $\log \overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                              -0.857641
# division_1_size_3                                 -0.829504
# division_1_size_2.5                               -0.642509
#
#                       $(\overline{I}_{1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.357591
# division_1_size_3                                    2.292181
# division_1_size_2.5                                  1.901245
#
#                       $\log \Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                               1.417139
# division_1_size_3                                  1.479414
# division_1_size_2.5                                1.561644
#
#                       $(\Sigma I_{p,\ 1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.242406
# division_1_size_3                                    0.227771
# division_1_size_2.5                                  0.209791
#
#                       $\log \overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                               -0.851863
# division_1_size_3                                  -0.845455
# division_1_size_2.5                                -0.434702
#
#                       $(\overline{I}_{1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  2.344010
# division_1_size_3                                     2.329038
# division_1_size_2.5                                   1.544503
#
#                       $\log \Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                                0.582743
# division_1_size_3                                   0.604266
# division_1_size_2.5                                 0.869630
#
#                       $(\Sigma I_{p,\ 1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  0.558364
# division_1_size_3                                     0.546475
# division_1_size_2.5                                   0.419107
#
#                       $\log \overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                               -0.559080
# division_1_size_3                                  -0.647194
# division_1_size_2.5                                -0.390776
#
#                       $(\overline{I}_{1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.749062
# division_1_size_3                                     1.910173
# division_1_size_2.5                                   1.478127
#
#                       $\log \Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                               -0.273672
# division_1_size_3                                  -0.361611
# division_1_size_2.5                                -0.221521
#
#                       $(\Sigma I_{p,\ 1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.314783
# division_1_size_3                                     1.435640
# division_1_size_2.5                                   1.247973
#
#                       $\log \overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                              -1.012422
# division_1_size_3                                 -0.898970
# division_1_size_2.5                               -0.997558
#
#                       $(\overline{I}_{1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.752259
# division_1_size_3                                    2.457072
# division_1_size_2.5                                  2.711653
#
#                       $\log \Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                               0.453478
# division_1_size_3                                  0.622676
# division_1_size_2.5                                0.456997
#
#                       $(\Sigma I_{p,\ 1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.635414
# division_1_size_3                                    0.536507
# division_1_size_2.5                                  0.633182
#
#                       $\log \overline{I}_{874 \pm 16}$  \
# division_1_size_bulk                         -3.051984
# division_1_size_3                            -2.182731
# division_1_size_2.5                          -2.216059
#
#                       $(\overline{I}_{874 \pm 16})^{-1}$  \
# division_1_size_bulk                           21.157274
# division_1_size_3                               8.870495
# division_1_size_2.5                             9.171115
#
#                       $\log \overline{I}_{874 \pm 32}$  \
# division_1_size_bulk                         -3.036257
# division_1_size_3                            -2.157802
# division_1_size_2.5                          -2.230550
#
#                       $(\overline{I}_{874 \pm 32})^{-1}$  \
# division_1_size_bulk                           20.827141
# division_1_size_3                               8.652097
# division_1_size_2.5                             9.304984
#
#                       $\log \overline{I}_{1084 \pm 16}$  \
# division_1_size_bulk                          -0.411741
# division_1_size_3                             -0.253127
# division_1_size_2.5                           -0.490706
#
#                       $(\overline{I}_{1084 \pm 16})^{-1}$  \
# division_1_size_bulk                             1.509444
# division_1_size_3                                1.288047
# division_1_size_2.5                              1.633469
#
#                       $\log \overline{I}_{1084 \pm 32}$  \
# division_1_size_bulk                          -0.419947
# division_1_size_3                             -0.266595
# division_1_size_2.5                           -0.490225
#
#                       $(\overline{I}_{1084 \pm 32})^{-1}$  \
# division_1_size_bulk                             1.521881
# division_1_size_3                                1.305511
# division_1_size_2.5                              1.632684
#
#                       $\log \overline{I}_{1182 \pm 16}$  \
# division_1_size_bulk                          -0.935195
# division_1_size_3                             -0.656926
# division_1_size_2.5                           -0.894727
#
#                       $(\overline{I}_{1182 \pm 16})^{-1}$  \
# division_1_size_bulk                             2.547710
# division_1_size_3                                1.928854
# division_1_size_2.5                              2.446667
#
#                       $\log \overline{I}_{1182 \pm 32}$  \
# division_1_size_bulk                          -0.901862
# division_1_size_3                             -0.630758
# division_1_size_2.5                           -0.870173
#
#                       $(\overline{I}_{1182 \pm 32})^{-1}$  \
# division_1_size_bulk                             2.464186
# division_1_size_3                                1.879034
# division_1_size_2.5                              2.387323
#
#                       $\log \overline{I}_{1241 \pm 16}$  \
# division_1_size_bulk                          -0.793744
# division_1_size_3                             -0.914173
# division_1_size_2.5                           -0.881392
#
#                       $(\overline{I}_{1241 \pm 16})^{-1}$  \
# division_1_size_bulk                             2.211661
# division_1_size_3                                2.494711
# division_1_size_2.5                              2.414258
#
#                       $\log \overline{I}_{1241 \pm 32}$  \
# division_1_size_bulk                          -0.806831
# division_1_size_3                             -0.909738
# division_1_size_2.5                           -0.885351
#
#                       $(\overline{I}_{1241 \pm 32})^{-1}$  \
# division_1_size_bulk                             2.240797
# division_1_size_3                                2.483671
# division_1_size_2.5                              2.423834
#
#                       $\log \overline{I}_{1393 \pm 16}$  \
# division_1_size_bulk                          -0.287159
# division_1_size_3                             -0.373508
# division_1_size_2.5                           -0.236412
#
#                       $(\overline{I}_{1393 \pm 16})^{-1}$  \
# division_1_size_bulk                             1.332636
# division_1_size_3                                1.452822
# division_1_size_2.5                              1.266697
#
#                       $\log \overline{I}_{1393 \pm 32}$  \
# division_1_size_bulk                          -0.316992
# division_1_size_3                             -0.403181
# division_1_size_2.5                           -0.252379
#
#                       $(\overline{I}_{1393 \pm 32})^{-1}$  \
# division_1_size_bulk                             1.372991
# division_1_size_3                                1.496578
# division_1_size_2.5                              1.287084
#
#                       $\log \overline{I}_{1541 \pm 16}$  \
# division_1_size_bulk                          -0.980775
# division_1_size_3                             -0.761681
# division_1_size_2.5                           -0.179850
#
#                       $(\overline{I}_{1541 \pm 16})^{-1}$  \
# division_1_size_bulk                             2.666523
# division_1_size_3                                2.141873
# division_1_size_2.5                              1.197037
#
#                       $\log \overline{I}_{1541 \pm 32}$  \
# division_1_size_bulk                          -0.920549
# division_1_size_3                             -0.725474
# division_1_size_2.5                           -0.200613
#
#                       $(\overline{I}_{1541 \pm 32})^{-1}$  \
# division_1_size_bulk                             2.510669
# division_1_size_3                                2.065710
# division_1_size_2.5                              1.222152
#
#                       $\log \overline{I}_{1625 \pm 16}$  \
# division_1_size_bulk                          -0.022916
# division_1_size_3                             -0.019589
# division_1_size_2.5                           -0.040271
#
#                       $(\overline{I}_{1625 \pm 16})^{-1}$  \
# division_1_size_bulk                             1.023181
# division_1_size_3                                1.019782
# division_1_size_2.5                              1.041093
#
#                       $\log \overline{I}_{1625 \pm 32}$  \
# division_1_size_bulk                          -0.076790
# division_1_size_3                             -0.062579
# division_1_size_2.5                           -0.047240
#
#                       $(\overline{I}_{1625 \pm 32})^{-1}$  \
# division_1_size_bulk                             1.079816
# division_1_size_3                                1.064578
# division_1_size_2.5                              1.048373
#
#                       $\log \overline{I}_{1725 \pm 16}$  \
# division_1_size_bulk                          -0.868116
# division_1_size_3                             -1.000179
# division_1_size_2.5                           -0.603442
#
#                       $(\overline{I}_{1725 \pm 16})^{-1}$  \
# division_1_size_bulk                             2.382418
# division_1_size_3                                2.718768
# division_1_size_2.5                              1.828401
#
#                       $\log \overline{I}_{1725 \pm 32}$  \
# division_1_size_bulk                          -0.877525
# division_1_size_3                             -0.991544
# division_1_size_2.5                           -0.575993
#
#                       $(\overline{I}_{1725 \pm 32})^{-1}$  \
# division_1_size_bulk                             2.404941
# division_1_size_3                                2.695394
# division_1_size_2.5                              1.778896
#
#                       $\frac{I_{874}}{I_{1084}}$  $\frac{I_{874}}{I_{1182}}$  \
# division_1_size_bulk                    0.071178                    0.124686
# division_1_size_3                       0.134441                    0.218553
# division_1_size_2.5                     0.177356                    0.280243
#
#                       $\frac{I_{874}}{I_{1241}}$  $\frac{I_{874}}{I_{1393}}$  \
# division_1_size_bulk                    0.106563                    0.063758
# division_1_size_3                       0.280375                    0.161389
# division_1_size_2.5                     0.273876                    0.142225
#
#                       $\frac{I_{874}}{I_{1541}}$  $\frac{I_{874}}{I_{1625}}$  \
# division_1_size_bulk                    0.131892                    0.048493
# division_1_size_3                       0.243771                    0.112416
# division_1_size_2.5                     0.135229                    0.113965
#
#                       $\frac{I_{874}}{I_{1725}}$  \
# division_1_size_bulk                    0.114567
# division_1_size_3                       0.304856
# division_1_size_2.5                     0.209776
#
#                       $\frac{I_{874}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                          0.114327
# division_1_size_3                                             0.257679
# division_1_size_2.5                                           0.216675
#
#                       $\frac{I_{874}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                          0.011755
# division_1_size_3                                             0.025605
# division_1_size_2.5                                           0.023909
#
#                       $\frac{I_{874}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.113668
# division_1_size_3                                              0.261822
# division_1_size_2.5                                            0.176019
#
#                       $\frac{I_{874}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.027077
# division_1_size_3                                              0.061433
# division_1_size_2.5                                            0.047763
#
#                       $\frac{I_{874}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.084817
# division_1_size_3                                              0.214735
# division_1_size_2.5                                            0.168454
#
#                       $\frac{I_{874}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.063758
# division_1_size_3                                              0.161389
# division_1_size_2.5                                            0.142225
#
#                       $\frac{I_{874}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                          0.133466
# division_1_size_3                                             0.276215
# division_1_size_2.5                                           0.309033
#
#                       $\frac{I_{874}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                          0.030813
# division_1_size_3                                             0.060312
# division_1_size_2.5                                           0.072161
#
#                       $\frac{I_{874}}{\overline{I}_{1084 \pm 16}}$  \
# division_1_size_bulk                                      0.073198
# division_1_size_3                                         0.144798
# division_1_size_2.5                                       0.186158
#
#                       $\frac{I_{874}}{\overline{I}_{1084 \pm 32}}$  \
# division_1_size_bulk                                      0.073801
# division_1_size_3                                         0.146761
# division_1_size_2.5                                       0.186068
#
#                       $\frac{I_{874}}{\overline{I}_{1182 \pm 16}}$  \
# division_1_size_bulk                                      0.123546
# division_1_size_3                                         0.216835
# division_1_size_2.5                                       0.278834
#
#                       $\frac{I_{874}}{\overline{I}_{1182 \pm 32}}$  \
# division_1_size_bulk                                      0.119496
# division_1_size_3                                         0.211234
# division_1_size_2.5                                       0.272071
#
#                       $\frac{I_{874}}{\overline{I}_{1241 \pm 16}}$  \
# division_1_size_bulk                                      0.107250
# division_1_size_3                                         0.280446
# division_1_size_2.5                                       0.275140
#
#                       $\frac{I_{874}}{\overline{I}_{1241 \pm 32}}$  \
# division_1_size_bulk                                      0.108663
# division_1_size_3                                         0.279205
# division_1_size_2.5                                       0.276232
#
#                       $\frac{I_{874}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                      0.064624
# division_1_size_3                                         0.163321
# division_1_size_2.5                                       0.144359
#
#                       $\frac{I_{874}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                      0.066581
# division_1_size_3                                         0.168240
# division_1_size_2.5                                       0.146682
#
#                       $\frac{I_{874}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                      0.129308
# division_1_size_3                                         0.240782
# division_1_size_2.5                                       0.136420
#
#                       $\frac{I_{874}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                      0.121750
# division_1_size_3                                         0.232220
# division_1_size_2.5                                       0.139282
#
#                       $\frac{I_{874}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                      0.049617
# division_1_size_3                                         0.114640
# division_1_size_2.5                                       0.118648
#
#                       $\frac{I_{874}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                      0.052364
# division_1_size_3                                         0.119676
# division_1_size_2.5                                       0.119478
#
#                       $\frac{I_{874}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                      0.115531
# division_1_size_3                                         0.305634
# division_1_size_2.5                                       0.208373
#
#                       $\frac{I_{874}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                      0.116623
# division_1_size_3                                         0.303006
# division_1_size_2.5                                       0.202732
#
#                       $\frac{I_{1084}}{I_{1182}}$  \
# division_1_size_bulk                     1.751748
# division_1_size_3                        1.625641
# division_1_size_2.5                      1.580113
#
#                       $\frac{I_{1084}}{I_{1241}}$  \
# division_1_size_bulk                     1.497132
# division_1_size_3                        2.085485
# division_1_size_2.5                      1.544218
#
#                       $\frac{I_{1084}}{I_{1393}}$  \
# division_1_size_bulk                     0.895754
# division_1_size_3                        1.200447
# division_1_size_2.5                      0.801918
#
#                       $\frac{I_{1084}}{I_{1541}}$  \
# division_1_size_bulk                     1.852994
# division_1_size_3                        1.813216
# division_1_size_2.5                      0.762470
#
#                       $\frac{I_{1084}}{I_{1625}}$  \
# division_1_size_bulk                     0.681294
# division_1_size_3                        0.836176
# division_1_size_2.5                      0.642576
#
#                       $\frac{I_{1084}}{I_{1725}}$  \
# division_1_size_bulk                     1.609587
# division_1_size_3                        2.267579
# division_1_size_2.5                      1.182793
#
#                       $\frac{I_{1084}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.606214
# division_1_size_3                                              1.916666
# division_1_size_2.5                                            1.221695
#
#                       $\frac{I_{1084}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.165150
# division_1_size_3                                              0.190457
# division_1_size_2.5                                            0.134807
#
#                       $\frac{I_{1084}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.596961
# division_1_size_3                                               1.947485
# division_1_size_2.5                                             0.992461
#
#                       $\frac{I_{1084}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.380411
# division_1_size_3                                               0.456949
# division_1_size_2.5                                             0.269308
#
#                       $\frac{I_{1084}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.191626
# division_1_size_3                                               1.597240
# division_1_size_2.5                                             0.949810
#
#                       $\frac{I_{1084}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.895754
# division_1_size_3                                               1.200447
# division_1_size_2.5                                             0.801918
#
#                       $\frac{I_{1084}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.875098
# division_1_size_3                                              2.054544
# division_1_size_2.5                                            1.742444
#
#                       $\frac{I_{1084}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.432904
# division_1_size_3                                              0.448614
# division_1_size_2.5                                            0.406868
#
#                       $\frac{I_{1084}}{\overline{I}_{874 \pm 16}}$  \
# division_1_size_bulk                                     14.414330
# division_1_size_3                                         7.417292
# division_1_size_2.5                                       5.893142
#
#                       $\frac{I_{1084}}{\overline{I}_{874 \pm 32}}$  \
# division_1_size_bulk                                     14.189412
# division_1_size_3                                         7.234673
# division_1_size_2.5                                       5.979163
#
#                       $\frac{I_{1084}}{\overline{I}_{1182 \pm 16}}$  \
# division_1_size_bulk                                       1.735740
# division_1_size_3                                          1.612861
# division_1_size_2.5                                        1.572170
#
#                       $\frac{I_{1084}}{\overline{I}_{1182 \pm 32}}$  \
# division_1_size_bulk                                       1.678836
# division_1_size_3                                          1.571203
# division_1_size_2.5                                        1.534038
#
#                       $\frac{I_{1084}}{\overline{I}_{1241 \pm 16}}$  \
# division_1_size_bulk                                       1.506792
# division_1_size_3                                          2.086017
# division_1_size_2.5                                        1.551345
#
#                       $\frac{I_{1084}}{\overline{I}_{1241 \pm 32}}$  \
# division_1_size_bulk                                       1.526642
# division_1_size_3                                          2.076785
# division_1_size_2.5                                        1.557499
#
#                       $\frac{I_{1084}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                       0.907917
# division_1_size_3                                          1.214814
# division_1_size_2.5                                        0.813949
#
#                       $\frac{I_{1084}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                       0.935411
# division_1_size_3                                          1.251402
# division_1_size_2.5                                        0.827050
#
#                       $\frac{I_{1084}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                       1.816687
# division_1_size_3                                          1.790982
# division_1_size_2.5                                        0.769188
#
#                       $\frac{I_{1084}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                       1.710504
# division_1_size_3                                          1.727296
# division_1_size_2.5                                        0.785326
#
#                       $\frac{I_{1084}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                       0.697087
# division_1_size_3                                          0.852717
# division_1_size_2.5                                        0.668982
#
#                       $\frac{I_{1084}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                       0.735672
# division_1_size_3                                          0.890175
# division_1_size_2.5                                        0.673660
#
#                       $\frac{I_{1084}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                       1.623128
# division_1_size_3                                          2.273368
# division_1_size_2.5                                        1.174887
#
#                       $\frac{I_{1084}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                       1.638473
# division_1_size_3                                          2.253823
# division_1_size_2.5                                        1.143076
#
#                       $\frac{I_{1182}}{I_{1241}}$  \
# division_1_size_bulk                     0.854650
# division_1_size_3                        1.282869
# division_1_size_2.5                      0.977283
#
#                       $\frac{I_{1182}}{I_{1393}}$  \
# division_1_size_bulk                     0.511349
# division_1_size_3                        0.738445
# division_1_size_2.5                      0.507507
#
#                       $\frac{I_{1182}}{I_{1541}}$  \
# division_1_size_bulk                     1.057797
# division_1_size_3                        1.115385
# division_1_size_2.5                      0.482541
#
#                       $\frac{I_{1182}}{I_{1625}}$  \
# division_1_size_bulk                     0.388923
# division_1_size_3                        0.514367
# division_1_size_2.5                      0.406665
#
#                       $\frac{I_{1182}}{I_{1725}}$  \
# division_1_size_bulk                     0.918847
# division_1_size_3                        1.394883
# division_1_size_2.5                      0.748550
#
#                       $\frac{I_{1182}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           0.916921
# division_1_size_3                                              1.179021
# division_1_size_2.5                                            0.773169
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.094277
# division_1_size_3                                              0.117158
# division_1_size_2.5                                            0.085315
#
#                       $\frac{I_{1182}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.911639
# division_1_size_3                                               1.197980
# division_1_size_2.5                                             0.628095
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.217161
# division_1_size_3                                               0.281089
# division_1_size_2.5                                             0.170436
#
#                       $\frac{I_{1182}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.680250
# division_1_size_3                                               0.982530
# division_1_size_2.5                                             0.601102
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.511349
# division_1_size_3                                               0.738445
# division_1_size_2.5                                             0.507507
#
#                       $\frac{I_{1182}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.070416
# division_1_size_3                                              1.263836
# division_1_size_2.5                                            1.102734
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.247127
# division_1_size_3                                              0.275961
# division_1_size_2.5                                            0.257493
#
#                       $\frac{I_{1182}}{\overline{I}_{874 \pm 16}}$  \
# division_1_size_bulk                                      8.228542
# division_1_size_3                                         4.562687
# division_1_size_2.5                                       3.729570
#
#                       $\frac{I_{1182}}{\overline{I}_{874 \pm 32}}$  \
# division_1_size_bulk                                      8.100146
# division_1_size_3                                         4.450351
# division_1_size_2.5                                       3.784010
#
#                       $\frac{I_{1182}}{\overline{I}_{1084 \pm 16}}$  \
# division_1_size_bulk                                       0.587057
# division_1_size_3                                          0.662529
# division_1_size_2.5                                        0.664275
#
#                       $\frac{I_{1182}}{\overline{I}_{1084 \pm 32}}$  \
# division_1_size_bulk                                       0.591894
# division_1_size_3                                          0.671511
# division_1_size_2.5                                        0.663955
#
#                       $\frac{I_{1182}}{\overline{I}_{1241 \pm 16}}$  \
# division_1_size_bulk                                       0.860165
# division_1_size_3                                          1.283196
# division_1_size_2.5                                        0.981794
#
#                       $\frac{I_{1182}}{\overline{I}_{1241 \pm 32}}$  \
# division_1_size_bulk                                       0.871497
# division_1_size_3                                          1.277518
# division_1_size_2.5                                        0.985688
#
#                       $\frac{I_{1182}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                       0.518292
# division_1_size_3                                          0.747283
# division_1_size_2.5                                        0.515121
#
#                       $\frac{I_{1182}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                       0.533987
# division_1_size_3                                          0.769790
# division_1_size_2.5                                        0.523412
#
#                       $\frac{I_{1182}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                       1.037071
# division_1_size_3                                          1.101708
# division_1_size_2.5                                        0.486793
#
#                       $\frac{I_{1182}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                       0.976456
# division_1_size_3                                          1.062532
# division_1_size_2.5                                        0.497006
#
#                       $\frac{I_{1182}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                       0.397938
# division_1_size_3                                          0.524542
# division_1_size_2.5                                        0.423376
#
#                       $\frac{I_{1182}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                       0.419965
# division_1_size_3                                          0.547584
# division_1_size_2.5                                        0.426337
#
#                       $\frac{I_{1182}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                       0.926576
# division_1_size_3                                          1.398444
# division_1_size_2.5                                        0.743546
#
#                       $\frac{I_{1182}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                       0.935336
# division_1_size_3                                          1.386421
# division_1_size_2.5                                        0.723414
#
#                       $\frac{I_{1241}}{I_{1393}}$  \
# division_1_size_bulk                     0.598314
# division_1_size_3                        0.575620
# division_1_size_2.5                      0.519304
#
#                       $\frac{I_{1241}}{I_{1541}}$  \
# division_1_size_bulk                     1.237696
# division_1_size_3                        0.869446
# division_1_size_2.5                      0.493758
#
#                       $\frac{I_{1241}}{I_{1625}}$  \
# division_1_size_bulk                     0.455066
# division_1_size_3                        0.400950
# division_1_size_2.5                      0.416118
#
#                       $\frac{I_{1241}}{I_{1725}}$  \
# division_1_size_bulk                     1.075114
# division_1_size_3                        1.087315
# division_1_size_2.5                      0.765950
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.072861
# division_1_size_3                                              0.919050
# division_1_size_2.5                                            0.791142
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.110311
# division_1_size_3                                              0.091325
# division_1_size_2.5                                            0.087298
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.066680
# division_1_size_3                                               0.933828
# division_1_size_2.5                                             0.642695
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.254093
# division_1_size_3                                               0.219109
# division_1_size_2.5                                             0.174398
#
#                       $\frac{I_{1241}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.795939
# division_1_size_3                                               0.765884
# division_1_size_2.5                                             0.615075
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.598314
# division_1_size_3                                               0.575620
# division_1_size_2.5                                             0.519304
#
#                       $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.252460
# division_1_size_3                                              0.985163
# division_1_size_2.5                                            1.128367
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.289156
# division_1_size_3                                              0.215113
# division_1_size_2.5                                            0.263478
#
#                       $\frac{I_{1241}}{\overline{I}_{874 \pm 16}}$  \
# division_1_size_bulk                                      9.627964
# division_1_size_3                                         3.556626
# division_1_size_2.5                                       3.816264
#
#                       $\frac{I_{1241}}{\overline{I}_{874 \pm 32}}$  \
# division_1_size_bulk                                      9.477732
# division_1_size_3                                         3.469060
# division_1_size_2.5                                       3.871969
#
#                       $\frac{I_{1241}}{\overline{I}_{1084 \pm 16}}$  \
# division_1_size_bulk                                       0.686897
# division_1_size_3                                          0.516443
# division_1_size_2.5                                        0.679716
#
#                       $\frac{I_{1241}}{\overline{I}_{1084 \pm 32}}$  \
# division_1_size_bulk                                       0.692557
# division_1_size_3                                          0.523445
# division_1_size_2.5                                        0.679389
#
#                       $\frac{I_{1241}}{\overline{I}_{1182 \pm 16}}$  \
# division_1_size_bulk                                       1.159377
# division_1_size_3                                          0.773374
# division_1_size_2.5                                        1.018101
#
#                       $\frac{I_{1241}}{\overline{I}_{1182 \pm 32}}$  \
# division_1_size_bulk                                       1.121368
# division_1_size_3                                          0.753399
# division_1_size_2.5                                        0.993408
#
#                       $\frac{I_{1241}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                       0.606438
# division_1_size_3                                          0.582509
# division_1_size_2.5                                        0.527095
#
#                       $\frac{I_{1241}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                       0.624802
# division_1_size_3                                          0.600053
# division_1_size_2.5                                        0.535578
#
#                       $\frac{I_{1241}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                       1.213445
# division_1_size_3                                          0.858784
# division_1_size_2.5                                        0.498108
#
#                       $\frac{I_{1241}}{\overline{I}_{1541 \pm 32}}$  \
# ...
# division_1_size_bulk                                                         1.018863
# division_1_size_3                                                            1.099346
# division_1_size_2.5                                                          0.511934
#
#                       $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.415220
# division_1_size_3                                                            0.542716
# division_1_size_2.5                                                          0.436092
#
#                       $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.438204
# division_1_size_3                                                            0.566556
# division_1_size_2.5                                                          0.439142
#
#                       $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         0.966818
# division_1_size_3                                                            1.446897
# division_1_size_2.5                                                          0.765879
#
#                       $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         0.975958
# division_1_size_3                                                            1.434457
# division_1_size_2.5                                                          0.745142
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                                         0.602550
# division_1_size_3                                                            0.582361
# division_1_size_2.5                                                          0.524673
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                                         0.620796
# division_1_size_3                                                            0.599900
# division_1_size_2.5                                                          0.533118
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                                         1.205665
# division_1_size_3                                                            0.858566
# division_1_size_2.5                                                          0.495820
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                                         1.135196
# division_1_size_3                                                            0.828036
# division_1_size_2.5                                                          0.506223
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.462630
# division_1_size_3                                                            0.408778
# division_1_size_2.5                                                          0.431227
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.488237
# division_1_size_3                                                            0.426734
# division_1_size_2.5                                                          0.434243
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         1.077208
# division_1_size_3                                                            1.089813
# division_1_size_2.5                                                          0.757334
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         1.087391
# division_1_size_3                                                            1.080443
# division_1_size_2.5                                                          0.736829
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                                         0.594715
# division_1_size_3                                                            0.584949
# division_1_size_2.5                                                          0.522600
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                                         0.612725
# division_1_size_3                                                            0.602567
# division_1_size_2.5                                                          0.531011
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                                         1.189989
# division_1_size_3                                                            0.862382
# division_1_size_2.5                                                          0.493861
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                                         1.120436
# division_1_size_3                                                            0.831716
# division_1_size_2.5                                                          0.504223
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.456615
# division_1_size_3                                                            0.410595
# division_1_size_2.5                                                          0.429523
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.481889
# division_1_size_3                                                            0.428631
# division_1_size_2.5                                                          0.432527
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         1.063201
# division_1_size_3                                                            1.094657
# division_1_size_2.5                                                          0.754342
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         1.073253
# division_1_size_3                                                            1.085246
# division_1_size_2.5                                                          0.733918
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                                         2.000939
# division_1_size_3                                                            1.474285
# division_1_size_2.5                                                          0.945007
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                                         1.883987
# division_1_size_3                                                            1.421860
# division_1_size_2.5                                                          0.964834
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.767787
# division_1_size_3                                                            0.701932
# division_1_size_2.5                                                          0.821896
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.810286
# division_1_size_3                                                            0.732766
# division_1_size_2.5                                                          0.827644
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         1.787749
# division_1_size_3                                                            1.871371
# division_1_size_2.5                                                          1.443440
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         1.804650
# division_1_size_3                                                            1.855282
# division_1_size_2.5                                                          1.404358
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                                         1.942127
# division_1_size_3                                                            1.431180
# division_1_size_2.5                                                          0.930039
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                                         1.828613
# division_1_size_3                                                            1.380289
# division_1_size_2.5                                                          0.949551
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.745220
# division_1_size_3                                                            0.681409
# division_1_size_2.5                                                          0.808877
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.786470
# division_1_size_3                                                            0.711342
# division_1_size_2.5                                                          0.814534
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         1.735203
# division_1_size_3                                                            1.816657
# division_1_size_2.5                                                          1.420576
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         1.751607
# division_1_size_3                                                            1.801038
# division_1_size_2.5                                                          1.382114
#
#                       $\frac{\overline{I}_{1541 \pm 16}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.383713
# division_1_size_3                                                            0.476117
# division_1_size_2.5                                                          0.869725
#
#                       $\frac{\overline{I}_{1541 \pm 16}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.404953
# division_1_size_3                                                            0.497032
# division_1_size_2.5                                                          0.875807
#
#                       $\frac{\overline{I}_{1541 \pm 16}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         0.893455
# division_1_size_3                                                            1.269341
# division_1_size_2.5                                                          1.527438
#
#                       $\frac{\overline{I}_{1541 \pm 16}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         0.901901
# division_1_size_3                                                            1.258428
# division_1_size_2.5                                                          1.486082
#
#                       $\frac{\overline{I}_{1541 \pm 32}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.407533
# division_1_size_3                                                            0.493671
# division_1_size_2.5                                                          0.851852
#
#                       $\frac{\overline{I}_{1541 \pm 32}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.430091
# division_1_size_3                                                            0.515357
# division_1_size_2.5                                                          0.857809
#
#                       $\frac{\overline{I}_{1541 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         0.948918
# division_1_size_3                                                            1.316143
# division_1_size_2.5                                                          1.496050
#
#                       $\frac{\overline{I}_{1541 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         0.957889
# division_1_size_3                                                            1.304827
# division_1_size_2.5                                                          1.455544
#
#                       $\frac{\overline{I}_{1625 \pm 16}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         2.328444
# division_1_size_3                                                            2.666030
# division_1_size_2.5                                                          1.756232
#
#                       $\frac{\overline{I}_{1625 \pm 16}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         2.350456
# division_1_size_3                                                            2.643108
# division_1_size_2.5                                                          1.708681
#
#                       $\frac{\overline{I}_{1625 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         2.206319
# division_1_size_3                                                            2.553845
# division_1_size_2.5                                                          1.744036
#
#                       $\frac{\overline{I}_{1625 \pm 32}}{\overline{I}_{1725 \pm 32}}$
# division_1_size_bulk                                                         2.227177
# division_1_size_3                                                            2.531888
# division_1_size_2.5                                                          1.696815

# %%
dataset_test = dataset.loc[dataset['Split'] == 'Test']

X_test = dataset_test.loc[:, ~dataset_test.columns.isin(['Split', 'Fraction_hue', 'Fraction_grouped_hue', 'Class'])]
y_test = dataset_test['Class']

hue_train = dataset_test['Fraction_grouped_hue'].tolist()

print(
    f'(*) X_train: {X_test.shape}',
    f'(*) y_train: {y_test.shape}',
    sep='\n'
)
X_test.head(3)
# Out:
# (*) X_train: (25, 487)
# (*) y_train: (25,)
#                    $I_{874}$  $I_{1084}$  $I_{1182}$  $I_{1241}$  $I_{1393}$  \
# division_1_size_5   0.092297    0.578199    0.416593    0.427988    0.687458
# division_2_size_5   0.284524    1.000000    0.678881    0.738885    0.892119
# division_2_size_3   0.492129    1.000000    0.714745    0.552366    0.632884
#
#                    $I_{1541}$  $I_{1625}$  $I_{1725}$  \
# division_1_size_5    0.297496    1.000000    0.384475
# division_2_size_5    0.442254    0.959395    0.438496
# division_2_size_3    0.439012    0.653723    0.348920
#
#                    $\overline{I}_{1900\text{–}800}$  \
# division_1_size_5                          0.378730
# division_2_size_5                          0.549735
# division_2_size_3                          0.512811
#
#                    $\Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_5                          3.884505
# division_2_size_5                          5.434554
# division_2_size_3                          4.833778
#
#                    $\overline{I}_{1900\text{–}1500}$  \
# division_1_size_5                           0.378004
# division_2_size_5                           0.404757
# division_2_size_3                           0.325820
#
#                    $\Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_5                           1.681970
# division_2_size_5                           1.840145
# division_2_size_3                           1.441654
#
#                    $\overline{I}_{1500\text{–}1300}$  \
# division_1_size_5                           0.502368
# division_2_size_5                           0.705363
# division_2_size_3                           0.530136
#
#                    $\Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_5                           0.687458
# division_2_size_5                           0.892119
# division_2_size_3                           0.632884
#
#                    $\overline{I}_{1300\text{–}800}$  \
# division_1_size_5                          0.329999
# division_2_size_5                          0.603590
# division_2_size_3                          0.655421
#
#                    $\Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_5                          1.515076
# division_2_size_5                          2.702290
# division_2_size_3                          2.759240
#
#                    $\overline{I}_{874 \pm 16}$  $\overline{I}_{874 \pm 32}$  \
# division_1_size_5                     0.092791                     0.094425
# division_2_size_5                     0.286251                     0.288898
# division_2_size_3                     0.495032                     0.500631
#
#                    $\overline{I}_{1084 \pm 16}$  $\overline{I}_{1084 \pm 32}$  \
# division_1_size_5                      0.574190                      0.561949
# division_2_size_5                      0.983587                      0.957667
# division_2_size_3                      0.989448                      0.964855
#
#                    $\overline{I}_{1182 \pm 16}$  $\overline{I}_{1182 \pm 32}$  \
# division_1_size_5                      0.420000                      0.431030
# division_2_size_5                      0.683130                      0.693804
# division_2_size_3                      0.714396                      0.713824
#
#                    $\overline{I}_{1241 \pm 16}$  $\overline{I}_{1241 \pm 32}$  \
# division_1_size_5                      0.426729                      0.424209
# division_2_size_5                      0.735231                      0.727732
# division_2_size_3                      0.553495                      0.557316
#
#                    $\overline{I}_{1393 \pm 16}$  $\overline{I}_{1393 \pm 32}$  \
# division_1_size_5                      0.678639                      0.657626
# division_2_size_5                      0.879183                      0.860245
# division_2_size_3                      0.625613                      0.614280
#
#                    $\overline{I}_{1541 \pm 16}$  $\overline{I}_{1541 \pm 32}$  \
# division_1_size_5                      0.305844                      0.331232
# division_2_size_5                      0.450605                      0.474413
# division_2_size_3                      0.437767                      0.441236
#
#                    $\overline{I}_{1625 \pm 16}$  $\overline{I}_{1625 \pm 32}$  \
# division_1_size_5                      0.978445                      0.923387
# division_2_size_5                      0.915102                      0.878865
# division_2_size_3                      0.643926                      0.625035
#
#                    $\overline{I}_{1725 \pm 16}$  $\overline{I}_{1725 \pm 32}$  \
# division_1_size_5                      0.381089                      0.376149
# division_2_size_5                      0.432754                      0.419216
# division_2_size_3                      0.345352                      0.340669
#
#                    $\log I_{874}$  $(I_{874})^{-1}$  $\log I_{1084}$  \
# division_1_size_5       -2.382747         10.834628        -0.547838
# division_2_size_5       -1.256939          3.514645         0.000000
# division_2_size_3       -0.709015          2.031989         0.000000
#
#                    $(I_{1084})^{-1}$  $\log I_{1182}$  $(I_{1182})^{-1}$  \
# division_1_size_5            1.72951        -0.875645           2.400424
# division_2_size_5            1.00000        -0.387309           1.473011
# division_2_size_3            1.00000        -0.335829           1.399100
#
#                    $\log I_{1241}$  $(I_{1241})^{-1}$  $\log I_{1393}$  \
# division_1_size_5        -0.848660           2.336514        -0.374754
# division_2_size_5        -0.302613           1.353390        -0.114156
# division_2_size_3        -0.593544           1.810394        -0.457469
#
#                    $(I_{1393})^{-1}$  $\log I_{1541}$  $(I_{1541})^{-1}$  \
# division_1_size_5           1.454634        -1.212356           3.361394
# division_2_size_5           1.120927        -0.815871           2.261145
# division_2_size_3           1.580070        -0.823228           2.277841
#
#                    $\log I_{1625}$  $(I_{1625})^{-1}$  $\log I_{1725}$  \
# division_1_size_5         0.000000           1.000000        -0.955877
# division_2_size_5        -0.041452           1.042324        -0.824404
# division_2_size_3        -0.425072           1.529701        -1.052914
#
#                    $(I_{1725})^{-1}$  $\log \overline{I}_{1900\text{–}800}$  \
# division_1_size_5           2.600952                              -0.970931
# division_2_size_5           2.280522                              -0.598319
# division_2_size_3           2.865991                              -0.667849
#
#                    $(\overline{I}_{1900\text{–}800})^{-1}$  \
# division_1_size_5                                 2.640400
# division_2_size_5                                 1.819058
# division_2_size_3                                 1.950038
#
#                    $\log \Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_5                               1.356996
# division_2_size_5                               1.692777
# division_2_size_3                               1.575628
#
#                    $(\Sigma I_{p,\ 1900\text{–}800})^{-1}$  \
# division_1_size_5                                 0.257433
# division_2_size_5                                 0.184008
# division_2_size_3                                 0.206878
#
#                    $\log \overline{I}_{1900\text{–}1500}$  \
# division_1_size_5                               -0.972851
# division_2_size_5                               -0.904468
# division_2_size_3                               -1.121410
#
#                    $(\overline{I}_{1900\text{–}1500})^{-1}$  \
# division_1_size_5                                  2.645477
# division_2_size_5                                  2.470617
# division_2_size_3                                  3.069178
#
#                    $\log \Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_5                                0.519966
# division_2_size_5                                0.609844
# division_2_size_3                                0.365791
#
#                    $(\Sigma I_{p,\ 1900\text{–}1500})^{-1}$  \
# division_1_size_5                                  0.594541
# division_2_size_5                                  0.543435
# division_2_size_3                                  0.693648
#
#                    $\log \overline{I}_{1500\text{–}1300}$  \
# division_1_size_5                               -0.688422
# division_2_size_5                               -0.349042
# division_2_size_3                               -0.634621
#
#                    $(\overline{I}_{1500\text{–}1300})^{-1}$  \
# division_1_size_5                                  1.990572
# division_2_size_5                                  1.417709
# division_2_size_3                                  1.886308
#
#                    $\log \Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_5                               -0.374754
# division_2_size_5                               -0.114156
# division_2_size_3                               -0.457469
#
#                    $(\Sigma I_{p,\ 1500\text{–}1300})^{-1}$  \
# division_1_size_5                                  1.454634
# division_2_size_5                                  1.120927
# division_2_size_3                                  1.580070
#
#                    $\log \overline{I}_{1300\text{–}800}$  \
# division_1_size_5                              -1.108665
# division_2_size_5                              -0.504860
# division_2_size_3                              -0.422478
#
#                    $(\overline{I}_{1300\text{–}800})^{-1}$  \
# division_1_size_5                                 3.030309
# division_2_size_5                                 1.656753
# division_2_size_3                                 1.525737
#
#                    $\log \Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_5                               0.415466
# division_2_size_5                               0.994100
# division_2_size_3                               1.014955
#
#                    $(\Sigma I_{p,\ 1300\text{–}800})^{-1}$  \
# division_1_size_5                                 0.660033
# division_2_size_5                                 0.370056
# division_2_size_3                                 0.362419
#
#                    $\log \overline{I}_{874 \pm 16}$  \
# division_1_size_5                         -2.377410
# division_2_size_5                         -1.250885
# division_2_size_3                         -0.703132
#
#                    $(\overline{I}_{874 \pm 16})^{-1}$  \
# division_1_size_5                           10.776958
# division_2_size_5                            3.493432
# division_2_size_3                            2.020070
#
#                    $\log \overline{I}_{874 \pm 32}$  \
# division_1_size_5                         -2.359950
# division_2_size_5                         -1.241680
# division_2_size_3                         -0.691887
#
#                    $(\overline{I}_{874 \pm 32})^{-1}$  \
# division_1_size_5                           10.590420
# division_2_size_5                            3.461424
# division_2_size_3                            1.997481
#
#                    $\log \overline{I}_{1084 \pm 16}$  \
# division_1_size_5                          -0.554795
# division_2_size_5                          -0.016549
# division_2_size_3                          -0.010608
#
#                    $(\overline{I}_{1084 \pm 16})^{-1}$  \
# division_1_size_5                             1.741583
# division_2_size_5                             1.016687
# division_2_size_3                             1.010664
#
#                    $\log \overline{I}_{1084 \pm 32}$  \
# division_1_size_5                          -0.576345
# division_2_size_5                          -0.043256
# division_2_size_3                          -0.035777
#
#                    $(\overline{I}_{1084 \pm 32})^{-1}$  \
# division_1_size_5                             1.779522
# division_2_size_5                             1.044205
# division_2_size_3                             1.036425
#
#                    $\log \overline{I}_{1182 \pm 16}$  \
# division_1_size_5                          -0.867500
# division_2_size_5                          -0.381071
# division_2_size_3                          -0.336318
#
#                    $(\overline{I}_{1182 \pm 16})^{-1}$  \
# division_1_size_5                             2.380950
# division_2_size_5                             1.463851
# division_2_size_3                             1.399784
#
#                    $\log \overline{I}_{1182 \pm 32}$  \
# division_1_size_5                          -0.841577
# division_2_size_5                          -0.365565
# division_2_size_3                          -0.337119
#
#                    $(\overline{I}_{1182 \pm 32})^{-1}$  \
# division_1_size_5                             2.320023
# division_2_size_5                             1.441329
# division_2_size_3                             1.400906
#
#                    $\log \overline{I}_{1241 \pm 16}$  \
# division_1_size_5                          -0.851606
# division_2_size_5                          -0.307571
# division_2_size_3                          -0.591503
#
#                    $(\overline{I}_{1241 \pm 16})^{-1}$  \
# division_1_size_5                             2.343408
# division_2_size_5                             1.360117
# division_2_size_3                             1.806701
#
#                    $\log \overline{I}_{1241 \pm 32}$  \
# division_1_size_5                          -0.857530
# division_2_size_5                          -0.317822
# division_2_size_3                          -0.584624
#
#                    $(\overline{I}_{1241 \pm 32})^{-1}$  \
# division_1_size_5                             2.357331
# division_2_size_5                             1.374132
# division_2_size_3                             1.794316
#
#                    $\log \overline{I}_{1393 \pm 16}$  \
# division_1_size_5                          -0.387665
# division_2_size_5                          -0.128762
# division_2_size_3                          -0.469023
#
#                    $(\overline{I}_{1393 \pm 16})^{-1}$  \
# division_1_size_5                             1.473537
# division_2_size_5                             1.137420
# division_2_size_3                             1.598432
#
#                    $\log \overline{I}_{1393 \pm 32}$  \
# division_1_size_5                          -0.419119
# division_2_size_5                          -0.150538
# division_2_size_3                          -0.487304
#
#                    $(\overline{I}_{1393 \pm 32})^{-1}$  \
# division_1_size_5                             1.520621
# division_2_size_5                             1.162460
# division_2_size_3                             1.627922
#
#                    $\log \overline{I}_{1541 \pm 16}$  \
# division_1_size_5                          -1.184680
# division_2_size_5                          -0.797165
# division_2_size_3                          -0.826068
#
#                    $(\overline{I}_{1541 \pm 16})^{-1}$  \
# division_1_size_5                             3.269642
# division_2_size_5                             2.219239
# division_2_size_3                             2.284320
#
#                    $\log \overline{I}_{1541 \pm 32}$  \
# division_1_size_5                          -1.104936
# division_2_size_5                          -0.745678
# division_2_size_3                          -0.818175
#
#                    $(\overline{I}_{1541 \pm 32})^{-1}$  \
# division_1_size_5                             3.019031
# division_2_size_5                             2.107870
# division_2_size_3                             2.266360
#
#                    $\log \overline{I}_{1625 \pm 16}$  \
# division_1_size_5                          -0.021791
# division_2_size_5                          -0.088719
# division_2_size_3                          -0.440172
#
#                    $(\overline{I}_{1625 \pm 16})^{-1}$  \
# division_1_size_5                             1.022030
# division_2_size_5                             1.092774
# division_2_size_3                             1.552974
#
#                    $\log \overline{I}_{1625 \pm 32}$  \
# division_1_size_5                          -0.079707
# division_2_size_5                          -0.129124
# division_2_size_3                          -0.469947
#
#                    $(\overline{I}_{1625 \pm 32})^{-1}$  \
# division_1_size_5                             1.082970
# division_2_size_5                             1.137832
# division_2_size_3                             1.599910
#
#                    $\log \overline{I}_{1725 \pm 16}$  \
# division_1_size_5                          -0.964723
# division_2_size_5                          -0.837586
# division_2_size_3                          -1.063190
#
#                    $(\overline{I}_{1725 \pm 16})^{-1}$  \
# division_1_size_5                             2.624062
# division_2_size_5                             2.310782
# division_2_size_3                             2.895594
#
#                    $\log \overline{I}_{1725 \pm 32}$  \
# division_1_size_5                          -0.977770
# division_2_size_5                          -0.869370
# division_2_size_3                          -1.076845
#
#                    $(\overline{I}_{1725 \pm 32})^{-1}$  \
# division_1_size_5                             2.658520
# division_2_size_5                             2.385408
# division_2_size_3                             2.935404
#
#                    $\frac{I_{874}}{I_{1084}}$  $\frac{I_{874}}{I_{1182}}$  \
# division_1_size_5                    0.159628                    0.221551
# division_2_size_5                    0.284524                    0.419107
# division_2_size_3                    0.492129                    0.688537
#
#                    $\frac{I_{874}}{I_{1241}}$  $\frac{I_{874}}{I_{1393}}$  \
# division_1_size_5                    0.215652                    0.134258
# division_2_size_5                    0.385072                    0.318930
# division_2_size_3                    0.890946                    0.777597
#
#                    $\frac{I_{874}}{I_{1541}}$  $\frac{I_{874}}{I_{1625}}$  \
# division_1_size_5                    0.310245                    0.092297
# division_2_size_5                    0.643349                    0.296566
# division_2_size_3                    1.120991                    0.752809
#
#                    $\frac{I_{874}}{I_{1725}}$  \
# division_1_size_5                    0.240059
# division_2_size_5                    0.648863
# division_2_size_3                    1.410436
#
#                    $\frac{I_{874}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_5                                          0.243700
# division_2_size_5                                          0.517565
# division_2_size_3                                          0.959669
#
#                    $\frac{I_{874}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_5                                          0.023760
# division_2_size_5                                          0.052355
# division_2_size_3                                          0.101810
#
#                    $\frac{I_{874}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_5                                           0.244169
# division_2_size_5                                           0.702949
# division_2_size_3                                           1.510430
#
#                    $\frac{I_{874}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_5                                           0.054874
# division_2_size_5                                           0.154620
# division_2_size_3                                           0.341364
#
#                    $\frac{I_{874}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_5                                           0.183723
# division_2_size_5                                           0.403372
# division_2_size_3                                           0.928306
#
#                    $\frac{I_{874}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_5                                           0.134258
# division_2_size_5                                           0.318930
# division_2_size_3                                           0.777597
#
#                    $\frac{I_{874}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_5                                          0.279687
# division_2_size_5                                          0.471386
# division_2_size_3                                          0.750859
#
#                    $\frac{I_{874}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_5                                          0.060919
# division_2_size_5                                          0.105290
# division_2_size_3                                          0.178357
#
#                    $\frac{I_{874}}{\overline{I}_{1084 \pm 16}}$  \
# division_1_size_5                                      0.160742
# division_2_size_5                                      0.289272
# division_2_size_3                                      0.497377
#
#                    $\frac{I_{874}}{\overline{I}_{1084 \pm 32}}$  \
# division_1_size_5                                      0.164244
# division_2_size_5                                      0.297101
# division_2_size_3                                      0.510054
#
#                    $\frac{I_{874}}{\overline{I}_{1182 \pm 16}}$  \
# division_1_size_5                                      0.219754
# division_2_size_5                                      0.416500
# division_2_size_3                                      0.688874
#
#                    $\frac{I_{874}}{\overline{I}_{1182 \pm 32}}$  \
# division_1_size_5                                      0.214130
# division_2_size_5                                      0.410092
# division_2_size_3                                      0.689426
#
#                    $\frac{I_{874}}{\overline{I}_{1241 \pm 16}}$  \
# division_1_size_5                                      0.216289
# division_2_size_5                                      0.386986
# division_2_size_3                                      0.889129
#
#                    $\frac{I_{874}}{\overline{I}_{1241 \pm 32}}$  \
# division_1_size_5                                      0.217574
# division_2_size_5                                      0.390973
# division_2_size_3                                      0.883034
#
#                    $\frac{I_{874}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_5                                      0.136003
# division_2_size_5                                      0.323623
# division_2_size_3                                      0.786634
#
#                    $\frac{I_{874}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_5                                      0.140348
# division_2_size_5                                      0.330747
# division_2_size_3                                      0.801147
#
#                    $\frac{I_{874}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_5                                      0.301777
# division_2_size_5                                      0.631426
# division_2_size_3                                      1.124179
#
#                    $\frac{I_{874}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_5                                      0.278646
# division_2_size_5                                      0.599739
# division_2_size_3                                      1.115341
#
#                    $\frac{I_{874}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_5                                      0.094330
# division_2_size_5                                      0.310920
# division_2_size_3                                      0.764263
#
#                    $\frac{I_{874}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_5                                      0.099955
# division_2_size_5                                      0.323740
# division_2_size_3                                      0.787361
#
#                    $\frac{I_{874}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_5                                      0.242192
# division_2_size_5                                      0.657473
# division_2_size_3                                      1.425005
#
#                    $\frac{I_{874}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_5                                      0.245373
# division_2_size_5                                      0.678705
# division_2_size_3                                      1.444596
#
#                    $\frac{I_{1084}}{I_{1182}}$  $\frac{I_{1084}}{I_{1241}}$  \
# division_1_size_5                     1.387922                     1.350969
# division_2_size_5                     1.473011                     1.353390
# division_2_size_3                     1.399100                     1.810394
#
#                    $\frac{I_{1084}}{I_{1393}}$  $\frac{I_{1084}}{I_{1541}}$  \
# division_1_size_5                     0.841067                     1.943553
# division_2_size_5                     1.120927                     2.261145
# division_2_size_3                     1.580070                     2.277841
#
#                    $\frac{I_{1084}}{I_{1625}}$  $\frac{I_{1084}}{I_{1725}}$  \
# division_1_size_5                     0.578199                     1.503866
# division_2_size_5                     1.042324                     2.280522
# division_2_size_3                     1.529701                     2.865991
#
#                    $\frac{I_{1084}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_5                                           1.526676
# division_2_size_5                                           1.819058
# division_2_size_3                                           1.950038
#
#                    $\frac{I_{1084}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_5                                           0.148847
# division_2_size_5                                           0.184008
# division_2_size_3                                           0.206878
#
#                    $\frac{I_{1084}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_5                                            1.529611
# division_2_size_5                                            2.470617
# division_2_size_3                                            3.069178
#
#                    $\frac{I_{1084}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_5                                            0.343763
# division_2_size_5                                            0.543435
# division_2_size_3                                            0.693648
#
#                    $\frac{I_{1084}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_5                                            1.150946
# division_2_size_5                                            1.417709
# division_2_size_3                                            1.886308
#
#                    $\frac{I_{1084}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_5                                            0.841067
# division_2_size_5                                            1.120927
# division_2_size_3                                            1.580070
#
#                    $\frac{I_{1084}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_5                                           1.752120
# division_2_size_5                                           1.656753
# division_2_size_3                                           1.525737
#
#                    $\frac{I_{1084}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_5                                           0.381630
# division_2_size_5                                           0.370056
# division_2_size_3                                           0.362419
#
#                    $\frac{I_{1084}}{\overline{I}_{874 \pm 16}}$  \
# division_1_size_5                                      6.231222
# division_2_size_5                                      3.493432
# division_2_size_3                                      2.020070
#
#                    $\frac{I_{1084}}{\overline{I}_{874 \pm 32}}$  \
# division_1_size_5                                      6.123365
# division_2_size_5                                      3.461424
# division_2_size_3                                      1.997481
#
#                    $\frac{I_{1084}}{\overline{I}_{1182 \pm 16}}$  \
# division_1_size_5                                       1.376662
# division_2_size_5                                       1.463851
# division_2_size_3                                       1.399784
#
#                    $\frac{I_{1084}}{\overline{I}_{1182 \pm 32}}$  \
# division_1_size_5                                       1.341434
# division_2_size_5                                       1.441329
# division_2_size_3                                       1.400906
#
#                    $\frac{I_{1084}}{\overline{I}_{1241 \pm 16}}$  \
# division_1_size_5                                       1.354955
# division_2_size_5                                       1.360117
# division_2_size_3                                       1.806701
#
#                    $\frac{I_{1084}}{\overline{I}_{1241 \pm 32}}$  \
# division_1_size_5                                       1.363005
# division_2_size_5                                       1.374132
# division_2_size_3                                       1.794316
#
#                    $\frac{I_{1084}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_5                                       0.851997
# division_2_size_5                                       1.137420
# division_2_size_3                                       1.598432
#
#                    $\frac{I_{1084}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_5                                       0.879221
# division_2_size_5                                       1.162460
# division_2_size_3                                       1.627922
#
#                    $\frac{I_{1084}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_5                                       1.890502
# division_2_size_5                                       2.219239
# division_2_size_3                                       2.284320
#
#                    $\frac{I_{1084}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_5                                       1.745599
# division_2_size_5                                       2.107870
# division_2_size_3                                       2.266360
#
#                    $\frac{I_{1084}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_5                                       0.590936
# division_2_size_5                                       1.092774
# division_2_size_3                                       1.552974
#
#                    $\frac{I_{1084}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_5                                       0.626172
# division_2_size_5                                       1.137832
# division_2_size_3                                       1.599910
#
#                    $\frac{I_{1084}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_5                                       1.517229
# division_2_size_5                                       2.310782
# division_2_size_3                                       2.895594
#
#                    $\frac{I_{1084}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_5                                       1.537153
# division_2_size_5                                       2.385408
# division_2_size_3                                       2.935404
#
#                    $\frac{I_{1182}}{I_{1241}}$  $\frac{I_{1182}}{I_{1393}}$  \
# division_1_size_5                     0.973376                     0.605990
# division_2_size_5                     0.918791                     0.760976
# division_2_size_3                     1.293970                     1.129347
#
#                    $\frac{I_{1182}}{I_{1541}}$  $\frac{I_{1182}}{I_{1625}}$  \
# division_1_size_5                     1.400333                     0.416593
# division_2_size_5                     1.535049                     0.707614
# division_2_size_3                     1.628077                     1.093346
#
#                    $\frac{I_{1182}}{I_{1725}}$  \
# division_1_size_5                     1.083538
# division_2_size_5                     1.548204
# division_2_size_3                     2.048454
#
#                    $\frac{I_{1182}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_5                                           1.099973
# division_2_size_5                                           1.234924
# division_2_size_3                                           1.393780
#
#                    $\frac{I_{1182}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_5                                           0.107245
# division_2_size_5                                           0.124919
# division_2_size_3                                           0.147865
#
#                    $\frac{I_{1182}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_5                                            1.102087
# division_2_size_5                                            1.677256
# division_2_size_3                                            2.193681
#
#                    $\frac{I_{1182}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_5                                            0.247682
# division_2_size_5                                            0.368928
# division_2_size_3                                            0.495781
#
#                    $\frac{I_{1182}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_5                                            0.829258
# division_2_size_5                                            0.962456
# division_2_size_3                                            1.348230
#
#                    $\frac{I_{1182}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_5                                            0.605990
# division_2_size_5                                            0.760976
# division_2_size_3                                            1.129347
#
#                    $\frac{I_{1182}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_5                                           1.262406
# division_2_size_5                                           1.124739
# division_2_size_3                                           1.090514
#
#                    $\frac{I_{1182}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_5                                           0.274965
# division_2_size_5                                           0.251224
# division_2_size_3                                           0.259037
#
#                    $\frac{I_{1182}}{\overline{I}_{874 \pm 16}}$  \
# division_1_size_5                                      4.489606
# division_2_size_5                                      2.371626
# division_2_size_3                                      1.443836
#
#                    $\frac{I_{1182}}{\overline{I}_{874 \pm 32}}$  \
# division_1_size_5                                      4.411895
# division_2_size_5                                      2.349897
# division_2_size_3                                      1.427690
#
#                    $\frac{I_{1182}}{\overline{I}_{1084 \pm 16}}$  \
# division_1_size_5                                       0.725532
# division_2_size_5                                       0.690210
# division_2_size_3                                       0.722368
#
#                    $\frac{I_{1182}}{\overline{I}_{1084 \pm 32}}$  \
# division_1_size_5                                       0.741336
# division_2_size_5                                       0.708891
# division_2_size_3                                       0.740780
#
#                    $\frac{I_{1182}}{\overline{I}_{1241 \pm 16}}$  \
# division_1_size_5                                       0.976248
# division_2_size_5                                       0.923358
# division_2_size_3                                       1.291331
#
#                    $\frac{I_{1182}}{\overline{I}_{1241 \pm 32}}$  \
# division_1_size_5                                       0.982048
# division_2_size_5                                       0.932873
# division_2_size_3                                       1.282479
#
#                    $\frac{I_{1182}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_5                                       0.613865
# division_2_size_5                                       0.772173
# division_2_size_3                                       1.142472
#
#                    $\frac{I_{1182}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_5                                       0.633480
# division_2_size_5                                       0.789172
# division_2_size_3                                       1.163550
#
#                    $\frac{I_{1182}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_5                                       1.362110
# division_2_size_5                                       1.506600
# division_2_size_3                                       1.632707
#
#                    $\frac{I_{1182}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_5                                       1.257707
# division_2_size_5                                       1.430994
# division_2_size_3                                       1.619870
#
#                    $\frac{I_{1182}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_5                                       0.425771
# division_2_size_5                                       0.741864
# division_2_size_3                                       1.109981
#
#                    $\frac{I_{1182}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_5                                       0.451158
# division_2_size_5                                       0.772453
# division_2_size_3                                       1.143528
#
#                    $\frac{I_{1182}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_5                                       1.093166
# division_2_size_5                                       1.568747
# division_2_size_3                                       2.069613
#
#                    $\frac{I_{1182}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_5                                       1.107521
# division_2_size_5                                       1.619409
# division_2_size_3                                       2.098067
#
#                    $\frac{I_{1241}}{I_{1393}}$  $\frac{I_{1241}}{I_{1541}}$  \
# division_1_size_5                     0.622566                     1.438636
# division_2_size_5                     0.828236                     1.670726
# division_2_size_3                     0.872777                     1.258202
#
#                    $\frac{I_{1241}}{I_{1625}}$  $\frac{I_{1241}}{I_{1725}}$  \
# division_1_size_5                     0.427988                     1.113176
# division_2_size_5                     0.770157                     1.685044
# division_2_size_3                     0.844955                     1.583076
#
#                    $\frac{I_{1241}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_5                                           1.130060
# division_2_size_5                                           1.344075
# division_2_size_3                                           1.077135
#
#                    $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_5                                           0.110178
# division_2_size_5                                           0.135961
# division_2_size_3                                           0.114272
#
#                    $\frac{I_{1241}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_5                                            1.132232
# division_2_size_5                                            1.825502
# division_2_size_3                                            1.695310
#
#                    $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_5                                            0.254456
# division_2_size_5                                            0.401536
# division_2_size_3                                            0.383147
#
#                    $\frac{I_{1241}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_5                                            0.851941
# division_2_size_5                                            1.047524
# division_2_size_3                                            1.041932
#
#                    $\frac{I_{1241}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_5                                            0.622566
# division_2_size_5                                            0.828236
# division_2_size_3                                            0.872777
#
#                    $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_5                                           1.296936
# division_2_size_5                                           1.224150
# division_2_size_3                                           0.842766
#
#                    $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_5                                           0.282486
# division_2_size_5                                           0.273429
# division_2_size_3                                           0.200188
#
#                    $\frac{I_{1241}}{\overline{I}_{874 \pm 16}}$  \
# division_1_size_5                                      4.612409
# division_2_size_5                                      2.581245
# division_2_size_3                                      1.115818
#
#                    $\frac{I_{1241}}{\overline{I}_{874 \pm 32}}$  \
# division_1_size_5                                      4.532572
# division_2_size_5                                      2.557595
# division_2_size_3                                      1.103341
#
#                    $\frac{I_{1241}}{\overline{I}_{1084 \pm 16}}$  \
# division_1_size_5                                       0.745377
# division_2_size_5                                       0.751215
# division_2_size_3                                       0.558257
#
#                    $\frac{I_{1241}}{\overline{I}_{1084 \pm 32}}$  \
# division_1_size_5                                       0.761614
# division_2_size_5                                       0.771547
# division_2_size_3                                       0.572486
#
#                    $\frac{I_{1241}}{\overline{I}_{1182 \pm 16}}$  \
# division_1_size_5                                       1.019018
# division_2_size_5                                       1.081618
# division_2_size_3                                       0.773193
#
#                    $\frac{I_{1241}}{\overline{I}_{1182 \pm 32}}$  \
# division_1_size_5                                       0.992942
# division_2_size_5                                       1.064976
# division_2_size_3                                       0.773813
#
#                    $\frac{I_{1241}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_5                                       0.630656
# division_2_size_5                                       0.840423
# division_2_size_3                                       0.882920
#
#                    $\frac{I_{1241}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_5                                       0.650807
# division_2_size_5                                       0.858924
# division_2_size_3                                       0.899209
#
#                    $\frac{I_{1241}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_5                                       1.399367
# division_2_size_5                                       1.639763
# division_2_size_3                                       1.261781
#
#                    $\frac{I_{1241}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_5                                       1.292109
# division_2_size_5                                       1.557474
# division_2_size_3                                       1.251860
#
#                    $\frac{I_{1241}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_5                                       0.437417
# division_2_size_5                                       0.807434
# division_2_size_3                                       0.857810
#
#                    $\frac{I_{1241}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_5                                       0.463498
# division_2_size_5                                       0.840727
# division_2_size_3                                       0.883736
#
#                    $\frac{I_{1241}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_5                                       1.123067
# division_2_size_5                                       1.707403
# division_2_size_3                                       1.599428
#
#                    $\frac{I_{1241}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_5                                       1.137815
# division_2_size_5                                       1.762542
# division_2_size_3                                       1.621418
#
#                    $\frac{I_{1393}}{I_{1541}}$  $\frac{I_{1393}}{I_{1625}}$  \
# division_1_size_5                     2.310818                     0.687458
# division_2_size_5                     2.017209                     0.929876
# division_2_size_3                     1.441608                     0.968122
#
#                    $\frac{I_{1393}}{I_{1725}}$  \
# division_1_size_5                     1.788046
# division_2_size_5                     2.034496
# division_2_size_3                     1.813838
#
#                    $\frac{I_{1393}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_5                                           1.815165
# division_2_size_5                                           1.622816
# division_2_size_3                                           1.234147
#
#                    $\frac{I_{1393}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_5                                           0.176974
# division_2_size_5                                           0.164157
# division_2_size_3                                           0.130929
#
#                    $\frac{I_{1393}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_5                                            1.818655
# division_2_size_5                                            2.204083
# division_2_size_3                                            1.942432
#
#                    $\frac{I_{1393}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_5                                            0.408722
# division_2_size_5                                            0.484809
# division_2_size_3                                            0.438998
#
#                    $\frac{I_{1393}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_5                                            1.368435
# division_2_size_5                                            1.264765
# division_2_size_3                                            1.193813
#
#                    $\frac{I_{1393}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_5                                                 1.0
# ...
# division_2_size_3                                                         1.162049
#
#                    $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_5                                                         1.409315
# division_2_size_5                                                         1.539718
# division_2_size_3                                                         1.630602
#
#                    $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_5                                                         1.301294
# division_2_size_5                                                         1.462449
# division_2_size_3                                                         1.617781
#
#                    $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_5                                                         0.440526
# division_2_size_5                                                         0.758171
# division_2_size_3                                                         1.108550
#
#                    $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_5                                                         0.466793
# division_2_size_5                                                         0.789433
# division_2_size_3                                                         1.142053
#
#                    $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_5                                                         1.131050
# division_2_size_5                                                         1.603231
# division_2_size_3                                                         2.066944
#
#                    $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_5                                                         1.145903
# division_2_size_5                                                         1.655006
# division_2_size_3                                                         2.095361
#
#                    $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_5                                                         0.628801
# division_2_size_5                                                         0.836266
# division_2_size_3                                                         0.884724
#
#                    $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_5                                                         0.648893
# division_2_size_5                                                         0.854676
# division_2_size_3                                                         0.901047
#
#                    $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_5                                                         1.395251
# division_2_size_5                                                         1.631654
# division_2_size_3                                                         1.264360
#
#                    $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_5                                                         1.288308
# division_2_size_5                                                         1.549771
# division_2_size_3                                                         1.254419
#
#                    $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_5                                                         0.436130
# division_2_size_5                                                         0.803441
# division_2_size_3                                                         0.859563
#
#                    $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_5                                                         0.462135
# division_2_size_5                                                         0.836569
# division_2_size_3                                                         0.885542
#
#                    $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_5                                                         1.119763
# division_2_size_5                                                         1.698959
# division_2_size_3                                                         1.602697
#
#                    $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_5                                                         1.134468
# division_2_size_5                                                         1.753826
# division_2_size_3                                                         1.624732
#
#                    $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_5                                                         0.625087
# division_2_size_5                                                         0.827737
# division_2_size_3                                                         0.890831
#
#                    $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_5                                                         0.645060
# division_2_size_5                                                         0.845959
# division_2_size_3                                                         0.907266
#
#                    $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_5                                                         1.387010
# division_2_size_5                                                         1.615012
# division_2_size_3                                                         1.273087
#
#                    $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_5                                                         1.280699
# division_2_size_5                                                         1.533965
# division_2_size_3                                                         1.263078
#
#                    $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_5                                                         0.433554
# division_2_size_5                                                         0.795247
# division_2_size_3                                                         0.865497
#
#                    $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_5                                                         0.459405
# division_2_size_5                                                         0.828037
# division_2_size_3                                                         0.891655
#
#                    $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_5                                                         1.113150
# division_2_size_5                                                         1.681631
# division_2_size_3                                                         1.613760
#
#                    $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_5                                                         1.127767
# division_2_size_5                                                         1.735938
# division_2_size_3                                                         1.635946
#
#                    $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_5                                                         2.218907
# division_2_size_5                                                         1.951117
# division_2_size_3                                                         1.429101
#
#                    $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_5                                                         2.048833
# division_2_size_5                                                         1.853203
# division_2_size_3                                                         1.417865
#
#                    $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_5                                                         0.693590
# division_2_size_5                                                         0.960748
# division_2_size_3                                                         0.971561
#
#                    $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_5                                                         0.734946
# division_2_size_5                                                         1.000362
# division_2_size_3                                                         1.000925
#
#                    $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_5                                                         1.780791
# division_2_size_5                                                         2.031600
# division_2_size_3                                                         1.811522
#
#                    $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_5                                                         1.804177
# division_2_size_5                                                         2.097209
# division_2_size_3                                                         1.836428
#
#                    $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_5                                                         2.150202
# division_2_size_5                                                         1.909089
# division_2_size_3                                                         1.403212
#
#                    $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_5                                                         1.985394
# division_2_size_5                                                         1.813284
# division_2_size_3                                                         1.392180
#
#                    $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_5                                                         0.672114
# division_2_size_5                                                         0.940053
# division_2_size_3                                                         0.953961
#
#                    $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_5                                                         0.712189
# division_2_size_5                                                         0.978814
# division_2_size_3                                                         0.982793
#
#                    $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_5                                                         1.725652
# division_2_size_5                                                         1.987839
# division_2_size_3                                                         1.778706
#
#                    $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_5                                                         1.748313
# division_2_size_5                                                         2.052035
# division_2_size_3                                                         1.803161
#
#                    $\frac{\overline{I}_{1541 \pm 16}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_5                                                         0.312582
# division_2_size_5                                                         0.492409
# division_2_size_3                                                         0.679841
#
#                    $\frac{\overline{I}_{1541 \pm 16}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_5                                                         0.331220
# division_2_size_5                                                         0.512712
# division_2_size_3                                                         0.700388
#
#                    $\frac{\overline{I}_{1541 \pm 16}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_5                                                         0.802553
# division_2_size_5                                                         1.041250
# division_2_size_3                                                         1.267596
#
#                    $\frac{\overline{I}_{1541 \pm 16}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_5                                                         0.813092
# division_2_size_5                                                         1.074876
# division_2_size_3                                                         1.285023
#
#                    $\frac{\overline{I}_{1541 \pm 32}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_5                                                         0.338529
# division_2_size_5                                                         0.518426
# division_2_size_3                                                         0.685228
#
#                    $\frac{\overline{I}_{1541 \pm 32}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_5                                                         0.358714
# division_2_size_5                                                         0.539802
# division_2_size_3                                                         0.705938
#
#                    $\frac{\overline{I}_{1541 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_5                                                         0.869173
# division_2_size_5                                                         1.096264
# division_2_size_3                                                         1.277641
#
#                    $\frac{\overline{I}_{1541 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_5                                                         0.880587
# division_2_size_5                                                         1.131667
# division_2_size_3                                                         1.295206
#
#                    $\frac{\overline{I}_{1625 \pm 16}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_5                                                         2.567499
# division_2_size_5                                                         2.114603
# division_2_size_3                                                         1.864548
#
#                    $\frac{\overline{I}_{1625 \pm 16}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_5                                                         2.601215
# division_2_size_5                                                         2.182892
# division_2_size_3                                                         1.890182
#
#                    $\frac{\overline{I}_{1625 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_5                                                         2.423024
# division_2_size_5                                                         2.030865
# division_2_size_3                                                         1.809848
#
#                    $\frac{\overline{I}_{1625 \pm 32}}{\overline{I}_{1725 \pm 32}}$
# division_1_size_5                                                         2.454842
# division_2_size_5                                                         2.096450
# division_2_size_3                                                         1.834731

# %%
dataset = pd.concat([dataset_train, dataset_test], axis=0)

print(dataset.shape)
dataset.head(3)
# Out:
# (75, 491)
#                       $I_{874}$  $I_{1084}$  $I_{1182}$  $I_{1241}$  \
# division_1_size_bulk   0.048493    0.681294    0.388923    0.455066
# division_1_size_3      0.112416    0.836176    0.514367    0.400950
# division_1_size_2.5    0.113965    0.642576    0.406665    0.416118
#
#                       $I_{1393}$  $I_{1541}$  $I_{1625}$  $I_{1725}$  \
# division_1_size_bulk    0.760582    0.367672         1.0    0.423273
# division_1_size_3       0.696553    0.461156         1.0    0.368753
# division_1_size_2.5     0.801299    0.842757         1.0    0.543270
#
#                       $\overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                          0.424162
# division_1_size_3                             0.436266
# division_1_size_2.5                           0.525971
#
#                       $\Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                          4.125303
# division_1_size_3                             4.390371
# division_1_size_2.5                           4.766650
#
#                       $\overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                           0.426619
# division_1_size_3                              0.429362
# division_1_size_2.5                            0.647458
#
#                       $\Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                           1.790945
# division_1_size_3                              1.829909
# division_1_size_2.5                            2.386027
#
#                       $\overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                           0.571735
# division_1_size_3                              0.523513
# division_1_size_2.5                            0.676532
#
#                       $\Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                           0.760582
# division_1_size_3                              0.696553
# division_1_size_2.5                            0.801299
#
#                       $\overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                          0.363338
# division_1_size_3                             0.406988
# division_1_size_2.5                           0.368779
#
#                       $\Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                          1.573776
# division_1_size_3                             1.863909
# division_1_size_2.5                           1.579324
#
#                       $\overline{I}_{874 \pm 16}$  \
# division_1_size_bulk                     0.047265
# division_1_size_3                        0.112733
# division_1_size_2.5                      0.109038
#
#                       $\overline{I}_{874 \pm 32}$  \
# division_1_size_bulk                     0.048014
# division_1_size_3                        0.115579
# division_1_size_2.5                      0.107469
#
#                       $\overline{I}_{1084 \pm 16}$  \
# division_1_size_bulk                      0.662496
# division_1_size_3                         0.776369
# division_1_size_2.5                       0.612194
#
#                       $\overline{I}_{1084 \pm 32}$  \
# division_1_size_bulk                      0.657082
# division_1_size_3                         0.765984
# division_1_size_2.5                       0.612489
#
#                       $\overline{I}_{1182 \pm 16}$  \
# division_1_size_bulk                      0.392509
# division_1_size_3                         0.518442
# division_1_size_2.5                       0.408719
#
#                       $\overline{I}_{1182 \pm 32}$  \
# division_1_size_bulk                      0.405814
# division_1_size_3                         0.532188
# division_1_size_2.5                       0.418879
#
#                       $\overline{I}_{1241 \pm 16}$  \
# division_1_size_bulk                      0.452149
# division_1_size_3                         0.400848
# division_1_size_2.5                       0.414206
#
#                       $\overline{I}_{1241 \pm 32}$  \
# division_1_size_bulk                      0.446270
# division_1_size_3                         0.402630
# division_1_size_2.5                       0.412569
#
#                       $\overline{I}_{1393 \pm 16}$  \
# division_1_size_bulk                      0.750393
# division_1_size_3                         0.688316
# division_1_size_2.5                       0.789455
#
#                       $\overline{I}_{1393 \pm 32}$  \
# division_1_size_bulk                      0.728337
# division_1_size_3                         0.668191
# division_1_size_2.5                       0.776950
#
#                       $\overline{I}_{1541 \pm 16}$  \
# division_1_size_bulk                      0.375020
# division_1_size_3                         0.466881
# division_1_size_2.5                       0.835396
#
#                       $\overline{I}_{1541 \pm 32}$  \
# division_1_size_bulk                      0.398300
# division_1_size_3                         0.484095
# division_1_size_2.5                       0.818229
#
#                       $\overline{I}_{1625 \pm 16}$  \
# division_1_size_bulk                      0.977345
# division_1_size_3                         0.980602
# division_1_size_2.5                       0.960529
#
#                       $\overline{I}_{1625 \pm 32}$  \
# division_1_size_bulk                      0.926084
# division_1_size_3                         0.939339
# division_1_size_2.5                       0.953859
#
#                       $\overline{I}_{1725 \pm 16}$  \
# division_1_size_bulk                      0.419742
# division_1_size_3                         0.367814
# division_1_size_2.5                       0.546926
#
#                       $\overline{I}_{1725 \pm 32}$  $\log I_{874}$  \
# division_1_size_bulk                      0.415811       -3.026334
# division_1_size_3                         0.371003       -2.185546
# division_1_size_2.5                       0.562146       -2.171866
#
#                       $(I_{874})^{-1}$  $\log I_{1084}$  $(I_{1084})^{-1}$  \
# division_1_size_bulk         20.621489        -0.383761           1.467794
# division_1_size_3             8.895503        -0.178917           1.195921
# division_1_size_2.5           8.774639        -0.442270           1.556235
#
#                       $\log I_{1182}$  $(I_{1182})^{-1}$  $\log I_{1241}$  \
# division_1_size_bulk        -0.944375           2.571206        -0.787312
# division_1_size_3           -0.664819           1.944138        -0.913918
# division_1_size_2.5         -0.899766           2.459028        -0.876787
#
#                       $(I_{1241})^{-1}$  $\log I_{1393}$  $(I_{1393})^{-1}$  \
# division_1_size_bulk           2.197482        -0.273672           1.314783
# division_1_size_3              2.494076        -0.361611           1.435640
# division_1_size_2.5            2.403166        -0.221521           1.247973
#
#                       $\log I_{1541}$  $(I_{1541})^{-1}$  $\log I_{1625}$  \
# division_1_size_bulk        -1.000564           2.719814              0.0
# division_1_size_3           -0.774019           2.168463              0.0
# division_1_size_2.5         -0.171077           1.186582              0.0
#
#                       $(I_{1625})^{-1}$  $\log I_{1725}$  $(I_{1725})^{-1}$  \
# division_1_size_bulk                1.0        -0.859739           2.362543
# division_1_size_3                   1.0        -0.997629           2.711845
# division_1_size_2.5                 1.0        -0.610149           1.840705
#
#                       $\log \overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                              -0.857641
# division_1_size_3                                 -0.829504
# division_1_size_2.5                               -0.642509
#
#                       $(\overline{I}_{1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.357591
# division_1_size_3                                    2.292181
# division_1_size_2.5                                  1.901245
#
#                       $\log \Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                               1.417139
# division_1_size_3                                  1.479414
# division_1_size_2.5                                1.561644
#
#                       $(\Sigma I_{p,\ 1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.242406
# division_1_size_3                                    0.227771
# division_1_size_2.5                                  0.209791
#
#                       $\log \overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                               -0.851863
# division_1_size_3                                  -0.845455
# division_1_size_2.5                                -0.434702
#
#                       $(\overline{I}_{1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  2.344010
# division_1_size_3                                     2.329038
# division_1_size_2.5                                   1.544503
#
#                       $\log \Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                                0.582743
# division_1_size_3                                   0.604266
# division_1_size_2.5                                 0.869630
#
#                       $(\Sigma I_{p,\ 1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  0.558364
# division_1_size_3                                     0.546475
# division_1_size_2.5                                   0.419107
#
#                       $\log \overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                               -0.559080
# division_1_size_3                                  -0.647194
# division_1_size_2.5                                -0.390776
#
#                       $(\overline{I}_{1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.749062
# division_1_size_3                                     1.910173
# division_1_size_2.5                                   1.478127
#
#                       $\log \Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                               -0.273672
# division_1_size_3                                  -0.361611
# division_1_size_2.5                                -0.221521
#
#                       $(\Sigma I_{p,\ 1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.314783
# division_1_size_3                                     1.435640
# division_1_size_2.5                                   1.247973
#
#                       $\log \overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                              -1.012422
# division_1_size_3                                 -0.898970
# division_1_size_2.5                               -0.997558
#
#                       $(\overline{I}_{1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.752259
# division_1_size_3                                    2.457072
# division_1_size_2.5                                  2.711653
#
#                       $\log \Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                               0.453478
# division_1_size_3                                  0.622676
# division_1_size_2.5                                0.456997
#
#                       $(\Sigma I_{p,\ 1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.635414
# division_1_size_3                                    0.536507
# division_1_size_2.5                                  0.633182
#
#                       $\log \overline{I}_{874 \pm 16}$  \
# division_1_size_bulk                         -3.051984
# division_1_size_3                            -2.182731
# division_1_size_2.5                          -2.216059
#
#                       $(\overline{I}_{874 \pm 16})^{-1}$  \
# division_1_size_bulk                           21.157274
# division_1_size_3                               8.870495
# division_1_size_2.5                             9.171115
#
#                       $\log \overline{I}_{874 \pm 32}$  \
# division_1_size_bulk                         -3.036257
# division_1_size_3                            -2.157802
# division_1_size_2.5                          -2.230550
#
#                       $(\overline{I}_{874 \pm 32})^{-1}$  \
# division_1_size_bulk                           20.827141
# division_1_size_3                               8.652097
# division_1_size_2.5                             9.304984
#
#                       $\log \overline{I}_{1084 \pm 16}$  \
# division_1_size_bulk                          -0.411741
# division_1_size_3                             -0.253127
# division_1_size_2.5                           -0.490706
#
#                       $(\overline{I}_{1084 \pm 16})^{-1}$  \
# division_1_size_bulk                             1.509444
# division_1_size_3                                1.288047
# division_1_size_2.5                              1.633469
#
#                       $\log \overline{I}_{1084 \pm 32}$  \
# division_1_size_bulk                          -0.419947
# division_1_size_3                             -0.266595
# division_1_size_2.5                           -0.490225
#
#                       $(\overline{I}_{1084 \pm 32})^{-1}$  \
# division_1_size_bulk                             1.521881
# division_1_size_3                                1.305511
# division_1_size_2.5                              1.632684
#
#                       $\log \overline{I}_{1182 \pm 16}$  \
# division_1_size_bulk                          -0.935195
# division_1_size_3                             -0.656926
# division_1_size_2.5                           -0.894727
#
#                       $(\overline{I}_{1182 \pm 16})^{-1}$  \
# division_1_size_bulk                             2.547710
# division_1_size_3                                1.928854
# division_1_size_2.5                              2.446667
#
#                       $\log \overline{I}_{1182 \pm 32}$  \
# division_1_size_bulk                          -0.901862
# division_1_size_3                             -0.630758
# division_1_size_2.5                           -0.870173
#
#                       $(\overline{I}_{1182 \pm 32})^{-1}$  \
# division_1_size_bulk                             2.464186
# division_1_size_3                                1.879034
# division_1_size_2.5                              2.387323
#
#                       $\log \overline{I}_{1241 \pm 16}$  \
# division_1_size_bulk                          -0.793744
# division_1_size_3                             -0.914173
# division_1_size_2.5                           -0.881392
#
#                       $(\overline{I}_{1241 \pm 16})^{-1}$  \
# division_1_size_bulk                             2.211661
# division_1_size_3                                2.494711
# division_1_size_2.5                              2.414258
#
#                       $\log \overline{I}_{1241 \pm 32}$  \
# division_1_size_bulk                          -0.806831
# division_1_size_3                             -0.909738
# division_1_size_2.5                           -0.885351
#
#                       $(\overline{I}_{1241 \pm 32})^{-1}$  \
# division_1_size_bulk                             2.240797
# division_1_size_3                                2.483671
# division_1_size_2.5                              2.423834
#
#                       $\log \overline{I}_{1393 \pm 16}$  \
# division_1_size_bulk                          -0.287159
# division_1_size_3                             -0.373508
# division_1_size_2.5                           -0.236412
#
#                       $(\overline{I}_{1393 \pm 16})^{-1}$  \
# division_1_size_bulk                             1.332636
# division_1_size_3                                1.452822
# division_1_size_2.5                              1.266697
#
#                       $\log \overline{I}_{1393 \pm 32}$  \
# division_1_size_bulk                          -0.316992
# division_1_size_3                             -0.403181
# division_1_size_2.5                           -0.252379
#
#                       $(\overline{I}_{1393 \pm 32})^{-1}$  \
# division_1_size_bulk                             1.372991
# division_1_size_3                                1.496578
# division_1_size_2.5                              1.287084
#
#                       $\log \overline{I}_{1541 \pm 16}$  \
# division_1_size_bulk                          -0.980775
# division_1_size_3                             -0.761681
# division_1_size_2.5                           -0.179850
#
#                       $(\overline{I}_{1541 \pm 16})^{-1}$  \
# division_1_size_bulk                             2.666523
# division_1_size_3                                2.141873
# division_1_size_2.5                              1.197037
#
#                       $\log \overline{I}_{1541 \pm 32}$  \
# division_1_size_bulk                          -0.920549
# division_1_size_3                             -0.725474
# division_1_size_2.5                           -0.200613
#
#                       $(\overline{I}_{1541 \pm 32})^{-1}$  \
# division_1_size_bulk                             2.510669
# division_1_size_3                                2.065710
# division_1_size_2.5                              1.222152
#
#                       $\log \overline{I}_{1625 \pm 16}$  \
# division_1_size_bulk                          -0.022916
# division_1_size_3                             -0.019589
# division_1_size_2.5                           -0.040271
#
#                       $(\overline{I}_{1625 \pm 16})^{-1}$  \
# division_1_size_bulk                             1.023181
# division_1_size_3                                1.019782
# division_1_size_2.5                              1.041093
#
#                       $\log \overline{I}_{1625 \pm 32}$  \
# division_1_size_bulk                          -0.076790
# division_1_size_3                             -0.062579
# division_1_size_2.5                           -0.047240
#
#                       $(\overline{I}_{1625 \pm 32})^{-1}$  \
# division_1_size_bulk                             1.079816
# division_1_size_3                                1.064578
# division_1_size_2.5                              1.048373
#
#                       $\log \overline{I}_{1725 \pm 16}$  \
# division_1_size_bulk                          -0.868116
# division_1_size_3                             -1.000179
# division_1_size_2.5                           -0.603442
#
#                       $(\overline{I}_{1725 \pm 16})^{-1}$  \
# division_1_size_bulk                             2.382418
# division_1_size_3                                2.718768
# division_1_size_2.5                              1.828401
#
#                       $\log \overline{I}_{1725 \pm 32}$  \
# division_1_size_bulk                          -0.877525
# division_1_size_3                             -0.991544
# division_1_size_2.5                           -0.575993
#
#                       $(\overline{I}_{1725 \pm 32})^{-1}$  \
# division_1_size_bulk                             2.404941
# division_1_size_3                                2.695394
# division_1_size_2.5                              1.778896
#
#                       $\frac{I_{874}}{I_{1084}}$  $\frac{I_{874}}{I_{1182}}$  \
# division_1_size_bulk                    0.071178                    0.124686
# division_1_size_3                       0.134441                    0.218553
# division_1_size_2.5                     0.177356                    0.280243
#
#                       $\frac{I_{874}}{I_{1241}}$  $\frac{I_{874}}{I_{1393}}$  \
# division_1_size_bulk                    0.106563                    0.063758
# division_1_size_3                       0.280375                    0.161389
# division_1_size_2.5                     0.273876                    0.142225
#
#                       $\frac{I_{874}}{I_{1541}}$  $\frac{I_{874}}{I_{1625}}$  \
# division_1_size_bulk                    0.131892                    0.048493
# division_1_size_3                       0.243771                    0.112416
# division_1_size_2.5                     0.135229                    0.113965
#
#                       $\frac{I_{874}}{I_{1725}}$  \
# division_1_size_bulk                    0.114567
# division_1_size_3                       0.304856
# division_1_size_2.5                     0.209776
#
#                       $\frac{I_{874}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                          0.114327
# division_1_size_3                                             0.257679
# division_1_size_2.5                                           0.216675
#
#                       $\frac{I_{874}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                          0.011755
# division_1_size_3                                             0.025605
# division_1_size_2.5                                           0.023909
#
#                       $\frac{I_{874}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.113668
# division_1_size_3                                              0.261822
# division_1_size_2.5                                            0.176019
#
#                       $\frac{I_{874}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.027077
# division_1_size_3                                              0.061433
# division_1_size_2.5                                            0.047763
#
#                       $\frac{I_{874}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.084817
# division_1_size_3                                              0.214735
# division_1_size_2.5                                            0.168454
#
#                       $\frac{I_{874}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.063758
# division_1_size_3                                              0.161389
# division_1_size_2.5                                            0.142225
#
#                       $\frac{I_{874}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                          0.133466
# division_1_size_3                                             0.276215
# division_1_size_2.5                                           0.309033
#
#                       $\frac{I_{874}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                          0.030813
# division_1_size_3                                             0.060312
# division_1_size_2.5                                           0.072161
#
#                       $\frac{I_{874}}{\overline{I}_{1084 \pm 16}}$  \
# division_1_size_bulk                                      0.073198
# division_1_size_3                                         0.144798
# division_1_size_2.5                                       0.186158
#
#                       $\frac{I_{874}}{\overline{I}_{1084 \pm 32}}$  \
# division_1_size_bulk                                      0.073801
# division_1_size_3                                         0.146761
# division_1_size_2.5                                       0.186068
#
#                       $\frac{I_{874}}{\overline{I}_{1182 \pm 16}}$  \
# division_1_size_bulk                                      0.123546
# division_1_size_3                                         0.216835
# division_1_size_2.5                                       0.278834
#
#                       $\frac{I_{874}}{\overline{I}_{1182 \pm 32}}$  \
# division_1_size_bulk                                      0.119496
# division_1_size_3                                         0.211234
# division_1_size_2.5                                       0.272071
#
#                       $\frac{I_{874}}{\overline{I}_{1241 \pm 16}}$  \
# division_1_size_bulk                                      0.107250
# division_1_size_3                                         0.280446
# division_1_size_2.5                                       0.275140
#
#                       $\frac{I_{874}}{\overline{I}_{1241 \pm 32}}$  \
# division_1_size_bulk                                      0.108663
# division_1_size_3                                         0.279205
# division_1_size_2.5                                       0.276232
#
#                       $\frac{I_{874}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                      0.064624
# division_1_size_3                                         0.163321
# division_1_size_2.5                                       0.144359
#
#                       $\frac{I_{874}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                      0.066581
# division_1_size_3                                         0.168240
# division_1_size_2.5                                       0.146682
#
#                       $\frac{I_{874}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                      0.129308
# division_1_size_3                                         0.240782
# division_1_size_2.5                                       0.136420
#
#                       $\frac{I_{874}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                      0.121750
# division_1_size_3                                         0.232220
# division_1_size_2.5                                       0.139282
#
#                       $\frac{I_{874}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                      0.049617
# division_1_size_3                                         0.114640
# division_1_size_2.5                                       0.118648
#
#                       $\frac{I_{874}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                      0.052364
# division_1_size_3                                         0.119676
# division_1_size_2.5                                       0.119478
#
#                       $\frac{I_{874}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                      0.115531
# division_1_size_3                                         0.305634
# division_1_size_2.5                                       0.208373
#
#                       $\frac{I_{874}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                      0.116623
# division_1_size_3                                         0.303006
# division_1_size_2.5                                       0.202732
#
#                       $\frac{I_{1084}}{I_{1182}}$  \
# division_1_size_bulk                     1.751748
# division_1_size_3                        1.625641
# division_1_size_2.5                      1.580113
#
#                       $\frac{I_{1084}}{I_{1241}}$  \
# division_1_size_bulk                     1.497132
# division_1_size_3                        2.085485
# division_1_size_2.5                      1.544218
#
#                       $\frac{I_{1084}}{I_{1393}}$  \
# division_1_size_bulk                     0.895754
# division_1_size_3                        1.200447
# division_1_size_2.5                      0.801918
#
#                       $\frac{I_{1084}}{I_{1541}}$  \
# division_1_size_bulk                     1.852994
# division_1_size_3                        1.813216
# division_1_size_2.5                      0.762470
#
#                       $\frac{I_{1084}}{I_{1625}}$  \
# division_1_size_bulk                     0.681294
# division_1_size_3                        0.836176
# division_1_size_2.5                      0.642576
#
#                       $\frac{I_{1084}}{I_{1725}}$  \
# division_1_size_bulk                     1.609587
# division_1_size_3                        2.267579
# division_1_size_2.5                      1.182793
#
#                       $\frac{I_{1084}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.606214
# division_1_size_3                                              1.916666
# division_1_size_2.5                                            1.221695
#
#                       $\frac{I_{1084}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.165150
# division_1_size_3                                              0.190457
# division_1_size_2.5                                            0.134807
#
#                       $\frac{I_{1084}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.596961
# division_1_size_3                                               1.947485
# division_1_size_2.5                                             0.992461
#
#                       $\frac{I_{1084}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.380411
# division_1_size_3                                               0.456949
# division_1_size_2.5                                             0.269308
#
#                       $\frac{I_{1084}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.191626
# division_1_size_3                                               1.597240
# division_1_size_2.5                                             0.949810
#
#                       $\frac{I_{1084}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.895754
# division_1_size_3                                               1.200447
# division_1_size_2.5                                             0.801918
#
#                       $\frac{I_{1084}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.875098
# division_1_size_3                                              2.054544
# division_1_size_2.5                                            1.742444
#
#                       $\frac{I_{1084}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.432904
# division_1_size_3                                              0.448614
# division_1_size_2.5                                            0.406868
#
#                       $\frac{I_{1084}}{\overline{I}_{874 \pm 16}}$  \
# division_1_size_bulk                                     14.414330
# division_1_size_3                                         7.417292
# division_1_size_2.5                                       5.893142
#
#                       $\frac{I_{1084}}{\overline{I}_{874 \pm 32}}$  \
# division_1_size_bulk                                     14.189412
# division_1_size_3                                         7.234673
# division_1_size_2.5                                       5.979163
#
#                       $\frac{I_{1084}}{\overline{I}_{1182 \pm 16}}$  \
# division_1_size_bulk                                       1.735740
# division_1_size_3                                          1.612861
# division_1_size_2.5                                        1.572170
#
#                       $\frac{I_{1084}}{\overline{I}_{1182 \pm 32}}$  \
# division_1_size_bulk                                       1.678836
# division_1_size_3                                          1.571203
# division_1_size_2.5                                        1.534038
#
#                       $\frac{I_{1084}}{\overline{I}_{1241 \pm 16}}$  \
# division_1_size_bulk                                       1.506792
# division_1_size_3                                          2.086017
# division_1_size_2.5                                        1.551345
#
#                       $\frac{I_{1084}}{\overline{I}_{1241 \pm 32}}$  \
# division_1_size_bulk                                       1.526642
# division_1_size_3                                          2.076785
# division_1_size_2.5                                        1.557499
#
#                       $\frac{I_{1084}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                       0.907917
# division_1_size_3                                          1.214814
# division_1_size_2.5                                        0.813949
#
#                       $\frac{I_{1084}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                       0.935411
# division_1_size_3                                          1.251402
# division_1_size_2.5                                        0.827050
#
#                       $\frac{I_{1084}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                       1.816687
# division_1_size_3                                          1.790982
# division_1_size_2.5                                        0.769188
#
#                       $\frac{I_{1084}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                       1.710504
# division_1_size_3                                          1.727296
# division_1_size_2.5                                        0.785326
#
#                       $\frac{I_{1084}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                       0.697087
# division_1_size_3                                          0.852717
# division_1_size_2.5                                        0.668982
#
#                       $\frac{I_{1084}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                       0.735672
# division_1_size_3                                          0.890175
# division_1_size_2.5                                        0.673660
#
#                       $\frac{I_{1084}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                       1.623128
# division_1_size_3                                          2.273368
# division_1_size_2.5                                        1.174887
#
#                       $\frac{I_{1084}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                       1.638473
# division_1_size_3                                          2.253823
# division_1_size_2.5                                        1.143076
#
#                       $\frac{I_{1182}}{I_{1241}}$  \
# division_1_size_bulk                     0.854650
# division_1_size_3                        1.282869
# division_1_size_2.5                      0.977283
#
#                       $\frac{I_{1182}}{I_{1393}}$  \
# division_1_size_bulk                     0.511349
# division_1_size_3                        0.738445
# division_1_size_2.5                      0.507507
#
#                       $\frac{I_{1182}}{I_{1541}}$  \
# division_1_size_bulk                     1.057797
# division_1_size_3                        1.115385
# division_1_size_2.5                      0.482541
#
#                       $\frac{I_{1182}}{I_{1625}}$  \
# division_1_size_bulk                     0.388923
# division_1_size_3                        0.514367
# division_1_size_2.5                      0.406665
#
#                       $\frac{I_{1182}}{I_{1725}}$  \
# division_1_size_bulk                     0.918847
# division_1_size_3                        1.394883
# division_1_size_2.5                      0.748550
#
#                       $\frac{I_{1182}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           0.916921
# division_1_size_3                                              1.179021
# division_1_size_2.5                                            0.773169
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.094277
# division_1_size_3                                              0.117158
# division_1_size_2.5                                            0.085315
#
#                       $\frac{I_{1182}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.911639
# division_1_size_3                                               1.197980
# division_1_size_2.5                                             0.628095
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.217161
# division_1_size_3                                               0.281089
# division_1_size_2.5                                             0.170436
#
#                       $\frac{I_{1182}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.680250
# division_1_size_3                                               0.982530
# division_1_size_2.5                                             0.601102
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.511349
# division_1_size_3                                               0.738445
# division_1_size_2.5                                             0.507507
#
#                       $\frac{I_{1182}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.070416
# division_1_size_3                                              1.263836
# division_1_size_2.5                                            1.102734
#
#                       $\frac{I_{1182}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.247127
# division_1_size_3                                              0.275961
# division_1_size_2.5                                            0.257493
#
#                       $\frac{I_{1182}}{\overline{I}_{874 \pm 16}}$  \
# division_1_size_bulk                                      8.228542
# division_1_size_3                                         4.562687
# division_1_size_2.5                                       3.729570
#
#                       $\frac{I_{1182}}{\overline{I}_{874 \pm 32}}$  \
# division_1_size_bulk                                      8.100146
# division_1_size_3                                         4.450351
# division_1_size_2.5                                       3.784010
#
#                       $\frac{I_{1182}}{\overline{I}_{1084 \pm 16}}$  \
# division_1_size_bulk                                       0.587057
# division_1_size_3                                          0.662529
# division_1_size_2.5                                        0.664275
#
#                       $\frac{I_{1182}}{\overline{I}_{1084 \pm 32}}$  \
# division_1_size_bulk                                       0.591894
# division_1_size_3                                          0.671511
# division_1_size_2.5                                        0.663955
#
#                       $\frac{I_{1182}}{\overline{I}_{1241 \pm 16}}$  \
# division_1_size_bulk                                       0.860165
# division_1_size_3                                          1.283196
# division_1_size_2.5                                        0.981794
#
#                       $\frac{I_{1182}}{\overline{I}_{1241 \pm 32}}$  \
# division_1_size_bulk                                       0.871497
# division_1_size_3                                          1.277518
# division_1_size_2.5                                        0.985688
#
#                       $\frac{I_{1182}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                       0.518292
# division_1_size_3                                          0.747283
# division_1_size_2.5                                        0.515121
#
#                       $\frac{I_{1182}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                       0.533987
# division_1_size_3                                          0.769790
# division_1_size_2.5                                        0.523412
#
#                       $\frac{I_{1182}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                       1.037071
# division_1_size_3                                          1.101708
# division_1_size_2.5                                        0.486793
#
#                       $\frac{I_{1182}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                       0.976456
# division_1_size_3                                          1.062532
# division_1_size_2.5                                        0.497006
#
#                       $\frac{I_{1182}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                       0.397938
# division_1_size_3                                          0.524542
# division_1_size_2.5                                        0.423376
#
#                       $\frac{I_{1182}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                       0.419965
# division_1_size_3                                          0.547584
# division_1_size_2.5                                        0.426337
#
#                       $\frac{I_{1182}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                       0.926576
# division_1_size_3                                          1.398444
# division_1_size_2.5                                        0.743546
#
#                       $\frac{I_{1182}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                       0.935336
# division_1_size_3                                          1.386421
# division_1_size_2.5                                        0.723414
#
#                       $\frac{I_{1241}}{I_{1393}}$  \
# division_1_size_bulk                     0.598314
# division_1_size_3                        0.575620
# division_1_size_2.5                      0.519304
#
#                       $\frac{I_{1241}}{I_{1541}}$  \
# division_1_size_bulk                     1.237696
# division_1_size_3                        0.869446
# division_1_size_2.5                      0.493758
#
#                       $\frac{I_{1241}}{I_{1625}}$  \
# division_1_size_bulk                     0.455066
# division_1_size_3                        0.400950
# division_1_size_2.5                      0.416118
#
#                       $\frac{I_{1241}}{I_{1725}}$  \
# division_1_size_bulk                     1.075114
# division_1_size_3                        1.087315
# division_1_size_2.5                      0.765950
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.072861
# division_1_size_3                                              0.919050
# division_1_size_2.5                                            0.791142
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.110311
# division_1_size_3                                              0.091325
# division_1_size_2.5                                            0.087298
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.066680
# division_1_size_3                                               0.933828
# division_1_size_2.5                                             0.642695
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.254093
# division_1_size_3                                               0.219109
# division_1_size_2.5                                             0.174398
#
#                       $\frac{I_{1241}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.795939
# division_1_size_3                                               0.765884
# division_1_size_2.5                                             0.615075
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.598314
# division_1_size_3                                               0.575620
# division_1_size_2.5                                             0.519304
#
#                       $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.252460
# division_1_size_3                                              0.985163
# division_1_size_2.5                                            1.128367
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.289156
# division_1_size_3                                              0.215113
# division_1_size_2.5                                            0.263478
#
#                       $\frac{I_{1241}}{\overline{I}_{874 \pm 16}}$  \
# division_1_size_bulk                                      9.627964
# division_1_size_3                                         3.556626
# division_1_size_2.5                                       3.816264
#
#                       $\frac{I_{1241}}{\overline{I}_{874 \pm 32}}$  \
# division_1_size_bulk                                      9.477732
# division_1_size_3                                         3.469060
# division_1_size_2.5                                       3.871969
#
#                       $\frac{I_{1241}}{\overline{I}_{1084 \pm 16}}$  \
# division_1_size_bulk                                       0.686897
# division_1_size_3                                          0.516443
# division_1_size_2.5                                        0.679716
#
#                       $\frac{I_{1241}}{\overline{I}_{1084 \pm 32}}$  \
# division_1_size_bulk                                       0.692557
# division_1_size_3                                          0.523445
# division_1_size_2.5                                        0.679389
#
#                       $\frac{I_{1241}}{\overline{I}_{1182 \pm 16}}$  \
# division_1_size_bulk                                       1.159377
# division_1_size_3                                          0.773374
# division_1_size_2.5                                        1.018101
#
#                       $\frac{I_{1241}}{\overline{I}_{1182 \pm 32}}$  \
# division_1_size_bulk                                       1.121368
# division_1_size_3                                          0.753399
# division_1_size_2.5                                        0.993408
#
#                       $\frac{I_{1241}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                       0.606438
# division_1_size_3                                          0.582509
# division_1_size_2.5                                        0.527095
#
#                       $\frac{I_{1241}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                       0.624802
# division_1_size_3                                          0.600053
# division_1_size_2.5                                        0.535578
#
#                       $\frac{I_{1241}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                       1.213445
# division_1_size_3                                          0.858784
# division_1_size_2.5                                        0.498108
#
#                       $\frac{I_{1241}}{\overline{I}_{1541 \pm 32}}$  \
# ...
#
#                       $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.415220
# division_1_size_3                                                            0.542716
# division_1_size_2.5                                                          0.436092
#
#                       $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.438204
# division_1_size_3                                                            0.566556
# division_1_size_2.5                                                          0.439142
#
#                       $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         0.966818
# division_1_size_3                                                            1.446897
# division_1_size_2.5                                                          0.765879
#
#                       $\frac{\overline{I}_{1182 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         0.975958
# division_1_size_3                                                            1.434457
# division_1_size_2.5                                                          0.745142
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                                         0.602550
# division_1_size_3                                                            0.582361
# division_1_size_2.5                                                          0.524673
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                                         0.620796
# division_1_size_3                                                            0.599900
# division_1_size_2.5                                                          0.533118
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                                         1.205665
# division_1_size_3                                                            0.858566
# division_1_size_2.5                                                          0.495820
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                                         1.135196
# division_1_size_3                                                            0.828036
# division_1_size_2.5                                                          0.506223
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.462630
# division_1_size_3                                                            0.408778
# division_1_size_2.5                                                          0.431227
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.488237
# division_1_size_3                                                            0.426734
# division_1_size_2.5                                                          0.434243
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         1.077208
# division_1_size_3                                                            1.089813
# division_1_size_2.5                                                          0.757334
#
#                       $\frac{\overline{I}_{1241 \pm 16}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         1.087391
# division_1_size_3                                                            1.080443
# division_1_size_2.5                                                          0.736829
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1393 \pm 16}}$  \
# division_1_size_bulk                                                         0.594715
# division_1_size_3                                                            0.584949
# division_1_size_2.5                                                          0.522600
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1393 \pm 32}}$  \
# division_1_size_bulk                                                         0.612725
# division_1_size_3                                                            0.602567
# division_1_size_2.5                                                          0.531011
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                                         1.189989
# division_1_size_3                                                            0.862382
# division_1_size_2.5                                                          0.493861
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                                         1.120436
# division_1_size_3                                                            0.831716
# division_1_size_2.5                                                          0.504223
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.456615
# division_1_size_3                                                            0.410595
# division_1_size_2.5                                                          0.429523
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.481889
# division_1_size_3                                                            0.428631
# division_1_size_2.5                                                          0.432527
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         1.063201
# division_1_size_3                                                            1.094657
# division_1_size_2.5                                                          0.754342
#
#                       $\frac{\overline{I}_{1241 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         1.073253
# division_1_size_3                                                            1.085246
# division_1_size_2.5                                                          0.733918
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                                         2.000939
# division_1_size_3                                                            1.474285
# division_1_size_2.5                                                          0.945007
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                                         1.883987
# division_1_size_3                                                            1.421860
# division_1_size_2.5                                                          0.964834
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.767787
# division_1_size_3                                                            0.701932
# division_1_size_2.5                                                          0.821896
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.810286
# division_1_size_3                                                            0.732766
# division_1_size_2.5                                                          0.827644
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         1.787749
# division_1_size_3                                                            1.871371
# division_1_size_2.5                                                          1.443440
#
#                       $\frac{\overline{I}_{1393 \pm 16}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         1.804650
# division_1_size_3                                                            1.855282
# division_1_size_2.5                                                          1.404358
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1541 \pm 16}}$  \
# division_1_size_bulk                                                         1.942127
# division_1_size_3                                                            1.431180
# division_1_size_2.5                                                          0.930039
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1541 \pm 32}}$  \
# division_1_size_bulk                                                         1.828613
# division_1_size_3                                                            1.380289
# division_1_size_2.5                                                          0.949551
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.745220
# division_1_size_3                                                            0.681409
# division_1_size_2.5                                                          0.808877
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.786470
# division_1_size_3                                                            0.711342
# division_1_size_2.5                                                          0.814534
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         1.735203
# division_1_size_3                                                            1.816657
# division_1_size_2.5                                                          1.420576
#
#                       $\frac{\overline{I}_{1393 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         1.751607
# division_1_size_3                                                            1.801038
# division_1_size_2.5                                                          1.382114
#
#                       $\frac{\overline{I}_{1541 \pm 16}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.383713
# division_1_size_3                                                            0.476117
# division_1_size_2.5                                                          0.869725
#
#                       $\frac{\overline{I}_{1541 \pm 16}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.404953
# division_1_size_3                                                            0.497032
# division_1_size_2.5                                                          0.875807
#
#                       $\frac{\overline{I}_{1541 \pm 16}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         0.893455
# division_1_size_3                                                            1.269341
# division_1_size_2.5                                                          1.527438
#
#                       $\frac{\overline{I}_{1541 \pm 16}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         0.901901
# division_1_size_3                                                            1.258428
# division_1_size_2.5                                                          1.486082
#
#                       $\frac{\overline{I}_{1541 \pm 32}}{\overline{I}_{1625 \pm 16}}$  \
# division_1_size_bulk                                                         0.407533
# division_1_size_3                                                            0.493671
# division_1_size_2.5                                                          0.851852
#
#                       $\frac{\overline{I}_{1541 \pm 32}}{\overline{I}_{1625 \pm 32}}$  \
# division_1_size_bulk                                                         0.430091
# division_1_size_3                                                            0.515357
# division_1_size_2.5                                                          0.857809
#
#                       $\frac{\overline{I}_{1541 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         0.948918
# division_1_size_3                                                            1.316143
# division_1_size_2.5                                                          1.496050
#
#                       $\frac{\overline{I}_{1541 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         0.957889
# division_1_size_3                                                            1.304827
# division_1_size_2.5                                                          1.455544
#
#                       $\frac{\overline{I}_{1625 \pm 16}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         2.328444
# division_1_size_3                                                            2.666030
# division_1_size_2.5                                                          1.756232
#
#                       $\frac{\overline{I}_{1625 \pm 16}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         2.350456
# division_1_size_3                                                            2.643108
# division_1_size_2.5                                                          1.708681
#
#                       $\frac{\overline{I}_{1625 \pm 32}}{\overline{I}_{1725 \pm 16}}$  \
# division_1_size_bulk                                                         2.206319
# division_1_size_3                                                            2.553845
# division_1_size_2.5                                                          1.744036
#
#                       $\frac{\overline{I}_{1625 \pm 32}}{\overline{I}_{1725 \pm 32}}$  \
# division_1_size_bulk                                                         2.227177
# division_1_size_3                                                            2.531888
# division_1_size_2.5                                                          1.696815
#
#                       Split Fraction_hue Fraction_grouped_hue  Class
# division_1_size_bulk  Train        $> 0$              $d > 5$      2
# division_1_size_3     Train        $< 3$       $2 < d \leq 5$      1
# division_1_size_2.5   Train      $< 2.5$       $2 < d \leq 5$      1

# %% [markdown]
# ## Base parameters

# %%
type_color_dict = {
    '$d \leq 2$': '#2166AC',
    '$2 < d \leq 5$': '#67A9CF',
    '$d > 5$': '#B2182B'
}

# %%
groups = list(type_color_dict.keys())

# %%
sns.set_theme()

# %% [markdown]
# ## Dictionary for features mapping to type

# %%
feature_to_types = defaultdict(list)

for feature_type, features in features_description.items():
    for feature in features:
        feature_to_types[feature].append(feature_type)

# %% [markdown]
# ## Dictionary for mapping *class* to *size group*

# %%
class_fraction_group_dict = {
    0: r'$d \leq 2$',
    1: r'$2 < d \leq 5$',
    2: r'$d > 5$'
}

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Target rate analysis

# %% [markdown]
# Mapping hue ~ group:
# * Class 0 — $0< d \leq 2$
# * Class 1 — $2 < d \leq 5$
# * Class 2 — $d > 5$

# %%
fractions_hue_train_df = pd.DataFrame(dataset_train['Fraction_hue'].value_counts()).sort_values(by='Fraction_hue')
fractions_hue_test_df = pd.DataFrame(dataset_test['Fraction_hue'].value_counts()).sort_values(by='Fraction_hue')

display(fractions_hue_train_df.T, fractions_hue_test_df.T)
# Out:
# Fraction_hue  $< 0.2$  $< 0.4$  $< 2$  $< 2.5$  $< 25$  $< 3$  $< 4$  $< 5$  \
# count               4        5      6        7       5      6      1      6
#
# Fraction_hue  $< 50$  $< 75$  $> 0$
# count              1       2      7
# Fraction_hue  $< 0.2$  $< 0.4$  $< 2$  $< 2.5$  $< 25$  $< 3$  $< 5$  $< 70$  \
# count               3        3      2        1       1      4      4       3
#
# Fraction_hue  $< 75$  $> 0$
# count              1      3

# %%
target_rate_train_df = pd.DataFrame(dataset_train['Fraction_grouped_hue'].value_counts()).sort_values(by='Fraction_grouped_hue')
target_rate_test_df = pd.DataFrame(dataset_test['Fraction_grouped_hue'].value_counts()).sort_values(by='Fraction_grouped_hue')

display(target_rate_train_df.T, target_rate_test_df.T)
# Out:
# Fraction_grouped_hue  $2 < d \leq 5$  $d > 5$  $d \leq 2$
# count                             20       15          15
# Fraction_grouped_hue  $2 < d \leq 5$  $d > 5$  $d \leq 2$
# count                              9        8           8

# %% [markdown]
# ### Data wrangling

# %%
train = target_rate_train_df.copy()
test  = target_rate_test_df.copy()

train = train["count"].reset_index()
test  = test["count"].reset_index()
train.columns = ["bin", "count_train"]
test.columns  = ["bin", "count_test"]

bins_order = list(train["bin"])
bins_order += [b for b in test["bin"] if b not in bins_order]

df = (pd.DataFrame({"bin": bins_order})
      .merge(train, on="bin", how="left")
      .merge(test,  on="bin", how="left"))
df[["count_train", "count_test"]] = df[["count_train", "count_test"]].fillna(0).astype(int)

sum_tr, sum_te = df["count_train"].sum(), df["count_test"].sum()
df["freq_train"] = df["count_train"] * 100 / sum_tr if sum_tr else 0
df["freq_test"]  = df["count_test"] * 100  / sum_te if sum_te else 0

# %% [markdown]
# ### Visualization

# %%
fontsize = 14

train_color = "#08519c"
test_color  = "#1f77b4"
edge_color = "white"

# %%
fig, ax = plt.subplots(figsize=(10, 4), dpi=300)

x = np.arange(len(df))

width = 0.35

bars_train = ax.bar(x - width/2, df["freq_train"].values, width=width, label="Train", color=train_color, alpha=0.7, edgecolor=edge_color, linewidth=0.6)
bars_test  = ax.bar(x + width/2, df["freq_test"].values,  width=width, label="Test",  color=test_color, alpha=0.7,  edgecolor=edge_color, linewidth=0.6)

ax.set_xlabel("")
ax.set_ylabel("Relative frequency", fontsize=fontsize, labelpad=5)

ax.set_xticks(x, df["bin"])
ax.tick_params(axis='x', labelsize=fontsize)
ax.tick_params(axis='y', labelsize=fontsize-2)

# ax.yaxis.set_major_formatter(PercentFormatter(1.0))
ax.yaxis.set_major_locator(ticker.MaxNLocator(nbins=10))

# ax.legend(frameon=True, fontsize=fontsize-2, title_fontsize=fontsize, title='Dataset split')
ax.legend(frameon=True, fontsize=fontsize-2)

def annotate(container, values):
    for rect, val in zip(container, values):
        h = rect.get_height()
        ax.annotate(f"{int(val)}",
                    xy=(rect.get_x() + rect.get_width()/2, h),
                    xytext=(0, 0), textcoords="offset points",
                    ha="center", va="bottom", fontsize=fontsize-2, fontweight='normal')

annotate(bars_train, df["count_train"].values)
annotate(bars_test, df["count_test"].values)

plt.tight_layout()

plt.savefig(f"{path_to_save}/target_rate_barplot.svg", dpi=600)

plt.show()

# %% [markdown]
# ## *One-factor (OF)* analysis

# %% [markdown]
# ### *OF*-statictics calculation

# %%
def of_analysis(feature, features_df_train, target_train, features_df_test, target_test, n_bootstrap=50, C=1.0, random_state=42, n_splits=3, cv_shuffle=True):

    def safe_auc(y_true, proba):
        try:
            return roc_auc_score(y_true, proba, multi_class="ovr")
        except ValueError:
            return np.nan

    def fit_logreg_and_auc(X_tr, y_tr, X_te, y_te, C=1.0, rs=42, return_scale=False):
        scaler = StandardScaler().fit(X_tr)
        X_tr_s = scaler.transform(X_tr)
        X_te_s = scaler.transform(X_te)

        clf = OneVsRestClassifier(
            LogisticRegression(
                penalty="l2", C=C, solver="lbfgs", max_iter=10_000, random_state=rs
            )
        )
        clf.fit(X_tr_s, y_tr)

        auc_train = safe_auc(y_tr, clf.predict_proba(X_tr_s))
        auc_test  = safe_auc(y_te, clf.predict_proba(X_te_s))

        if return_scale:
            return auc_train, auc_test, float(scaler.mean_[0]), float(scaler.scale_[0])
        return auc_train, auc_test

    def bootstrap_block(X_source, y_train, X_test_raw, y_test, n_bs, C, rs=42):
        aucs_train, aucs_test = [], []
        for seed in range(n_bs):
            X_bs, y_bs = resample(X_source, y_train, replace=True, random_state=seed)
            a_tr, a_te = fit_logreg_and_auc(X_bs, y_bs, X_test_raw, y_test, C=C, rs=rs)
            aucs_train.append(a_tr)
            aucs_test.append(a_te)
        return np.asarray(aucs_train, float), np.asarray(aucs_test, float)

    def cv_block(X_train_raw, y_train, n_splits, shuffle, rs, C):
        skf = StratifiedKFold(n_splits=n_splits, shuffle=shuffle, random_state=rs)
        oof_scores = []
        for tr_idx, val_idx in skf.split(X_train_raw, y_train):
            X_tr, X_val = X_train_raw[tr_idx], X_train_raw[val_idx]
            y_tr, y_val = y_train[tr_idx], y_train[val_idx]

            scaler = StandardScaler().fit(X_tr)
            X_tr_s  = scaler.transform(X_tr)
            X_val_s = scaler.transform(X_val)

            clf = OneVsRestClassifier(
                LogisticRegression(
                    penalty="l2", C=C, solver="lbfgs", max_iter=10_000, random_state=rs
                )
            )
            clf.fit(X_tr_s, y_tr)
            proba_val = clf.predict_proba(X_val_s)
            oof_scores.append(safe_auc(y_val, proba_val))

        return np.asarray(oof_scores, float)

    def summarize(arr):
        arr = np.asarray(arr, float)
        if arr.size == 0:
            return np.nan, np.nan, np.nan
        return float(np.nanmean(arr)), float(np.nanpercentile(arr, 5)), float(np.nanpercentile(arr, 95))

    rng = np.random.default_rng(random_state)

    X_train_raw = features_df_train[[feature]].values
    y_train     = target_train.values
    X_test_raw  = features_df_test[[feature]].values
    y_test      = target_test.values

    # Глобальные (единственная подгонка на всём трейне)
    auc_global_train, auc_global_test, mean_val, std_val = fit_logreg_and_auc(
        X_train_raw, y_train, X_test_raw, y_test, C=C, rs=random_state, return_scale=True
    )

    # Бутстрэп
    bs_train, bs_test = bootstrap_block(
        X_train_raw, y_train, X_test_raw, y_test, n_bs=n_bootstrap, C=C, rs=random_state
    )
    bs_mean_train, bs_ci5_train, bs_ci95_train = summarize(bs_train)
    bs_mean_test,  bs_ci5_test,  bs_ci95_test  = summarize(bs_test)

    # Нoise baseline (перемешанный train)
    shuffled_train = rng.permutation(X_train_raw.ravel()).reshape(-1, 1)
    noise_train, noise_test = bootstrap_block(
        shuffled_train, y_train, X_test_raw, y_test, n_bs=n_bootstrap, C=C, rs=random_state
    )
    noise_mean_train, noise_ci5_train, noise_ci95_train = summarize(noise_train)
    noise_mean_test,  noise_ci5_test,  noise_ci95_test  = summarize(noise_test)

    # Δ и z-score
    delta_auc_train = bs_mean_train - noise_mean_train
    delta_auc_test  = bs_mean_test  - noise_mean_test
    std_noise_train = np.nanstd(noise_train)
    std_noise_test  = np.nanstd(noise_test)
    z_score_train = (delta_auc_train / std_noise_train) if std_noise_train > 0 else np.nan
    z_score_test  = (delta_auc_test  / std_noise_test)  if std_noise_test  > 0 else np.nan

    # CV-OOF
    cv_scores = cv_block(X_train_raw, y_train, n_splits=n_splits, shuffle=cv_shuffle, rs=random_state, C=C)
    cv_mean_train, cv_ci5_train, cv_ci95_train = summarize(cv_scores)

    return {
        "Feature": feature,
        "$scale-mean$": mean_val,
        "$scale-std$": std_val,
        "$C$": C,

        "$ROC-AUC_{ovr}^{global,train}$": auc_global_train,
        "$ROC-AUC_{ovr}^{global,test}$":  auc_global_test,

        "$ROC-AUC_{ovr}^{BS,train}$": bs_mean_train,
        "$CI_{5\\%}^{BS,train}$":     bs_ci5_train,
        "$CI_{95\\%}^{BS,train}$":    bs_ci95_train,
        "$ROC-AUC_{ovr}^{BS,test}$":  bs_mean_test,
        "$CI_{5\\%}^{BS,test}$":      bs_ci5_test,
        "$CI_{95\\%}^{BS,test}$":     bs_ci95_test,

        "$ROC-AUC_{ovr}^{CV,train}$": cv_mean_train,
        "$CI_{5\\%}^{CV,train}$":     cv_ci5_train,
        "$CI_{95\\%}^{CV,train}$":    cv_ci95_train,
        "$n_{folds}^{CV}$":           int(np.isfinite(cv_scores).sum()),

        "$ROC-AUC_{ovr}^{noise,train}$": noise_mean_train,
        "$CI_{5\\%}^{noise,train}$":     noise_ci5_train,
        "$CI_{95\\%}^{noise,train}$":    noise_ci95_train,
        "$ROC-AUC_{ovr}^{noise,test}$":  noise_mean_test,
        "$CI_{5\\%}^{noise,test}$":      noise_ci5_test,
        "$CI_{95\\%}^{noise,test}$":     noise_ci95_test,

        "$ΔROC-AUC^{train}$": delta_auc_train,
        "$ΔROC-AUC^{test}$":  delta_auc_test,
        "$z-score^{train}$":  z_score_train,
        "$z-score^{test}$":   z_score_test,

        "$n_{valid}^{BS,train}$":      int(np.isfinite(bs_train).sum()),
        "$n_{valid}^{BS,test}$":       int(np.isfinite(bs_test).sum()),
        "$n_{valid}^{noise,train}$":   int(np.isfinite(noise_train).sum()),
        "$n_{valid}^{noise,test}$":    int(np.isfinite(noise_test).sum()),
    }

# %%
# %%time

features_list = X_train.columns.tolist()

with tqdm_joblib(desc="Calculation progress", total=len(features_list)):
    results = Parallel(n_jobs=-1, backend="loky")(
        delayed(of_analysis)(
            feature,
            X_train,
            y_train,
            X_test,
            y_test,
            n_bootstrap=50,
            C=1.0,
        )
        for feature in features_list
    )

# %%
of_metrics_df = pd.DataFrame(results).sort_values(
    by=[
        "$CI_{5\%}^{BS,train}$",
        "$ROC-AUC_{ovr}^{BS,train}$",
        "$ROC-AUC_{ovr}^{global,train}$"
    ],
    ascending=[
        False,
        False,
        False
    ]
)
print(of_metrics_df.shape)
of_metrics_df.head(3)

# %% [markdown]
# ### *Hard-check* factor selection

# %%
of_features_to_save = (
    of_metrics_df
    .loc[
        (of_metrics_df['$CI_{5\%}^{BS,train}$'] >= 0.60)
        # & (of_metrics_df['$CI_{5\%}^{CV,train}$'] >= 0.55)
        & (of_metrics_df['$ROC-AUC_{ovr}^{global,train}$'] >= 0.60)
    ]['Feature']
).tolist()

print(
    f'Число фичей',
    f'(*) до отбора: {len(of_metrics_df["Feature"].unique())}',
    f'(*) после отбора: {len(of_features_to_save)}',
    f'Доля фичей, прошедших однофакторный отбор: {round(len(of_features_to_save) / len(of_metrics_df["Feature"].unique()) * 100, 2)}%',
    sep='\n'
)

# %%
of_metrics_df = of_metrics_df.loc[of_metrics_df['Feature'].isin(of_features_to_save)]

print(of_metrics_df.shape)
of_metrics_df.head(3)

# %% [markdown]
# ### Mapping features with their types

# %%
rows = []

for _, row in of_metrics_df.iterrows():
    feature = row['Feature']
    feature_types = feature_to_types.get(feature, [])

    for feature_type in feature_types:
        row_copy = row.copy()
        row_copy['Feature_Type'] = feature_type
        rows.append(row_copy)

of_metrics_expanded_df = pd.DataFrame(rows)

print(of_metrics_expanded_df.shape)
of_metrics_expanded_df.head(3)

# %% [markdown]
# ### Visualization

# %%
train_color = "#08519c"
test_color  = "#1f77b4"

PLOT_STYLE = {
    'TITLE_FONT_SIZE': 18, 'TITLE_FONTSTYLE': 'normal',
    'X_LABEL_FONT_SIZE': 14, 'Y_TICK_LABEL_FONT_SIZE': 14,
    'X_LABELPAD': 8, 'X_NBINS': 8,
    'BAR_HEIGHT': 0.34, 'BAR_ALPHA': 0.7,
    'FIG_DPI': 300, 'SUBPLOT_WIDTH': 6, 'SUBPLOT_HEIGHT': 4.2,
    'TOP_N': 5, 'LEGEND_FONT_SIZE': 12, 'ERR_CAPSIZE': 3, 'ERR_LINEWIDTH': 1.4,
    'HUE_COLORS': {'train': train_color, 'test': test_color}
}

KEYS = {
    'bs_train': "$ROC-AUC_{ovr}^{BS,train}$",     'glob_train': "$ROC-AUC_{ovr}^{global,train}$",
    'bs_test': "$ROC-AUC_{ovr}^{BS,test}$",       'glob_test': "$ROC-AUC_{ovr}^{global,test}$",
    'ci5_train': "$CI_{5\\%}^{BS,train}$",        'ci95_train': "$CI_{95\\%}^{BS,train}$",
    'ci5_test': "$CI_{5\\%}^{BS,test}$",          'ci95_test': "$CI_{95\\%}^{BS,test}$",
    'cv_train': '$ROC-AUC_{ovr}^{CV,train}$',     'ci5_cv_train': '$CI_{5\%}^{CV,train}$',
    'ci95_cv_train': '$CI_{95\%}^{CV,train}$'
}

VISUAL_TYPE_LABELS = {'peaks': 'Peak-based', 'intervals': 'Region-based'}

# %%
def extract_base_and_range(feature_type: str):
    if not isinstance(feature_type, str):
        return None, None

    parts = feature_type.lower().split('_')

    # база (тип)
    if 'peaks' in parts:
        base = 'peaks'
    elif 'intervals' in parts:
        base = 'intervals'
    else:
        base = None

    # диапазон — две последние числовые части
    nums = [p for p in parts if re.fullmatch(r'\d+(?:\.\d+)?', p)]
    rng = None
    if len(nums) >= 2:
        a, b = float(nums[-2]), float(nums[-1])
        hi, lo = (max(a, b), min(a, b))
        def _fmt(x):
            xi = int(round(x))
            return str(xi) if abs(x - xi) < 1e-9 else f"{x:g}"
        rng = f"{_fmt(hi)}–{_fmt(lo)}"

    # валидируем базу по словарю визуальных меток
    if base not in VISUAL_TYPE_LABELS:
        base = None

    return base, rng


def group_sort_key(gr):
    base, rng = gr
    base_order = list(VISUAL_TYPE_LABELS.keys())
    base_idx = base_order.index(base) if base in base_order else len(base_order)

    hi = lo = None
    if isinstance(rng, str):
        m = re.findall(r'\d+(?:\.\d+)?', rng)
        if len(m) >= 2:
            a, b = float(m[0]), float(m[1])
            hi, lo = (max(a, b), min(a, b))

    # hi -> сортируем по убыванию (поэтому минус), lo -> по возрастанию
    return (base_idx, -(hi if hi is not None else -1e9), (lo if lo is not None else 1e9))


def panel_title_from_group(gr):
    base, rng = gr
    base_label = VISUAL_TYPE_LABELS.get(base, base or "")
    return f"{base_label} | {rng} cm$^{{-1}}$" if rng else base_label


def build_plot_df(subset: pd.DataFrame, top_n: int = 5):
    rows = []
    for _, row in subset.iterrows():
        feat = row.get('Feature')
        if pd.isna(feat):
            continue

        for split in ('train', 'test'):
            mean_col_bs = KEYS[f'bs_{split}']
            mean_col_glob = KEYS[f'glob_{split}']
            ci5_col = KEYS[f'ci5_{split}']
            ci95_col = KEYS[f'ci95_{split}']

            mean = row.get(mean_col_bs)
            ci5  = row.get(ci5_col)
            ci95 = row.get(ci95_col)

            # если bootstrap-метрик нет — используем global без ошибок
            if pd.isna(mean):
                mean = row.get(mean_col_glob)
                ci5, ci95 = np.nan, np.nan

            if pd.isna(mean):
                continue

            err_left  = float(mean - ci5)  if (ci5  is not None and not pd.isna(ci5))  else 0.0
            err_right = float(ci95 - mean) if (ci95 is not None and not pd.isna(ci95)) else 0.0

            rows.append({
                'Feature': feat,
                'Split': split,
                'mean': float(mean),
                'err_left': err_left,
                'err_right': err_right
            })

    plot_df = pd.DataFrame(rows)
    if plot_df.empty:
        return plot_df, []

    order_feats = (
        plot_df.groupby('Feature')['mean']
        .mean()
        .sort_values(ascending=False)
        .head(top_n)
        .index.tolist()
    )
    plot_df = plot_df[plot_df['Feature'].isin(order_feats)].copy()
    return plot_df, order_feats

# %%
tmp = of_metrics_expanded_df.copy()

tmp[['viz_base','viz_range']] = tmp['Feature_Type'].apply(lambda s: pd.Series(extract_base_and_range(s)))
tmp = tmp[tmp['viz_base'].isin(VISUAL_TYPE_LABELS) & tmp['viz_range'].notna()]

present_groups = sorted(tmp[['viz_base','viz_range']].drop_duplicates().itertuples(index=False, name=None), key=group_sort_key)

# %%
# --- layout ---
n = len(present_groups)
ncols = 2 if n > 1 else 1
nrows = math.ceil(n / ncols)
fig, axes = plt.subplots(nrows=nrows, ncols=ncols,
                         figsize=(ncols*PLOT_STYLE['SUBPLOT_WIDTH'], nrows*PLOT_STYLE['SUBPLOT_HEIGHT']),
                         dpi=PLOT_STYLE['FIG_DPI'])
axes = np.atleast_1d(axes).ravel()

# --- panels ---
for i, g in enumerate(present_groups):
    ax = axes[i]
    base, rng = g
    subset = tmp[(tmp['viz_base']==base) & (tmp['viz_range']==rng)].copy()
    plot_df, order_feats = build_plot_df(subset, PLOT_STYLE['TOP_N'])
    if plot_df.empty:
        ax.set_title(panel_title_from_group(g), fontsize=PLOT_STYLE['TITLE_FONT_SIZE'],
                     fontstyle=PLOT_STYLE['TITLE_FONTSTYLE'])
        ax.text(0.5,0.5,'no data',ha='center',va='center',fontsize=12,alpha=0.7)
        ax.set_axis_off()
        continue

    plot_df['Feature'] = pd.Categorical(plot_df['Feature'], categories=order_feats, ordered=True)
    y0 = np.arange(len(order_feats)); off = PLOT_STYLE['BAR_HEIGHT']/2

    for split, sign in (('train',-1),('test',+1)):
        sub = plot_df[plot_df['Split']==split].sort_values('Feature')
        y = y0 + sign*off
        xerr = np.vstack([sub['err_left'].to_numpy(), sub['err_right'].to_numpy()])
        ax.barh(y, sub['mean'], height=PLOT_STYLE['BAR_HEIGHT'], alpha=PLOT_STYLE['BAR_ALPHA'],
                label=split.capitalize(), color=PLOT_STYLE['HUE_COLORS'][split],
                xerr=xerr, error_kw={'capsize':PLOT_STYLE['ERR_CAPSIZE'], 'lw':PLOT_STYLE['ERR_LINEWIDTH']})

    ax.set_yticks(y0, labels=order_feats, fontsize=PLOT_STYLE['Y_TICK_LABEL_FONT_SIZE'])
    ax.invert_yaxis()
    ax.set_xlabel('$ROC\\!-\\!AUC_{ovr}$', fontsize=PLOT_STYLE['X_LABEL_FONT_SIZE'],
                  labelpad=PLOT_STYLE['X_LABELPAD'])
    ax.set_xlim(0,1)
    ax.set_title(panel_title_from_group(g), fontsize=PLOT_STYLE['TITLE_FONT_SIZE'],
                 fontstyle=PLOT_STYLE['TITLE_FONTSTYLE'])
    ax.xaxis.set_major_locator(ticker.MaxNLocator(nbins=PLOT_STYLE['X_NBINS']))
    ax.legend(loc='upper left', fontsize=PLOT_STYLE['LEGEND_FONT_SIZE'], frameon=True)

# hide unused axes
for j in range(len(present_groups), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()

plt.savefig(f'{path_to_save}/roc_auc_barplots.svg', dpi=600)

plt.show()

# %% [markdown]
# ## *Multi-factor* analysis

# %% [markdown]
# ### Functions for processing & config-parameters

# %% [markdown]
# #### Forward selection

# %%
def forward_selection_bootstrap(
    X_train: pd.DataFrame,
    y_train: pd.Series | np.ndarray,
    X_test: pd.DataFrame,
    y_test: pd.Series | np.ndarray,
    candidate_features: list[str],
    scoring: str = "roc_auc_ovr",          # 'roc_auc_ovr' | 'pr_auc'
    min_uplift: float | None = None,
    max_features: int | None = None,
    n_bootstrap: int = 50,
    n_jobs: int = -1,
    use_tqdm: bool = True,
    uplift_type: str = "mean",             # 'mean' | 'low' | 'high' — USED ONLY WHEN selection_mode='bootstrap'
    return_ci: bool = True,                # kept for compatibility; CI is always calculated in bootstrap mode
    random_state: int = 42,
    selection_mode: str = "bootstrap",     # 'bootstrap' | 'train'
):
    rng = np.random.RandomState(random_state)

    # convert targets to arrays/indices
    y_tr = np.asarray(y_train).ravel() if isinstance(y_train, (pd.Series, pd.DataFrame)) else np.asarray(y_train).ravel()
    y_te = np.asarray(y_test).ravel() if isinstance(y_test, (pd.Series, pd.DataFrame)) else np.asarray(y_test).ravel()

    # fix the set of classes (important for PR AUC / aligning probability column order)
    classes = np.unique(np.concatenate([y_tr, y_te]))

    def _score_metric(y_true, proba):
        try:
            if scoring == "roc_auc_ovr":
                return roc_auc_score(y_true, proba, multi_class="ovr", labels=classes)
            elif scoring == "pr_auc":
                y_bin = label_binarize(y_true, classes=classes)
                return average_precision_score(y_bin, proba, average="macro")
            else:
                raise ValueError(f"Unsupported metric: {scoring}")
        except Exception:
            return np.nan

    # Общий пайплайн обучение→прогноз→метрика
    def _fit_and_score(Xtr, ytr, Xte, seed):
        est = Pipeline([
            ("scaler", StandardScaler()),
            ("clf", OneVsRestClassifier(
                LogisticRegression(
                    penalty="l2",
                    C=1.0,
                    solver="lbfgs",
                    max_iter=10_000,
                    random_state=seed
                ),
                n_jobs=None
            ))
        ])
        est.fit(Xtr, ytr)
        proba_tr = est.predict_proba(Xtr)
        proba_te = est.predict_proba(Xte)
        if hasattr(est, "classes_"):
            order = [int(np.where(est.classes_ == c)[0][0]) for c in classes]
            proba_tr = proba_tr[:, order]
            proba_te = proba_te[:, order]
        train_metric = _score_metric(ytr, proba_tr)
        test_metric  = _score_metric(y_te, proba_te)
        return train_metric, test_metric

    selected: list[str] = []
    best_train_score = -np.inf
    history: list[dict] = []
    remain = list(candidate_features)

    # --- режим 1: bootstrap (как было) ---
    def bootstrap_scores(feature_set: list[str]):
        Xtr = X_train[feature_set].values
        Xte = X_test[feature_set].values

        def single_bootstrap(seed: int):
            idx = resample(np.arange(len(y_tr)), replace=True, random_state=seed)
            X_bs = Xtr[idx]
            y_bs = y_tr[idx]
            if np.unique(y_bs).size < 2:
                return np.nan, np.nan
            try:
                return _fit_and_score(X_bs, y_bs, Xte, seed)
            except Exception:
                return np.nan, np.nan

        seeds = rng.randint(0, 10**9, size=n_bootstrap)
        pairs = Parallel(n_jobs=n_jobs)(
            delayed(single_bootstrap)(int(s)) for s in seeds
        )
        pairs = np.asarray(pairs, dtype=float)
        train_scores = pairs[:, 0]
        test_scores  = pairs[:, 1]

        def _agg(x):
            return (np.nanmean(x), np.nanpercentile(x, 5), np.nanpercentile(x, 95))

        tr_mean, tr_low, tr_high = _agg(train_scores)
        te_mean, te_low, te_high = _agg(test_scores)
        return (tr_mean, tr_low, tr_high), (te_mean, te_low, te_high)

    # --- режим 2: plain train (без бутстрапа) ---
    def plain_train_scores(feature_set: list[str]):
        Xtr = X_train[feature_set].values
        Xte = X_test[feature_set].values
        try:
            tr, te = _fit_and_score(Xtr, y_tr, Xte, random_state)
        except Exception:
            tr, te = np.nan, np.nan
        # совместимость с полями *_mean/low/high
        return (tr, tr, tr), (te, te, te)

    step = 0
    while remain:
        step += 1
        iterator = tqdm(remain, desc=f"Step {step}") if use_tqdm else remain

        if selection_mode not in ("bootstrap", "train"):
            raise ValueError("selection_mode must be 'bootstrap' or 'train'")

        scorer = bootstrap_scores if selection_mode == "bootstrap" else plain_train_scores

        results = Parallel(n_jobs=n_jobs)(
            delayed(scorer)(selected + [feat]) for feat in iterator
        )

        candidates_info = []
        for feat, ((tr_m, tr_l, tr_h), (te_m, te_l, te_h)) in zip(remain, results):
            candidates_info.append({
                "feature":   feat,
                "train_mean": float(tr_m),
                "train_low":  float(tr_l),
                "train_high": float(tr_h),
                "test_mean":  float(te_m),
                "test_low":   float(te_l),
                "test_high":  float(te_h),
            })

        # ключ выбора
        if selection_mode == "bootstrap":
            if uplift_type == "mean":
                key = "train_mean"
            elif uplift_type == "low":
                key = "train_low"
            elif uplift_type == "high":
                key = "train_high"
            else:
                raise ValueError("uplift_type must be one of: 'mean', 'low', 'high'")
        else:
            # в train-режиме берем train_mean (он же = low = high)
            key = "train_mean"

        best_candidate = max(candidates_info, key=lambda x: (x[key], -np.inf if np.isnan(x[key]) else 0))

        uplift = best_candidate[key] - best_train_score
        if (min_uplift is not None) and (uplift < min_uplift):
            break

        selected.append(best_candidate["feature"])
        remain.remove(best_candidate["feature"])
        best_train_score = best_candidate[key]

        history.append({
            "feature":     best_candidate["feature"],
            "train_mean":  best_candidate["train_mean"],
            "train_low":   best_candidate["train_low"],
            "train_high":  best_candidate["train_high"],
            "test_mean":   best_candidate["test_mean"],
            "test_low":    best_candidate["test_low"],
            "test_high":   best_candidate["test_high"],
            "uplift_train": float(uplift),
            "n_selected":  len(selected),
            "selection_mode": selection_mode,   # NEW: для прозрачности в логе
        })

        if (max_features is not None) and (len(selected) >= max_features):
            break

    return selected, history

# %% [markdown]
# #### *Metric-uplift* line plot

# %%
def plot_cumulative_score_line_bootstrap(
    selection_log,
    ax=None,
    show_ci=True,
    show_test=True,
    annotate=True,
):
    # Prepare data
    df_log = pd.DataFrame(selection_log).copy()
    if df_log.empty:
        raise ValueError("selection_log is empty.")

    # Backward compatibility with old keys
    if {"score_mean", "score_low", "score_high"}.issubset(df_log.columns):
        df_log["train_mean"] = df_log["score_mean"]
        df_log["train_low"]  = df_log["score_low"]
        df_log["train_high"] = df_log["score_high"]

    req_train = {"train_mean", "train_low", "train_high"}
    if not req_train.issubset(df_log.columns):
        missing = req_train - set(df_log.columns)
        raise ValueError(f"Missing train columns: {missing}")

    df_log["Step"] = np.arange(1, len(df_log) + 1)

    created_fig = False
    if ax is None:
        fig, ax = plt.subplots(figsize=(max(6, len(df_log) * 1.2), 5), dpi=150)
        created_fig = True

    # Style from PLOT_STYLE (direct access)
    title           = PLOT_STYLE["TITLE"]
    title_fs        = PLOT_STYLE["TITLE_FONT_SIZE"]
    title_fs_style  = PLOT_STYLE["TITLE_FONTSTYLE"]
    x_label         = PLOT_STYLE["X_LABEL"]
    x_label_fs      = PLOT_STYLE["X_LABEL_FONT_SIZE"]
    x_labelpad      = PLOT_STYLE["X_LABELPAD"]
    y_label         = PLOT_STYLE["Y_LABEL"]
    y_label_fs      = PLOT_STYLE["Y_LABEL_FONT_SIZE"]
    y_labelpad      = PLOT_STYLE["Y_LABELPAD"]
    x_tick_fs       = PLOT_STYLE["X_TICK_LABEL_FONT_SIZE"]
    y_tick_fs       = PLOT_STYLE["Y_TICK_LABEL_FONT_SIZE"]
    metric_value_fs = PLOT_STYLE["METRIC_VALUE_FONT_SIZE"]

    # Fixed colors
    train_color = "#08519c"
    test_color  = "#1f77b4"

    # Train line
    line_train, = ax.plot(
        df_log["Step"],
        df_log["train_mean"],
        marker="o",
        linewidth=2,
        alpha=0.7,
        linestyle="-",
        label="Train",
        color=train_color,
    )
    if show_ci:
        ax.fill_between(
            df_log["Step"],
            df_log["train_low"],
            df_log["train_high"],
            alpha=0.20,
            color=train_color,
        )

    # Test line (nominal)
    line_test = None
    if show_test and {"test_mean","test_low","test_high"}.issubset(df_log.columns):
        line_test, = ax.plot(
            df_log["Step"],
            df_log["test_mean"],
            marker="s",
            linewidth=2,
            alpha=0.7,
            linestyle="-",
            label="Test",
            color=test_color,
        )
        if show_ci:
            ax.fill_between(
                df_log["Step"],
                df_log["test_low"],
                df_log["test_high"],
                alpha=0.20,
                color=test_color,
            )

    # Point annotations
    if annotate:
        for _, row in df_log.iterrows():
            ax.text(
                row["Step"],
                row["train_mean"] + 0.005,
                f'{row["train_mean"]:.3f}',
                ha="center",
                va="bottom",
                fontsize=metric_value_fs,
                color='black',
            )
        if line_test is not None:
            for _, row in df_log.iterrows():
                ax.text(
                    row["Step"],
                    row["test_mean"] - 0.020,
                    f'{row["test_mean"]:.3f}',
                    ha="center",
                    va="bottom",
                    fontsize=metric_value_fs,
                    color='black',
                )

    # Axes formatting
    ax.set_title(title, fontsize=title_fs, fontstyle=title_fs_style)
    ax.set_xlabel(x_label, fontsize=x_label_fs, labelpad=x_labelpad)
    ax.set_ylabel(y_label, fontsize=y_label_fs, labelpad=y_labelpad)
    ax.tick_params(axis="x", labelsize=x_tick_fs)
    ax.tick_params(axis="y", labelsize=y_tick_fs)

    # Exactly 10 ticks on Y
    ax.yaxis.set_major_locator(ticker.MaxNLocator(10))

    # Steps and labels
    ax.set_xticks(df_log["Step"])
    if "feature" in df_log.columns:
        ax.set_xticklabels(df_log["feature"], rotation=0)

    # Legend with only two line entries
    handles = [line_train] + ([line_test] if line_test is not None else [])
    labels = ["Train"] + (["Test"] if line_test is not None else [])
    ax.legend(handles, labels, loc="upper left", frameon=True)

    # Y limits padding
    y_candidates = [df_log["train_low"], df_log["train_high"], df_log["train_mean"]]
    if line_test is not None:
        y_candidates += [df_log["test_low"], df_log["test_high"], df_log["test_mean"]]
    y_min = np.nanmin([c.min() for c in y_candidates])
    y_max = np.nanmax([c.max() for c in y_candidates])
    if np.isfinite(y_min) and np.isfinite(y_max):
        pad = (y_max - y_min) * 0.06 if y_max > y_min else 0.02
        ax.set_ylim(y_min - pad, y_max + pad)

    if created_fig:
        plt.tight_layout()
        plt.show()

    return ax

# %% [markdown]
# ### Feature selection

# %%
candidate_features = []

for feature in of_features_to_save:
    feature_types_lst = feature_to_types[feature]
    for feature_type in feature_types_lst:
        candidate_features.append(feature)

print(f'Число фичей для многофакторного анализа: {len(candidate_features)}')

# %%
# %%time

selected_feats, selection_log = forward_selection_bootstrap(
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    candidate_features=candidate_features,
    scoring='roc_auc_ovr',
    min_uplift=0.005,
    max_features=4,
    n_bootstrap=50,
    uplift_type='low',  # 'mean', 'low', 'high'
    n_jobs=-1
)

# %%
PLOT_STYLE = {
    'TITLE': '',
    'TITLE_FONT_SIZE': 12,
    'TITLE_FONTSTYLE': 'normal',
    'X_LABEL': '',
    'Y_LABEL': '$ROC-AUC_{ovr}$',
    'X_LABEL_FONT_SIZE': 12,
    'Y_LABEL_FONT_SIZE': 12,
    'X_TICK_LABEL_FONT_SIZE': 16,
    'Y_TICK_LABEL_FONT_SIZE': 10,
    'X_LABELPAD': 10,
    'Y_LABELPAD': 10,
    'METRIC_VALUE_FONT_SIZE': 8,
    'Y_NBINS': 10
}

# %%
fig, ax = plt.subplots(figsize=(8, 4), dpi=300)

plot_cumulative_score_line_bootstrap(
    selection_log=selection_log,
    ax=ax,
    show_ci=True
)

plt.tight_layout()
plt.savefig(f'{path_to_save}/fs_uplift_lineplot_bootstrap.svg', dpi=600)
plt.show()

# %% [markdown]
# ## Models analysis

# %% [markdown]
# ### Functions for processing

# %% [markdown]
# #### Modeling process (*scaling, `lr` fitting, cross-validation, metrics calculation*)

# %%
def logreg_bootstrap_train_test(
    X_train: pd.DataFrame,
    y_train: pd.Series,
    X_test: pd.DataFrame,
    y_test: pd.Series,
    feature_list=None,
    C_values=None,
    n_bootstrap: int = 50,
    random_state: int = 42,
    reoptimize_C_on_bootstrap: bool = True,
    solver: str = "lbfgs",
    max_iter: int = 10_000,
):
    # ---- feature selection & alignment ----
    if feature_list is not None:
        feature_list = list(feature_list)
        missing_train = [f for f in feature_list if f not in X_train.columns]
        missing_test  = [f for f in feature_list if f not in X_test.columns]
        if missing_train or missing_test:
            raise ValueError(
                f"Selected features missing:\n"
                f"- in X_train: {missing_train}\n"
                f"- in X_test : {missing_test}"
            )
        X_train_use = X_train.loc[:, feature_list].copy()
        X_test_use  = X_test.loc[:, feature_list].copy()
    else:
        # If not provided, use the intersection to be safe and keep consistent order from X_train
        common = [c for c in X_train.columns if c in X_test.columns]
        if not common:
            raise ValueError("No common features between X_train and X_test.")
        feature_list = common
        X_train_use = X_train.loc[:, feature_list].copy()
        X_test_use  = X_test.loc[:, feature_list].copy()

    # ---- grids and classes ----
    if C_values is None:
        C_values = np.logspace(-4, 4, 30)

    classes = np.unique(y_train)

    def optimize_C(X_tr_scaled, y_tr, C_grid, scoring='roc_auc'):
        """Tune C by maximizing macro ROC-AUC on the (scaled) training set."""
        scores = []
        for C in C_grid:
            clf = OneVsRestClassifier(
                LogisticRegression(C=C, solver=solver, max_iter=max_iter)
            )
            clf.fit(X_tr_scaled, y_tr)
            proba = clf.predict_proba(X_tr_scaled)
            score = roc_auc_score(y_tr, proba, multi_class='ovr', average='macro')
            scores.append(score)
        c_metric_df_ = pd.DataFrame({'C': C_grid, scoring: scores})
        best_C_ = c_metric_df_.loc[c_metric_df_[scoring].idxmax(), 'C']
        return best_C_, c_metric_df_

    def compute_metrics(y_true, proba, classes_):
        """Return macro ROC-AUC (OvR) and macro PR-AUC for multiclass."""
        roc = roc_auc_score(y_true, proba, multi_class='ovr', average='macro')
        Y_bin = label_binarize(y_true, classes=classes_)
        pr = average_precision_score(Y_bin, proba, average='macro')
        return roc, pr

    def ci_percentile(data, lower=5, upper=95):
        """Percentile-based confidence interval."""
        return float(np.percentile(data, lower)), float(np.percentile(data, upper))

    # ---- final model (tune C on full train, fit once) ----
    scaler = StandardScaler().fit(X_train_use.values)
    X_tr_scaled = scaler.transform(X_train_use.values)
    X_te_scaled = scaler.transform(X_test_use.values)

    best_C_full, c_metric_df = optimize_C(X_tr_scaled, y_train.values, C_values)

    clf_full = OneVsRestClassifier(
        LogisticRegression(C=best_C_full, solver=solver, max_iter=max_iter)
    )
    clf_full.fit(X_tr_scaled, y_train.values)

    proba_tr = clf_full.predict_proba(X_tr_scaled)
    proba_te = clf_full.predict_proba(X_te_scaled)

    roc_train_point, pr_train_point = compute_metrics(y_train.values, proba_tr, classes)
    roc_test_point,  pr_test_point  = compute_metrics(y_test.values,  proba_te, classes)

    # ---- coefficients & scaler summary ----
    coef_df = pd.DataFrame(
        [est.coef_.flatten() for est in clf_full.estimators_],
        columns=feature_list,
        index=[f'Class {c}' for c in clf_full.classes_]
    )
    coef_df['Intercept'] = [float(est.intercept_[0]) for est in clf_full.estimators_]

    scaler_df = pd.DataFrame({'Feature': feature_list, 'Mean': scaler.mean_, 'Std': scaler.scale_})

    # ---- bootstrap: CIs for train and test ----
    rng = np.random.RandomState(random_state)
    roc_train_boot, pr_train_boot = [], []
    roc_test_boot,  pr_test_boot  = [], []

    n = len(X_train_use)
    X_te_np = X_test_use.values
    y_te_np = y_test.values

    for _ in tqdm(range(n_bootstrap), desc="Calculation progress"):
        # resample indices with replacement from training set
        idx = rng.choice(n, size=n, replace=True)
        Xb = X_train_use.values[idx]
        yb = y_train.values[idx]

        # fit scaler on bootstrap sample to avoid leakage
        scaler_b = StandardScaler().fit(Xb)
        Xb_scaled = scaler_b.transform(Xb)
        Xte_scaled_b = scaler_b.transform(X_te_np)

        # optionally re-tune C inside bootstrap
        if reoptimize_C_on_bootstrap:
            C_b, _ = optimize_C(Xb_scaled, yb, C_values)
        else:
            C_b = best_C_full

        clf_b = OneVsRestClassifier(
            LogisticRegression(C=C_b, solver=solver, max_iter=max_iter)
        )
        clf_b.fit(Xb_scaled, yb)

        proba_b_tr = clf_b.predict_proba(Xb_scaled)
        proba_b_te = clf_b.predict_proba(Xte_scaled_b)

        roc_tr_b, pr_tr_b = compute_metrics(yb, proba_b_tr, classes)
        roc_te_b, pr_te_b = compute_metrics(y_te_np, proba_b_te, classes)

        roc_train_boot.append(roc_tr_b)
        pr_train_boot.append(pr_tr_b)
        roc_test_boot.append(roc_te_b)
        pr_test_boot.append(pr_te_b)

    metrics_df = pd.DataFrame({
        'ROC-AUC (macro, OvR)': {
            'Train point': round(roc_train_point, 6),
            'Test point' : round(roc_test_point,  6),
            'Train CI 5–95%': [round(x, 6) for x in ci_percentile(roc_train_boot)],
            'Test  CI 5–95%': [round(x, 6) for x in ci_percentile(roc_test_boot)],
        },
        'PR-AUC (macro)': {
            'Train point': round(pr_train_point, 6),
            'Test point' : round(pr_test_point,  6),
            'Train CI 5–95%': [round(x, 6) for x in ci_percentile(pr_train_boot)],
            'Test  CI 5–95%': [round(x, 6) for x in ci_percentile(pr_test_boot)],
        }
    })

    return clf_full, X_tr_scaled, X_te_scaled, scaler, coef_df, scaler_df, metrics_df, best_C_full, c_metric_df

# %% [markdown]
# #### `C` optimaztion visualization

# %%
def plot_c_metric_curve(c_metric_df, metric_name='roc_auc', best_C=None, ax=None):
    external_ax = ax is not None
    fig, ax = plt.subplots(figsize=PLOT_STYLE['FIGSIZE'], dpi=300) if not external_ax else (None, ax)

    sns.lineplot(
        data=c_metric_df,
        x='C',
        y=metric_name,
        color='teal',
        linewidth=3.5,
        ax=ax
    )

    ax.set_xscale('log')

    if best_C is not None:
        best_y = c_metric_df.loc[c_metric_df['C'] == best_C, metric_name].values
        if len(best_y):
            ax.axvline(x=best_C, color='darkred', linestyle='--', linewidth=1.8)
            ax.scatter(best_C, best_y[0], color='darkred', s=50, zorder=5)

    ax.set_title(PLOT_STYLE['TITLE'], fontsize=PLOT_STYLE['TITLE_FONT_SIZE'], fontstyle=PLOT_STYLE['TITLE_FONTSTYLE'])
    
    ax.set_xlabel(PLOT_STYLE['X_LABEL'], fontsize=PLOT_STYLE['X_LABEL_FONT_SIZE'], labelpad=PLOT_STYLE['X_LABELPAD'])
    ax.set_ylabel(PLOT_STYLE['Y_LABEL'], fontsize=PLOT_STYLE['Y_LABEL_FONT_SIZE'], labelpad=PLOT_STYLE['Y_LABELPAD'])
    
    ax.tick_params(axis='x', labelsize=PLOT_STYLE['X_TICK_LABEL_FONT_SIZE'])
    ax.tick_params(axis='y', labelsize=PLOT_STYLE['Y_TICK_LABEL_FONT_SIZE'])

    if not external_ax:
        plt.tight_layout()
        plt.show()

# %% [markdown]
# #### *ROC*-curves visualization

# %%
def plot_roc_curve_per_class(
    model, 
    X_train, y_train, 
    X_test, y_test, 
    class_index, ax
):
    classes = model.classes_
    y_train_bin = label_binarize(y_train, classes=classes)
    y_test_bin  = label_binarize(y_test,  classes=classes)

    # predict probabilities
    y_score_train = model.predict_proba(X_train)
    y_score_test  = model.predict_proba(X_test)

    # compute ROC curve
    fpr_tr, tpr_tr, _ = roc_curve(y_train_bin[:, class_index], y_score_train[:, class_index])
    fpr_te, tpr_te, _ = roc_curve(y_test_bin[:, class_index],  y_score_test[:,  class_index])

    # compute AUC
    auc_tr = auc(fpr_tr, tpr_tr)
    auc_te = auc(fpr_te, tpr_te)

    class_label = class_fraction_group_dict[class_index]
    class_color = type_color_dict[class_label]

    # plot train curve
    ax.plot(
        fpr_tr, tpr_tr,
        color=class_color,
        linewidth=PLOT_STYLE['LINE_WIDTH'],
        linestyle='-',
        label=fr'$ROC\text{{-}}AUC^{{train}} = {auc_tr:.2f}$'
    )

    # plot test curve
    ax.plot(
        fpr_te, tpr_te,
        color=class_color,
        linewidth=PLOT_STYLE['LINE_WIDTH'],
        linestyle='--',
        label=fr'$ROC\text{{-}}AUC^{{test}} = {auc_te:.2f}$'
    )

    # random baseline
    ax.plot([0, 1], [0, 1], linestyle=':', color='gray', linewidth=1, label='')

    # formatting
    ax.set_title(class_label, fontsize=PLOT_STYLE['TITLE_FONT_SIZE'], fontstyle=PLOT_STYLE['TITLE_FONTSTYLE'])
    ax.set_xlabel(PLOT_STYLE['X_LABEL'], fontsize=PLOT_STYLE['X_LABEL_FONT_SIZE'], labelpad=PLOT_STYLE['X_LABELPAD'])
    ax.set_ylabel(PLOT_STYLE['Y_LABEL'], fontsize=PLOT_STYLE['Y_LABEL_FONT_SIZE'], labelpad=PLOT_STYLE['Y_LABELPAD'])

    ax.tick_params(axis='x', labelsize=PLOT_STYLE['X_TICK_LABEL_FONT_SIZE'])
    ax.tick_params(axis='y', labelsize=PLOT_STYLE['Y_TICK_LABEL_FONT_SIZE'])

    if 'X_NBINS' in PLOT_STYLE:
        ax.xaxis.set_major_locator(ticker.MaxNLocator(nbins=PLOT_STYLE['X_NBINS']))
    if 'Y_NBINS' in PLOT_STYLE:
        ax.yaxis.set_major_locator(ticker.MaxNLocator(nbins=PLOT_STYLE['Y_NBINS']))

    ax.legend(loc='lower right', fontsize=PLOT_STYLE['LEGEND_FONT_SIZE'])

# %% [markdown]
# #### *SHAP*-values visualization (*beeswarm*)

# %%
def plot_shap_summary_logreg(
    model,
    X_train_scaled: pd.DataFrame,
    X_test_scaled: pd.DataFrame,
    features_lst: list[str],
    class_index: int = 0,
    max_display: int = 20,
    show_colorbar: bool = True,
    ax=None
):
    """
    Build a SHAP summary (beeswarm) for a multinomial One-vs-Rest LogisticRegression (or plain LogisticRegression)
    using a merged dataset of train + test.

    Parameters
    ----------
    model : fitted estimator
        Either OneVsRestClassifier(LogisticRegression) or LogisticRegression.
    X_train_scaled : pd.DataFrame
        Scaled train features. Must have the same columns and order as test.
    X_test_scaled : pd.DataFrame
        Scaled test features. Must have the same columns and order as train.
    features_lst : list[str]
        Feature names in the order matching columns of X_*_scaled.
    class_index : int
        Index of the class to explain when model is OneVsRestClassifier.
    max_display : int
        Max number of features to display in the beeswarm.
    show_colorbar : bool
        Whether to show SHAP colorbar.
    ax : matplotlib.axes.Axes | None
        Axis to draw on. If None, a new figure/axis is created.

    Notes
    -----
    - We merge X_train and X_test vertically and compute SHAP values on the merged matrix.
    - Color encodes feature values (default SHAP behavior).
    - If your model is OVR, we pick `estimators_[class_index]`.
    """

    # pick base binary logistic regression if it is OneVsRestClassifier
    base_model = model.estimators_[class_index] if hasattr(model, 'estimators_') else model

    # sanity checks on columns
    if list(X_train_scaled.columns) != list(X_test_scaled.columns):
        raise ValueError("Train/Test columns (order) must match exactly.")
    if features_lst and list(X_train_scaled.columns) != list(features_lst):
        # keep behavior predictable: columns should match features_lst
        raise ValueError("features_lst must match X_*_scaled columns order.")

    # merge train + test by rows
    X_merged = pd.concat([X_train_scaled, X_test_scaled], axis=0, ignore_index=True)

    # build explainer on merged data (interventional background = merged)
    explainer = shap.LinearExplainer(base_model, X_merged, feature_perturbation='interventional')

    # compute SHAP values for merged matrix
    shap_values = explainer(X_merged)
    shap_values.feature_names = list(features_lst)

    # figure/axis handling
    external_ax = ax is not None
    fig, ax = plt.subplots(figsize=PLOT_STYLE['FIGSIZE']) if ax is None else (plt.gcf(), ax)

    # draw beeswarm for merged data
    shap.plots.beeswarm(
        shap_values,
        max_display=max_display,
        show=False,
        color_bar=show_colorbar,
        ax=ax,
        s=PLOT_STYLE.get('DOT_SIZE', 12),
        plot_size=None
    )

    # titles/labels/ticks styling
    ax.set_title(
        PLOT_STYLE['TITLE'],
        fontsize=PLOT_STYLE['TITLE_FONT_SIZE'],
        fontstyle=PLOT_STYLE['TITLE_FONTSTYLE']
    )
    ax.set_xlabel(
        PLOT_STYLE['X_LABEL'],
        fontsize=PLOT_STYLE['X_LABEL_FONT_SIZE'],
        labelpad=PLOT_STYLE['X_LABELPAD']
    )
    ax.set_ylabel(
        PLOT_STYLE['Y_LABEL'],
        fontsize=PLOT_STYLE['Y_LABEL_FONT_SIZE'],
        labelpad=PLOT_STYLE['Y_LABELPAD']
    )
    ax.tick_params(axis='x', labelsize=PLOT_STYLE['X_TICK_LABEL_FONT_SIZE'])
    ax.tick_params(axis='y', labelsize=PLOT_STYLE['Y_TICK_LABEL_FONT_SIZE'])

    if 'X_NBINS' in PLOT_STYLE:
        ax.xaxis.set_major_locator(ticker.MaxNLocator(nbins=PLOT_STYLE['X_NBINS']))

    # style SHAP colorbar (which SHAP draws as a separate axis) if present
    if show_colorbar:
        current_fig = plt.gcf()
        for other_ax in current_fig.axes:
            # heuristic: SHAP colorbar axis has no xticks and has yticks
            if other_ax is not ax and len(other_ax.get_xticks()) == 0 and len(other_ax.get_yticks()) > 0:
                other_ax.set_ylabel(PLOT_STYLE['LEGEND_TITLE'], fontsize=PLOT_STYLE['LEGEND_FONT_SIZE'])
                other_ax.tick_params(labelsize=PLOT_STYLE['LEGEND_FONT_SIZE'])
                if 'COLORBAR_TICKS' in PLOT_STYLE:
                    other_ax.set_yticklabels(PLOT_STYLE['COLORBAR_TICKS'])

    if not external_ax:
        plt.tight_layout()
        plt.show()

# %% [markdown]
# ### Model investigation

# %% [markdown]
# #### Model fitting

# %%
model, X_tr_scaled, X_te_scaled, scaler, coef_df, scaler_df, metrics_df, best_C_full, c_metric_df = logreg_bootstrap_train_test(
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    feature_list=selected_feats,
    C_values=np.logspace(-8, 8, 50),
    n_bootstrap=50,
    random_state=42
)

# %%
X_tr_scaled = pd.DataFrame(X_tr_scaled, columns=selected_feats)

print(X_tr_scaled.shape)
X_tr_scaled.head(3)

# %%
X_te_scaled = pd.DataFrame(X_te_scaled, columns=selected_feats)

print(X_te_scaled.shape)
X_te_scaled.head(3)

# %% [markdown]
# *Parameters for scaling*

# %%
display(scaler_df.T)

# %% [markdown]
# *Model parameters (weights & intercept)*

# %%
display(coef_df)

# %% [markdown]
# *Model metrics*

# %%
display(metrics_df)

# %% [markdown]
# *Optimal inverse of regulation strength value*

# %% [markdown]
# #### Visualization of `C` optimization

# %%
print(f'Optimal value of regularization coefficient (C): {round(best_C_full, 4)}')

# %%
PLOT_STYLE = {
    'FIGSIZE': (10, 3.3),
    'TITLE': '',
    'TITLE_FONT_SIZE': 14,
    'TITLE_FONTSTYLE': 'normal',
    'X_LABEL': 'Обратный коэффициент регуляризации ($C$)',
    'Y_LABEL': '$ROC-AUC_{ovr}$',
    'X_LABEL_FONT_SIZE': 12,
    'Y_LABEL_FONT_SIZE': 12,
    'X_LABELPAD': 6,
    'Y_LABELPAD': 6,
    'X_TICK_LABEL_FONT_SIZE': 12,
    'Y_TICK_LABEL_FONT_SIZE': 11
}

# %%
fig, ax = plt.subplots(figsize=PLOT_STYLE['FIGSIZE'], dpi=300)

plot_c_metric_curve(
    c_metric_df=c_metric_df,
    metric_name='roc_auc',
    best_C=best_C_full,
    ax=ax
)

plt.tight_layout()

plt.savefig(f'{path_to_save}/c_optimization_curve.svg', dpi=600)

plt.show()

# %% [markdown]
# #### *ROC*-curves visualization

# %%
PLOT_STYLE = {
    'FIGSIZE': (10, 4),
    'TITLE_FONT_SIZE': 16,
    'TITLE_FONTSTYLE': 'normal',
    'X_LABEL': 'False Positive Rate',
    'Y_LABEL': 'True Positive Rate',
    'X_LABEL_FONT_SIZE': 14,
    'Y_LABEL_FONT_SIZE': 14,
    'X_TICK_LABEL_FONT_SIZE': 12,
    'Y_TICK_LABEL_FONT_SIZE': 12,
    'X_LABELPAD': 6,
    'Y_LABELPAD': 6,
    'LEGEND_FONT_SIZE': 10,
    'X_NBINS': 6,
    'Y_NBINS': 6,
    'LINE_WIDTH': 2.5
}

# %%
fig, axes = plt.subplots(1, 3, figsize=PLOT_STYLE['FIGSIZE'], dpi=300)
axes = axes.flat

for i, ax in enumerate(axes):
    plot_roc_curve_per_class(
        model=model,
        X_train=X_tr_scaled,
        y_train=y_train,
        X_test=X_te_scaled,
        y_test=y_test,
        class_index=i,
        ax=ax
    )

plt.tight_layout()
plt.savefig(f'{path_to_save}/roc_curves_train_test.svg')
plt.show()

# %% [markdown]
# #### *SHAP-values* diagram

# %%
PLOT_STYLE = {
    'FIGSIZE': (14, 5),
    'TITLE': '',
    'TITLE_FONT_SIZE': 16,
    'TITLE_FONTSTYLE': 'normal',
    'X_LABEL': '$SHAP$ value',
    'Y_LABEL': '',
    'X_LABEL_FONT_SIZE': 14,
    'Y_LABEL_FONT_SIZE': 12,
    'X_TICK_LABEL_FONT_SIZE': 12,
    'Y_TICK_LABEL_FONT_SIZE': 20,
    'X_LABELPAD': 8,
    'Y_LABELPAD': 20,
    'DOT_SIZE': 64,
    'LEGEND_TITLE': 'Значение признака',
    'LEGEND_FONT_SIZE': 14,
    'X_NBINS': 6,
    'COLORBAR_TICKS': ['Низкое', 'Высокое']
}

# %%
nrows, ncols = 1, 3
fig, axes = plt.subplots(nrows, ncols, figsize=PLOT_STYLE['FIGSIZE'], dpi=300)
axes = axes.flat

for i, ax in enumerate(axes):
    show_colorbar = (i == ncols - 1)  # show only on the last subplot
    PLOT_STYLE['TITLE'] = class_fraction_group_dict[i]  # заголовок как раньше

    plot_shap_summary_logreg(
        model=model,
        X_train_scaled=X_tr_scaled,
        X_test_scaled=X_te_scaled,
        features_lst=X_tr_scaled.columns.tolist(),
        class_index=i,
        max_display=20,
        show_colorbar=show_colorbar,
        ax=ax
    )

plt.tight_layout()
plt.savefig(f'{path_to_save}/shap_3_subplots.svg')
plt.show()
