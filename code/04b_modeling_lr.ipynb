# %% [markdown]
# # Import libraries

# %%
import os
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.cm as cm

import seaborn as sns

import math

import json

import re

import shap

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import label_binarize

from sklearn.model_selection import cross_validate
from sklearn.model_selection import StratifiedKFold

from sklearn.utils import resample

from sklearn.multiclass import OneVsRestClassifier

from sklearn.linear_model import LogisticRegression

from sklearn.pipeline import Pipeline

from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn.metrics import make_scorer
from sklearn.metrics import confusion_matrix

from scipy.stats import t

from joblib import Parallel
from joblib import delayed
from tqdm_joblib import tqdm_joblib

from itertools import combinations

from collections import defaultdict

from tqdm.notebook import tqdm

# %%
warnings.filterwarnings("ignore")

np.seterr(all='ignore')

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', None)

# %%
path_to_save = './../results/04b_modeling_lr'

# %% [markdown]
# # Loading data

# %%
path_to_ftir_data = './../data/processed_data/dataset_1900_800_engineered.csv'
path_to_features_description = './../data/processed_data/features_description_1900_800.json'

# %% [markdown]
# ## FTIR-features (*long-list*)

# %%
dataset = pd.read_csv(path_to_ftir_data, sep=';', index_col=0)

print(dataset.shape)
dataset.head(3)
# Out:
# (75, 324)
#                       $I_{873}$  $I_{1105}$  $I_{1241}$  $I_{1394}$  \
# division_1_size_bulk   0.048208    0.681294    0.455066    0.760582
# division_1_size_5      0.091875    0.606138    0.427988    0.687458
# division_1_size_3      0.110321    0.836176    0.400950    0.696553
#
#                       $I_{1615}$  $I_{1726}$  \
# division_1_size_bulk         1.0    0.421995
# division_1_size_5            1.0    0.383362
# division_1_size_3            1.0    0.366658
#
#                       $\overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                          0.424162
# division_1_size_5                             0.378730
# division_1_size_3                             0.436266
#
#                       $\Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                          3.367146
# division_1_size_5                             3.196821
# division_1_size_3                             3.410658
#
#                       $\overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                           0.426619
# division_1_size_5                              0.378004
# division_1_size_3                              0.429362
#
#                       $\Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                           1.421995
# division_1_size_5                              1.383362
# division_1_size_3                              1.366658
#
#                       $\overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                           0.571735
# division_1_size_5                              0.502368
# division_1_size_3                              0.523513
#
#                       $\Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                           0.760582
# division_1_size_5                              0.687458
# division_1_size_3                              0.696553
#
#                       $\overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                          0.363338
# division_1_size_5                             0.329999
# division_1_size_3                             0.406988
#
#                       $\Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                          1.184569
# division_1_size_5                             1.126001
# division_1_size_3                             1.347446
#
#                       $\overline{I}_{873 \pm 25}$  \
# division_1_size_bulk                     0.047543
# division_1_size_5                        0.093349
# division_1_size_3                        0.113396
#
#                       $\overline{I}_{873 \pm 50}$  \
# division_1_size_bulk                     0.047916
# division_1_size_5                        0.096086
# division_1_size_3                        0.114054
#
#                       $\overline{I}_{1105 \pm 25}$  \
# division_1_size_bulk                      0.628121
# division_1_size_5                         0.593910
# division_1_size_3                         0.816077
#
#                       $\overline{I}_{1105 \pm 50}$  \
# division_1_size_bulk                      0.615327
# division_1_size_5                         0.562713
# division_1_size_3                         0.774107
#
#                       $\overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                      0.447733
# division_1_size_5                         0.424918
# division_1_size_3                         0.401435
#
#                       $\overline{I}_{1241 \pm 50}$  \
# division_1_size_bulk                      0.442677
# division_1_size_5                         0.421892
# division_1_size_3                         0.409080
#
#                       $\overline{I}_{1394 \pm 25}$  \
# division_1_size_bulk                      0.738860
# division_1_size_5                         0.667947
# division_1_size_3                         0.678774
#
#                       $\overline{I}_{1394 \pm 50}$  \
# division_1_size_bulk                      0.689531
# division_1_size_5                         0.619315
# division_1_size_3                         0.631706
#
#                       $\overline{I}_{1615 \pm 25}$  \
# division_1_size_bulk                      0.944739
# division_1_size_5                         0.937481
# division_1_size_3                         0.957114
#
#                       $\overline{I}_{1615 \pm 50}$  \
# division_1_size_bulk                      0.845640
# division_1_size_5                         0.831352
# division_1_size_3                         0.877520
#
#                       $\overline{I}_{1726 \pm 25}$  \
# division_1_size_bulk                      0.415802
# division_1_size_5                         0.376555
# division_1_size_3                         0.366774
#
#                       $\overline{I}_{1726 \pm 50}$  $\log I_{873}$  \
# division_1_size_bulk                      0.413416       -3.032222
# division_1_size_5                         0.371393       -2.387325
# division_1_size_3                         0.375602       -2.204364
#
#                       $(I_{873})^{-1}$  $\log I_{1105}$  $(I_{1105})^{-1}$  \
# division_1_size_bulk         20.743271        -0.383761           1.467794
# division_1_size_5            10.884335        -0.500648           1.649790
# division_1_size_3             9.064483        -0.178917           1.195921
#
#                       $\log I_{1241}$  $(I_{1241})^{-1}$  $\log I_{1394}$  \
# division_1_size_bulk        -0.787312           2.197482        -0.273672
# division_1_size_5           -0.848660           2.336514        -0.374754
# division_1_size_3           -0.913918           2.494076        -0.361611
#
#                       $(I_{1394})^{-1}$  $\log I_{1615}$  $(I_{1615})^{-1}$  \
# division_1_size_bulk           1.314783              0.0                1.0
# division_1_size_5              1.454634              0.0                1.0
# division_1_size_3              1.435640              0.0                1.0
#
#                       $\log I_{1726}$  $(I_{1726})^{-1}$  \
# division_1_size_bulk        -0.862761           2.369695
# division_1_size_5           -0.958776           2.608502
# division_1_size_3           -1.003327           2.727339
#
#                       $\log \overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                              -0.857641
# division_1_size_5                                 -0.970931
# division_1_size_3                                 -0.829504
#
#                       $(\overline{I}_{1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.357591
# division_1_size_5                                    2.640400
# division_1_size_3                                    2.292181
#
#                       $\log \Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                               1.214065
# division_1_size_5                                  1.162157
# division_1_size_3                                  1.226905
#
#                       $(\Sigma I_{p,\ 1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.296987
# division_1_size_5                                    0.312811
# division_1_size_3                                    0.293199
#
#                       $\log \overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                               -0.851863
# division_1_size_5                                  -0.972851
# division_1_size_3                                  -0.845455
#
#                       $(\overline{I}_{1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  2.344010
# division_1_size_5                                     2.645477
# division_1_size_3                                     2.329038
#
#                       $\log \Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                                0.352061
# division_1_size_5                                   0.324517
# division_1_size_3                                   0.312368
#
#                       $(\Sigma I_{p,\ 1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  0.703237
# division_1_size_5                                     0.722877
# division_1_size_3                                     0.731712
#
#                       $\log \overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                               -0.559080
# division_1_size_5                                  -0.688422
# division_1_size_3                                  -0.647194
#
#                       $(\overline{I}_{1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.749062
# division_1_size_5                                     1.990572
# division_1_size_3                                     1.910173
#
#                       $\log \Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                               -0.273672
# division_1_size_5                                  -0.374754
# division_1_size_3                                  -0.361611
#
#                       $(\Sigma I_{p,\ 1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.314783
# division_1_size_5                                     1.454634
# division_1_size_3                                     1.435640
#
#                       $\log \overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                              -1.012422
# division_1_size_5                                 -1.108665
# division_1_size_3                                 -0.898970
#
#                       $(\overline{I}_{1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.752259
# division_1_size_5                                    3.030309
# division_1_size_3                                    2.457072
#
#                       $\log \Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                               0.169379
# division_1_size_5                                  0.118672
# division_1_size_3                                  0.298211
#
#                       $(\Sigma I_{p,\ 1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.844189
# division_1_size_5                                    0.888099
# division_1_size_3                                    0.742145
#
#                       $\log \overline{I}_{873 \pm 25}$  \
# division_1_size_bulk                         -3.046113
# division_1_size_5                            -2.371406
# division_1_size_3                            -2.176872
#
#                       $(\overline{I}_{873 \pm 25})^{-1}$  \
# division_1_size_bulk                           21.033424
# division_1_size_5                              10.712443
# division_1_size_3                               8.818675
#
#                       $\log \overline{I}_{873 \pm 50}$  \
# division_1_size_bulk                         -3.038304
# division_1_size_5                            -2.342512
# division_1_size_3                            -2.171085
#
#                       $(\overline{I}_{873 \pm 50})^{-1}$  \
# division_1_size_bulk                           20.869820
# division_1_size_5                              10.407351
# division_1_size_3                               8.767790
#
#                       $\log \overline{I}_{1105 \pm 25}$  \
# division_1_size_bulk                          -0.465023
# division_1_size_5                             -0.521028
# division_1_size_3                             -0.203247
#
#                       $(\overline{I}_{1105 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.592050
# division_1_size_5                                1.683757
# division_1_size_3                                1.225375
#
#                       $\log \overline{I}_{1105 \pm 50}$  \
# division_1_size_bulk                          -0.485601
# division_1_size_5                             -0.574985
# division_1_size_3                             -0.256045
#
#                       $(\overline{I}_{1105 \pm 50})^{-1}$  \
# division_1_size_bulk                             1.625151
# division_1_size_5                                1.777105
# division_1_size_3                                1.291811
#
#                       $\log \overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                          -0.803558
# division_1_size_5                             -0.855859
# division_1_size_3                             -0.912710
#
#                       $(\overline{I}_{1241 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.233473
# division_1_size_5                                2.353396
# division_1_size_3                                2.491063
#
#                       $\log \overline{I}_{1241 \pm 50}$  \
# division_1_size_bulk                          -0.814914
# division_1_size_5                             -0.863007
# division_1_size_3                             -0.893845
#
#                       $(\overline{I}_{1241 \pm 50})^{-1}$  \
# division_1_size_bulk                             2.258982
# division_1_size_5                                2.370277
# division_1_size_3                                2.444512
#
#                       $\log \overline{I}_{1394 \pm 25}$  \
# division_1_size_bulk                          -0.302647
# division_1_size_5                             -0.403547
# division_1_size_3                             -0.387466
#
#                       $(\overline{I}_{1394 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.353436
# division_1_size_5                                1.497126
# division_1_size_3                                1.473243
#
#                       $\log \overline{I}_{1394 \pm 50}$  \
# division_1_size_bulk                          -0.371743
# division_1_size_5                             -0.479141
# division_1_size_3                             -0.459332
#
#                       $(\overline{I}_{1394 \pm 50})^{-1}$  \
# division_1_size_bulk                             1.450261
# division_1_size_5                                1.614687
# division_1_size_3                                1.583015
#
#                       $\log \overline{I}_{1615 \pm 25}$  \
# division_1_size_bulk                          -0.056847
# division_1_size_5                             -0.064558
# division_1_size_3                             -0.043832
#
#                       $(\overline{I}_{1615 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.058493
# division_1_size_5                                1.066688
# division_1_size_3                                1.044807
#
#                       $\log \overline{I}_{1615 \pm 50}$  \
# division_1_size_bulk                          -0.167661
# division_1_size_5                             -0.184702
# division_1_size_3                             -0.130656
#
#                       $(\overline{I}_{1615 \pm 50})^{-1}$  \
# division_1_size_bulk                             1.182536
# division_1_size_5                                1.202860
# division_1_size_3                                1.139575
#
#                       $\log \overline{I}_{1726 \pm 25}$  \
# division_1_size_bulk                          -0.877547
# division_1_size_5                             -0.976691
# division_1_size_3                             -1.003010
#
#                       $(\overline{I}_{1726 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.404992
# division_1_size_5                                2.655654
# division_1_size_3                                2.726475
#
#                       $\log \overline{I}_{1726 \pm 50}$  \
# division_1_size_bulk                          -0.883300
# division_1_size_5                             -0.990494
# division_1_size_3                             -0.979224
#
#                       $(\overline{I}_{1726 \pm 50})^{-1}$  \
# division_1_size_bulk                             2.418869
# division_1_size_5                                2.692566
# division_1_size_3                                2.662390
#
#                       $\frac{I_{873}}{I_{1105}}$  $\frac{I_{873}}{I_{1241}}$  \
# division_1_size_bulk                    0.070760                    0.105937
# division_1_size_5                       0.151575                    0.214668
# division_1_size_3                       0.131935                    0.275148
#
#                       $\frac{I_{873}}{I_{1394}}$  $\frac{I_{873}}{I_{1615}}$  \
# division_1_size_bulk                    0.063384                    0.048208
# division_1_size_5                       0.133645                    0.091875
# division_1_size_3                       0.158381                    0.110321
#
#                       $\frac{I_{873}}{I_{1726}}$  \
# division_1_size_bulk                    0.114239
# division_1_size_5                       0.239657
# division_1_size_3                       0.300882
#
#                       $\frac{I_{873}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                          0.113656
# division_1_size_5                                             0.242587
# division_1_size_3                                             0.252875
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                          0.014317
# division_1_size_5                                             0.028740
# division_1_size_3                                             0.032346
#
#                       $\frac{I_{873}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.113001
# division_1_size_5                                              0.243054
# division_1_size_3                                              0.256941
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.033902
# division_1_size_5                                              0.066414
# division_1_size_3                                              0.080723
#
#                       $\frac{I_{873}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.084320
# division_1_size_5                                              0.182884
# division_1_size_3                                              0.210732
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.063384
# division_1_size_5                                              0.133645
# division_1_size_3                                              0.158381
#
#                       $\frac{I_{873}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                          0.132682
# division_1_size_5                                             0.278410
# division_1_size_3                                             0.271066
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                          0.040697
# division_1_size_5                                             0.081594
# division_1_size_3                                             0.081874
#
#                       $\frac{I_{873}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_bulk                                      0.076750
# division_1_size_5                                         0.154695
# division_1_size_3                                         0.135184
#
#                       $\frac{I_{873}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_bulk                                      0.078346
# division_1_size_5                                         0.163272
# division_1_size_3                                         0.142513
#
#                       $\frac{I_{873}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                      0.107672
# division_1_size_5                                         0.216219
# division_1_size_3                                         0.274816
#
#                       $\frac{I_{873}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                      0.108902
# division_1_size_5                                         0.217770
# division_1_size_3                                         0.269680
#
#                       $\frac{I_{873}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                      0.065247
# division_1_size_5                                         0.137549
# division_1_size_3                                         0.162529
#
#                       $\frac{I_{873}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                      0.069915
# division_1_size_5                                         0.148350
# division_1_size_3                                         0.174639
#
#                       $\frac{I_{873}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                      0.051028
# division_1_size_5                                         0.098002
# division_1_size_3                                         0.115264
#
#                       $\frac{I_{873}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                      0.057008
# division_1_size_5                                         0.110513
# division_1_size_3                                         0.125719
#
#                       $\frac{I_{873}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                      0.115941
# division_1_size_5                                         0.243989
# division_1_size_3                                         0.300787
#
#                       $\frac{I_{873}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                      0.116610
# division_1_size_5                                         0.247380
# division_1_size_3                                         0.293717
#
#                       $\frac{I_{1105}}{I_{1241}}$  \
# division_1_size_bulk                     1.497132
# division_1_size_5                        1.416250
# division_1_size_3                        2.085485
#
#                       $\frac{I_{1105}}{I_{1394}}$  \
# division_1_size_bulk                     0.895754
# division_1_size_5                        0.881708
# division_1_size_3                        1.200447
#
#                       $\frac{I_{1105}}{I_{1615}}$  \
# division_1_size_bulk                     0.681294
# division_1_size_5                        0.606138
# division_1_size_3                        0.836176
#
#                       $\frac{I_{1105}}{I_{1726}}$  \
# division_1_size_bulk                     1.614460
# division_1_size_5                        1.581111
# division_1_size_3                        2.280535
#
#                       $\frac{I_{1105}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.606214
# division_1_size_5                                              1.600446
# division_1_size_3                                              1.916666
#
#                       $\frac{I_{1105}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.202336
# division_1_size_5                                              0.189606
# division_1_size_3                                              0.245166
#
#                       $\frac{I_{1105}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.596961
# division_1_size_5                                               1.603523
# division_1_size_3                                               1.947485
#
#                       $\frac{I_{1105}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.479111
# division_1_size_5                                               0.438163
# division_1_size_3                                               0.611840
#
#                       $\frac{I_{1105}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.191626
# division_1_size_5                                               1.206561
# division_1_size_3                                               1.597240
#
#                       $\frac{I_{1105}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.895754
# division_1_size_5                                               0.881708
# division_1_size_3                                               1.200447
#
#                       $\frac{I_{1105}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.875098
# division_1_size_5                                              1.836785
# division_1_size_3                                              2.054544
#
#                       $\frac{I_{1105}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.575141
# division_1_size_5                                              0.538310
# division_1_size_3                                              0.620563
#
#                       $\frac{I_{1105}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     14.329951
# division_1_size_5                                         6.493216
# division_1_size_3                                         7.373961
#
#                       $\frac{I_{1105}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_bulk                                     14.218489
# division_1_size_5                                         6.308289
# division_1_size_3                                         7.331412
#
#                       $\frac{I_{1105}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.521652
# division_1_size_5                                          1.426482
# division_1_size_3                                          2.082966
#
#                       $\frac{I_{1105}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                       1.539031
# division_1_size_5                                          1.436714
# division_1_size_3                                          2.044041
#
#                       $\frac{I_{1105}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.922089
# division_1_size_5                                          0.907465
# division_1_size_3                                          1.231890
#
#                       $\frac{I_{1105}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                       0.988054
# division_1_size_5                                          0.978723
# division_1_size_3                                          1.323679
#
#                       $\frac{I_{1105}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                       0.721146
# division_1_size_5                                          0.646560
# division_1_size_3                                          0.873642
#
#                       $\frac{I_{1105}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                       0.805655
# division_1_size_5                                          0.729099
# division_1_size_3                                          0.952885
#
#                       $\frac{I_{1105}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                       1.638507
# division_1_size_5                                          1.609692
# division_1_size_3                                          2.279812
#
#                       $\frac{I_{1105}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                       1.647962
# division_1_size_5                                          1.632066
# division_1_size_3                                          2.226225
#
#                       $\frac{I_{1241}}{I_{1394}}$  \
# division_1_size_bulk                     0.598314
# division_1_size_5                        0.622566
# division_1_size_3                        0.575620
#
#                       $\frac{I_{1241}}{I_{1615}}$  \
# division_1_size_bulk                     0.455066
# division_1_size_5                        0.427988
# division_1_size_3                        0.400950
#
#                       $\frac{I_{1241}}{I_{1726}}$  \
# division_1_size_bulk                     1.078368
# division_1_size_5                        1.116407
# division_1_size_3                        1.093527
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.072861
# division_1_size_5                                              1.130060
# division_1_size_3                                              0.919050
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.135149
# division_1_size_5                                              0.133879
# division_1_size_3                                              0.117558
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.066680
# division_1_size_5                                               1.132232
# division_1_size_3                                               0.933828
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.320020
# division_1_size_5                                               0.309383
# division_1_size_3                                               0.293380
#
#                       $\frac{I_{1241}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.795939
# division_1_size_5                                               0.851941
# division_1_size_3                                               0.765884
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.598314
# division_1_size_5                                               0.622566
# division_1_size_3                                               0.575620
#
#                       $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.252460
# division_1_size_5                                              1.296936
# division_1_size_3                                              0.985163
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.384162
# division_1_size_5                                              0.380096
# division_1_size_3                                              0.297563
#
#                       $\frac{I_{1241}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                      9.571604
# division_1_size_5                                         4.584797
# division_1_size_3                                         3.535849
#
#                       $\frac{I_{1241}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_bulk                                      9.497153
# division_1_size_5                                         4.454221
# division_1_size_3                                         3.515446
#
#                       $\frac{I_{1241}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_bulk                                       0.724488
# division_1_size_5                                          0.720628
# division_1_size_3                                          0.491314
#
#                       $\frac{I_{1241}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_bulk                                       0.739552
# division_1_size_5                                          0.760579
# division_1_size_3                                          0.517952
#
#                       $\frac{I_{1241}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.615903
# division_1_size_5                                          0.640752
# division_1_size_3                                          0.590697
#
#                       $\frac{I_{1241}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                       0.659965
# division_1_size_5                                          0.691067
# division_1_size_3                                          0.634710
#
#                       $\frac{I_{1241}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                       0.481685
# division_1_size_5                                          0.456530
# division_1_size_3                                          0.418916
#
#                       $\frac{I_{1241}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                       0.538132
# division_1_size_5                                          0.514810
# division_1_size_3                                          0.456913
#
#                       $\frac{I_{1241}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                       1.094431
# division_1_size_5                                          1.136588
# division_1_size_3                                          1.093180
#
#                       $\frac{I_{1241}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                       1.100746
# division_1_size_5                                          1.152386
# division_1_size_3                                          1.067486
#
#                       $\frac{I_{1394}}{I_{1615}}$  \
# division_1_size_bulk                     0.760582
# division_1_size_5                        0.687458
# division_1_size_3                        0.696553
#
#                       $\frac{I_{1394}}{I_{1726}}$  \
# division_1_size_bulk                     1.802346
# division_1_size_5                        1.793236
# division_1_size_3                        1.899738
#
#                       $\frac{I_{1394}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.793141
# division_1_size_5                                              1.815165
# division_1_size_3                                              1.596626
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.225883
# division_1_size_5                                              0.215044
# division_1_size_3                                              0.204228
#
#                       $\frac{I_{1394}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.782811
# division_1_size_5                                               1.818655
# division_1_size_3                                               1.622300
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.534869
# division_1_size_5                                               0.496948
# division_1_size_3                                               0.509677
#
#                       $\frac{I_{1394}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.330305
# division_1_size_5                                               1.368435
# division_1_size_3                                               1.330538
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                 1.0
# division_1_size_5                                                    1.0
# division_1_size_3                                                    1.0
#
#                       $\frac{I_{1394}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.093317
# division_1_size_5                                              2.083211
# division_1_size_3                                              1.711482
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.642074
# division_1_size_5                                              0.610531
# division_1_size_3                                              0.516943
#
#                       $\frac{I_{1394}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     15.997634
# division_1_size_5                                         7.364358
# division_1_size_3                                         6.142679
#
#                       $\frac{I_{1394}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_bulk                                     15.873200
# division_1_size_5                                         7.154620
# division_1_size_3                                         6.107234
#
#                       $\frac{I_{1394}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_bulk                                       1.210884
# division_1_size_5                                          1.157513
# division_1_size_3                                          0.853539
#
#                       $\frac{I_{1394}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_bulk                                       1.236060
# division_1_size_5                                          1.221685
# division_1_size_3                                          0.899815
#
#                       $\frac{I_{1394}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.698738
# division_1_size_5                                          1.617862
# division_1_size_3                                          1.735159
#
#                       $\frac{I_{1394}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                       1.718140
# division_1_size_5                                          1.629467
# division_1_size_3                                          1.702733
#
#                       $\frac{I_{1394}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                       0.805071
# division_1_size_5                                          0.733303
# division_1_size_3                                          0.727764
#
#                       $\frac{I_{1394}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                       0.899415
# division_1_size_5                                          0.826916
# division_1_size_3                                          0.793775
#
#                       $\frac{I_{1394}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                       1.829193
# division_1_size_5                                          1.825651
# division_1_size_3                                          1.899135
#
#                       $\frac{I_{1394}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                       1.839747
# division_1_size_5                                          1.851027
# division_1_size_3                                          1.854497
#
#                       $\frac{I_{1615}}{I_{1726}}$  \
# division_1_size_bulk                     2.369695
# division_1_size_5                        2.608502
# division_1_size_3                        2.727339
#
#                       $\frac{I_{1615}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           2.357591
# division_1_size_5                                              2.640400
# division_1_size_3                                              2.292181
#
#                       $\frac{I_{1615}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.296987
# division_1_size_5                                              0.312811
# division_1_size_3                                              0.293199
#
#                       $\frac{I_{1615}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            2.344010
# division_1_size_5                                               2.645477
# division_1_size_3                                               2.329038
#
#                       $\frac{I_{1615}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.703237
# division_1_size_5                                               0.722877
# division_1_size_3                                               0.731712
#
#                       $\frac{I_{1615}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.749062
# division_1_size_5                                               1.990572
# division_1_size_3                                               1.910173
#
#                       $\frac{I_{1615}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.314783
# division_1_size_5                                               1.454634
# division_1_size_3                                               1.435640
#
#                       $\frac{I_{1615}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.752259
# division_1_size_5                                              3.030309
# division_1_size_3                                              2.457072
#
#                       $\frac{I_{1615}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.844189
# division_1_size_5                                              0.888099
# division_1_size_3                                              0.742145
#
#                       $\frac{I_{1615}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     21.033424
# division_1_size_5                                        10.712443
# division_1_size_3                                         8.818675
#
#                       $\frac{I_{1615}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_bulk                                     20.869820
# division_1_size_5                                        10.407351
# division_1_size_3                                         8.767790
#
#                       $\frac{I_{1615}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_bulk                                       1.592050
# division_1_size_5                                          1.683757
# division_1_size_3                                          1.225375
#
#                       $\frac{I_{1615}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_bulk                                       1.625151
# division_1_size_5                                          1.777105
# division_1_size_3                                          1.291811
#
#                       $\frac{I_{1615}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       2.233473
# division_1_size_5                                          2.353396
# division_1_size_3                                          2.491063
#
#                       $\frac{I_{1615}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                       2.258982
# division_1_size_5                                          2.370277
# division_1_size_3                                          2.444512
#
#                       $\frac{I_{1615}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       1.353436
# division_1_size_5                                          1.497126
# division_1_size_3                                          1.473243
#
#                       $\frac{I_{1615}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                       1.450261
# division_1_size_5                                          1.614687
# division_1_size_3                                          1.583015
#
#                       $\frac{I_{1615}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                       2.404992
# division_1_size_5                                          2.655654
# division_1_size_3                                          2.726475
#
#                       $\frac{I_{1615}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                       2.418869
# division_1_size_5                                          2.692566
# division_1_size_3                                          2.662390
#
#                       $\frac{I_{1726}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           0.994892
# division_1_size_5                                              1.012229
# division_1_size_3                                              0.840446
#
#                       $\frac{I_{1726}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.125327
# division_1_size_5                                              0.119920
# division_1_size_3                                              0.107504
#
#                       $\frac{I_{1726}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.989161
# division_1_size_5                                               1.014175
# division_1_size_3                                               0.853960
#
#                       $\frac{I_{1726}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.296763
# division_1_size_5                                               0.277123
# division_1_size_3                                               0.268288
#
#                       $\frac{I_{1726}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.738096
# division_1_size_5                                               0.763109
# division_1_size_3                                               0.700380
#
#                       $\frac{I_{1726}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.554832
# division_1_size_5                                               0.557651
# division_1_size_3                                               0.526389
#
#                       $\frac{I_{1726}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.161440
# division_1_size_5                                              1.161705
# division_1_size_3                                              0.900904
#
#                       $\frac{I_{1726}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.356244
# division_1_size_5                                              0.340463
# division_1_size_3                                              0.272113
#
#                       $\frac{I_{1726}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                      8.876005
# ...
#
#                       $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                        0.050719
# division_1_size_5                                                           0.102494
# division_1_size_3                                                           0.119164
#
#                       $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                        0.056663
# division_1_size_5                                                           0.115578
# division_1_size_3                                                           0.129973
#
#                       $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                        0.115238
# division_1_size_5                                                           0.255171
# division_1_size_3                                                           0.310965
#
#                       $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                        0.115903
# division_1_size_5                                                           0.258718
# division_1_size_3                                                           0.303656
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                         1.402891
# division_1_size_5                                                            1.397705
# division_1_size_3                                                            2.032899
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                                         1.418914
# division_1_size_5                                                            1.407731
# division_1_size_3                                                            1.994910
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.850122
# division_1_size_5                                                            0.889158
# division_1_size_3                                                            1.202280
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                                         0.910939
# division_1_size_5                                                            0.958979
# division_1_size_3                                                            1.291862
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.664862
# division_1_size_5                                                            0.633516
# division_1_size_3                                                            0.852643
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.742776
# division_1_size_5                                                            0.714391
# division_1_size_3                                                            0.929981
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.510626
# division_1_size_5                                                            1.577219
# division_1_size_3                                                            2.225013
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.519342
# division_1_size_5                                                            1.599141
# division_1_size_3                                                            2.172715
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                         1.374317
# division_1_size_5                                                            1.324287
# division_1_size_3                                                            1.928350
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                                         1.390013
# division_1_size_5                                                            1.333786
# division_1_size_3                                                            1.892314
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.832807
# division_1_size_5                                                            0.842452
# division_1_size_3                                                            1.140448
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                                         0.892385
# division_1_size_5                                                            0.908606
# division_1_size_3                                                            1.225424
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.651320
# division_1_size_5                                                            0.600239
# division_1_size_3                                                            0.808793
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.727647
# division_1_size_5                                                            0.676865
# division_1_size_3                                                            0.882154
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.479858
# division_1_size_5                                                            1.494371
# division_1_size_3                                                            2.110584
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.488396
# division_1_size_5                                                            1.515142
# division_1_size_3                                                            2.060975
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.605978
# division_1_size_5                                                            0.636156
# division_1_size_3                                                            0.591411
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                                         0.649330
# division_1_size_5                                                            0.686109
# division_1_size_3                                                            0.635478
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.473923
# division_1_size_5                                                            0.453255
# division_1_size_3                                                            0.419422
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.529461
# division_1_size_5                                                            0.511117
# division_1_size_3                                                            0.457465
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.076795
# division_1_size_5                                                            1.128435
# division_1_size_3                                                            1.094502
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.083008
# division_1_size_5                                                            1.144119
# division_1_size_3                                                            1.068776
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.599136
# division_1_size_5                                                            0.631625
# division_1_size_3                                                            0.602674
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                                         0.641997
# division_1_size_5                                                            0.681223
# division_1_size_3                                                            0.647579
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.468571
# division_1_size_5                                                            0.450027
# division_1_size_3                                                            0.427409
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.523482
# division_1_size_5                                                            0.507477
# division_1_size_3                                                            0.466177
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.064635
# division_1_size_5                                                            1.120398
# division_1_size_3                                                            1.115345
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.070778
# division_1_size_5                                                            1.135971
# division_1_size_3                                                            1.089129
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.782078
# division_1_size_5                                                            0.712490
# division_1_size_3                                                            0.709188
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.873729
# division_1_size_5                                                            0.803446
# division_1_size_3                                                            0.773515
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.776952
# division_1_size_5                                                            1.773835
# division_1_size_3                                                            1.850661
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.787205
# division_1_size_5                                                            1.798490
# division_1_size_3                                                            1.807162
#
#                       $\frac{\overline{I}_{1394 \pm 50}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.729864
# division_1_size_5                                                            0.660616
# division_1_size_3                                                            0.660011
#
#                       $\frac{\overline{I}_{1394 \pm 50}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.815396
# division_1_size_5                                                            0.744949
# division_1_size_3                                                            0.719876
#
#                       $\frac{\overline{I}_{1394 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.658317
# division_1_size_5                                                            1.644686
# division_1_size_3                                                            1.722330
#
#                       $\frac{\overline{I}_{1394 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.667886
# division_1_size_5                                                            1.667546
# division_1_size_3                                                            1.681847
#
#                       $\frac{\overline{I}_{1615 \pm 25}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         2.272090
# division_1_size_5                                                            2.489626
# division_1_size_3                                                            2.609548
#
#                       $\frac{\overline{I}_{1615 \pm 25}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         2.285200
# division_1_size_5                                                            2.524230
# division_1_size_3                                                            2.548211
#
#                       $\frac{\overline{I}_{1615 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         2.033758
# division_1_size_5                                                            2.207783
# division_1_size_3                                                            2.392536
#
#                       $\frac{\overline{I}_{1615 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         2.045493
# division_1_size_5                                                            2.238470
# division_1_size_3                                                            2.336300
#
#                       Split Fraction_hue Fraction_grouped_hue  Class
# division_1_size_bulk  Train        $> 0$              $d > 5$      2
# division_1_size_5     Train        $< 5$       $2 < d \leq 5$      1
# division_1_size_3     Train        $< 3$       $2 < d \leq 5$      1

# %% [markdown]
# ## Features description

# %%
with open(path_to_features_description, 'r', encoding='utf-8') as f:
    features_description = json.load(f)

# %% [markdown]
# # Data wrangling

# %% [markdown]
# ## Data wrangling

# %%
dataset_train = dataset.loc[dataset['Split'] == 'Train']

X_train = dataset_train.loc[:, ~dataset_train.columns.isin(['Split', 'Fraction_hue', 'Fraction_grouped_hue', 'Class'])]
y_train = dataset_train['Class']

print(
    f'(*) X_train: {X_train.shape}',
    f'(*) y_train: {y_train.shape}',
    sep='\n'
)
X_train.head(3)
# Out:
# (*) X_train: (50, 320)
# (*) y_train: (50,)
#                       $I_{873}$  $I_{1105}$  $I_{1241}$  $I_{1394}$  \
# division_1_size_bulk   0.048208    0.681294    0.455066    0.760582
# division_1_size_5      0.091875    0.606138    0.427988    0.687458
# division_1_size_3      0.110321    0.836176    0.400950    0.696553
#
#                       $I_{1615}$  $I_{1726}$  \
# division_1_size_bulk         1.0    0.421995
# division_1_size_5            1.0    0.383362
# division_1_size_3            1.0    0.366658
#
#                       $\overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                          0.424162
# division_1_size_5                             0.378730
# division_1_size_3                             0.436266
#
#                       $\Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                          3.367146
# division_1_size_5                             3.196821
# division_1_size_3                             3.410658
#
#                       $\overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                           0.426619
# division_1_size_5                              0.378004
# division_1_size_3                              0.429362
#
#                       $\Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                           1.421995
# division_1_size_5                              1.383362
# division_1_size_3                              1.366658
#
#                       $\overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                           0.571735
# division_1_size_5                              0.502368
# division_1_size_3                              0.523513
#
#                       $\Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                           0.760582
# division_1_size_5                              0.687458
# division_1_size_3                              0.696553
#
#                       $\overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                          0.363338
# division_1_size_5                             0.329999
# division_1_size_3                             0.406988
#
#                       $\Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                          1.184569
# division_1_size_5                             1.126001
# division_1_size_3                             1.347446
#
#                       $\overline{I}_{873 \pm 25}$  \
# division_1_size_bulk                     0.047543
# division_1_size_5                        0.093349
# division_1_size_3                        0.113396
#
#                       $\overline{I}_{873 \pm 50}$  \
# division_1_size_bulk                     0.047916
# division_1_size_5                        0.096086
# division_1_size_3                        0.114054
#
#                       $\overline{I}_{1105 \pm 25}$  \
# division_1_size_bulk                      0.628121
# division_1_size_5                         0.593910
# division_1_size_3                         0.816077
#
#                       $\overline{I}_{1105 \pm 50}$  \
# division_1_size_bulk                      0.615327
# division_1_size_5                         0.562713
# division_1_size_3                         0.774107
#
#                       $\overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                      0.447733
# division_1_size_5                         0.424918
# division_1_size_3                         0.401435
#
#                       $\overline{I}_{1241 \pm 50}$  \
# division_1_size_bulk                      0.442677
# division_1_size_5                         0.421892
# division_1_size_3                         0.409080
#
#                       $\overline{I}_{1394 \pm 25}$  \
# division_1_size_bulk                      0.738860
# division_1_size_5                         0.667947
# division_1_size_3                         0.678774
#
#                       $\overline{I}_{1394 \pm 50}$  \
# division_1_size_bulk                      0.689531
# division_1_size_5                         0.619315
# division_1_size_3                         0.631706
#
#                       $\overline{I}_{1615 \pm 25}$  \
# division_1_size_bulk                      0.944739
# division_1_size_5                         0.937481
# division_1_size_3                         0.957114
#
#                       $\overline{I}_{1615 \pm 50}$  \
# division_1_size_bulk                      0.845640
# division_1_size_5                         0.831352
# division_1_size_3                         0.877520
#
#                       $\overline{I}_{1726 \pm 25}$  \
# division_1_size_bulk                      0.415802
# division_1_size_5                         0.376555
# division_1_size_3                         0.366774
#
#                       $\overline{I}_{1726 \pm 50}$  $\log I_{873}$  \
# division_1_size_bulk                      0.413416       -3.032222
# division_1_size_5                         0.371393       -2.387325
# division_1_size_3                         0.375602       -2.204364
#
#                       $(I_{873})^{-1}$  $\log I_{1105}$  $(I_{1105})^{-1}$  \
# division_1_size_bulk         20.743271        -0.383761           1.467794
# division_1_size_5            10.884335        -0.500648           1.649790
# division_1_size_3             9.064483        -0.178917           1.195921
#
#                       $\log I_{1241}$  $(I_{1241})^{-1}$  $\log I_{1394}$  \
# division_1_size_bulk        -0.787312           2.197482        -0.273672
# division_1_size_5           -0.848660           2.336514        -0.374754
# division_1_size_3           -0.913918           2.494076        -0.361611
#
#                       $(I_{1394})^{-1}$  $\log I_{1615}$  $(I_{1615})^{-1}$  \
# division_1_size_bulk           1.314783              0.0                1.0
# division_1_size_5              1.454634              0.0                1.0
# division_1_size_3              1.435640              0.0                1.0
#
#                       $\log I_{1726}$  $(I_{1726})^{-1}$  \
# division_1_size_bulk        -0.862761           2.369695
# division_1_size_5           -0.958776           2.608502
# division_1_size_3           -1.003327           2.727339
#
#                       $\log \overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                              -0.857641
# division_1_size_5                                 -0.970931
# division_1_size_3                                 -0.829504
#
#                       $(\overline{I}_{1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.357591
# division_1_size_5                                    2.640400
# division_1_size_3                                    2.292181
#
#                       $\log \Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                               1.214065
# division_1_size_5                                  1.162157
# division_1_size_3                                  1.226905
#
#                       $(\Sigma I_{p,\ 1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.296987
# division_1_size_5                                    0.312811
# division_1_size_3                                    0.293199
#
#                       $\log \overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                               -0.851863
# division_1_size_5                                  -0.972851
# division_1_size_3                                  -0.845455
#
#                       $(\overline{I}_{1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  2.344010
# division_1_size_5                                     2.645477
# division_1_size_3                                     2.329038
#
#                       $\log \Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                                0.352061
# division_1_size_5                                   0.324517
# division_1_size_3                                   0.312368
#
#                       $(\Sigma I_{p,\ 1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  0.703237
# division_1_size_5                                     0.722877
# division_1_size_3                                     0.731712
#
#                       $\log \overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                               -0.559080
# division_1_size_5                                  -0.688422
# division_1_size_3                                  -0.647194
#
#                       $(\overline{I}_{1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.749062
# division_1_size_5                                     1.990572
# division_1_size_3                                     1.910173
#
#                       $\log \Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                               -0.273672
# division_1_size_5                                  -0.374754
# division_1_size_3                                  -0.361611
#
#                       $(\Sigma I_{p,\ 1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.314783
# division_1_size_5                                     1.454634
# division_1_size_3                                     1.435640
#
#                       $\log \overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                              -1.012422
# division_1_size_5                                 -1.108665
# division_1_size_3                                 -0.898970
#
#                       $(\overline{I}_{1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.752259
# division_1_size_5                                    3.030309
# division_1_size_3                                    2.457072
#
#                       $\log \Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                               0.169379
# division_1_size_5                                  0.118672
# division_1_size_3                                  0.298211
#
#                       $(\Sigma I_{p,\ 1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.844189
# division_1_size_5                                    0.888099
# division_1_size_3                                    0.742145
#
#                       $\log \overline{I}_{873 \pm 25}$  \
# division_1_size_bulk                         -3.046113
# division_1_size_5                            -2.371406
# division_1_size_3                            -2.176872
#
#                       $(\overline{I}_{873 \pm 25})^{-1}$  \
# division_1_size_bulk                           21.033424
# division_1_size_5                              10.712443
# division_1_size_3                               8.818675
#
#                       $\log \overline{I}_{873 \pm 50}$  \
# division_1_size_bulk                         -3.038304
# division_1_size_5                            -2.342512
# division_1_size_3                            -2.171085
#
#                       $(\overline{I}_{873 \pm 50})^{-1}$  \
# division_1_size_bulk                           20.869820
# division_1_size_5                              10.407351
# division_1_size_3                               8.767790
#
#                       $\log \overline{I}_{1105 \pm 25}$  \
# division_1_size_bulk                          -0.465023
# division_1_size_5                             -0.521028
# division_1_size_3                             -0.203247
#
#                       $(\overline{I}_{1105 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.592050
# division_1_size_5                                1.683757
# division_1_size_3                                1.225375
#
#                       $\log \overline{I}_{1105 \pm 50}$  \
# division_1_size_bulk                          -0.485601
# division_1_size_5                             -0.574985
# division_1_size_3                             -0.256045
#
#                       $(\overline{I}_{1105 \pm 50})^{-1}$  \
# division_1_size_bulk                             1.625151
# division_1_size_5                                1.777105
# division_1_size_3                                1.291811
#
#                       $\log \overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                          -0.803558
# division_1_size_5                             -0.855859
# division_1_size_3                             -0.912710
#
#                       $(\overline{I}_{1241 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.233473
# division_1_size_5                                2.353396
# division_1_size_3                                2.491063
#
#                       $\log \overline{I}_{1241 \pm 50}$  \
# division_1_size_bulk                          -0.814914
# division_1_size_5                             -0.863007
# division_1_size_3                             -0.893845
#
#                       $(\overline{I}_{1241 \pm 50})^{-1}$  \
# division_1_size_bulk                             2.258982
# division_1_size_5                                2.370277
# division_1_size_3                                2.444512
#
#                       $\log \overline{I}_{1394 \pm 25}$  \
# division_1_size_bulk                          -0.302647
# division_1_size_5                             -0.403547
# division_1_size_3                             -0.387466
#
#                       $(\overline{I}_{1394 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.353436
# division_1_size_5                                1.497126
# division_1_size_3                                1.473243
#
#                       $\log \overline{I}_{1394 \pm 50}$  \
# division_1_size_bulk                          -0.371743
# division_1_size_5                             -0.479141
# division_1_size_3                             -0.459332
#
#                       $(\overline{I}_{1394 \pm 50})^{-1}$  \
# division_1_size_bulk                             1.450261
# division_1_size_5                                1.614687
# division_1_size_3                                1.583015
#
#                       $\log \overline{I}_{1615 \pm 25}$  \
# division_1_size_bulk                          -0.056847
# division_1_size_5                             -0.064558
# division_1_size_3                             -0.043832
#
#                       $(\overline{I}_{1615 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.058493
# division_1_size_5                                1.066688
# division_1_size_3                                1.044807
#
#                       $\log \overline{I}_{1615 \pm 50}$  \
# division_1_size_bulk                          -0.167661
# division_1_size_5                             -0.184702
# division_1_size_3                             -0.130656
#
#                       $(\overline{I}_{1615 \pm 50})^{-1}$  \
# division_1_size_bulk                             1.182536
# division_1_size_5                                1.202860
# division_1_size_3                                1.139575
#
#                       $\log \overline{I}_{1726 \pm 25}$  \
# division_1_size_bulk                          -0.877547
# division_1_size_5                             -0.976691
# division_1_size_3                             -1.003010
#
#                       $(\overline{I}_{1726 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.404992
# division_1_size_5                                2.655654
# division_1_size_3                                2.726475
#
#                       $\log \overline{I}_{1726 \pm 50}$  \
# division_1_size_bulk                          -0.883300
# division_1_size_5                             -0.990494
# division_1_size_3                             -0.979224
#
#                       $(\overline{I}_{1726 \pm 50})^{-1}$  \
# division_1_size_bulk                             2.418869
# division_1_size_5                                2.692566
# division_1_size_3                                2.662390
#
#                       $\frac{I_{873}}{I_{1105}}$  $\frac{I_{873}}{I_{1241}}$  \
# division_1_size_bulk                    0.070760                    0.105937
# division_1_size_5                       0.151575                    0.214668
# division_1_size_3                       0.131935                    0.275148
#
#                       $\frac{I_{873}}{I_{1394}}$  $\frac{I_{873}}{I_{1615}}$  \
# division_1_size_bulk                    0.063384                    0.048208
# division_1_size_5                       0.133645                    0.091875
# division_1_size_3                       0.158381                    0.110321
#
#                       $\frac{I_{873}}{I_{1726}}$  \
# division_1_size_bulk                    0.114239
# division_1_size_5                       0.239657
# division_1_size_3                       0.300882
#
#                       $\frac{I_{873}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                          0.113656
# division_1_size_5                                             0.242587
# division_1_size_3                                             0.252875
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                          0.014317
# division_1_size_5                                             0.028740
# division_1_size_3                                             0.032346
#
#                       $\frac{I_{873}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.113001
# division_1_size_5                                              0.243054
# division_1_size_3                                              0.256941
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.033902
# division_1_size_5                                              0.066414
# division_1_size_3                                              0.080723
#
#                       $\frac{I_{873}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.084320
# division_1_size_5                                              0.182884
# division_1_size_3                                              0.210732
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.063384
# division_1_size_5                                              0.133645
# division_1_size_3                                              0.158381
#
#                       $\frac{I_{873}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                          0.132682
# division_1_size_5                                             0.278410
# division_1_size_3                                             0.271066
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                          0.040697
# division_1_size_5                                             0.081594
# division_1_size_3                                             0.081874
#
#                       $\frac{I_{873}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_bulk                                      0.076750
# division_1_size_5                                         0.154695
# division_1_size_3                                         0.135184
#
#                       $\frac{I_{873}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_bulk                                      0.078346
# division_1_size_5                                         0.163272
# division_1_size_3                                         0.142513
#
#                       $\frac{I_{873}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                      0.107672
# division_1_size_5                                         0.216219
# division_1_size_3                                         0.274816
#
#                       $\frac{I_{873}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                      0.108902
# division_1_size_5                                         0.217770
# division_1_size_3                                         0.269680
#
#                       $\frac{I_{873}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                      0.065247
# division_1_size_5                                         0.137549
# division_1_size_3                                         0.162529
#
#                       $\frac{I_{873}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                      0.069915
# division_1_size_5                                         0.148350
# division_1_size_3                                         0.174639
#
#                       $\frac{I_{873}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                      0.051028
# division_1_size_5                                         0.098002
# division_1_size_3                                         0.115264
#
#                       $\frac{I_{873}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                      0.057008
# division_1_size_5                                         0.110513
# division_1_size_3                                         0.125719
#
#                       $\frac{I_{873}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                      0.115941
# division_1_size_5                                         0.243989
# division_1_size_3                                         0.300787
#
#                       $\frac{I_{873}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                      0.116610
# division_1_size_5                                         0.247380
# division_1_size_3                                         0.293717
#
#                       $\frac{I_{1105}}{I_{1241}}$  \
# division_1_size_bulk                     1.497132
# division_1_size_5                        1.416250
# division_1_size_3                        2.085485
#
#                       $\frac{I_{1105}}{I_{1394}}$  \
# division_1_size_bulk                     0.895754
# division_1_size_5                        0.881708
# division_1_size_3                        1.200447
#
#                       $\frac{I_{1105}}{I_{1615}}$  \
# division_1_size_bulk                     0.681294
# division_1_size_5                        0.606138
# division_1_size_3                        0.836176
#
#                       $\frac{I_{1105}}{I_{1726}}$  \
# division_1_size_bulk                     1.614460
# division_1_size_5                        1.581111
# division_1_size_3                        2.280535
#
#                       $\frac{I_{1105}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.606214
# division_1_size_5                                              1.600446
# division_1_size_3                                              1.916666
#
#                       $\frac{I_{1105}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.202336
# division_1_size_5                                              0.189606
# division_1_size_3                                              0.245166
#
#                       $\frac{I_{1105}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.596961
# division_1_size_5                                               1.603523
# division_1_size_3                                               1.947485
#
#                       $\frac{I_{1105}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.479111
# division_1_size_5                                               0.438163
# division_1_size_3                                               0.611840
#
#                       $\frac{I_{1105}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.191626
# division_1_size_5                                               1.206561
# division_1_size_3                                               1.597240
#
#                       $\frac{I_{1105}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.895754
# division_1_size_5                                               0.881708
# division_1_size_3                                               1.200447
#
#                       $\frac{I_{1105}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.875098
# division_1_size_5                                              1.836785
# division_1_size_3                                              2.054544
#
#                       $\frac{I_{1105}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.575141
# division_1_size_5                                              0.538310
# division_1_size_3                                              0.620563
#
#                       $\frac{I_{1105}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     14.329951
# division_1_size_5                                         6.493216
# division_1_size_3                                         7.373961
#
#                       $\frac{I_{1105}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_bulk                                     14.218489
# division_1_size_5                                         6.308289
# division_1_size_3                                         7.331412
#
#                       $\frac{I_{1105}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.521652
# division_1_size_5                                          1.426482
# division_1_size_3                                          2.082966
#
#                       $\frac{I_{1105}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                       1.539031
# division_1_size_5                                          1.436714
# division_1_size_3                                          2.044041
#
#                       $\frac{I_{1105}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.922089
# division_1_size_5                                          0.907465
# division_1_size_3                                          1.231890
#
#                       $\frac{I_{1105}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                       0.988054
# division_1_size_5                                          0.978723
# division_1_size_3                                          1.323679
#
#                       $\frac{I_{1105}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                       0.721146
# division_1_size_5                                          0.646560
# division_1_size_3                                          0.873642
#
#                       $\frac{I_{1105}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                       0.805655
# division_1_size_5                                          0.729099
# division_1_size_3                                          0.952885
#
#                       $\frac{I_{1105}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                       1.638507
# division_1_size_5                                          1.609692
# division_1_size_3                                          2.279812
#
#                       $\frac{I_{1105}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                       1.647962
# division_1_size_5                                          1.632066
# division_1_size_3                                          2.226225
#
#                       $\frac{I_{1241}}{I_{1394}}$  \
# division_1_size_bulk                     0.598314
# division_1_size_5                        0.622566
# division_1_size_3                        0.575620
#
#                       $\frac{I_{1241}}{I_{1615}}$  \
# division_1_size_bulk                     0.455066
# division_1_size_5                        0.427988
# division_1_size_3                        0.400950
#
#                       $\frac{I_{1241}}{I_{1726}}$  \
# division_1_size_bulk                     1.078368
# division_1_size_5                        1.116407
# division_1_size_3                        1.093527
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.072861
# division_1_size_5                                              1.130060
# division_1_size_3                                              0.919050
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.135149
# division_1_size_5                                              0.133879
# division_1_size_3                                              0.117558
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.066680
# division_1_size_5                                               1.132232
# division_1_size_3                                               0.933828
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.320020
# division_1_size_5                                               0.309383
# division_1_size_3                                               0.293380
#
#                       $\frac{I_{1241}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.795939
# division_1_size_5                                               0.851941
# division_1_size_3                                               0.765884
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.598314
# division_1_size_5                                               0.622566
# division_1_size_3                                               0.575620
#
#                       $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.252460
# division_1_size_5                                              1.296936
# division_1_size_3                                              0.985163
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.384162
# division_1_size_5                                              0.380096
# division_1_size_3                                              0.297563
#
#                       $\frac{I_{1241}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                      9.571604
# division_1_size_5                                         4.584797
# division_1_size_3                                         3.535849
#
#                       $\frac{I_{1241}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_bulk                                      9.497153
# division_1_size_5                                         4.454221
# division_1_size_3                                         3.515446
#
#                       $\frac{I_{1241}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_bulk                                       0.724488
# division_1_size_5                                          0.720628
# division_1_size_3                                          0.491314
#
#                       $\frac{I_{1241}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_bulk                                       0.739552
# division_1_size_5                                          0.760579
# division_1_size_3                                          0.517952
#
#                       $\frac{I_{1241}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.615903
# division_1_size_5                                          0.640752
# division_1_size_3                                          0.590697
#
#                       $\frac{I_{1241}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                       0.659965
# division_1_size_5                                          0.691067
# division_1_size_3                                          0.634710
#
#                       $\frac{I_{1241}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                       0.481685
# division_1_size_5                                          0.456530
# division_1_size_3                                          0.418916
#
#                       $\frac{I_{1241}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                       0.538132
# division_1_size_5                                          0.514810
# division_1_size_3                                          0.456913
#
#                       $\frac{I_{1241}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                       1.094431
# division_1_size_5                                          1.136588
# division_1_size_3                                          1.093180
#
#                       $\frac{I_{1241}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                       1.100746
# division_1_size_5                                          1.152386
# division_1_size_3                                          1.067486
#
#                       $\frac{I_{1394}}{I_{1615}}$  \
# division_1_size_bulk                     0.760582
# division_1_size_5                        0.687458
# division_1_size_3                        0.696553
#
#                       $\frac{I_{1394}}{I_{1726}}$  \
# division_1_size_bulk                     1.802346
# division_1_size_5                        1.793236
# division_1_size_3                        1.899738
#
#                       $\frac{I_{1394}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.793141
# division_1_size_5                                              1.815165
# division_1_size_3                                              1.596626
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.225883
# division_1_size_5                                              0.215044
# division_1_size_3                                              0.204228
#
#                       $\frac{I_{1394}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.782811
# division_1_size_5                                               1.818655
# division_1_size_3                                               1.622300
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.534869
# division_1_size_5                                               0.496948
# division_1_size_3                                               0.509677
#
#                       $\frac{I_{1394}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.330305
# division_1_size_5                                               1.368435
# division_1_size_3                                               1.330538
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                 1.0
# division_1_size_5                                                    1.0
# division_1_size_3                                                    1.0
#
#                       $\frac{I_{1394}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.093317
# division_1_size_5                                              2.083211
# division_1_size_3                                              1.711482
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.642074
# division_1_size_5                                              0.610531
# division_1_size_3                                              0.516943
#
#                       $\frac{I_{1394}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     15.997634
# division_1_size_5                                         7.364358
# division_1_size_3                                         6.142679
#
#                       $\frac{I_{1394}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_bulk                                     15.873200
# division_1_size_5                                         7.154620
# division_1_size_3                                         6.107234
#
#                       $\frac{I_{1394}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_bulk                                       1.210884
# division_1_size_5                                          1.157513
# division_1_size_3                                          0.853539
#
#                       $\frac{I_{1394}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_bulk                                       1.236060
# division_1_size_5                                          1.221685
# division_1_size_3                                          0.899815
#
#                       $\frac{I_{1394}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.698738
# division_1_size_5                                          1.617862
# division_1_size_3                                          1.735159
#
#                       $\frac{I_{1394}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                       1.718140
# division_1_size_5                                          1.629467
# division_1_size_3                                          1.702733
#
#                       $\frac{I_{1394}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                       0.805071
# division_1_size_5                                          0.733303
# division_1_size_3                                          0.727764
#
#                       $\frac{I_{1394}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                       0.899415
# division_1_size_5                                          0.826916
# division_1_size_3                                          0.793775
#
#                       $\frac{I_{1394}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                       1.829193
# division_1_size_5                                          1.825651
# division_1_size_3                                          1.899135
#
#                       $\frac{I_{1394}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                       1.839747
# division_1_size_5                                          1.851027
# division_1_size_3                                          1.854497
#
#                       $\frac{I_{1615}}{I_{1726}}$  \
# division_1_size_bulk                     2.369695
# division_1_size_5                        2.608502
# division_1_size_3                        2.727339
#
#                       $\frac{I_{1615}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           2.357591
# division_1_size_5                                              2.640400
# division_1_size_3                                              2.292181
#
#                       $\frac{I_{1615}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.296987
# division_1_size_5                                              0.312811
# division_1_size_3                                              0.293199
#
#                       $\frac{I_{1615}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            2.344010
# division_1_size_5                                               2.645477
# division_1_size_3                                               2.329038
#
#                       $\frac{I_{1615}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.703237
# division_1_size_5                                               0.722877
# division_1_size_3                                               0.731712
#
#                       $\frac{I_{1615}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.749062
# division_1_size_5                                               1.990572
# division_1_size_3                                               1.910173
#
#                       $\frac{I_{1615}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.314783
# division_1_size_5                                               1.454634
# division_1_size_3                                               1.435640
#
#                       $\frac{I_{1615}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.752259
# division_1_size_5                                              3.030309
# division_1_size_3                                              2.457072
#
#                       $\frac{I_{1615}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.844189
# division_1_size_5                                              0.888099
# division_1_size_3                                              0.742145
#
#                       $\frac{I_{1615}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     21.033424
# division_1_size_5                                        10.712443
# division_1_size_3                                         8.818675
#
#                       $\frac{I_{1615}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_bulk                                     20.869820
# division_1_size_5                                        10.407351
# division_1_size_3                                         8.767790
#
#                       $\frac{I_{1615}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_bulk                                       1.592050
# division_1_size_5                                          1.683757
# division_1_size_3                                          1.225375
#
#                       $\frac{I_{1615}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_bulk                                       1.625151
# division_1_size_5                                          1.777105
# division_1_size_3                                          1.291811
#
#                       $\frac{I_{1615}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       2.233473
# division_1_size_5                                          2.353396
# division_1_size_3                                          2.491063
#
#                       $\frac{I_{1615}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                       2.258982
# division_1_size_5                                          2.370277
# division_1_size_3                                          2.444512
#
#                       $\frac{I_{1615}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       1.353436
# division_1_size_5                                          1.497126
# division_1_size_3                                          1.473243
#
#                       $\frac{I_{1615}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                       1.450261
# division_1_size_5                                          1.614687
# division_1_size_3                                          1.583015
#
#                       $\frac{I_{1615}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                       2.404992
# division_1_size_5                                          2.655654
# division_1_size_3                                          2.726475
#
#                       $\frac{I_{1615}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                       2.418869
# division_1_size_5                                          2.692566
# division_1_size_3                                          2.662390
#
#                       $\frac{I_{1726}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           0.994892
# division_1_size_5                                              1.012229
# division_1_size_3                                              0.840446
#
#                       $\frac{I_{1726}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.125327
# division_1_size_5                                              0.119920
# division_1_size_3                                              0.107504
#
#                       $\frac{I_{1726}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.989161
# division_1_size_5                                               1.014175
# division_1_size_3                                               0.853960
#
#                       $\frac{I_{1726}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.296763
# division_1_size_5                                               0.277123
# division_1_size_3                                               0.268288
#
#                       $\frac{I_{1726}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.738096
# division_1_size_5                                               0.763109
# division_1_size_3                                               0.700380
#
#                       $\frac{I_{1726}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.554832
# division_1_size_5                                               0.557651
# division_1_size_3                                               0.526389
#
#                       $\frac{I_{1726}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.161440
# division_1_size_5                                              1.161705
# division_1_size_3                                              0.900904
#
#                       $\frac{I_{1726}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.356244
# division_1_size_5                                              0.340463
# division_1_size_3                                              0.272113
#
#                       $\frac{I_{1726}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                      8.876005
# ...
# division_1_size_bulk                                                        0.069491
# division_1_size_5                                                           0.155149
# division_1_size_3                                                           0.180549
#
#                       $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                        0.050719
# division_1_size_5                                                           0.102494
# division_1_size_3                                                           0.119164
#
#                       $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                        0.056663
# division_1_size_5                                                           0.115578
# division_1_size_3                                                           0.129973
#
#                       $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                        0.115238
# division_1_size_5                                                           0.255171
# division_1_size_3                                                           0.310965
#
#                       $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                        0.115903
# division_1_size_5                                                           0.258718
# division_1_size_3                                                           0.303656
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                         1.402891
# division_1_size_5                                                            1.397705
# division_1_size_3                                                            2.032899
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                                         1.418914
# division_1_size_5                                                            1.407731
# division_1_size_3                                                            1.994910
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.850122
# division_1_size_5                                                            0.889158
# division_1_size_3                                                            1.202280
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                                         0.910939
# division_1_size_5                                                            0.958979
# division_1_size_3                                                            1.291862
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.664862
# division_1_size_5                                                            0.633516
# division_1_size_3                                                            0.852643
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.742776
# division_1_size_5                                                            0.714391
# division_1_size_3                                                            0.929981
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.510626
# division_1_size_5                                                            1.577219
# division_1_size_3                                                            2.225013
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.519342
# division_1_size_5                                                            1.599141
# division_1_size_3                                                            2.172715
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                         1.374317
# division_1_size_5                                                            1.324287
# division_1_size_3                                                            1.928350
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                                         1.390013
# division_1_size_5                                                            1.333786
# division_1_size_3                                                            1.892314
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.832807
# division_1_size_5                                                            0.842452
# division_1_size_3                                                            1.140448
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                                         0.892385
# division_1_size_5                                                            0.908606
# division_1_size_3                                                            1.225424
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.651320
# division_1_size_5                                                            0.600239
# division_1_size_3                                                            0.808793
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.727647
# division_1_size_5                                                            0.676865
# division_1_size_3                                                            0.882154
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.479858
# division_1_size_5                                                            1.494371
# division_1_size_3                                                            2.110584
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.488396
# division_1_size_5                                                            1.515142
# division_1_size_3                                                            2.060975
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.605978
# division_1_size_5                                                            0.636156
# division_1_size_3                                                            0.591411
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                                         0.649330
# division_1_size_5                                                            0.686109
# division_1_size_3                                                            0.635478
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.473923
# division_1_size_5                                                            0.453255
# division_1_size_3                                                            0.419422
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.529461
# division_1_size_5                                                            0.511117
# division_1_size_3                                                            0.457465
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.076795
# division_1_size_5                                                            1.128435
# division_1_size_3                                                            1.094502
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.083008
# division_1_size_5                                                            1.144119
# division_1_size_3                                                            1.068776
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.599136
# division_1_size_5                                                            0.631625
# division_1_size_3                                                            0.602674
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                                         0.641997
# division_1_size_5                                                            0.681223
# division_1_size_3                                                            0.647579
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.468571
# division_1_size_5                                                            0.450027
# division_1_size_3                                                            0.427409
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.523482
# division_1_size_5                                                            0.507477
# division_1_size_3                                                            0.466177
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.064635
# division_1_size_5                                                            1.120398
# division_1_size_3                                                            1.115345
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.070778
# division_1_size_5                                                            1.135971
# division_1_size_3                                                            1.089129
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.782078
# division_1_size_5                                                            0.712490
# division_1_size_3                                                            0.709188
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.873729
# division_1_size_5                                                            0.803446
# division_1_size_3                                                            0.773515
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.776952
# division_1_size_5                                                            1.773835
# division_1_size_3                                                            1.850661
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.787205
# division_1_size_5                                                            1.798490
# division_1_size_3                                                            1.807162
#
#                       $\frac{\overline{I}_{1394 \pm 50}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.729864
# division_1_size_5                                                            0.660616
# division_1_size_3                                                            0.660011
#
#                       $\frac{\overline{I}_{1394 \pm 50}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.815396
# division_1_size_5                                                            0.744949
# division_1_size_3                                                            0.719876
#
#                       $\frac{\overline{I}_{1394 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.658317
# division_1_size_5                                                            1.644686
# division_1_size_3                                                            1.722330
#
#                       $\frac{\overline{I}_{1394 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.667886
# division_1_size_5                                                            1.667546
# division_1_size_3                                                            1.681847
#
#                       $\frac{\overline{I}_{1615 \pm 25}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         2.272090
# division_1_size_5                                                            2.489626
# division_1_size_3                                                            2.609548
#
#                       $\frac{\overline{I}_{1615 \pm 25}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         2.285200
# division_1_size_5                                                            2.524230
# division_1_size_3                                                            2.548211
#
#                       $\frac{\overline{I}_{1615 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         2.033758
# division_1_size_5                                                            2.207783
# division_1_size_3                                                            2.392536
#
#                       $\frac{\overline{I}_{1615 \pm 50}}{\overline{I}_{1726 \pm 50}}$
# division_1_size_bulk                                                         2.045493
# division_1_size_5                                                            2.238470
# division_1_size_3                                                            2.336300

# %%
dataset_test = dataset.loc[dataset['Split'] == 'Test']

X_test = dataset_test.loc[:, ~dataset_test.columns.isin(['Split', 'Fraction_hue', 'Fraction_grouped_hue', 'Class'])]
y_test = dataset_test['Class']

hue_train = dataset_test['Fraction_grouped_hue'].tolist()

print(
    f'(*) X_train: {X_test.shape}',
    f'(*) y_train: {y_test.shape}',
    sep='\n'
)
X_test.head(3)
# Out:
# (*) X_train: (25, 320)
# (*) y_train: (25,)
#                      $I_{873}$  $I_{1105}$  $I_{1241}$  $I_{1394}$  \
# division_1_size_0.4   0.022650    0.538501    0.345015    0.651226
# division_1_size_0.2   0.033274    0.677844    0.361602    1.000000
# division_2_size_5     0.283754    0.913079    0.738885    0.892119
#
#                      $I_{1615}$  $I_{1726}$  $\overline{I}_{1900\text{–}800}$  \
# division_1_size_0.4    0.789417    0.380312                          0.403457
# division_1_size_0.2    0.971316    0.394997                          0.461139
# division_2_size_5      0.959395    0.436810                          0.549735
#
#                      $\Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_0.4                          2.727121
# division_1_size_0.2                          3.439033
# division_2_size_5                            4.224041
#
#                      $\overline{I}_{1900\text{–}1500}$  \
# division_1_size_0.4                           0.465038
# division_1_size_0.2                           0.478522
# division_2_size_5                             0.404757
#
#                      $\Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_0.4                           1.169729
# division_1_size_0.2                           1.366313
# division_2_size_5                             1.396205
#
#                      $\overline{I}_{1500\text{–}1300}$  \
# division_1_size_0.4                           0.523335
# division_1_size_0.2                           0.743613
# division_2_size_5                             0.705363
#
#                      $\Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_0.4                           0.651226
# division_1_size_0.2                           1.000000
# division_2_size_5                             0.892119
#
#                      $\overline{I}_{1300\text{–}800}$  \
# division_1_size_0.4                          0.306403
# division_1_size_0.2                          0.334577
# division_2_size_5                            0.603590
#
#                      $\Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_0.4                          0.906166
# division_1_size_0.2                          1.072720
# division_2_size_5                            1.935718
#
#                      $\overline{I}_{873 \pm 25}$  $\overline{I}_{873 \pm 50}$  \
# division_1_size_0.4                     0.027172                     0.033917
# division_1_size_0.2                     0.039136                     0.049319
# division_2_size_5                       0.287046                     0.291212
#
#                      $\overline{I}_{1105 \pm 25}$  \
# division_1_size_0.4                      0.537466
# division_1_size_0.2                      0.652666
# division_2_size_5                        0.911689
#
#                      $\overline{I}_{1105 \pm 50}$  \
# division_1_size_0.4                      0.533865
# division_1_size_0.2                      0.622679
# division_2_size_5                        0.891331
#
#                      $\overline{I}_{1241 \pm 25}$  \
# division_1_size_0.4                      0.352113
# division_1_size_0.2                      0.358081
# division_2_size_5                        0.731277
#
#                      $\overline{I}_{1241 \pm 50}$  \
# division_1_size_0.4                      0.359403
# division_1_size_0.2                      0.363699
# division_2_size_5                        0.718126
#
#                      $\overline{I}_{1394 \pm 25}$  \
# division_1_size_0.4                      0.636313
# division_1_size_0.2                      0.973721
# division_2_size_5                        0.868429
#
#                      $\overline{I}_{1394 \pm 50}$  \
# division_1_size_0.4                      0.598092
# division_1_size_0.2                      0.915361
# division_2_size_5                        0.825167
#
#                      $\overline{I}_{1615 \pm 25}$  \
# division_1_size_0.4                      0.792581
# division_1_size_0.2                      0.953350
# division_2_size_5                        0.922138
#
#                      $\overline{I}_{1615 \pm 50}$  \
# division_1_size_0.4                      0.803438
# division_1_size_0.2                      0.912715
# division_2_size_5                        0.835190
#
#                      $\overline{I}_{1726 \pm 25}$  \
# division_1_size_0.4                      0.392568
# division_1_size_0.2                      0.405552
# division_2_size_5                        0.423749
#
#                      $\overline{I}_{1726 \pm 50}$  $\log I_{873}$  \
# division_1_size_0.4                      0.422537       -3.787599
# division_1_size_0.2                      0.421421       -3.402980
# division_2_size_5                        0.397792       -1.259648
#
#                      $(I_{873})^{-1}$  $\log I_{1105}$  $(I_{1105})^{-1}$  \
# division_1_size_0.4         44.150249        -0.618965           1.857006
# division_1_size_0.2         30.053513        -0.388838           1.475266
# division_2_size_5            3.524182        -0.090933           1.095196
#
#                      $\log I_{1241}$  $(I_{1241})^{-1}$  $\log I_{1394}$  \
# division_1_size_0.4        -1.064168           2.898425        -0.428898
# division_1_size_0.2        -1.017211           2.765471         0.000000
# division_2_size_5          -0.302613           1.353390        -0.114156
#
#                      $(I_{1394})^{-1}$  $\log I_{1615}$  $(I_{1615})^{-1}$  \
# division_1_size_0.4           1.535565        -0.236461           1.266758
# division_1_size_0.2           1.000000        -0.029103           1.029531
# division_2_size_5             1.120927        -0.041452           1.042324
#
#                      $\log I_{1726}$  $(I_{1726})^{-1}$  \
# division_1_size_0.4        -0.966764           2.629422
# division_1_size_0.2        -0.928876           2.531663
# division_2_size_5          -0.828257           2.289326
#
#                      $\log \overline{I}_{1900\text{–}800}$  \
# division_1_size_0.4                              -0.907685
# division_1_size_0.2                              -0.774056
# division_2_size_5                                -0.598319
#
#                      $(\overline{I}_{1900\text{–}800})^{-1}$  \
# division_1_size_0.4                                 2.478579
# division_1_size_0.2                                 2.168543
# division_2_size_5                                   1.819058
#
#                      $\log \Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_0.4                               1.003246
# division_1_size_0.2                               1.235190
# division_2_size_5                                 1.440792
#
#                      $(\Sigma I_{p,\ 1900\text{–}800})^{-1}$  \
# division_1_size_0.4                                 0.366687
# division_1_size_0.2                                 0.290779
# division_2_size_5                                   0.236740
#
#                      $\log \overline{I}_{1900\text{–}1500}$  \
# division_1_size_0.4                               -0.765635
# division_1_size_0.2                               -0.737054
# division_2_size_5                                 -0.904468
#
#                      $(\overline{I}_{1900\text{–}1500})^{-1}$  \
# division_1_size_0.4                                  2.150360
# division_1_size_0.2                                  2.089770
# division_2_size_5                                    2.470617
#
#                      $\log \Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_0.4                                0.156772
# division_1_size_0.2                                0.312116
# division_2_size_5                                  0.333758
#
#                      $(\Sigma I_{p,\ 1900\text{–}1500})^{-1}$  \
# division_1_size_0.4                                  0.854899
# division_1_size_0.2                                  0.731897
# division_2_size_5                                    0.716227
#
#                      $\log \overline{I}_{1500\text{–}1300}$  \
# division_1_size_0.4                               -0.647534
# division_1_size_0.2                               -0.296234
# division_2_size_5                                 -0.349042
#
#                      $(\overline{I}_{1500\text{–}1300})^{-1}$  \
# division_1_size_0.4                                  1.910823
# division_1_size_0.2                                  1.344785
# division_2_size_5                                    1.417709
#
#                      $\log \Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_0.4                               -0.428898
# division_1_size_0.2                                0.000000
# division_2_size_5                                 -0.114156
#
#                      $(\Sigma I_{p,\ 1500\text{–}1300})^{-1}$  \
# division_1_size_0.4                                  1.535565
# division_1_size_0.2                                  1.000000
# division_2_size_5                                    1.120927
#
#                      $\log \overline{I}_{1300\text{–}800}$  \
# division_1_size_0.4                              -1.182854
# division_1_size_0.2                              -1.094889
# division_2_size_5                                -0.504860
#
#                      $(\overline{I}_{1300\text{–}800})^{-1}$  \
# division_1_size_0.4                                 3.263674
# division_1_size_0.2                                 2.988851
# division_2_size_5                                   1.656753
#
#                      $\log \Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_0.4                              -0.098533
# division_1_size_0.2                               0.070198
# division_2_size_5                                 0.660478
#
#                      $(\Sigma I_{p,\ 1300\text{–}800})^{-1}$  \
# division_1_size_0.4                                 1.103550
# division_1_size_0.2                                 0.932210
# division_2_size_5                                   0.516604
#
#                      $\log \overline{I}_{873 \pm 25}$  \
# division_1_size_0.4                         -3.605555
# division_1_size_0.2                         -3.240714
# division_2_size_5                           -1.248113
#
#                      $(\overline{I}_{873 \pm 25})^{-1}$  \
# division_1_size_0.4                           36.802102
# division_1_size_0.2                           25.551965
# division_2_size_5                              3.483763
#
#                      $\log \overline{I}_{873 \pm 50}$  \
# division_1_size_0.4                         -3.383827
# division_1_size_0.2                         -3.009439
# division_2_size_5                           -1.233702
#
#                      $(\overline{I}_{873 \pm 50})^{-1}$  \
# division_1_size_0.4                           29.483380
# division_1_size_0.2                           20.276021
# division_2_size_5                              3.433920
#
#                      $\log \overline{I}_{1105 \pm 25}$  \
# division_1_size_0.4                          -0.620891
# division_1_size_0.2                          -0.426689
# division_2_size_5                            -0.092456
#
#                      $(\overline{I}_{1105 \pm 25})^{-1}$  \
# division_1_size_0.4                             1.860585
# division_1_size_0.2                             1.532177
# division_2_size_5                               1.096865
#
#                      $\log \overline{I}_{1105 \pm 50}$  \
# division_1_size_0.4                          -0.627612
# division_1_size_0.2                          -0.473724
# division_2_size_5                            -0.115040
#
#                      $(\overline{I}_{1105 \pm 50})^{-1}$  \
# division_1_size_0.4                             1.873133
# division_1_size_0.2                             1.605963
# division_2_size_5                               1.121918
#
#                      $\log \overline{I}_{1241 \pm 25}$  \
# division_1_size_0.4                          -1.043804
# division_1_size_0.2                          -1.026996
# division_2_size_5                            -0.312964
#
#                      $(\overline{I}_{1241 \pm 25})^{-1}$  \
# division_1_size_0.4                             2.840000
# division_1_size_0.2                             2.792665
# division_2_size_5                               1.367472
#
#                      $\log \overline{I}_{1241 \pm 50}$  \
# division_1_size_0.4                          -1.023311
# division_1_size_0.2                          -1.011430
# division_2_size_5                            -0.331110
#
#                      $(\overline{I}_{1241 \pm 50})^{-1}$  \
# division_1_size_0.4                             2.782392
# division_1_size_0.2                             2.749530
# division_2_size_5                               1.392513
#
#                      $\log \overline{I}_{1394 \pm 25}$  \
# division_1_size_0.4                          -0.452065
# division_1_size_0.2                          -0.026630
# division_2_size_5                            -0.141070
#
#                      $(\overline{I}_{1394 \pm 25})^{-1}$  \
# division_1_size_0.4                             1.571554
# division_1_size_0.2                             1.026988
# division_2_size_5                               1.151505
#
#                      $\log \overline{I}_{1394 \pm 50}$  \
# division_1_size_0.4                          -0.514011
# division_1_size_0.2                          -0.088436
# division_2_size_5                            -0.192170
#
#                      $(\overline{I}_{1394 \pm 50})^{-1}$  \
# division_1_size_0.4                             1.671983
# division_1_size_0.2                             1.092465
# division_2_size_5                               1.211876
#
#                      $\log \overline{I}_{1615 \pm 25}$  \
# division_1_size_0.4                          -0.232461
# division_1_size_0.2                          -0.047773
# division_2_size_5                            -0.081060
#
#                      $(\overline{I}_{1615 \pm 25})^{-1}$  \
# division_1_size_0.4                             1.261701
# division_1_size_0.2                             1.048933
# division_2_size_5                               1.084436
#
#                      $\log \overline{I}_{1615 \pm 50}$  \
# division_1_size_0.4                          -0.218855
# division_1_size_0.2                          -0.091332
# division_2_size_5                            -0.180096
#
#                      $(\overline{I}_{1615 \pm 50})^{-1}$  \
# division_1_size_0.4                             1.244651
# division_1_size_0.2                             1.095632
# division_2_size_5                               1.197332
#
#                      $\log \overline{I}_{1726 \pm 25}$  \
# division_1_size_0.4                          -0.935047
# division_1_size_0.2                          -0.902506
# division_2_size_5                            -0.858615
#
#                      $(\overline{I}_{1726 \pm 25})^{-1}$  \
# division_1_size_0.4                             2.547333
# division_1_size_0.2                             2.465775
# division_2_size_5                               2.359890
#
#                      $\log \overline{I}_{1726 \pm 50}$  \
# division_1_size_0.4                          -0.861478
# division_1_size_0.2                          -0.864122
# division_2_size_5                            -0.921825
#
#                      $(\overline{I}_{1726 \pm 50})^{-1}$  \
# division_1_size_0.4                             2.366656
# division_1_size_0.2                             2.372922
# division_2_size_5                               2.513874
#
#                      $\frac{I_{873}}{I_{1105}}$  $\frac{I_{873}}{I_{1241}}$  \
# division_1_size_0.4                    0.042061                    0.065649
# division_1_size_0.2                    0.049088                    0.092018
# division_2_size_5                      0.310766                    0.384030
#
#                      $\frac{I_{873}}{I_{1394}}$  $\frac{I_{873}}{I_{1615}}$  \
# division_1_size_0.4                    0.034780                    0.028692
# division_1_size_0.2                    0.033274                    0.034257
# division_2_size_5                      0.318067                    0.295763
#
#                      $\frac{I_{873}}{I_{1726}}$  \
# division_1_size_0.4                    0.059556
# division_1_size_0.2                    0.084238
# division_2_size_5                      0.649605
#
#                      $\frac{I_{873}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_0.4                                          0.056140
# division_1_size_0.2                                          0.072156
# division_2_size_5                                            0.516165
#
#                      $\frac{I_{873}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_0.4                                          0.008305
# division_1_size_0.2                                          0.009675
# division_2_size_5                                            0.067176
#
#                      $\frac{I_{873}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_0.4                                           0.048705
# division_1_size_0.2                                           0.069535
# division_2_size_5                                             0.701047
#
#                      $\frac{I_{873}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_0.4                                           0.019363
# division_1_size_0.2                                           0.024353
# division_2_size_5                                             0.203232
#
#                      $\frac{I_{873}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_0.4                                           0.043280
# division_1_size_0.2                                           0.044746
# division_2_size_5                                             0.402280
#
#                      $\frac{I_{873}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_0.4                                           0.034780
# division_1_size_0.2                                           0.033274
# division_2_size_5                                             0.318067
#
#                      $\frac{I_{873}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_0.4                                          0.073922
# division_1_size_0.2                                          0.099451
# division_2_size_5                                            0.470110
#
#                      $\frac{I_{873}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_0.4                                          0.024995
# division_1_size_0.2                                          0.031018
# division_2_size_5                                            0.146588
#
#                      $\frac{I_{873}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_0.4                                      0.042142
# division_1_size_0.2                                      0.050982
# division_2_size_5                                        0.311240
#
#                      $\frac{I_{873}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_0.4                                      0.042426
# division_1_size_0.2                                      0.053437
# division_2_size_5                                        0.318348
#
#                      $\frac{I_{873}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.4                                      0.064326
# division_1_size_0.2                                      0.092923
# division_2_size_5                                        0.388025
#
#                      $\frac{I_{873}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_0.4                                      0.063021
# division_1_size_0.2                                      0.091488
# division_2_size_5                                        0.395131
#
#                      $\frac{I_{873}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.4                                      0.035596
# division_1_size_0.2                                      0.034172
# division_2_size_5                                        0.326744
#
#                      $\frac{I_{873}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_0.4                                      0.037870
# division_1_size_0.2                                      0.036351
# division_2_size_5                                        0.343875
#
#                      $\frac{I_{873}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_0.4                                      0.028577
# division_1_size_0.2                                      0.034902
# division_2_size_5                                        0.307713
#
#                      $\frac{I_{873}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_0.4                                      0.028191
# division_1_size_0.2                                      0.036456
# division_2_size_5                                        0.339748
#
#                      $\frac{I_{873}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_0.4                                      0.057697
# division_1_size_0.2                                      0.082046
# division_2_size_5                                        0.669628
#
#                      $\frac{I_{873}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_0.4                                      0.053605
# division_1_size_0.2                                      0.078957
# division_2_size_5                                        0.713321
#
#                      $\frac{I_{1105}}{I_{1241}}$  $\frac{I_{1105}}{I_{1394}}$  \
# division_1_size_0.4                     1.560806                     0.826904
# division_1_size_0.2                     1.874558                     0.677844
# division_2_size_5                       1.235752                     1.023495
#
#                      $\frac{I_{1105}}{I_{1615}}$  $\frac{I_{1105}}{I_{1726}}$  \
# division_1_size_0.4                     0.682151                     1.415947
# division_1_size_0.2                     0.697861                     1.716072
# division_2_size_5                       0.951724                     2.090335
#
#                      $\frac{I_{1105}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_0.4                                           1.334718
# division_1_size_0.2                                           1.469934
# division_2_size_5                                             1.660943
#
#                      $\frac{I_{1105}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_0.4                                           0.197461
# division_1_size_0.2                                           0.197103
# division_2_size_5                                             0.216162
#
#                      $\frac{I_{1105}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_0.4                                            1.157972
# division_1_size_0.2                                            1.416538
# division_2_size_5                                              2.255868
#
#                      $\frac{I_{1105}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_0.4                                            0.460364
# division_1_size_0.2                                            0.496112
# division_2_size_5                                              0.653972
#
#                      $\frac{I_{1105}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_0.4                                            1.028981
# division_1_size_0.2                                            0.911555
# division_2_size_5                                              1.294480
#
#                      $\frac{I_{1105}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_0.4                                            0.826904
# division_1_size_0.2                                            0.677844
# division_2_size_5                                              1.023495
#
#                      $\frac{I_{1105}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_0.4                                           1.757493
# division_1_size_0.2                                           2.025975
# division_2_size_5                                             1.512746
#
#                      $\frac{I_{1105}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_0.4                                           0.594263
# division_1_size_0.2                                           0.631893
# division_2_size_5                                             0.471700
#
#                      $\frac{I_{1105}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_0.4                                     19.817981
# division_1_size_0.2                                     17.320246
# division_2_size_5                                        3.180950
#
#                      $\frac{I_{1105}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_0.4                                     15.876839
# division_1_size_0.2                                     13.743979
# division_2_size_5                                        3.135439
#
#                      $\frac{I_{1105}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.4                                       1.529344
# division_1_size_0.2                                       1.892991
# division_2_size_5                                         1.248609
#
#                      $\frac{I_{1105}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_0.4                                       1.498322
# division_1_size_0.2                                       1.863752
# division_2_size_5                                         1.271474
#
#                      $\frac{I_{1105}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.4                                       0.846284
# division_1_size_0.2                                       0.696138
# division_2_size_5                                         1.051414
#
#                      $\frac{I_{1105}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_0.4                                       0.900365
# division_1_size_0.2                                       0.740521
# division_2_size_5                                         1.106539
#
#                      $\frac{I_{1105}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_0.4                                       0.679428
# division_1_size_0.2                                       0.711013
# division_2_size_5                                         0.990176
#
#                      $\frac{I_{1105}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_0.4                                       0.670246
# division_1_size_0.2                                       0.742668
# division_2_size_5                                         1.093258
#
#                      $\frac{I_{1105}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_0.4                                       1.371742
# division_1_size_0.2                                       1.671411
# division_2_size_5                                         2.154765
#
#                      $\frac{I_{1105}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_0.4                                       1.274447
# division_1_size_0.2                                       1.608471
# division_2_size_5                                         2.295365
#
#                      $\frac{I_{1241}}{I_{1394}}$  $\frac{I_{1241}}{I_{1615}}$  \
# division_1_size_0.4                     0.529793                     0.437050
# division_1_size_0.2                     0.361602                     0.372281
# division_2_size_5                       0.828236                     0.770157
#
#                      $\frac{I_{1241}}{I_{1726}}$  \
# division_1_size_0.4                     0.907190
# division_1_size_0.2                     0.915454
# division_2_size_5                       1.691549
#
#                      $\frac{I_{1241}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_0.4                                           0.855147
# division_1_size_0.2                                           0.784150
# division_2_size_5                                             1.344075
#
#                      $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_0.4                                           0.126513
# division_1_size_0.2                                           0.105146
# division_2_size_5                                             0.174924
#
#                      $\frac{I_{1241}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_0.4                                            0.741906
# division_1_size_0.2                                            0.755665
# division_2_size_5                                              1.825502
#
#                      $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_0.4                                            0.294953
# division_1_size_0.2                                            0.264655
# division_2_size_5                                              0.529210
#
#                      $\frac{I_{1241}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_0.4                                            0.659263
# division_1_size_0.2                                            0.486277
# division_2_size_5                                              1.047524
#
#                      $\frac{I_{1241}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_0.4                                            0.529793
# division_1_size_0.2                                            0.361602
# division_2_size_5                                              0.828236
#
#                      $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_0.4                                           1.126016
# division_1_size_0.2                                           1.080775
# division_2_size_5                                             1.224150
#
#                      $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_0.4                                           0.380741
# division_1_size_0.2                                           0.337089
# division_2_size_5                                             0.381711
#
#                      $\frac{I_{1241}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_0.4                                     12.697276
# division_1_size_0.2                                      9.239643
# division_2_size_5                                        2.574101
#
#                      $\frac{I_{1241}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_0.4                                     10.172207
# division_1_size_0.2                                      7.331851
# division_2_size_5                                        2.537273
#
#                      $\frac{I_{1241}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_0.4                                       0.641929
# division_1_size_0.2                                       0.554038
# division_2_size_5                                         0.810457
#
#                      $\frac{I_{1241}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_0.4                                       0.646259
# division_1_size_0.2                                       0.580720
# division_2_size_5                                         0.828968
#
#                      $\frac{I_{1241}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.4                                       0.542210
# division_1_size_0.2                                       0.371361
# division_2_size_5                                         0.850830
#
#                      $\frac{I_{1241}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_0.4                                       0.576859
# division_1_size_0.2                                       0.395037
# division_2_size_5                                         0.895437
#
#                      $\frac{I_{1241}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_0.4                                       0.435306
# division_1_size_0.2                                       0.379296
# division_2_size_5                                         0.801274
#
#                      $\frac{I_{1241}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_0.4                                       0.429423
# division_1_size_0.2                                       0.396183
# division_2_size_5                                         0.884691
#
#                      $\frac{I_{1241}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_0.4                                       0.878868
# division_1_size_0.2                                       0.891629
# division_2_size_5                                         1.743688
#
#                      $\frac{I_{1241}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_0.4                                       0.816532
# division_1_size_0.2                                       0.858054
# division_2_size_5                                         1.857464
#
#                      $\frac{I_{1394}}{I_{1615}}$  $\frac{I_{1394}}{I_{1726}}$  \
# division_1_size_0.4                     0.824946                     1.712348
# division_1_size_0.2                     1.029531                     2.531663
# division_2_size_5                       0.929876                     2.042350
#
#                      $\frac{I_{1394}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_0.4                                           1.614115
# division_1_size_0.2                                           2.168543
# division_2_size_5                                             1.622816
#
#                      $\frac{I_{1394}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_0.4                                           0.238796
# division_1_size_0.2                                           0.290779
# division_2_size_5                                             0.211200
#
#                      $\frac{I_{1394}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_0.4                                            1.400370
# division_1_size_0.2                                            2.089770
# division_2_size_5                                              2.204083
#
#                      $\frac{I_{1394}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_0.4                                            0.556733
# division_1_size_0.2                                            0.731897
# division_2_size_5                                              0.638960
#
#                      $\frac{I_{1394}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_0.4                                            1.244378
# division_1_size_0.2                                            1.344785
# division_2_size_5                                              1.264765
#
#                      $\frac{I_{1394}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_0.4                                                 1.0
# division_1_size_0.2                                                 1.0
# division_2_size_5                                                   1.0
#
#                      $\frac{I_{1394}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_0.4                                           2.125390
# division_1_size_0.2                                           2.988851
# division_2_size_5                                             1.478021
#
#                      $\frac{I_{1394}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_0.4                                           0.718661
# division_1_size_0.2                                           0.932210
# division_2_size_5                                             0.460872
#
#                      $\frac{I_{1394}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_0.4                                     23.966487
# division_1_size_0.2                                     25.551965
# division_2_size_5                                        3.107930
#
#                      $\frac{I_{1394}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_0.4                                     19.200344
# division_1_size_0.2                                     20.276021
# division_2_size_5                                        3.063464
#
#                      $\frac{I_{1394}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_0.4                                       1.211661
# division_1_size_0.2                                       1.532177
# division_2_size_5                                         0.978534
#
#                      $\frac{I_{1394}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_0.4                                       1.219833
# division_1_size_0.2                                       1.605963
# division_2_size_5                                         1.000884
#
#                      $\frac{I_{1394}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.4                                       1.849482
# division_1_size_0.2                                       2.792665
# division_2_size_5                                         1.219947
#
#                      $\frac{I_{1394}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_0.4                                       1.811966
# division_1_size_0.2                                       2.749530
# division_2_size_5                                         1.242287
#
#                      $\frac{I_{1394}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_0.4                                       0.821653
# division_1_size_0.2                                       1.048933
# division_2_size_5                                         0.967446
#
#                      $\frac{I_{1394}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_0.4                                       0.810549
# division_1_size_0.2                                       1.095632
# division_2_size_5                                         1.068162
#
#                      $\frac{I_{1394}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_0.4                                       1.658889
# division_1_size_0.2                                       2.465775
# division_2_size_5                                         2.105302
#
#                      $\frac{I_{1394}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_0.4                                       1.541228
# division_1_size_0.2                                       2.372922
# division_2_size_5                                         2.242674
#
#                      $\frac{I_{1615}}{I_{1726}}$  \
# division_1_size_0.4                     2.075710
# division_1_size_0.2                     2.459045
# division_2_size_5                       2.196368
#
#                      $\frac{I_{1615}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_0.4                                           1.956632
# division_1_size_0.2                                           2.106341
# division_2_size_5                                             1.745195
#
#                      $\frac{I_{1615}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_0.4                                           0.289469
# division_1_size_0.2                                           0.282439
# division_2_size_5                                             0.227127
#
#                      $\frac{I_{1615}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_0.4                                            1.697530
# division_1_size_0.2                                            2.029827
# division_2_size_5                                              2.370297
#
#                      $\frac{I_{1615}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_0.4                                            0.674872
# division_1_size_0.2                                            0.710903
# division_2_size_5                                              0.687145
#
#                      $\frac{I_{1615}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_0.4                                            1.508436
# division_1_size_0.2                                            1.306212
# division_2_size_5                                              1.360143
#
#                      $\frac{I_{1615}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_0.4                                            1.212201
# division_1_size_0.2                                            0.971316
# division_2_size_5                                              1.075412
#
#                      $\frac{I_{1615}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_0.4                                           2.576400
# division_1_size_0.2                                           2.903119
# division_2_size_5                                             1.589481
#
#                      $\frac{I_{1615}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_0.4                                           0.871161
# division_1_size_0.2                                           0.905470
# division_2_size_5                                             0.495628
#
#                      $\frac{I_{1615}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_0.4                                     29.052199
# division_1_size_0.2                                     24.819033
# division_2_size_5                                        3.342305
#
#                      $\frac{I_{1615}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_0.4                                     23.274677
# division_1_size_0.2                                     19.694424
# division_2_size_5                                        3.294485
#
#                      $\frac{I_{1615}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_0.4                                       1.468777
# division_1_size_0.2                                       1.488228
# division_2_size_5                                         1.052327
#
#                      $\frac{I_{1615}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_0.4                                       1.478683
# division_1_size_0.2                                       1.559898
# division_2_size_5                                         1.076362
#
#                      $\frac{I_{1615}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.4                                       2.241944
# division_1_size_0.2                                       2.712560
# division_2_size_5                                         1.311945
#
#                      $\frac{I_{1615}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_0.4                                       2.196467
# division_1_size_0.2                                       2.670662
# division_2_size_5                                         1.335970
#
#                      $\frac{I_{1615}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.4                                       1.240611
# division_1_size_0.2                                       0.997530
# division_2_size_5                                         1.104748
#
#                      $\frac{I_{1615}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_0.4                                       1.319892
# division_1_size_0.2                                       1.061128
# division_2_size_5                                         1.162668
#
#                      $\frac{I_{1615}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_0.4                                       2.010907
# division_1_size_0.2                                       2.395046
# division_2_size_5                                         2.264066
#
#                      $\frac{I_{1615}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_0.4                                       1.868278
# division_1_size_0.2                                       2.304857
# division_2_size_5                                         2.411798
#
#                      $\frac{I_{1726}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_0.4                                           0.942632
# division_1_size_0.2                                           0.856569
# division_2_size_5                                             0.794582
#
#                      $\frac{I_{1726}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_0.4                                           0.139455
# division_1_size_0.2                                           0.114857
# division_2_size_5                                             0.103410
#
#                      $\frac{I_{1726}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_0.4                                            0.817807
# division_1_size_0.2                                            0.825454
# division_2_size_5                                              1.079190
#
#                      $\frac{I_{1726}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_0.4                                            0.325128
# division_1_size_0.2                                            0.289097
# division_2_size_5                                              0.312855
#
#                      $\frac{I_{1726}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_0.4                                            0.726708
# division_1_size_0.2                                            0.531187
# division_2_size_5                                              0.619269
#
#                      $\frac{I_{1726}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_0.4                                            0.583993
# division_1_size_0.2                                            0.394997
# division_2_size_5                                              0.489632
#
#                      $\frac{I_{1726}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_0.4                                           1.241213
# division_1_size_0.2                                           1.180588
# division_2_size_5                                             0.723686
#
#                      $\frac{I_{1726}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_0.4                                           0.419693
# division_1_size_0.2                                           0.368220
# division_2_size_5                                             0.225658
#
#                      $\frac{I_{1726}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_0.4                                     13.996269
# division_1_size_0.2                                     10.092958
# division_2_size_5                                        1.521742
#
#                      $\frac{I_{1726}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_0.4                                     11.212873
# division_1_size_0.2                                      8.008974
# division_2_size_5                                        1.499970
#
#                      $\frac{I_{1726}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_0.4                                       0.707602
# division_1_size_0.2                                       0.605206
# division_2_size_5                                         0.479121
#
#                      $\frac{I_{1726}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_0.4                                       0.712374
# division_1_size_0.2                                       0.634351
# division_2_size_5                                         0.490065
#
#                      $\frac{I_{1726}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.4                                       1.080085
# division_1_size_0.2                                       1.103095
# division_2_size_5                                         0.597325
#
# ...
# division_2_size_5                                                          0.335332
#
#                      $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_0.4                                                        0.056709
# division_1_size_0.2                                                        0.053880
# division_2_size_5                                                          0.352913
#
#                      $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_0.4                                                        0.042794
# division_1_size_0.2                                                        0.051733
# division_2_size_5                                                          0.315801
#
#                      $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_0.4                                                        0.042215
# division_1_size_0.2                                                        0.054036
# division_2_size_5                                                          0.348678
#
#                      $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_0.4                                                        0.086399
# division_1_size_0.2                                                        0.121610
# division_2_size_5                                                          0.687229
#
#                      $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_0.4                                                        0.080271
# division_1_size_0.2                                                        0.117031
# division_2_size_5                                                          0.732071
#
#                      $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.4                                                         1.526402
# division_1_size_0.2                                                         1.822678
# division_2_size_5                                                           1.246709
#
#                      $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_0.4                                                         1.495440
# division_1_size_0.2                                                         1.794525
# division_2_size_5                                                           1.269539
#
#                      $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.4                                                         0.844656
# division_1_size_0.2                                                         0.670280
# division_2_size_5                                                           1.049815
#
#                      $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_0.4                                                         0.898633
# division_1_size_0.2                                                         0.713015
# division_2_size_5                                                           1.104855
#
#                      $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_0.4                                                         0.678121
# division_1_size_0.2                                                         0.684603
# division_2_size_5                                                           0.988669
#
#                      $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_0.4                                                         0.668957
# division_1_size_0.2                                                         0.715082
# division_2_size_5                                                           1.091595
#
#                      $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_0.4                                                         1.369103
# division_1_size_0.2                                                         1.609328
# division_2_size_5                                                           2.151486
#
#                      $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_0.4                                                         1.271996
# division_1_size_0.2                                                         1.548726
# division_2_size_5                                                           2.291872
#
#                      $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_0.4                                                         1.516177
# division_1_size_0.2                                                         1.738934
# division_2_size_5                                                           1.218870
#
#                      $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_0.4                                                         1.485422
# division_1_size_0.2                                                         1.712075
# division_2_size_5                                                           1.241190
#
#                      $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.4                                                         0.838998
# division_1_size_0.2                                                         0.639484
# division_2_size_5                                                           1.026372
#
#                      $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_0.4                                                         0.892613
# division_1_size_0.2                                                         0.680255
# division_2_size_5                                                           1.080183
#
#                      $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_0.4                                                         0.673578
# division_1_size_0.2                                                         0.653148
# division_2_size_5                                                           0.966592
#
#                      $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_0.4                                                         0.664476
# division_1_size_0.2                                                         0.682227
# division_2_size_5                                                           1.067219
#
#                      $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_0.4                                                         1.359932
# division_1_size_0.2                                                         1.535387
# division_2_size_5                                                           2.103443
#
#                      $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_0.4                                                         1.263475
# division_1_size_0.2                                                         1.477569
# division_2_size_5                                                           2.240693
#
#                      $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.4                                                         0.553364
# division_1_size_0.2                                                         0.367745
# division_2_size_5                                                           0.842068
#
#                      $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_0.4                                                         0.588726
# division_1_size_0.2                                                         0.391191
# division_2_size_5                                                           0.886217
#
#                      $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_0.4                                                         0.444261
# division_1_size_0.2                                                         0.375603
# division_2_size_5                                                           0.793023
#
#                      $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_0.4                                                         0.438257
# division_1_size_0.2                                                         0.392325
# division_2_size_5                                                           0.875581
#
#                      $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_0.4                                                         0.896948
# division_1_size_0.2                                                         0.882947
# division_2_size_5                                                           1.725732
#
#                      $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_0.4                                                         0.833329
# division_1_size_0.2                                                         0.849698
# division_2_size_5                                                           1.838337
#
#                      $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_0.4                                                         0.564821
# division_1_size_0.2                                                         0.373514
# division_2_size_5                                                           0.826926
#
#                      $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_0.4                                                         0.600916
# division_1_size_0.2                                                         0.397328
# division_2_size_5                                                           0.870280
#
#                      $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_0.4                                                         0.453459
# division_1_size_0.2                                                         0.381495
# division_2_size_5                                                           0.778762
#
#                      $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_0.4                                                         0.447331
# division_1_size_0.2                                                         0.398480
# division_2_size_5                                                           0.859836
#
#                      $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_0.4                                                         0.915519
# division_1_size_0.2                                                         0.896799
# division_2_size_5                                                           1.694699
#
#                      $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_0.4                                                         0.850583
# division_1_size_0.2                                                         0.863028
# division_2_size_5                                                           1.805279
#
#                      $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_0.4                                                         0.802837
# division_1_size_0.2                                                         1.021368
# division_2_size_5                                                           0.941756
#
#                      $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_0.4                                                         0.791987
# division_1_size_0.2                                                         1.066840
# division_2_size_5                                                           1.039798
#
#                      $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_0.4                                                         1.620900
# division_1_size_0.2                                                         2.400977
# division_2_size_5                                                           2.049397
#
#                      $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_0.4                                                         1.505933
# division_1_size_0.2                                                         2.310565
# division_2_size_5                                                           2.183121
#
#                      $\frac{\overline{I}_{1394 \pm 50}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_0.4                                                         0.754614
# division_1_size_0.2                                                         0.960152
# division_2_size_5                                                           0.894841
#
#                      $\frac{\overline{I}_{1394 \pm 50}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_0.4                                                         0.744416
# division_1_size_0.2                                                         1.002899
# division_2_size_5                                                           0.987999
#
#                      $\frac{\overline{I}_{1394 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_0.4                                                         1.523540
# division_1_size_0.2                                                         2.257075
# division_2_size_5                                                           1.947302
#
#                      $\frac{\overline{I}_{1394 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_0.4                                                         1.415478
# division_1_size_0.2                                                         2.172081
# division_2_size_5                                                           2.074365
#
#                      $\frac{\overline{I}_{1615 \pm 25}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_0.4                                                         2.018967
# division_1_size_0.2                                                         2.350746
# division_2_size_5                                                           2.176144
#
#                      $\frac{\overline{I}_{1615 \pm 25}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_0.4                                                         1.875766
# division_1_size_0.2                                                         2.262226
# division_2_size_5                                                           2.318139
#
#                      $\frac{\overline{I}_{1615 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_0.4                                                         2.046624
# division_1_size_0.2                                                         2.250550
# division_2_size_5                                                           1.970957
#
#                      $\frac{\overline{I}_{1615 \pm 50}}{\overline{I}_{1726 \pm 50}}$
# division_1_size_0.4                                                         1.901461
# division_1_size_0.2                                                         2.165802
# division_2_size_5                                                           2.099563

# %%
dataset = pd.concat([dataset_train, dataset_test], axis=0)

print(dataset.shape)
dataset.head(3)
# Out:
# (75, 324)
#                       $I_{873}$  $I_{1105}$  $I_{1241}$  $I_{1394}$  \
# division_1_size_bulk   0.048208    0.681294    0.455066    0.760582
# division_1_size_5      0.091875    0.606138    0.427988    0.687458
# division_1_size_3      0.110321    0.836176    0.400950    0.696553
#
#                       $I_{1615}$  $I_{1726}$  \
# division_1_size_bulk         1.0    0.421995
# division_1_size_5            1.0    0.383362
# division_1_size_3            1.0    0.366658
#
#                       $\overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                          0.424162
# division_1_size_5                             0.378730
# division_1_size_3                             0.436266
#
#                       $\Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                          3.367146
# division_1_size_5                             3.196821
# division_1_size_3                             3.410658
#
#                       $\overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                           0.426619
# division_1_size_5                              0.378004
# division_1_size_3                              0.429362
#
#                       $\Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                           1.421995
# division_1_size_5                              1.383362
# division_1_size_3                              1.366658
#
#                       $\overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                           0.571735
# division_1_size_5                              0.502368
# division_1_size_3                              0.523513
#
#                       $\Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                           0.760582
# division_1_size_5                              0.687458
# division_1_size_3                              0.696553
#
#                       $\overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                          0.363338
# division_1_size_5                             0.329999
# division_1_size_3                             0.406988
#
#                       $\Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                          1.184569
# division_1_size_5                             1.126001
# division_1_size_3                             1.347446
#
#                       $\overline{I}_{873 \pm 25}$  \
# division_1_size_bulk                     0.047543
# division_1_size_5                        0.093349
# division_1_size_3                        0.113396
#
#                       $\overline{I}_{873 \pm 50}$  \
# division_1_size_bulk                     0.047916
# division_1_size_5                        0.096086
# division_1_size_3                        0.114054
#
#                       $\overline{I}_{1105 \pm 25}$  \
# division_1_size_bulk                      0.628121
# division_1_size_5                         0.593910
# division_1_size_3                         0.816077
#
#                       $\overline{I}_{1105 \pm 50}$  \
# division_1_size_bulk                      0.615327
# division_1_size_5                         0.562713
# division_1_size_3                         0.774107
#
#                       $\overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                      0.447733
# division_1_size_5                         0.424918
# division_1_size_3                         0.401435
#
#                       $\overline{I}_{1241 \pm 50}$  \
# division_1_size_bulk                      0.442677
# division_1_size_5                         0.421892
# division_1_size_3                         0.409080
#
#                       $\overline{I}_{1394 \pm 25}$  \
# division_1_size_bulk                      0.738860
# division_1_size_5                         0.667947
# division_1_size_3                         0.678774
#
#                       $\overline{I}_{1394 \pm 50}$  \
# division_1_size_bulk                      0.689531
# division_1_size_5                         0.619315
# division_1_size_3                         0.631706
#
#                       $\overline{I}_{1615 \pm 25}$  \
# division_1_size_bulk                      0.944739
# division_1_size_5                         0.937481
# division_1_size_3                         0.957114
#
#                       $\overline{I}_{1615 \pm 50}$  \
# division_1_size_bulk                      0.845640
# division_1_size_5                         0.831352
# division_1_size_3                         0.877520
#
#                       $\overline{I}_{1726 \pm 25}$  \
# division_1_size_bulk                      0.415802
# division_1_size_5                         0.376555
# division_1_size_3                         0.366774
#
#                       $\overline{I}_{1726 \pm 50}$  $\log I_{873}$  \
# division_1_size_bulk                      0.413416       -3.032222
# division_1_size_5                         0.371393       -2.387325
# division_1_size_3                         0.375602       -2.204364
#
#                       $(I_{873})^{-1}$  $\log I_{1105}$  $(I_{1105})^{-1}$  \
# division_1_size_bulk         20.743271        -0.383761           1.467794
# division_1_size_5            10.884335        -0.500648           1.649790
# division_1_size_3             9.064483        -0.178917           1.195921
#
#                       $\log I_{1241}$  $(I_{1241})^{-1}$  $\log I_{1394}$  \
# division_1_size_bulk        -0.787312           2.197482        -0.273672
# division_1_size_5           -0.848660           2.336514        -0.374754
# division_1_size_3           -0.913918           2.494076        -0.361611
#
#                       $(I_{1394})^{-1}$  $\log I_{1615}$  $(I_{1615})^{-1}$  \
# division_1_size_bulk           1.314783              0.0                1.0
# division_1_size_5              1.454634              0.0                1.0
# division_1_size_3              1.435640              0.0                1.0
#
#                       $\log I_{1726}$  $(I_{1726})^{-1}$  \
# division_1_size_bulk        -0.862761           2.369695
# division_1_size_5           -0.958776           2.608502
# division_1_size_3           -1.003327           2.727339
#
#                       $\log \overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                              -0.857641
# division_1_size_5                                 -0.970931
# division_1_size_3                                 -0.829504
#
#                       $(\overline{I}_{1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.357591
# division_1_size_5                                    2.640400
# division_1_size_3                                    2.292181
#
#                       $\log \Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                               1.214065
# division_1_size_5                                  1.162157
# division_1_size_3                                  1.226905
#
#                       $(\Sigma I_{p,\ 1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.296987
# division_1_size_5                                    0.312811
# division_1_size_3                                    0.293199
#
#                       $\log \overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                               -0.851863
# division_1_size_5                                  -0.972851
# division_1_size_3                                  -0.845455
#
#                       $(\overline{I}_{1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  2.344010
# division_1_size_5                                     2.645477
# division_1_size_3                                     2.329038
#
#                       $\log \Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                                0.352061
# division_1_size_5                                   0.324517
# division_1_size_3                                   0.312368
#
#                       $(\Sigma I_{p,\ 1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  0.703237
# division_1_size_5                                     0.722877
# division_1_size_3                                     0.731712
#
#                       $\log \overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                               -0.559080
# division_1_size_5                                  -0.688422
# division_1_size_3                                  -0.647194
#
#                       $(\overline{I}_{1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.749062
# division_1_size_5                                     1.990572
# division_1_size_3                                     1.910173
#
#                       $\log \Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                               -0.273672
# division_1_size_5                                  -0.374754
# division_1_size_3                                  -0.361611
#
#                       $(\Sigma I_{p,\ 1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.314783
# division_1_size_5                                     1.454634
# division_1_size_3                                     1.435640
#
#                       $\log \overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                              -1.012422
# division_1_size_5                                 -1.108665
# division_1_size_3                                 -0.898970
#
#                       $(\overline{I}_{1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.752259
# division_1_size_5                                    3.030309
# division_1_size_3                                    2.457072
#
#                       $\log \Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                               0.169379
# division_1_size_5                                  0.118672
# division_1_size_3                                  0.298211
#
#                       $(\Sigma I_{p,\ 1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.844189
# division_1_size_5                                    0.888099
# division_1_size_3                                    0.742145
#
#                       $\log \overline{I}_{873 \pm 25}$  \
# division_1_size_bulk                         -3.046113
# division_1_size_5                            -2.371406
# division_1_size_3                            -2.176872
#
#                       $(\overline{I}_{873 \pm 25})^{-1}$  \
# division_1_size_bulk                           21.033424
# division_1_size_5                              10.712443
# division_1_size_3                               8.818675
#
#                       $\log \overline{I}_{873 \pm 50}$  \
# division_1_size_bulk                         -3.038304
# division_1_size_5                            -2.342512
# division_1_size_3                            -2.171085
#
#                       $(\overline{I}_{873 \pm 50})^{-1}$  \
# division_1_size_bulk                           20.869820
# division_1_size_5                              10.407351
# division_1_size_3                               8.767790
#
#                       $\log \overline{I}_{1105 \pm 25}$  \
# division_1_size_bulk                          -0.465023
# division_1_size_5                             -0.521028
# division_1_size_3                             -0.203247
#
#                       $(\overline{I}_{1105 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.592050
# division_1_size_5                                1.683757
# division_1_size_3                                1.225375
#
#                       $\log \overline{I}_{1105 \pm 50}$  \
# division_1_size_bulk                          -0.485601
# division_1_size_5                             -0.574985
# division_1_size_3                             -0.256045
#
#                       $(\overline{I}_{1105 \pm 50})^{-1}$  \
# division_1_size_bulk                             1.625151
# division_1_size_5                                1.777105
# division_1_size_3                                1.291811
#
#                       $\log \overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                          -0.803558
# division_1_size_5                             -0.855859
# division_1_size_3                             -0.912710
#
#                       $(\overline{I}_{1241 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.233473
# division_1_size_5                                2.353396
# division_1_size_3                                2.491063
#
#                       $\log \overline{I}_{1241 \pm 50}$  \
# division_1_size_bulk                          -0.814914
# division_1_size_5                             -0.863007
# division_1_size_3                             -0.893845
#
#                       $(\overline{I}_{1241 \pm 50})^{-1}$  \
# division_1_size_bulk                             2.258982
# division_1_size_5                                2.370277
# division_1_size_3                                2.444512
#
#                       $\log \overline{I}_{1394 \pm 25}$  \
# division_1_size_bulk                          -0.302647
# division_1_size_5                             -0.403547
# division_1_size_3                             -0.387466
#
#                       $(\overline{I}_{1394 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.353436
# division_1_size_5                                1.497126
# division_1_size_3                                1.473243
#
#                       $\log \overline{I}_{1394 \pm 50}$  \
# division_1_size_bulk                          -0.371743
# division_1_size_5                             -0.479141
# division_1_size_3                             -0.459332
#
#                       $(\overline{I}_{1394 \pm 50})^{-1}$  \
# division_1_size_bulk                             1.450261
# division_1_size_5                                1.614687
# division_1_size_3                                1.583015
#
#                       $\log \overline{I}_{1615 \pm 25}$  \
# division_1_size_bulk                          -0.056847
# division_1_size_5                             -0.064558
# division_1_size_3                             -0.043832
#
#                       $(\overline{I}_{1615 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.058493
# division_1_size_5                                1.066688
# division_1_size_3                                1.044807
#
#                       $\log \overline{I}_{1615 \pm 50}$  \
# division_1_size_bulk                          -0.167661
# division_1_size_5                             -0.184702
# division_1_size_3                             -0.130656
#
#                       $(\overline{I}_{1615 \pm 50})^{-1}$  \
# division_1_size_bulk                             1.182536
# division_1_size_5                                1.202860
# division_1_size_3                                1.139575
#
#                       $\log \overline{I}_{1726 \pm 25}$  \
# division_1_size_bulk                          -0.877547
# division_1_size_5                             -0.976691
# division_1_size_3                             -1.003010
#
#                       $(\overline{I}_{1726 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.404992
# division_1_size_5                                2.655654
# division_1_size_3                                2.726475
#
#                       $\log \overline{I}_{1726 \pm 50}$  \
# division_1_size_bulk                          -0.883300
# division_1_size_5                             -0.990494
# division_1_size_3                             -0.979224
#
#                       $(\overline{I}_{1726 \pm 50})^{-1}$  \
# division_1_size_bulk                             2.418869
# division_1_size_5                                2.692566
# division_1_size_3                                2.662390
#
#                       $\frac{I_{873}}{I_{1105}}$  $\frac{I_{873}}{I_{1241}}$  \
# division_1_size_bulk                    0.070760                    0.105937
# division_1_size_5                       0.151575                    0.214668
# division_1_size_3                       0.131935                    0.275148
#
#                       $\frac{I_{873}}{I_{1394}}$  $\frac{I_{873}}{I_{1615}}$  \
# division_1_size_bulk                    0.063384                    0.048208
# division_1_size_5                       0.133645                    0.091875
# division_1_size_3                       0.158381                    0.110321
#
#                       $\frac{I_{873}}{I_{1726}}$  \
# division_1_size_bulk                    0.114239
# division_1_size_5                       0.239657
# division_1_size_3                       0.300882
#
#                       $\frac{I_{873}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                          0.113656
# division_1_size_5                                             0.242587
# division_1_size_3                                             0.252875
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                          0.014317
# division_1_size_5                                             0.028740
# division_1_size_3                                             0.032346
#
#                       $\frac{I_{873}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.113001
# division_1_size_5                                              0.243054
# division_1_size_3                                              0.256941
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.033902
# division_1_size_5                                              0.066414
# division_1_size_3                                              0.080723
#
#                       $\frac{I_{873}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.084320
# division_1_size_5                                              0.182884
# division_1_size_3                                              0.210732
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.063384
# division_1_size_5                                              0.133645
# division_1_size_3                                              0.158381
#
#                       $\frac{I_{873}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                          0.132682
# division_1_size_5                                             0.278410
# division_1_size_3                                             0.271066
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                          0.040697
# division_1_size_5                                             0.081594
# division_1_size_3                                             0.081874
#
#                       $\frac{I_{873}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_bulk                                      0.076750
# division_1_size_5                                         0.154695
# division_1_size_3                                         0.135184
#
#                       $\frac{I_{873}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_bulk                                      0.078346
# division_1_size_5                                         0.163272
# division_1_size_3                                         0.142513
#
#                       $\frac{I_{873}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                      0.107672
# division_1_size_5                                         0.216219
# division_1_size_3                                         0.274816
#
#                       $\frac{I_{873}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                      0.108902
# division_1_size_5                                         0.217770
# division_1_size_3                                         0.269680
#
#                       $\frac{I_{873}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                      0.065247
# division_1_size_5                                         0.137549
# division_1_size_3                                         0.162529
#
#                       $\frac{I_{873}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                      0.069915
# division_1_size_5                                         0.148350
# division_1_size_3                                         0.174639
#
#                       $\frac{I_{873}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                      0.051028
# division_1_size_5                                         0.098002
# division_1_size_3                                         0.115264
#
#                       $\frac{I_{873}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                      0.057008
# division_1_size_5                                         0.110513
# division_1_size_3                                         0.125719
#
#                       $\frac{I_{873}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                      0.115941
# division_1_size_5                                         0.243989
# division_1_size_3                                         0.300787
#
#                       $\frac{I_{873}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                      0.116610
# division_1_size_5                                         0.247380
# division_1_size_3                                         0.293717
#
#                       $\frac{I_{1105}}{I_{1241}}$  \
# division_1_size_bulk                     1.497132
# division_1_size_5                        1.416250
# division_1_size_3                        2.085485
#
#                       $\frac{I_{1105}}{I_{1394}}$  \
# division_1_size_bulk                     0.895754
# division_1_size_5                        0.881708
# division_1_size_3                        1.200447
#
#                       $\frac{I_{1105}}{I_{1615}}$  \
# division_1_size_bulk                     0.681294
# division_1_size_5                        0.606138
# division_1_size_3                        0.836176
#
#                       $\frac{I_{1105}}{I_{1726}}$  \
# division_1_size_bulk                     1.614460
# division_1_size_5                        1.581111
# division_1_size_3                        2.280535
#
#                       $\frac{I_{1105}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.606214
# division_1_size_5                                              1.600446
# division_1_size_3                                              1.916666
#
#                       $\frac{I_{1105}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.202336
# division_1_size_5                                              0.189606
# division_1_size_3                                              0.245166
#
#                       $\frac{I_{1105}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.596961
# division_1_size_5                                               1.603523
# division_1_size_3                                               1.947485
#
#                       $\frac{I_{1105}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.479111
# division_1_size_5                                               0.438163
# division_1_size_3                                               0.611840
#
#                       $\frac{I_{1105}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.191626
# division_1_size_5                                               1.206561
# division_1_size_3                                               1.597240
#
#                       $\frac{I_{1105}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.895754
# division_1_size_5                                               0.881708
# division_1_size_3                                               1.200447
#
#                       $\frac{I_{1105}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.875098
# division_1_size_5                                              1.836785
# division_1_size_3                                              2.054544
#
#                       $\frac{I_{1105}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.575141
# division_1_size_5                                              0.538310
# division_1_size_3                                              0.620563
#
#                       $\frac{I_{1105}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     14.329951
# division_1_size_5                                         6.493216
# division_1_size_3                                         7.373961
#
#                       $\frac{I_{1105}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_bulk                                     14.218489
# division_1_size_5                                         6.308289
# division_1_size_3                                         7.331412
#
#                       $\frac{I_{1105}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.521652
# division_1_size_5                                          1.426482
# division_1_size_3                                          2.082966
#
#                       $\frac{I_{1105}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                       1.539031
# division_1_size_5                                          1.436714
# division_1_size_3                                          2.044041
#
#                       $\frac{I_{1105}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.922089
# division_1_size_5                                          0.907465
# division_1_size_3                                          1.231890
#
#                       $\frac{I_{1105}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                       0.988054
# division_1_size_5                                          0.978723
# division_1_size_3                                          1.323679
#
#                       $\frac{I_{1105}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                       0.721146
# division_1_size_5                                          0.646560
# division_1_size_3                                          0.873642
#
#                       $\frac{I_{1105}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                       0.805655
# division_1_size_5                                          0.729099
# division_1_size_3                                          0.952885
#
#                       $\frac{I_{1105}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                       1.638507
# division_1_size_5                                          1.609692
# division_1_size_3                                          2.279812
#
#                       $\frac{I_{1105}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                       1.647962
# division_1_size_5                                          1.632066
# division_1_size_3                                          2.226225
#
#                       $\frac{I_{1241}}{I_{1394}}$  \
# division_1_size_bulk                     0.598314
# division_1_size_5                        0.622566
# division_1_size_3                        0.575620
#
#                       $\frac{I_{1241}}{I_{1615}}$  \
# division_1_size_bulk                     0.455066
# division_1_size_5                        0.427988
# division_1_size_3                        0.400950
#
#                       $\frac{I_{1241}}{I_{1726}}$  \
# division_1_size_bulk                     1.078368
# division_1_size_5                        1.116407
# division_1_size_3                        1.093527
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.072861
# division_1_size_5                                              1.130060
# division_1_size_3                                              0.919050
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.135149
# division_1_size_5                                              0.133879
# division_1_size_3                                              0.117558
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.066680
# division_1_size_5                                               1.132232
# division_1_size_3                                               0.933828
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.320020
# division_1_size_5                                               0.309383
# division_1_size_3                                               0.293380
#
#                       $\frac{I_{1241}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.795939
# division_1_size_5                                               0.851941
# division_1_size_3                                               0.765884
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.598314
# division_1_size_5                                               0.622566
# division_1_size_3                                               0.575620
#
#                       $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.252460
# division_1_size_5                                              1.296936
# division_1_size_3                                              0.985163
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.384162
# division_1_size_5                                              0.380096
# division_1_size_3                                              0.297563
#
#                       $\frac{I_{1241}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                      9.571604
# division_1_size_5                                         4.584797
# division_1_size_3                                         3.535849
#
#                       $\frac{I_{1241}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_bulk                                      9.497153
# division_1_size_5                                         4.454221
# division_1_size_3                                         3.515446
#
#                       $\frac{I_{1241}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_bulk                                       0.724488
# division_1_size_5                                          0.720628
# division_1_size_3                                          0.491314
#
#                       $\frac{I_{1241}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_bulk                                       0.739552
# division_1_size_5                                          0.760579
# division_1_size_3                                          0.517952
#
#                       $\frac{I_{1241}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       0.615903
# division_1_size_5                                          0.640752
# division_1_size_3                                          0.590697
#
#                       $\frac{I_{1241}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                       0.659965
# division_1_size_5                                          0.691067
# division_1_size_3                                          0.634710
#
#                       $\frac{I_{1241}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                       0.481685
# division_1_size_5                                          0.456530
# division_1_size_3                                          0.418916
#
#                       $\frac{I_{1241}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                       0.538132
# division_1_size_5                                          0.514810
# division_1_size_3                                          0.456913
#
#                       $\frac{I_{1241}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                       1.094431
# division_1_size_5                                          1.136588
# division_1_size_3                                          1.093180
#
#                       $\frac{I_{1241}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                       1.100746
# division_1_size_5                                          1.152386
# division_1_size_3                                          1.067486
#
#                       $\frac{I_{1394}}{I_{1615}}$  \
# division_1_size_bulk                     0.760582
# division_1_size_5                        0.687458
# division_1_size_3                        0.696553
#
#                       $\frac{I_{1394}}{I_{1726}}$  \
# division_1_size_bulk                     1.802346
# division_1_size_5                        1.793236
# division_1_size_3                        1.899738
#
#                       $\frac{I_{1394}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.793141
# division_1_size_5                                              1.815165
# division_1_size_3                                              1.596626
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.225883
# division_1_size_5                                              0.215044
# division_1_size_3                                              0.204228
#
#                       $\frac{I_{1394}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.782811
# division_1_size_5                                               1.818655
# division_1_size_3                                               1.622300
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.534869
# division_1_size_5                                               0.496948
# division_1_size_3                                               0.509677
#
#                       $\frac{I_{1394}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.330305
# division_1_size_5                                               1.368435
# division_1_size_3                                               1.330538
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                 1.0
# division_1_size_5                                                    1.0
# division_1_size_3                                                    1.0
#
#                       $\frac{I_{1394}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.093317
# division_1_size_5                                              2.083211
# division_1_size_3                                              1.711482
#
#                       $\frac{I_{1394}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.642074
# division_1_size_5                                              0.610531
# division_1_size_3                                              0.516943
#
#                       $\frac{I_{1394}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     15.997634
# division_1_size_5                                         7.364358
# division_1_size_3                                         6.142679
#
#                       $\frac{I_{1394}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_bulk                                     15.873200
# division_1_size_5                                         7.154620
# division_1_size_3                                         6.107234
#
#                       $\frac{I_{1394}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_bulk                                       1.210884
# division_1_size_5                                          1.157513
# division_1_size_3                                          0.853539
#
#                       $\frac{I_{1394}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_bulk                                       1.236060
# division_1_size_5                                          1.221685
# division_1_size_3                                          0.899815
#
#                       $\frac{I_{1394}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.698738
# division_1_size_5                                          1.617862
# division_1_size_3                                          1.735159
#
#                       $\frac{I_{1394}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                       1.718140
# division_1_size_5                                          1.629467
# division_1_size_3                                          1.702733
#
#                       $\frac{I_{1394}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                       0.805071
# division_1_size_5                                          0.733303
# division_1_size_3                                          0.727764
#
#                       $\frac{I_{1394}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                       0.899415
# division_1_size_5                                          0.826916
# division_1_size_3                                          0.793775
#
#                       $\frac{I_{1394}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                       1.829193
# division_1_size_5                                          1.825651
# division_1_size_3                                          1.899135
#
#                       $\frac{I_{1394}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                       1.839747
# division_1_size_5                                          1.851027
# division_1_size_3                                          1.854497
#
#                       $\frac{I_{1615}}{I_{1726}}$  \
# division_1_size_bulk                     2.369695
# division_1_size_5                        2.608502
# division_1_size_3                        2.727339
#
#                       $\frac{I_{1615}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           2.357591
# division_1_size_5                                              2.640400
# division_1_size_3                                              2.292181
#
#                       $\frac{I_{1615}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.296987
# division_1_size_5                                              0.312811
# division_1_size_3                                              0.293199
#
#                       $\frac{I_{1615}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            2.344010
# division_1_size_5                                               2.645477
# division_1_size_3                                               2.329038
#
#                       $\frac{I_{1615}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.703237
# division_1_size_5                                               0.722877
# division_1_size_3                                               0.731712
#
#                       $\frac{I_{1615}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.749062
# division_1_size_5                                               1.990572
# division_1_size_3                                               1.910173
#
#                       $\frac{I_{1615}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.314783
# division_1_size_5                                               1.454634
# division_1_size_3                                               1.435640
#
#                       $\frac{I_{1615}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.752259
# division_1_size_5                                              3.030309
# division_1_size_3                                              2.457072
#
#                       $\frac{I_{1615}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.844189
# division_1_size_5                                              0.888099
# division_1_size_3                                              0.742145
#
#                       $\frac{I_{1615}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     21.033424
# division_1_size_5                                        10.712443
# division_1_size_3                                         8.818675
#
#                       $\frac{I_{1615}}{\overline{I}_{873 \pm 50}}$  \
# division_1_size_bulk                                     20.869820
# division_1_size_5                                        10.407351
# division_1_size_3                                         8.767790
#
#                       $\frac{I_{1615}}{\overline{I}_{1105 \pm 25}}$  \
# division_1_size_bulk                                       1.592050
# division_1_size_5                                          1.683757
# division_1_size_3                                          1.225375
#
#                       $\frac{I_{1615}}{\overline{I}_{1105 \pm 50}}$  \
# division_1_size_bulk                                       1.625151
# division_1_size_5                                          1.777105
# division_1_size_3                                          1.291811
#
#                       $\frac{I_{1615}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       2.233473
# division_1_size_5                                          2.353396
# division_1_size_3                                          2.491063
#
#                       $\frac{I_{1615}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                       2.258982
# division_1_size_5                                          2.370277
# division_1_size_3                                          2.444512
#
#                       $\frac{I_{1615}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                       1.353436
# division_1_size_5                                          1.497126
# division_1_size_3                                          1.473243
#
#                       $\frac{I_{1615}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                       1.450261
# division_1_size_5                                          1.614687
# division_1_size_3                                          1.583015
#
#                       $\frac{I_{1615}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                       2.404992
# division_1_size_5                                          2.655654
# division_1_size_3                                          2.726475
#
#                       $\frac{I_{1615}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                       2.418869
# division_1_size_5                                          2.692566
# division_1_size_3                                          2.662390
#
#                       $\frac{I_{1726}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           0.994892
# division_1_size_5                                              1.012229
# division_1_size_3                                              0.840446
#
#                       $\frac{I_{1726}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.125327
# division_1_size_5                                              0.119920
# division_1_size_3                                              0.107504
#
#                       $\frac{I_{1726}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.989161
# division_1_size_5                                               1.014175
# division_1_size_3                                               0.853960
#
#                       $\frac{I_{1726}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.296763
# division_1_size_5                                               0.277123
# division_1_size_3                                               0.268288
#
#                       $\frac{I_{1726}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.738096
# division_1_size_5                                               0.763109
# division_1_size_3                                               0.700380
#
#                       $\frac{I_{1726}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.554832
# division_1_size_5                                               0.557651
# division_1_size_3                                               0.526389
#
#                       $\frac{I_{1726}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.161440
# division_1_size_5                                              1.161705
# division_1_size_3                                              0.900904
#
#                       $\frac{I_{1726}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.356244
# division_1_size_5                                              0.340463
# division_1_size_3                                              0.272113
#
#                       $\frac{I_{1726}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                      8.876005
# ...
#
#                       $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                        0.050719
# division_1_size_5                                                           0.102494
# division_1_size_3                                                           0.119164
#
#                       $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                        0.056663
# division_1_size_5                                                           0.115578
# division_1_size_3                                                           0.129973
#
#                       $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                        0.115238
# division_1_size_5                                                           0.255171
# division_1_size_3                                                           0.310965
#
#                       $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                        0.115903
# division_1_size_5                                                           0.258718
# division_1_size_3                                                           0.303656
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                         1.402891
# division_1_size_5                                                            1.397705
# division_1_size_3                                                            2.032899
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                                         1.418914
# division_1_size_5                                                            1.407731
# division_1_size_3                                                            1.994910
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.850122
# division_1_size_5                                                            0.889158
# division_1_size_3                                                            1.202280
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                                         0.910939
# division_1_size_5                                                            0.958979
# division_1_size_3                                                            1.291862
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.664862
# division_1_size_5                                                            0.633516
# division_1_size_3                                                            0.852643
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.742776
# division_1_size_5                                                            0.714391
# division_1_size_3                                                            0.929981
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.510626
# division_1_size_5                                                            1.577219
# division_1_size_3                                                            2.225013
#
#                       $\frac{\overline{I}_{1105 \pm 25}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.519342
# division_1_size_5                                                            1.599141
# division_1_size_3                                                            2.172715
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                         1.374317
# division_1_size_5                                                            1.324287
# division_1_size_3                                                            1.928350
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1241 \pm 50}}$  \
# division_1_size_bulk                                                         1.390013
# division_1_size_5                                                            1.333786
# division_1_size_3                                                            1.892314
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.832807
# division_1_size_5                                                            0.842452
# division_1_size_3                                                            1.140448
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                                         0.892385
# division_1_size_5                                                            0.908606
# division_1_size_3                                                            1.225424
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.651320
# division_1_size_5                                                            0.600239
# division_1_size_3                                                            0.808793
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.727647
# division_1_size_5                                                            0.676865
# division_1_size_3                                                            0.882154
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.479858
# division_1_size_5                                                            1.494371
# division_1_size_3                                                            2.110584
#
#                       $\frac{\overline{I}_{1105 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.488396
# division_1_size_5                                                            1.515142
# division_1_size_3                                                            2.060975
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.605978
# division_1_size_5                                                            0.636156
# division_1_size_3                                                            0.591411
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                                         0.649330
# division_1_size_5                                                            0.686109
# division_1_size_3                                                            0.635478
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.473923
# division_1_size_5                                                            0.453255
# division_1_size_3                                                            0.419422
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.529461
# division_1_size_5                                                            0.511117
# division_1_size_3                                                            0.457465
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.076795
# division_1_size_5                                                            1.128435
# division_1_size_3                                                            1.094502
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.083008
# division_1_size_5                                                            1.144119
# division_1_size_3                                                            1.068776
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1394 \pm 25}}$  \
# division_1_size_bulk                                                         0.599136
# division_1_size_5                                                            0.631625
# division_1_size_3                                                            0.602674
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1394 \pm 50}}$  \
# division_1_size_bulk                                                         0.641997
# division_1_size_5                                                            0.681223
# division_1_size_3                                                            0.647579
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.468571
# division_1_size_5                                                            0.450027
# division_1_size_3                                                            0.427409
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.523482
# division_1_size_5                                                            0.507477
# division_1_size_3                                                            0.466177
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.064635
# division_1_size_5                                                            1.120398
# division_1_size_3                                                            1.115345
#
#                       $\frac{\overline{I}_{1241 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.070778
# division_1_size_5                                                            1.135971
# division_1_size_3                                                            1.089129
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.782078
# division_1_size_5                                                            0.712490
# division_1_size_3                                                            0.709188
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.873729
# division_1_size_5                                                            0.803446
# division_1_size_3                                                            0.773515
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.776952
# division_1_size_5                                                            1.773835
# division_1_size_3                                                            1.850661
#
#                       $\frac{\overline{I}_{1394 \pm 25}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.787205
# division_1_size_5                                                            1.798490
# division_1_size_3                                                            1.807162
#
#                       $\frac{\overline{I}_{1394 \pm 50}}{\overline{I}_{1615 \pm 25}}$  \
# division_1_size_bulk                                                         0.729864
# division_1_size_5                                                            0.660616
# division_1_size_3                                                            0.660011
#
#                       $\frac{\overline{I}_{1394 \pm 50}}{\overline{I}_{1615 \pm 50}}$  \
# division_1_size_bulk                                                         0.815396
# division_1_size_5                                                            0.744949
# division_1_size_3                                                            0.719876
#
#                       $\frac{\overline{I}_{1394 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         1.658317
# division_1_size_5                                                            1.644686
# division_1_size_3                                                            1.722330
#
#                       $\frac{\overline{I}_{1394 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         1.667886
# division_1_size_5                                                            1.667546
# division_1_size_3                                                            1.681847
#
#                       $\frac{\overline{I}_{1615 \pm 25}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         2.272090
# division_1_size_5                                                            2.489626
# division_1_size_3                                                            2.609548
#
#                       $\frac{\overline{I}_{1615 \pm 25}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         2.285200
# division_1_size_5                                                            2.524230
# division_1_size_3                                                            2.548211
#
#                       $\frac{\overline{I}_{1615 \pm 50}}{\overline{I}_{1726 \pm 25}}$  \
# division_1_size_bulk                                                         2.033758
# division_1_size_5                                                            2.207783
# division_1_size_3                                                            2.392536
#
#                       $\frac{\overline{I}_{1615 \pm 50}}{\overline{I}_{1726 \pm 50}}$  \
# division_1_size_bulk                                                         2.045493
# division_1_size_5                                                            2.238470
# division_1_size_3                                                            2.336300
#
#                       Split Fraction_hue Fraction_grouped_hue  Class
# division_1_size_bulk  Train        $> 0$              $d > 5$      2
# division_1_size_5     Train        $< 5$       $2 < d \leq 5$      1
# division_1_size_3     Train        $< 3$       $2 < d \leq 5$      1

# %% [markdown]
# ## Base parameters

# %%
type_color_dict = {
    '$d \leq 2$': '#2166AC',
    '$2 < d \leq 5$': '#67A9CF',
    '$d > 5$': '#B2182B'
}

# %%
groups = list(type_color_dict.keys())

# %%
sns.set_theme()

# %% [markdown]
# ## Dictionary for features mapping to type

# %%
feature_to_types = defaultdict(list)

for feature_type, features in features_description.items():
    for feature in features:
        feature_to_types[feature].append(feature_type)

# %% [markdown]
# ## Dictionary for mapping *class* to *size group*

# %%
class_fraction_group_dict = {
    0: r'$d \leq 2$',
    1: r'$2 < d \leq 5$',
    2: r'$d > 5$'
}

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Target rate analysis

# %% [markdown]
# Mapping hue ~ group:
# * Class 0 — $0< d \leq 2$
# * Class 1 — $2 < d \leq 5$
# * Class 2 — $d > 5$

# %%
fractions_hue_train_df = pd.DataFrame(dataset_train['Fraction_hue'].value_counts()).sort_values(by='Fraction_hue')
fractions_hue_test_df = pd.DataFrame(dataset_test['Fraction_hue'].value_counts()).sort_values(by='Fraction_hue')

display(fractions_hue_train_df.T, fractions_hue_test_df.T)
# Out:
# Fraction_hue  $< 0.2$  $< 0.4$  $< 2$  $< 2.5$  $< 25$  $< 3$  $< 4$  $< 5$  \
# count               3        6      6        6       4      6      1      6
#
# Fraction_hue  $< 50$  $< 70$  $< 75$  $> 0$
# count              1       3       1      7
# Fraction_hue  $< 0.2$  $< 0.4$  $< 2$  $< 2.5$  $< 25$  $< 3$  $< 5$  $< 75$  \
# count               4        2      2        2       2      4      4       2
#
# Fraction_hue  $> 0$
# count             3

# %%
target_rate_train_df = pd.DataFrame(dataset_train['Fraction_grouped_hue'].value_counts()).sort_values(by='Fraction_grouped_hue')
target_rate_test_df = pd.DataFrame(dataset_test['Fraction_grouped_hue'].value_counts()).sort_values(by='Fraction_grouped_hue')

display(target_rate_train_df.T, target_rate_test_df.T)
# Out:
# Fraction_grouped_hue  $2 < d \leq 5$  $d > 5$  $d \leq 2$
# count                             19       16          15
# Fraction_grouped_hue  $2 < d \leq 5$  $d > 5$  $d \leq 2$
# count                             10        7           8

# %% [markdown]
# ### Data wrangling

# %%
train = target_rate_train_df.copy()
test  = target_rate_test_df.copy()

train = train["count"].reset_index()
test  = test["count"].reset_index()
train.columns = ["bin", "count_train"]
test.columns  = ["bin", "count_test"]

bins_order = list(train["bin"])
bins_order += [b for b in test["bin"] if b not in bins_order]

df = (pd.DataFrame({"bin": bins_order})
      .merge(train, on="bin", how="left")
      .merge(test,  on="bin", how="left"))
df[["count_train", "count_test"]] = df[["count_train", "count_test"]].fillna(0).astype(int)

sum_tr, sum_te = df["count_train"].sum(), df["count_test"].sum()
df["freq_train"] = df["count_train"] * 100 / sum_tr if sum_tr else 0
df["freq_test"]  = df["count_test"] * 100  / sum_te if sum_te else 0

# %% [markdown]
# ### Visualization

# %%
fontsize = 14

train_color = "#08519c"
test_color  = "#1f77b4"
edge_color = "white"

# %%
fig, ax = plt.subplots(figsize=(10, 4), dpi=300)

x = np.arange(len(df))

width = 0.35

bars_train = ax.bar(x - width/2, df["freq_train"].values, width=width, label="Train", color=train_color, alpha=0.7, edgecolor=edge_color, linewidth=0.6)
bars_test  = ax.bar(x + width/2, df["freq_test"].values,  width=width, label="Test",  color=test_color, alpha=0.7,  edgecolor=edge_color, linewidth=0.6)

ax.set_xlabel("")
ax.set_ylabel("Relative frequency", fontsize=fontsize, labelpad=5)

ax.set_xticks(x, df["bin"])
ax.tick_params(axis='x', labelsize=fontsize)
ax.tick_params(axis='y', labelsize=fontsize-2)

# ax.yaxis.set_major_formatter(PercentFormatter(1.0))
ax.yaxis.set_major_locator(ticker.MaxNLocator(nbins=10))

# ax.legend(frameon=True, fontsize=fontsize-2, title_fontsize=fontsize, title='Dataset split')
ax.legend(frameon=True, fontsize=fontsize-2)

def annotate(container, values):
    for rect, val in zip(container, values):
        h = rect.get_height()
        ax.annotate(f"{int(val)}",
                    xy=(rect.get_x() + rect.get_width()/2, h),
                    xytext=(0, 0), textcoords="offset points",
                    ha="center", va="bottom", fontsize=fontsize-2, fontweight='normal')

annotate(bars_train, df["count_train"].values)
annotate(bars_test, df["count_test"].values)

plt.tight_layout()

plt.savefig(f"{path_to_save}/target_rate_barplot.svg", dpi=600)

plt.show()

# %% [markdown]
# ## *One-factor (OF)* analysis

# %% [markdown]
# ### *OF*-statictics calculation

# %%
def of_analysis(feature, features_df_train, target_train, features_df_test, target_test, n_bootstrap=50, C=1.0, random_state=42, n_splits=3, cv_shuffle=True):

    def safe_auc(y_true, proba):
        try:
            return roc_auc_score(y_true, proba, multi_class="ovr")
        except ValueError:
            return np.nan

    def fit_logreg_and_auc(X_tr, y_tr, X_te, y_te, C=1.0, rs=42, return_scale=False):
        scaler = StandardScaler().fit(X_tr)
        X_tr_s = scaler.transform(X_tr)
        X_te_s = scaler.transform(X_te)

        clf = OneVsRestClassifier(
            LogisticRegression(
                penalty="l2", C=C, solver="lbfgs", max_iter=10_000, random_state=rs
            )
        )
        clf.fit(X_tr_s, y_tr)

        auc_train = safe_auc(y_tr, clf.predict_proba(X_tr_s))
        auc_test  = safe_auc(y_te, clf.predict_proba(X_te_s))

        if return_scale:
            return auc_train, auc_test, float(scaler.mean_[0]), float(scaler.scale_[0])
        return auc_train, auc_test

    def bootstrap_block(X_source, y_train, X_test_raw, y_test, n_bs, C, rs=42):
        aucs_train, aucs_test = [], []
        for seed in range(n_bs):
            X_bs, y_bs = resample(X_source, y_train, replace=True, random_state=seed)
            a_tr, a_te = fit_logreg_and_auc(X_bs, y_bs, X_test_raw, y_test, C=C, rs=rs)
            aucs_train.append(a_tr)
            aucs_test.append(a_te)
        return np.asarray(aucs_train, float), np.asarray(aucs_test, float)

    def cv_block(X_train_raw, y_train, n_splits, shuffle, rs, C):
        skf = StratifiedKFold(n_splits=n_splits, shuffle=shuffle, random_state=rs)
        oof_scores = []
        for tr_idx, val_idx in skf.split(X_train_raw, y_train):
            X_tr, X_val = X_train_raw[tr_idx], X_train_raw[val_idx]
            y_tr, y_val = y_train[tr_idx], y_train[val_idx]

            scaler = StandardScaler().fit(X_tr)
            X_tr_s  = scaler.transform(X_tr)
            X_val_s = scaler.transform(X_val)

            clf = OneVsRestClassifier(
                LogisticRegression(
                    penalty="l2", C=C, solver="lbfgs", max_iter=10_000, random_state=rs
                )
            )
            clf.fit(X_tr_s, y_tr)
            proba_val = clf.predict_proba(X_val_s)
            oof_scores.append(safe_auc(y_val, proba_val))

        return np.asarray(oof_scores, float)

    def summarize(arr):
        arr = np.asarray(arr, float)
        if arr.size == 0:
            return np.nan, np.nan, np.nan
        return float(np.nanmean(arr)), float(np.nanpercentile(arr, 5)), float(np.nanpercentile(arr, 95))

    rng = np.random.default_rng(random_state)

    X_train_raw = features_df_train[[feature]].values
    y_train     = target_train.values
    X_test_raw  = features_df_test[[feature]].values
    y_test      = target_test.values

    # Глобальные (единственная подгонка на всём трейне)
    auc_global_train, auc_global_test, mean_val, std_val = fit_logreg_and_auc(
        X_train_raw, y_train, X_test_raw, y_test, C=C, rs=random_state, return_scale=True
    )

    # Бутстрэп
    bs_train, bs_test = bootstrap_block(
        X_train_raw, y_train, X_test_raw, y_test, n_bs=n_bootstrap, C=C, rs=random_state
    )
    bs_mean_train, bs_ci5_train, bs_ci95_train = summarize(bs_train)
    bs_mean_test,  bs_ci5_test,  bs_ci95_test  = summarize(bs_test)

    # Нoise baseline (перемешанный train)
    shuffled_train = rng.permutation(X_train_raw.ravel()).reshape(-1, 1)
    noise_train, noise_test = bootstrap_block(
        shuffled_train, y_train, X_test_raw, y_test, n_bs=n_bootstrap, C=C, rs=random_state
    )
    noise_mean_train, noise_ci5_train, noise_ci95_train = summarize(noise_train)
    noise_mean_test,  noise_ci5_test,  noise_ci95_test  = summarize(noise_test)

    # Δ и z-score
    delta_auc_train = bs_mean_train - noise_mean_train
    delta_auc_test  = bs_mean_test  - noise_mean_test
    std_noise_train = np.nanstd(noise_train)
    std_noise_test  = np.nanstd(noise_test)
    z_score_train = (delta_auc_train / std_noise_train) if std_noise_train > 0 else np.nan
    z_score_test  = (delta_auc_test  / std_noise_test)  if std_noise_test  > 0 else np.nan

    # CV-OOF
    cv_scores = cv_block(X_train_raw, y_train, n_splits=n_splits, shuffle=cv_shuffle, rs=random_state, C=C)
    cv_mean_train, cv_ci5_train, cv_ci95_train = summarize(cv_scores)

    return {
        "Feature": feature,
        "$scale-mean$": mean_val,
        "$scale-std$": std_val,
        "$C$": C,

        "$ROC-AUC_{ovr}^{global,train}$": auc_global_train,
        "$ROC-AUC_{ovr}^{global,test}$":  auc_global_test,

        "$ROC-AUC_{ovr}^{BS,train}$": bs_mean_train,
        "$CI_{5\\%}^{BS,train}$":     bs_ci5_train,
        "$CI_{95\\%}^{BS,train}$":    bs_ci95_train,
        "$ROC-AUC_{ovr}^{BS,test}$":  bs_mean_test,
        "$CI_{5\\%}^{BS,test}$":      bs_ci5_test,
        "$CI_{95\\%}^{BS,test}$":     bs_ci95_test,

        "$ROC-AUC_{ovr}^{CV,train}$": cv_mean_train,
        "$CI_{5\\%}^{CV,train}$":     cv_ci5_train,
        "$CI_{95\\%}^{CV,train}$":    cv_ci95_train,
        "$n_{folds}^{CV}$":           int(np.isfinite(cv_scores).sum()),

        "$ROC-AUC_{ovr}^{noise,train}$": noise_mean_train,
        "$CI_{5\\%}^{noise,train}$":     noise_ci5_train,
        "$CI_{95\\%}^{noise,train}$":    noise_ci95_train,
        "$ROC-AUC_{ovr}^{noise,test}$":  noise_mean_test,
        "$CI_{5\\%}^{noise,test}$":      noise_ci5_test,
        "$CI_{95\\%}^{noise,test}$":     noise_ci95_test,

        "$ΔROC-AUC^{train}$": delta_auc_train,
        "$ΔROC-AUC^{test}$":  delta_auc_test,
        "$z-score^{train}$":  z_score_train,
        "$z-score^{test}$":   z_score_test,

        "$n_{valid}^{BS,train}$":      int(np.isfinite(bs_train).sum()),
        "$n_{valid}^{BS,test}$":       int(np.isfinite(bs_test).sum()),
        "$n_{valid}^{noise,train}$":   int(np.isfinite(noise_train).sum()),
        "$n_{valid}^{noise,test}$":    int(np.isfinite(noise_test).sum()),
    }

# %%
# %%time

features_list = X_train.columns.tolist()

with tqdm_joblib(desc="Calculation progress", total=len(features_list)):
    results = Parallel(n_jobs=-1, backend="loky")(
        delayed(of_analysis)(
            feature,
            X_train,
            y_train,
            X_test,
            y_test,
            n_bootstrap=50,
            C=1.0,
        )
        for feature in features_list
    )
# Out:
# Calculation progress:   0%|          | 0/320 [00:00<?, ?it/s]
# CPU times: user 671 ms, sys: 172 ms, total: 844 ms
# Wall time: 14.5 s

# %%
of_metrics_df = pd.DataFrame(results).sort_values(
    by=[
        "$CI_{5\%}^{BS,train}$",
        "$ROC-AUC_{ovr}^{BS,train}$",
        "$ROC-AUC_{ovr}^{global,train}$"
    ],
    ascending=[
        False,
        False,
        False
    ]
)
print(of_metrics_df.shape)
of_metrics_df.head(3)
# Out:
# (320, 30)
#                                                             Feature  \
# 79                                       $\frac{I_{873}}{I_{1241}}$
# 93                     $\frac{I_{873}}{\overline{I}_{1241 \pm 25}}$
# 272  $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1241 \pm 25}}$
#
#      $scale-mean$  $scale-std$  $C$  $ROC-AUC_{ovr}^{global,train}$  \
# 79       0.405594     0.332484  1.0                        0.775395
# 93       0.403579     0.328337  1.0                        0.777230
# 272      0.404515     0.316297  1.0                        0.782390
#
#      $ROC-AUC_{ovr}^{global,test}$  $ROC-AUC_{ovr}^{BS,train}$  \
# 79                        0.828968                    0.790664
# 93                        0.835864                    0.792631
# 272                       0.823411                    0.794852
#
#      $CI_{5\%}^{BS,train}$  $CI_{95\%}^{BS,train}$  $ROC-AUC_{ovr}^{BS,test}$  \
# 79                0.705018                0.859617                   0.788775
# 93                0.702916                0.863322                   0.793364
# 272               0.692865                0.866683                   0.786365
#
#      $CI_{5\%}^{BS,test}$  $CI_{95\%}^{BS,test}$  $ROC-AUC_{ovr}^{CV,train}$  \
# 79               0.681968               0.835635                    0.757528
# 93               0.683864               0.840308                    0.759115
# 272              0.682189               0.825633                    0.757552
#
#      $CI_{5\%}^{CV,train}$  $CI_{95\%}^{CV,train}$  $n_{folds}^{CV}$  \
# 79                0.735202                0.786890                 3
# 93                0.735202                0.791176                 3
# 272               0.747374                0.769127                 3
#
#      $ROC-AUC_{ovr}^{noise,train}$  $CI_{5\%}^{noise,train}$  \
# 79                        0.595780                  0.507859
# 93                        0.597413                  0.508217
# 272                       0.605764                  0.547425
#
#      $CI_{95\%}^{noise,train}$  $ROC-AUC_{ovr}^{noise,test}$  \
# 79                    0.696738                      0.477434
# 93                    0.685937                      0.480825
# 272                   0.704462                      0.501071
#
#      $CI_{5\%}^{noise,test}$  $CI_{95\%}^{noise,test}$  $ΔROC-AUC^{train}$  \
# 79                  0.233254                  0.781413            0.194884
# 93                  0.233025                  0.786530            0.195218
# 272                 0.296695                  0.772300            0.189089
#
#      $ΔROC-AUC^{test}$  $z-score^{train}$  $z-score^{test}$  \
# 79            0.311341           3.833740          1.628731
# 93            0.312540           3.874300          1.650990
# 272           0.285294           3.742709          1.578354
#
#      $n_{valid}^{BS,train}$  $n_{valid}^{BS,test}$  $n_{valid}^{noise,train}$  \
# 79                       50                     50                         50
# 93                       50                     50                         50
# 272                      50                     50                         50
#
#      $n_{valid}^{noise,test}$
# 79                         50
# 93                         50
# 272                        50

# %% [markdown]
# ### *Hard-check* factor selection

# %%
of_features_to_save = (
    of_metrics_df
    .loc[
        (of_metrics_df['$CI_{5\%}^{BS,train}$'] >= 0.60)
        # & (of_metrics_df['$CI_{5\%}^{CV,train}$'] >= 0.55)
        & (of_metrics_df['$ROC-AUC_{ovr}^{global,train}$'] >= 0.60)
    ]['Feature']
).tolist()

print(
    f'Число фичей',
    f'(*) до отбора: {len(of_metrics_df["Feature"].unique())}',
    f'(*) после отбора: {len(of_features_to_save)}',
    f'Доля фичей, прошедших однофакторный отбор: {round(len(of_features_to_save) / len(of_metrics_df["Feature"].unique()) * 100, 2)}%',
    sep='\n'
)
# Out:
# Число фичей
# (*) до отбора: 320
# (*) после отбора: 28
# Доля фичей, прошедших однофакторный отбор: 8.75%

# %%
of_metrics_df = of_metrics_df.loc[of_metrics_df['Feature'].isin(of_features_to_save)]

print(of_metrics_df.shape)
of_metrics_df.head(3)
# Out:
# (28, 30)
#                                                             Feature  \
# 79                                       $\frac{I_{873}}{I_{1241}}$
# 93                     $\frac{I_{873}}{\overline{I}_{1241 \pm 25}}$
# 272  $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1241 \pm 25}}$
#
#      $scale-mean$  $scale-std$  $C$  $ROC-AUC_{ovr}^{global,train}$  \
# 79       0.405594     0.332484  1.0                        0.775395
# 93       0.403579     0.328337  1.0                        0.777230
# 272      0.404515     0.316297  1.0                        0.782390
#
#      $ROC-AUC_{ovr}^{global,test}$  $ROC-AUC_{ovr}^{BS,train}$  \
# 79                        0.828968                    0.790664
# 93                        0.835864                    0.792631
# 272                       0.823411                    0.794852
#
#      $CI_{5\%}^{BS,train}$  $CI_{95\%}^{BS,train}$  $ROC-AUC_{ovr}^{BS,test}$  \
# 79                0.705018                0.859617                   0.788775
# 93                0.702916                0.863322                   0.793364
# 272               0.692865                0.866683                   0.786365
#
#      $CI_{5\%}^{BS,test}$  $CI_{95\%}^{BS,test}$  $ROC-AUC_{ovr}^{CV,train}$  \
# 79               0.681968               0.835635                    0.757528
# 93               0.683864               0.840308                    0.759115
# 272              0.682189               0.825633                    0.757552
#
#      $CI_{5\%}^{CV,train}$  $CI_{95\%}^{CV,train}$  $n_{folds}^{CV}$  \
# 79                0.735202                0.786890                 3
# 93                0.735202                0.791176                 3
# 272               0.747374                0.769127                 3
#
#      $ROC-AUC_{ovr}^{noise,train}$  $CI_{5\%}^{noise,train}$  \
# 79                        0.595780                  0.507859
# 93                        0.597413                  0.508217
# 272                       0.605764                  0.547425
#
#      $CI_{95\%}^{noise,train}$  $ROC-AUC_{ovr}^{noise,test}$  \
# 79                    0.696738                      0.477434
# 93                    0.685937                      0.480825
# 272                   0.704462                      0.501071
#
#      $CI_{5\%}^{noise,test}$  $CI_{95\%}^{noise,test}$  $ΔROC-AUC^{train}$  \
# 79                  0.233254                  0.781413            0.194884
# 93                  0.233025                  0.786530            0.195218
# 272                 0.296695                  0.772300            0.189089
#
#      $ΔROC-AUC^{test}$  $z-score^{train}$  $z-score^{test}$  \
# 79            0.311341           3.833740          1.628731
# 93            0.312540           3.874300          1.650990
# 272           0.285294           3.742709          1.578354
#
#      $n_{valid}^{BS,train}$  $n_{valid}^{BS,test}$  $n_{valid}^{noise,train}$  \
# 79                       50                     50                         50
# 93                       50                     50                         50
# 272                      50                     50                         50
#
#      $n_{valid}^{noise,test}$
# 79                         50
# 93                         50
# 272                        50

# %% [markdown]
# ### Mapping features with their types

# %%
rows = []

for _, row in of_metrics_df.iterrows():
    feature = row['Feature']
    feature_types = feature_to_types.get(feature, [])

    for feature_type in feature_types:
        row_copy = row.copy()
        row_copy['Feature_Type'] = feature_type
        rows.append(row_copy)

of_metrics_expanded_df = pd.DataFrame(rows)

print(of_metrics_expanded_df.shape)
of_metrics_expanded_df.head(3)
# Out:
# (56, 31)
#                                          Feature  $scale-mean$  $scale-std$  \
# 79                    $\frac{I_{873}}{I_{1241}}$      0.405594     0.332484
# 79                    $\frac{I_{873}}{I_{1241}}$      0.405594     0.332484
# 93  $\frac{I_{873}}{\overline{I}_{1241 \pm 25}}$      0.403579     0.328337
#
#     $C$  $ROC-AUC_{ovr}^{global,train}$  $ROC-AUC_{ovr}^{global,test}$  \
# 79  1.0                        0.775395                       0.828968
# 79  1.0                        0.775395                       0.828968
# 93  1.0                        0.777230                       0.835864
#
#     $ROC-AUC_{ovr}^{BS,train}$  $CI_{5\%}^{BS,train}$  $CI_{95\%}^{BS,train}$  \
# 79                    0.790664               0.705018                0.859617
# 79                    0.790664               0.705018                0.859617
# 93                    0.792631               0.702916                0.863322
#
#     $ROC-AUC_{ovr}^{BS,test}$  $CI_{5\%}^{BS,test}$  $CI_{95\%}^{BS,test}$  \
# 79                   0.788775              0.681968               0.835635
# 79                   0.788775              0.681968               0.835635
# 93                   0.793364              0.683864               0.840308
#
#     $ROC-AUC_{ovr}^{CV,train}$  $CI_{5\%}^{CV,train}$  $CI_{95\%}^{CV,train}$  \
# 79                    0.757528               0.735202                0.786890
# 79                    0.757528               0.735202                0.786890
# 93                    0.759115               0.735202                0.791176
#
#     $n_{folds}^{CV}$  $ROC-AUC_{ovr}^{noise,train}$  $CI_{5\%}^{noise,train}$  \
# 79                 3                       0.595780                  0.507859
# 79                 3                       0.595780                  0.507859
# 93                 3                       0.597413                  0.508217
#
#     $CI_{95\%}^{noise,train}$  $ROC-AUC_{ovr}^{noise,test}$  \
# 79                   0.696738                      0.477434
# 79                   0.696738                      0.477434
# 93                   0.685937                      0.480825
#
#     $CI_{5\%}^{noise,test}$  $CI_{95\%}^{noise,test}$  $ΔROC-AUC^{train}$  \
# 79                 0.233254                  0.781413            0.194884
# 79                 0.233254                  0.781413            0.194884
# 93                 0.233025                  0.786530            0.195218
#
#     $ΔROC-AUC^{test}$  $z-score^{train}$  $z-score^{test}$  \
# 79           0.311341            3.83374          1.628731
# 79           0.311341            3.83374          1.628731
# 93           0.312540            3.87430          1.650990
#
#     $n_{valid}^{BS,train}$  $n_{valid}^{BS,test}$  $n_{valid}^{noise,train}$  \
# 79                      50                     50                         50
# 79                      50                     50                         50
# 93                      50                     50                         50
#
#     $n_{valid}^{noise,test}$                            Feature_Type
# 79                        50      engineered_features_peaks_1900_800
# 79                        50                     engineered_features
# 93                        50  engineered_features_intervals_1900_800

# %% [markdown]
# ### Visualization

# %%
train_color = "#08519c"
test_color  = "#1f77b4"

PLOT_STYLE = {
    'TITLE_FONT_SIZE': 18, 'TITLE_FONTSTYLE': 'normal',
    'X_LABEL_FONT_SIZE': 14, 'Y_TICK_LABEL_FONT_SIZE': 14,
    'X_LABELPAD': 8, 'X_NBINS': 8,
    'BAR_HEIGHT': 0.34, 'BAR_ALPHA': 0.7,
    'FIG_DPI': 300, 'SUBPLOT_WIDTH': 6, 'SUBPLOT_HEIGHT': 4.2,
    'TOP_N': 5, 'LEGEND_FONT_SIZE': 12, 'ERR_CAPSIZE': 3, 'ERR_LINEWIDTH': 1.4,
    'HUE_COLORS': {'train': train_color, 'test': test_color}
}

KEYS = {
    'bs_train': "$ROC-AUC_{ovr}^{BS,train}$",     'glob_train': "$ROC-AUC_{ovr}^{global,train}$",
    'bs_test': "$ROC-AUC_{ovr}^{BS,test}$",       'glob_test': "$ROC-AUC_{ovr}^{global,test}$",
    'ci5_train': "$CI_{5\\%}^{BS,train}$",        'ci95_train': "$CI_{95\\%}^{BS,train}$",
    'ci5_test': "$CI_{5\\%}^{BS,test}$",          'ci95_test': "$CI_{95\\%}^{BS,test}$",
    'cv_train': '$ROC-AUC_{ovr}^{CV,train}$',     'ci5_cv_train': '$CI_{5\%}^{CV,train}$',
    'ci95_cv_train': '$CI_{95\%}^{CV,train}$'
}

VISUAL_TYPE_LABELS = {'peaks': 'Peak-based', 'intervals': 'Region-based'}

# %%
def extract_base_and_range(feature_type: str):
    if not isinstance(feature_type, str):
        return None, None

    parts = feature_type.lower().split('_')

    # база (тип)
    if 'peaks' in parts:
        base = 'peaks'
    elif 'intervals' in parts:
        base = 'intervals'
    else:
        base = None

    # диапазон — две последние числовые части
    nums = [p for p in parts if re.fullmatch(r'\d+(?:\.\d+)?', p)]
    rng = None
    if len(nums) >= 2:
        a, b = float(nums[-2]), float(nums[-1])
        hi, lo = (max(a, b), min(a, b))
        def _fmt(x):
            xi = int(round(x))
            return str(xi) if abs(x - xi) < 1e-9 else f"{x:g}"
        rng = f"{_fmt(hi)}–{_fmt(lo)}"

    # валидируем базу по словарю визуальных меток
    if base not in VISUAL_TYPE_LABELS:
        base = None

    return base, rng


def group_sort_key(gr):
    base, rng = gr
    base_order = list(VISUAL_TYPE_LABELS.keys())
    base_idx = base_order.index(base) if base in base_order else len(base_order)

    hi = lo = None
    if isinstance(rng, str):
        m = re.findall(r'\d+(?:\.\d+)?', rng)
        if len(m) >= 2:
            a, b = float(m[0]), float(m[1])
            hi, lo = (max(a, b), min(a, b))

    # hi -> сортируем по убыванию (поэтому минус), lo -> по возрастанию
    return (base_idx, -(hi if hi is not None else -1e9), (lo if lo is not None else 1e9))


def panel_title_from_group(gr):
    base, rng = gr
    base_label = VISUAL_TYPE_LABELS.get(base, base or "")
    return f"{base_label} | {rng} cm$^{{-1}}$" if rng else base_label


def build_plot_df(subset: pd.DataFrame, top_n: int = 5):
    rows = []
    for _, row in subset.iterrows():
        feat = row.get('Feature')
        if pd.isna(feat):
            continue

        for split in ('train', 'test'):
            mean_col_bs = KEYS[f'bs_{split}']
            mean_col_glob = KEYS[f'glob_{split}']
            ci5_col = KEYS[f'ci5_{split}']
            ci95_col = KEYS[f'ci95_{split}']

            mean = row.get(mean_col_bs)
            ci5  = row.get(ci5_col)
            ci95 = row.get(ci95_col)

            # если bootstrap-метрик нет — используем global без ошибок
            if pd.isna(mean):
                mean = row.get(mean_col_glob)
                ci5, ci95 = np.nan, np.nan

            if pd.isna(mean):
                continue

            err_left  = float(mean - ci5)  if (ci5  is not None and not pd.isna(ci5))  else 0.0
            err_right = float(ci95 - mean) if (ci95 is not None and not pd.isna(ci95)) else 0.0

            rows.append({
                'Feature': feat,
                'Split': split,
                'mean': float(mean),
                'err_left': err_left,
                'err_right': err_right
            })

    plot_df = pd.DataFrame(rows)
    if plot_df.empty:
        return plot_df, []

    order_feats = (
        plot_df.groupby('Feature')['mean']
        .mean()
        .sort_values(ascending=False)
        .head(top_n)
        .index.tolist()
    )
    plot_df = plot_df[plot_df['Feature'].isin(order_feats)].copy()
    return plot_df, order_feats

# %%
tmp = of_metrics_expanded_df.copy()

tmp[['viz_base','viz_range']] = tmp['Feature_Type'].apply(lambda s: pd.Series(extract_base_and_range(s)))
tmp = tmp[tmp['viz_base'].isin(VISUAL_TYPE_LABELS) & tmp['viz_range'].notna()]

present_groups = sorted(tmp[['viz_base','viz_range']].drop_duplicates().itertuples(index=False, name=None), key=group_sort_key)

# %%
# --- layout ---
n = len(present_groups)
ncols = 2 if n > 1 else 1
nrows = math.ceil(n / ncols)
fig, axes = plt.subplots(nrows=nrows, ncols=ncols,
                         figsize=(ncols*PLOT_STYLE['SUBPLOT_WIDTH'], nrows*PLOT_STYLE['SUBPLOT_HEIGHT']),
                         dpi=PLOT_STYLE['FIG_DPI'])
axes = np.atleast_1d(axes).ravel()

# --- panels ---
for i, g in enumerate(present_groups):
    ax = axes[i]
    base, rng = g
    subset = tmp[(tmp['viz_base']==base) & (tmp['viz_range']==rng)].copy()
    plot_df, order_feats = build_plot_df(subset, PLOT_STYLE['TOP_N'])
    if plot_df.empty:
        ax.set_title(panel_title_from_group(g), fontsize=PLOT_STYLE['TITLE_FONT_SIZE'],
                     fontstyle=PLOT_STYLE['TITLE_FONTSTYLE'])
        ax.text(0.5,0.5,'no data',ha='center',va='center',fontsize=12,alpha=0.7)
        ax.set_axis_off()
        continue

    plot_df['Feature'] = pd.Categorical(plot_df['Feature'], categories=order_feats, ordered=True)
    y0 = np.arange(len(order_feats)); off = PLOT_STYLE['BAR_HEIGHT']/2

    for split, sign in (('train',-1),('test',+1)):
        sub = plot_df[plot_df['Split']==split].sort_values('Feature')
        y = y0 + sign*off
        xerr = np.vstack([sub['err_left'].to_numpy(), sub['err_right'].to_numpy()])
        ax.barh(y, sub['mean'], height=PLOT_STYLE['BAR_HEIGHT'], alpha=PLOT_STYLE['BAR_ALPHA'],
                label=split.capitalize(), color=PLOT_STYLE['HUE_COLORS'][split],
                xerr=xerr, error_kw={'capsize':PLOT_STYLE['ERR_CAPSIZE'], 'lw':PLOT_STYLE['ERR_LINEWIDTH']})

    ax.set_yticks(y0, labels=order_feats, fontsize=PLOT_STYLE['Y_TICK_LABEL_FONT_SIZE'])
    ax.invert_yaxis()
    ax.set_xlabel('$ROC\\!-\\!AUC_{ovr}$', fontsize=PLOT_STYLE['X_LABEL_FONT_SIZE'],
                  labelpad=PLOT_STYLE['X_LABELPAD'])
    ax.set_xlim(0,1)
    ax.set_title(panel_title_from_group(g), fontsize=PLOT_STYLE['TITLE_FONT_SIZE'],
                 fontstyle=PLOT_STYLE['TITLE_FONTSTYLE'])
    ax.xaxis.set_major_locator(ticker.MaxNLocator(nbins=PLOT_STYLE['X_NBINS']))
    ax.legend(loc='upper left', fontsize=PLOT_STYLE['LEGEND_FONT_SIZE'], frameon=True)

# hide unused axes
for j in range(len(present_groups), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()

plt.savefig(f'{path_to_save}/roc_auc_barplots.svg', dpi=600)

plt.show()

# %% [markdown]
# ## *Multi-factor* analysis

# %% [markdown]
# ### Functions for processing & config-parameters

# %% [markdown]
# #### Forward selection

# %%
def forward_selection_bootstrap(
    X_train: pd.DataFrame,
    y_train: pd.Series | np.ndarray,
    X_test: pd.DataFrame,
    y_test: pd.Series | np.ndarray,
    candidate_features: list[str],
    scoring: str = "roc_auc_ovr",          # 'roc_auc_ovr' | 'pr_auc'
    min_uplift: float | None = None,
    max_features: int | None = None,
    n_bootstrap: int = 50,
    n_jobs: int = -1,
    use_tqdm: bool = True,
    uplift_type: str = "mean",             # 'mean' | 'low' | 'high' — USED ONLY WHEN selection_mode='bootstrap'
    return_ci: bool = True,                # kept for compatibility; CI is always calculated in bootstrap mode
    random_state: int = 42,
    selection_mode: str = "bootstrap",     # 'bootstrap' | 'train'
):
    rng = np.random.RandomState(random_state)

    # convert targets to arrays/indices
    y_tr = np.asarray(y_train).ravel() if isinstance(y_train, (pd.Series, pd.DataFrame)) else np.asarray(y_train).ravel()
    y_te = np.asarray(y_test).ravel() if isinstance(y_test, (pd.Series, pd.DataFrame)) else np.asarray(y_test).ravel()

    # fix the set of classes (important for PR AUC / aligning probability column order)
    classes = np.unique(np.concatenate([y_tr, y_te]))

    def _score_metric(y_true, proba):
        try:
            if scoring == "roc_auc_ovr":
                return roc_auc_score(y_true, proba, multi_class="ovr", labels=classes)
            elif scoring == "pr_auc":
                y_bin = label_binarize(y_true, classes=classes)
                return average_precision_score(y_bin, proba, average="macro")
            else:
                raise ValueError(f"Unsupported metric: {scoring}")
        except Exception:
            return np.nan

    # Общий пайплайн обучение→прогноз→метрика
    def _fit_and_score(Xtr, ytr, Xte, seed):
        est = Pipeline([
            ("scaler", StandardScaler()),
            ("clf", OneVsRestClassifier(
                LogisticRegression(
                    penalty="l2",
                    C=1.0,
                    solver="lbfgs",
                    max_iter=10_000,
                    random_state=seed
                ),
                n_jobs=None
            ))
        ])
        est.fit(Xtr, ytr)
        proba_tr = est.predict_proba(Xtr)
        proba_te = est.predict_proba(Xte)
        if hasattr(est, "classes_"):
            order = [int(np.where(est.classes_ == c)[0][0]) for c in classes]
            proba_tr = proba_tr[:, order]
            proba_te = proba_te[:, order]
        train_metric = _score_metric(ytr, proba_tr)
        test_metric  = _score_metric(y_te, proba_te)
        return train_metric, test_metric

    selected: list[str] = []
    best_train_score = -np.inf
    history: list[dict] = []
    remain = list(candidate_features)

    # --- режим 1: bootstrap (как было) ---
    def bootstrap_scores(feature_set: list[str]):
        Xtr = X_train[feature_set].values
        Xte = X_test[feature_set].values

        def single_bootstrap(seed: int):
            idx = resample(np.arange(len(y_tr)), replace=True, random_state=seed)
            X_bs = Xtr[idx]
            y_bs = y_tr[idx]
            if np.unique(y_bs).size < 2:
                return np.nan, np.nan
            try:
                return _fit_and_score(X_bs, y_bs, Xte, seed)
            except Exception:
                return np.nan, np.nan

        seeds = rng.randint(0, 10**9, size=n_bootstrap)
        pairs = Parallel(n_jobs=n_jobs)(
            delayed(single_bootstrap)(int(s)) for s in seeds
        )
        pairs = np.asarray(pairs, dtype=float)
        train_scores = pairs[:, 0]
        test_scores  = pairs[:, 1]

        def _agg(x):
            return (np.nanmean(x), np.nanpercentile(x, 5), np.nanpercentile(x, 95))

        tr_mean, tr_low, tr_high = _agg(train_scores)
        te_mean, te_low, te_high = _agg(test_scores)
        return (tr_mean, tr_low, tr_high), (te_mean, te_low, te_high)

    # --- режим 2: plain train (без бутстрапа) ---
    def plain_train_scores(feature_set: list[str]):
        Xtr = X_train[feature_set].values
        Xte = X_test[feature_set].values
        try:
            tr, te = _fit_and_score(Xtr, y_tr, Xte, random_state)
        except Exception:
            tr, te = np.nan, np.nan
        # совместимость с полями *_mean/low/high
        return (tr, tr, tr), (te, te, te)

    step = 0
    while remain:
        step += 1
        iterator = tqdm(remain, desc=f"Step {step}") if use_tqdm else remain

        if selection_mode not in ("bootstrap", "train"):
            raise ValueError("selection_mode must be 'bootstrap' or 'train'")

        scorer = bootstrap_scores if selection_mode == "bootstrap" else plain_train_scores

        results = Parallel(n_jobs=n_jobs)(
            delayed(scorer)(selected + [feat]) for feat in iterator
        )

        candidates_info = []
        for feat, ((tr_m, tr_l, tr_h), (te_m, te_l, te_h)) in zip(remain, results):
            candidates_info.append({
                "feature":   feat,
                "train_mean": float(tr_m),
                "train_low":  float(tr_l),
                "train_high": float(tr_h),
                "test_mean":  float(te_m),
                "test_low":   float(te_l),
                "test_high":  float(te_h),
            })

        # ключ выбора
        if selection_mode == "bootstrap":
            if uplift_type == "mean":
                key = "train_mean"
            elif uplift_type == "low":
                key = "train_low"
            elif uplift_type == "high":
                key = "train_high"
            else:
                raise ValueError("uplift_type must be one of: 'mean', 'low', 'high'")
        else:
            # в train-режиме берем train_mean (он же = low = high)
            key = "train_mean"

        best_candidate = max(candidates_info, key=lambda x: (x[key], -np.inf if np.isnan(x[key]) else 0))

        uplift = best_candidate[key] - best_train_score
        if (min_uplift is not None) and (uplift < min_uplift):
            break

        selected.append(best_candidate["feature"])
        remain.remove(best_candidate["feature"])
        best_train_score = best_candidate[key]

        history.append({
            "feature":     best_candidate["feature"],
            "train_mean":  best_candidate["train_mean"],
            "train_low":   best_candidate["train_low"],
            "train_high":  best_candidate["train_high"],
            "test_mean":   best_candidate["test_mean"],
            "test_low":    best_candidate["test_low"],
            "test_high":   best_candidate["test_high"],
            "uplift_train": float(uplift),
            "n_selected":  len(selected),
            "selection_mode": selection_mode,   # NEW: для прозрачности в логе
        })

        if (max_features is not None) and (len(selected) >= max_features):
            break

    return selected, history

# %% [markdown]
# #### *Metric-uplift* line plot

# %%
def plot_cumulative_score_line_bootstrap(
    selection_log,
    ax=None,
    show_ci=True,
    show_test=True,
    annotate=True,
):
    # Prepare data
    df_log = pd.DataFrame(selection_log).copy()
    if df_log.empty:
        raise ValueError("selection_log is empty.")

    # Backward compatibility with old keys
    if {"score_mean", "score_low", "score_high"}.issubset(df_log.columns):
        df_log["train_mean"] = df_log["score_mean"]
        df_log["train_low"]  = df_log["score_low"]
        df_log["train_high"] = df_log["score_high"]

    req_train = {"train_mean", "train_low", "train_high"}
    if not req_train.issubset(df_log.columns):
        missing = req_train - set(df_log.columns)
        raise ValueError(f"Missing train columns: {missing}")

    df_log["Step"] = np.arange(1, len(df_log) + 1)

    created_fig = False
    if ax is None:
        fig, ax = plt.subplots(figsize=(max(6, len(df_log) * 1.2), 5), dpi=150)
        created_fig = True

    # Style from PLOT_STYLE (direct access)
    title           = PLOT_STYLE["TITLE"]
    title_fs        = PLOT_STYLE["TITLE_FONT_SIZE"]
    title_fs_style  = PLOT_STYLE["TITLE_FONTSTYLE"]
    x_label         = PLOT_STYLE["X_LABEL"]
    x_label_fs      = PLOT_STYLE["X_LABEL_FONT_SIZE"]
    x_labelpad      = PLOT_STYLE["X_LABELPAD"]
    y_label         = PLOT_STYLE["Y_LABEL"]
    y_label_fs      = PLOT_STYLE["Y_LABEL_FONT_SIZE"]
    y_labelpad      = PLOT_STYLE["Y_LABELPAD"]
    x_tick_fs       = PLOT_STYLE["X_TICK_LABEL_FONT_SIZE"]
    y_tick_fs       = PLOT_STYLE["Y_TICK_LABEL_FONT_SIZE"]
    metric_value_fs = PLOT_STYLE["METRIC_VALUE_FONT_SIZE"]

    # Fixed colors
    train_color = "#08519c"
    test_color  = "#1f77b4"

    # Train line
    line_train, = ax.plot(
        df_log["Step"],
        df_log["train_mean"],
        marker="o",
        linewidth=2,
        alpha=0.7,
        linestyle="-",
        label="Train",
        color=train_color,
    )
    if show_ci:
        ax.fill_between(
            df_log["Step"],
            df_log["train_low"],
            df_log["train_high"],
            alpha=0.20,
            color=train_color,
        )

    # Test line (nominal)
    line_test = None
    if show_test and {"test_mean","test_low","test_high"}.issubset(df_log.columns):
        line_test, = ax.plot(
            df_log["Step"],
            df_log["test_mean"],
            marker="s",
            linewidth=2,
            alpha=0.7,
            linestyle="-",
            label="Test",
            color=test_color,
        )
        if show_ci:
            ax.fill_between(
                df_log["Step"],
                df_log["test_low"],
                df_log["test_high"],
                alpha=0.20,
                color=test_color,
            )

    # Point annotations
    if annotate:
        for _, row in df_log.iterrows():
            ax.text(
                row["Step"],
                row["train_mean"] + 0.005,
                f'{row["train_mean"]:.3f}',
                ha="center",
                va="bottom",
                fontsize=metric_value_fs,
                color='black',
            )
        if line_test is not None:
            for _, row in df_log.iterrows():
                ax.text(
                    row["Step"],
                    row["test_mean"] - 0.020,
                    f'{row["test_mean"]:.3f}',
                    ha="center",
                    va="bottom",
                    fontsize=metric_value_fs,
                    color='black',
                )

    # Axes formatting
    ax.set_title(title, fontsize=title_fs, fontstyle=title_fs_style)
    ax.set_xlabel(x_label, fontsize=x_label_fs, labelpad=x_labelpad)
    ax.set_ylabel(y_label, fontsize=y_label_fs, labelpad=y_labelpad)
    ax.tick_params(axis="x", labelsize=x_tick_fs)
    ax.tick_params(axis="y", labelsize=y_tick_fs)

    # Exactly 10 ticks on Y
    ax.yaxis.set_major_locator(ticker.MaxNLocator(10))

    # Steps and labels
    ax.set_xticks(df_log["Step"])
    if "feature" in df_log.columns:
        ax.set_xticklabels(df_log["feature"], rotation=0)

    # Legend with only two line entries
    handles = [line_train] + ([line_test] if line_test is not None else [])
    labels = ["Train"] + (["Test"] if line_test is not None else [])
    ax.legend(handles, labels, loc="upper left", frameon=True)

    # Y limits padding
    y_candidates = [df_log["train_low"], df_log["train_high"], df_log["train_mean"]]
    if line_test is not None:
        y_candidates += [df_log["test_low"], df_log["test_high"], df_log["test_mean"]]
    y_min = np.nanmin([c.min() for c in y_candidates])
    y_max = np.nanmax([c.max() for c in y_candidates])
    if np.isfinite(y_min) and np.isfinite(y_max):
        pad = (y_max - y_min) * 0.06 if y_max > y_min else 0.02
        ax.set_ylim(y_min - pad, y_max + pad)

    if created_fig:
        plt.tight_layout()
        plt.show()

    return ax

# %% [markdown]
# ### Feature selection

# %%
candidate_features = []

for feature in of_features_to_save:
    feature_types_lst = feature_to_types[feature]
    for feature_type in feature_types_lst:
        candidate_features.append(feature)

print(f'Число фичей для многофакторного анализа: {len(candidate_features)}')
# Out:
# Число фичей для многофакторного анализа: 56

# %%
# %%time

selected_feats, selection_log = forward_selection_bootstrap(
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    candidate_features=candidate_features,
    scoring='roc_auc_ovr',
    min_uplift=0.020,
    max_features=5,
    n_bootstrap=50,
    uplift_type='low',  # 'mean', 'low', 'high'
    n_jobs=-1
)
# Out:
# Step 1:   0%|          | 0/56 [00:00<?, ?it/s]
# Step 2:   0%|          | 0/55 [00:00<?, ?it/s]
# Step 3:   0%|          | 0/54 [00:00<?, ?it/s]
# Step 4:   0%|          | 0/53 [00:00<?, ?it/s]
# Step 5:   0%|          | 0/52 [00:00<?, ?it/s]
# CPU times: user 458 ms, sys: 84.6 ms, total: 543 ms
# Wall time: 8.45 s

# %%
PLOT_STYLE = {
    'TITLE': '',
    'TITLE_FONT_SIZE': 12,
    'TITLE_FONTSTYLE': 'normal',
    'X_LABEL': '',
    'Y_LABEL': '$ROC-AUC_{ovr}$',
    'X_LABEL_FONT_SIZE': 12,
    'Y_LABEL_FONT_SIZE': 12,
    'X_TICK_LABEL_FONT_SIZE': 16,
    'Y_TICK_LABEL_FONT_SIZE': 10,
    'X_LABELPAD': 10,
    'Y_LABELPAD': 10,
    'METRIC_VALUE_FONT_SIZE': 8,
    'Y_NBINS': 10
}

# %%
fig, ax = plt.subplots(figsize=(8, 4), dpi=300)

plot_cumulative_score_line_bootstrap(
    selection_log=selection_log,
    ax=ax,
    show_ci=True
)

plt.tight_layout()
plt.savefig(f'{path_to_save}/fs_uplift_lineplot_bootstrap.svg', dpi=600)
plt.show()

# %% [markdown]
# ## Models analysis

# %% [markdown]
# ### Functions for processing

# %% [markdown]
# #### Modeling process (*scaling, `lr` fitting, cross-validation, metrics calculation*)

# %%
def logreg_bootstrap_train_test(
    X_train: pd.DataFrame,
    y_train: pd.Series,
    X_test: pd.DataFrame,
    y_test: pd.Series,
    feature_list=None,
    C_values=None,
    n_bootstrap: int = 50,
    random_state: int = 42,
    reoptimize_C_on_bootstrap: bool = True,
    solver: str = "lbfgs",
    max_iter: int = 10_000,
):
    # ---- feature selection & alignment ----
    if feature_list is not None:
        feature_list = list(feature_list)
        missing_train = [f for f in feature_list if f not in X_train.columns]
        missing_test  = [f for f in feature_list if f not in X_test.columns]
        if missing_train or missing_test:
            raise ValueError(
                f"Selected features missing:\n"
                f"- in X_train: {missing_train}\n"
                f"- in X_test : {missing_test}"
            )
        X_train_use = X_train.loc[:, feature_list].copy()
        X_test_use  = X_test.loc[:, feature_list].copy()
    else:
        # If not provided, use the intersection to be safe and keep consistent order from X_train
        common = [c for c in X_train.columns if c in X_test.columns]
        if not common:
            raise ValueError("No common features between X_train and X_test.")
        feature_list = common
        X_train_use = X_train.loc[:, feature_list].copy()
        X_test_use  = X_test.loc[:, feature_list].copy()

    # ---- grids and classes ----
    if C_values is None:
        C_values = np.logspace(-4, 4, 30)

    classes = np.unique(y_train)

    def optimize_C(X_tr_scaled, y_tr, C_grid, scoring='roc_auc'):
        """Tune C by maximizing macro ROC-AUC on the (scaled) training set."""
        scores = []
        for C in C_grid:
            clf = OneVsRestClassifier(
                LogisticRegression(C=C, solver=solver, max_iter=max_iter)
            )
            clf.fit(X_tr_scaled, y_tr)
            proba = clf.predict_proba(X_tr_scaled)
            score = roc_auc_score(y_tr, proba, multi_class='ovr', average='macro')
            scores.append(score)
        c_metric_df_ = pd.DataFrame({'C': C_grid, scoring: scores})
        best_C_ = c_metric_df_.loc[c_metric_df_[scoring].idxmax(), 'C']
        return best_C_, c_metric_df_

    def compute_metrics(y_true, proba, classes_):
        """Return macro ROC-AUC (OvR) and macro PR-AUC for multiclass."""
        roc = roc_auc_score(y_true, proba, multi_class='ovr', average='macro')
        Y_bin = label_binarize(y_true, classes=classes_)
        pr = average_precision_score(Y_bin, proba, average='macro')
        return roc, pr

    def ci_percentile(data, lower=5, upper=95):
        """Percentile-based confidence interval."""
        return float(np.percentile(data, lower)), float(np.percentile(data, upper))

    # ---- final model (tune C on full train, fit once) ----
    scaler = StandardScaler().fit(X_train_use.values)
    X_tr_scaled = scaler.transform(X_train_use.values)
    X_te_scaled = scaler.transform(X_test_use.values)

    best_C_full, c_metric_df = optimize_C(X_tr_scaled, y_train.values, C_values)

    clf_full = OneVsRestClassifier(
        LogisticRegression(C=best_C_full, solver=solver, max_iter=max_iter)
    )
    clf_full.fit(X_tr_scaled, y_train.values)

    proba_tr = clf_full.predict_proba(X_tr_scaled)
    proba_te = clf_full.predict_proba(X_te_scaled)

    roc_train_point, pr_train_point = compute_metrics(y_train.values, proba_tr, classes)
    roc_test_point,  pr_test_point  = compute_metrics(y_test.values,  proba_te, classes)

    # ---- coefficients & scaler summary ----
    coef_df = pd.DataFrame(
        [est.coef_.flatten() for est in clf_full.estimators_],
        columns=feature_list,
        index=[f'Class {c}' for c in clf_full.classes_]
    )
    coef_df['Intercept'] = [float(est.intercept_[0]) for est in clf_full.estimators_]

    scaler_df = pd.DataFrame({'Feature': feature_list, 'Mean': scaler.mean_, 'Std': scaler.scale_})

    # ---- bootstrap: CIs for train and test ----
    rng = np.random.RandomState(random_state)
    roc_train_boot, pr_train_boot = [], []
    roc_test_boot,  pr_test_boot  = [], []

    n = len(X_train_use)
    X_te_np = X_test_use.values
    y_te_np = y_test.values

    for _ in tqdm(range(n_bootstrap), desc="Calculation progress"):
        # resample indices with replacement from training set
        idx = rng.choice(n, size=n, replace=True)
        Xb = X_train_use.values[idx]
        yb = y_train.values[idx]

        # fit scaler on bootstrap sample to avoid leakage
        scaler_b = StandardScaler().fit(Xb)
        Xb_scaled = scaler_b.transform(Xb)
        Xte_scaled_b = scaler_b.transform(X_te_np)

        # optionally re-tune C inside bootstrap
        if reoptimize_C_on_bootstrap:
            C_b, _ = optimize_C(Xb_scaled, yb, C_values)
        else:
            C_b = best_C_full

        clf_b = OneVsRestClassifier(
            LogisticRegression(C=C_b, solver=solver, max_iter=max_iter)
        )
        clf_b.fit(Xb_scaled, yb)

        proba_b_tr = clf_b.predict_proba(Xb_scaled)
        proba_b_te = clf_b.predict_proba(Xte_scaled_b)

        roc_tr_b, pr_tr_b = compute_metrics(yb, proba_b_tr, classes)
        roc_te_b, pr_te_b = compute_metrics(y_te_np, proba_b_te, classes)

        roc_train_boot.append(roc_tr_b)
        pr_train_boot.append(pr_tr_b)
        roc_test_boot.append(roc_te_b)
        pr_test_boot.append(pr_te_b)

    metrics_df = pd.DataFrame({
        'ROC-AUC (macro, OvR)': {
            'Train point': round(roc_train_point, 6),
            'Test point' : round(roc_test_point,  6),
            'Train CI 5–95%': [round(x, 6) for x in ci_percentile(roc_train_boot)],
            'Test  CI 5–95%': [round(x, 6) for x in ci_percentile(roc_test_boot)],
        },
        'PR-AUC (macro)': {
            'Train point': round(pr_train_point, 6),
            'Test point' : round(pr_test_point,  6),
            'Train CI 5–95%': [round(x, 6) for x in ci_percentile(pr_train_boot)],
            'Test  CI 5–95%': [round(x, 6) for x in ci_percentile(pr_test_boot)],
        }
    })

    return clf_full, X_tr_scaled, X_te_scaled, scaler, coef_df, scaler_df, metrics_df, best_C_full, c_metric_df

# %% [markdown]
# #### `C` optimaztion visualization

# %%
def plot_c_metric_curve(c_metric_df, metric_name='roc_auc', best_C=None, ax=None):
    external_ax = ax is not None
    fig, ax = plt.subplots(figsize=PLOT_STYLE['FIGSIZE'], dpi=300) if not external_ax else (None, ax)

    sns.lineplot(
        data=c_metric_df,
        x='C',
        y=metric_name,
        color='teal',
        linewidth=3.5,
        ax=ax
    )

    ax.set_xscale('log')

    if best_C is not None:
        best_y = c_metric_df.loc[c_metric_df['C'] == best_C, metric_name].values
        if len(best_y):
            ax.axvline(x=best_C, color='darkred', linestyle='--', linewidth=1.8)
            ax.scatter(best_C, best_y[0], color='darkred', s=50, zorder=5)

    ax.set_title(PLOT_STYLE['TITLE'], fontsize=PLOT_STYLE['TITLE_FONT_SIZE'], fontstyle=PLOT_STYLE['TITLE_FONTSTYLE'])
    
    ax.set_xlabel(PLOT_STYLE['X_LABEL'], fontsize=PLOT_STYLE['X_LABEL_FONT_SIZE'], labelpad=PLOT_STYLE['X_LABELPAD'])
    ax.set_ylabel(PLOT_STYLE['Y_LABEL'], fontsize=PLOT_STYLE['Y_LABEL_FONT_SIZE'], labelpad=PLOT_STYLE['Y_LABELPAD'])
    
    ax.tick_params(axis='x', labelsize=PLOT_STYLE['X_TICK_LABEL_FONT_SIZE'])
    ax.tick_params(axis='y', labelsize=PLOT_STYLE['Y_TICK_LABEL_FONT_SIZE'])

    if not external_ax:
        plt.tight_layout()
        plt.show()

# %% [markdown]
# #### *ROC*-curves visualization

# %%
def plot_roc_curve_per_class(
    model, 
    X_train, y_train, 
    X_test, y_test, 
    class_index, ax
):
    classes = model.classes_
    y_train_bin = label_binarize(y_train, classes=classes)
    y_test_bin  = label_binarize(y_test,  classes=classes)

    # predict probabilities
    y_score_train = model.predict_proba(X_train)
    y_score_test  = model.predict_proba(X_test)

    # compute ROC curve
    fpr_tr, tpr_tr, _ = roc_curve(y_train_bin[:, class_index], y_score_train[:, class_index])
    fpr_te, tpr_te, _ = roc_curve(y_test_bin[:, class_index],  y_score_test[:,  class_index])

    # compute AUC
    auc_tr = auc(fpr_tr, tpr_tr)
    auc_te = auc(fpr_te, tpr_te)

    class_label = class_fraction_group_dict[class_index]
    class_color = type_color_dict[class_label]

    # plot train curve
    ax.plot(
        fpr_tr, tpr_tr,
        color=class_color,
        linewidth=PLOT_STYLE['LINE_WIDTH'],
        linestyle='-',
        label=fr'$ROC\text{{-}}AUC^{{train}} = {auc_tr:.2f}$'
    )

    # plot test curve
    ax.plot(
        fpr_te, tpr_te,
        color=class_color,
        linewidth=PLOT_STYLE['LINE_WIDTH'],
        linestyle='--',
        label=fr'$ROC\text{{-}}AUC^{{test}} = {auc_te:.2f}$'
    )

    # random baseline
    ax.plot([0, 1], [0, 1], linestyle=':', color='gray', linewidth=1, label='')

    # formatting
    ax.set_title(class_label, fontsize=PLOT_STYLE['TITLE_FONT_SIZE'], fontstyle=PLOT_STYLE['TITLE_FONTSTYLE'])
    ax.set_xlabel(PLOT_STYLE['X_LABEL'], fontsize=PLOT_STYLE['X_LABEL_FONT_SIZE'], labelpad=PLOT_STYLE['X_LABELPAD'])
    ax.set_ylabel(PLOT_STYLE['Y_LABEL'], fontsize=PLOT_STYLE['Y_LABEL_FONT_SIZE'], labelpad=PLOT_STYLE['Y_LABELPAD'])

    ax.tick_params(axis='x', labelsize=PLOT_STYLE['X_TICK_LABEL_FONT_SIZE'])
    ax.tick_params(axis='y', labelsize=PLOT_STYLE['Y_TICK_LABEL_FONT_SIZE'])

    if 'X_NBINS' in PLOT_STYLE:
        ax.xaxis.set_major_locator(ticker.MaxNLocator(nbins=PLOT_STYLE['X_NBINS']))
    if 'Y_NBINS' in PLOT_STYLE:
        ax.yaxis.set_major_locator(ticker.MaxNLocator(nbins=PLOT_STYLE['Y_NBINS']))

    ax.legend(loc='lower right', fontsize=PLOT_STYLE['LEGEND_FONT_SIZE'])

# %% [markdown]
# #### *SHAP*-values visualization (*beeswarm*)

# %%
def plot_shap_summary_logreg(
    model,
    X_train_scaled: pd.DataFrame,
    X_test_scaled: pd.DataFrame,
    features_lst: list[str],
    class_index: int = 0,
    max_display: int = 20,
    show_colorbar: bool = True,
    ax=None
):
    """
    Build a SHAP summary (beeswarm) for a multinomial One-vs-Rest LogisticRegression (or plain LogisticRegression)
    using a merged dataset of train + test.

    Parameters
    ----------
    model : fitted estimator
        Either OneVsRestClassifier(LogisticRegression) or LogisticRegression.
    X_train_scaled : pd.DataFrame
        Scaled train features. Must have the same columns and order as test.
    X_test_scaled : pd.DataFrame
        Scaled test features. Must have the same columns and order as train.
    features_lst : list[str]
        Feature names in the order matching columns of X_*_scaled.
    class_index : int
        Index of the class to explain when model is OneVsRestClassifier.
    max_display : int
        Max number of features to display in the beeswarm.
    show_colorbar : bool
        Whether to show SHAP colorbar.
    ax : matplotlib.axes.Axes | None
        Axis to draw on. If None, a new figure/axis is created.

    Notes
    -----
    - We merge X_train and X_test vertically and compute SHAP values on the merged matrix.
    - Color encodes feature values (default SHAP behavior).
    - If your model is OVR, we pick `estimators_[class_index]`.
    """

    # pick base binary logistic regression if it is OneVsRestClassifier
    base_model = model.estimators_[class_index] if hasattr(model, 'estimators_') else model

    # sanity checks on columns
    if list(X_train_scaled.columns) != list(X_test_scaled.columns):
        raise ValueError("Train/Test columns (order) must match exactly.")
    if features_lst and list(X_train_scaled.columns) != list(features_lst):
        # keep behavior predictable: columns should match features_lst
        raise ValueError("features_lst must match X_*_scaled columns order.")

    # merge train + test by rows
    X_merged = pd.concat([X_train_scaled, X_test_scaled], axis=0, ignore_index=True)

    # build explainer on merged data (interventional background = merged)
    explainer = shap.LinearExplainer(base_model, X_merged, feature_perturbation='interventional')

    # compute SHAP values for merged matrix
    shap_values = explainer(X_merged)
    shap_values.feature_names = list(features_lst)

    # figure/axis handling
    external_ax = ax is not None
    fig, ax = plt.subplots(figsize=PLOT_STYLE['FIGSIZE']) if ax is None else (plt.gcf(), ax)

    # draw beeswarm for merged data
    shap.plots.beeswarm(
        shap_values,
        max_display=max_display,
        show=False,
        color_bar=show_colorbar,
        ax=ax,
        s=PLOT_STYLE.get('DOT_SIZE', 12),
        plot_size=None
    )

    # titles/labels/ticks styling
    ax.set_title(
        PLOT_STYLE['TITLE'],
        fontsize=PLOT_STYLE['TITLE_FONT_SIZE'],
        fontstyle=PLOT_STYLE['TITLE_FONTSTYLE']
    )
    ax.set_xlabel(
        PLOT_STYLE['X_LABEL'],
        fontsize=PLOT_STYLE['X_LABEL_FONT_SIZE'],
        labelpad=PLOT_STYLE['X_LABELPAD']
    )
    ax.set_ylabel(
        PLOT_STYLE['Y_LABEL'],
        fontsize=PLOT_STYLE['Y_LABEL_FONT_SIZE'],
        labelpad=PLOT_STYLE['Y_LABELPAD']
    )
    ax.tick_params(axis='x', labelsize=PLOT_STYLE['X_TICK_LABEL_FONT_SIZE'])
    ax.tick_params(axis='y', labelsize=PLOT_STYLE['Y_TICK_LABEL_FONT_SIZE'])

    if 'X_NBINS' in PLOT_STYLE:
        ax.xaxis.set_major_locator(ticker.MaxNLocator(nbins=PLOT_STYLE['X_NBINS']))

    # style SHAP colorbar (which SHAP draws as a separate axis) if present
    if show_colorbar:
        current_fig = plt.gcf()
        for other_ax in current_fig.axes:
            # heuristic: SHAP colorbar axis has no xticks and has yticks
            if other_ax is not ax and len(other_ax.get_xticks()) == 0 and len(other_ax.get_yticks()) > 0:
                other_ax.set_ylabel(PLOT_STYLE['LEGEND_TITLE'], fontsize=PLOT_STYLE['LEGEND_FONT_SIZE'])
                other_ax.tick_params(labelsize=PLOT_STYLE['LEGEND_FONT_SIZE'])
                if 'COLORBAR_TICKS' in PLOT_STYLE:
                    other_ax.set_yticklabels(PLOT_STYLE['COLORBAR_TICKS'])

    if not external_ax:
        plt.tight_layout()
        plt.show()

# %% [markdown]
# ### Model investigation

# %% [markdown]
# #### Model fitting

# %%
model, X_tr_scaled, X_te_scaled, scaler, coef_df, scaler_df, metrics_df, best_C_full, c_metric_df = logreg_bootstrap_train_test(
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    feature_list=selected_feats,
    C_values=np.logspace(-8, 8, 50),
    n_bootstrap=50,
    random_state=42
)
# Out:
# Calculation progress:   0%|          | 0/50 [00:00<?, ?it/s]

# %%
X_tr_scaled = pd.DataFrame(X_tr_scaled, columns=selected_feats)

print(X_tr_scaled.shape)
X_tr_scaled.head(3)
# Out:
# (50, 5)
#    $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1241 \pm 25}}$  \
# 0                                                       -0.940558
# 1                                                       -0.563985
# 2                                                       -0.380654
#
#    $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# 0                                                             0.201877
# 1                                                             0.060385
# 2                                                             0.553800
#
#    $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1394 \pm 50}}$  \
# 0                                                             -0.026680
# 1                                                             -0.053351
# 2                                                              0.168054
#
#    $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# 0                                           0.053595
# 1                                           0.021350
# 2                                          -0.633113
#
#    $\frac{I_{873}}{\overline{I}_{1726 \pm 25}}$
# 0                                     -0.871061
# 1                                     -0.724136
# 2                                     -0.658964

# %%
X_te_scaled = pd.DataFrame(X_te_scaled, columns=selected_feats)

print(X_te_scaled.shape)
X_te_scaled.head(3)
# Out:
# (25, 5)
#    $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1241 \pm 25}}$  \
# 0                                                       -0.974368
# 1                                                       -0.843456
# 2                                                       -0.019887
#
#    $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# 0                                                             0.702868
# 1                                                             1.061296
# 2                                                            -0.291900
#
#    $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1394 \pm 50}}$  \
# 0                                                              0.480546
# 1                                                             -0.333075
# 2                                                             -0.436074
#
#    $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# 0                                           0.026471
# 1                                          -0.319682
# 2                                           0.034162
#
#    $\frac{I_{873}}{\overline{I}_{1726 \pm 25}}$
# 0                                     -0.937892
# 1                                     -0.909953
# 2                                     -0.235746

# %% [markdown]
# *Parameters for scaling*

# %%
display(scaler_df.T)
# Out:
#                                                                       0  \
# Feature  $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1241 \pm 25}}$
# Mean                                                           0.404515
# Std                                                            0.316297
#
#                                                                            1  \
# Feature  $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1241 \pm 25}}$
# Mean                                                                0.867381
# Std                                                                 0.396143
#
#                                                                             2  \
# Feature  $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1394 \pm 50}}$
# Mean                                                                 0.627063
# Std                                                                   0.31313
#
#                                                          3  \
# Feature  $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$
# Mean                                              0.377403
# Std                                               0.126107
#
#                                                     4
# Feature  $\frac{I_{873}}{\overline{I}_{1726 \pm 25}}$
# Mean                                         0.875084
# Std                                          0.871516

# %% [markdown]
# *Model parameters (weights & intercept)*

# %%
display(coef_df)
# Out:
#          $\frac{\overline{I}_{873 \pm 50}}{\overline{I}_{1241 \pm 25}}$  \
# Class 0                                                        0.334137
# Class 1                                                       -0.049912
# Class 2                                                      -28.784419
#
#          $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# Class 0                                                             1.164741
# Class 1                                                             0.540739
# Class 2                                                           -86.882913
#
#          $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1394 \pm 50}}$  \
# Class 0                                                             -0.204188
# Class 1                                                              0.928084
# Class 2                                                            -48.767376
#
#          $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# Class 0                                          -0.649605
# Class 1                                           0.046655
# Class 2                                          38.337531
#
#          $\frac{I_{873}}{\overline{I}_{1726 \pm 25}}$  Intercept
# Class 0                                      1.000139  -1.370590
# Class 1                                      0.402939  -0.537909
# Class 2                                    -77.732467 -75.426731

# %% [markdown]
# *Model metrics*

# %%
display(metrics_df)
# Out:
#                 ROC-AUC (macro, OvR)        PR-AUC (macro)
# Train point                 0.918342                0.8411
# Test point                  0.851373              0.753303
# Train CI 5–95%  [0.896402, 0.974691]  [0.826865, 0.953919]
# Test  CI 5–95%  [0.748629, 0.903765]  [0.645495, 0.853131]

# %% [markdown]
# *Optimal inverse of regulation strength value*

# %% [markdown]
# #### Visualization of `C` optimization

# %%
print(f'Optimal value of regularization coefficient (C): {round(best_C_full, 4)}')
# Out:
# Optimal value of regularization coefficient (C): 517947.4679

# %%
PLOT_STYLE = {
    'FIGSIZE': (10, 3.3),
    'TITLE': '',
    'TITLE_FONT_SIZE': 14,
    'TITLE_FONTSTYLE': 'normal',
    'X_LABEL': 'Обратный коэффициент регуляризации ($C$)',
    'Y_LABEL': '$ROC-AUC_{ovr}$',
    'X_LABEL_FONT_SIZE': 12,
    'Y_LABEL_FONT_SIZE': 12,
    'X_LABELPAD': 6,
    'Y_LABELPAD': 6,
    'X_TICK_LABEL_FONT_SIZE': 12,
    'Y_TICK_LABEL_FONT_SIZE': 11
}

# %%
fig, ax = plt.subplots(figsize=PLOT_STYLE['FIGSIZE'], dpi=300)

plot_c_metric_curve(
    c_metric_df=c_metric_df,
    metric_name='roc_auc',
    best_C=best_C_full,
    ax=ax
)

plt.tight_layout()

plt.savefig(f'{path_to_save}/c_optimization_curve.svg', dpi=600)

plt.show()

# %% [markdown]
# #### *ROC*-curves visualization

# %%
PLOT_STYLE = {
    'FIGSIZE': (10, 4),
    'TITLE_FONT_SIZE': 16,
    'TITLE_FONTSTYLE': 'normal',
    'X_LABEL': 'False Positive Rate',
    'Y_LABEL': 'True Positive Rate',
    'X_LABEL_FONT_SIZE': 14,
    'Y_LABEL_FONT_SIZE': 14,
    'X_TICK_LABEL_FONT_SIZE': 12,
    'Y_TICK_LABEL_FONT_SIZE': 12,
    'X_LABELPAD': 6,
    'Y_LABELPAD': 6,
    'LEGEND_FONT_SIZE': 10,
    'X_NBINS': 6,
    'Y_NBINS': 6,
    'LINE_WIDTH': 2.5
}

# %%
fig, axes = plt.subplots(1, 3, figsize=PLOT_STYLE['FIGSIZE'], dpi=300)
axes = axes.flat

for i, ax in enumerate(axes):
    plot_roc_curve_per_class(
        model=model,
        X_train=X_tr_scaled,
        y_train=y_train,
        X_test=X_te_scaled,
        y_test=y_test,
        class_index=i,
        ax=ax
    )

plt.tight_layout()
plt.savefig(f'{path_to_save}/roc_curves_train_test.svg')
plt.show()

# %% [markdown]
# #### *SHAP-values* diagram

# %%
PLOT_STYLE = {
    'FIGSIZE': (14, 5),
    'TITLE': '',
    'TITLE_FONT_SIZE': 16,
    'TITLE_FONTSTYLE': 'normal',
    'X_LABEL': '$SHAP$ value',
    'Y_LABEL': '',
    'X_LABEL_FONT_SIZE': 14,
    'Y_LABEL_FONT_SIZE': 12,
    'X_TICK_LABEL_FONT_SIZE': 12,
    'Y_TICK_LABEL_FONT_SIZE': 20,
    'X_LABELPAD': 8,
    'Y_LABELPAD': 20,
    'DOT_SIZE': 64,
    'LEGEND_TITLE': 'Значение признака',
    'LEGEND_FONT_SIZE': 14,
    'X_NBINS': 6,
    'COLORBAR_TICKS': ['Низкое', 'Высокое']
}

# %%
nrows, ncols = 1, 3
fig, axes = plt.subplots(nrows, ncols, figsize=PLOT_STYLE['FIGSIZE'], dpi=300)
axes = axes.flat

for i, ax in enumerate(axes):
    show_colorbar = (i == ncols - 1)  # show only on the last subplot
    PLOT_STYLE['TITLE'] = class_fraction_group_dict[i]  # заголовок как раньше

    plot_shap_summary_logreg(
        model=model,
        X_train_scaled=X_tr_scaled,
        X_test_scaled=X_te_scaled,
        features_lst=X_tr_scaled.columns.tolist(),
        class_index=i,
        max_display=20,
        show_colorbar=show_colorbar,
        ax=ax
    )

plt.tight_layout()
plt.savefig(f'{path_to_save}/shap_3_subplots.svg')
plt.show()
