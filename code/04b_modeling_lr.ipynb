# %% [markdown]
# # Import libraries

# %%
import os
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.cm as cm

import seaborn as sns

import math

import json

import re

import shap

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import label_binarize

from sklearn.model_selection import cross_validate
from sklearn.model_selection import StratifiedKFold

from sklearn.utils import resample

from sklearn.multiclass import OneVsRestClassifier

from sklearn.linear_model import LogisticRegression

from sklearn.pipeline import Pipeline

from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn.metrics import make_scorer
from sklearn.metrics import confusion_matrix

from scipy.stats import t

from joblib import Parallel
from joblib import delayed
from tqdm_joblib import tqdm_joblib

from itertools import combinations

from collections import defaultdict

from tqdm.notebook import tqdm

# %%
warnings.filterwarnings("ignore")

np.seterr(all='ignore')

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', None)

# %%
path_to_save = './../results/04b_modeling_lr'

# %% [markdown]
# # Loading data

# %%
path_to_ftir_data = './../data/processed_data/dataset_1900_800_engineered.csv'
path_to_features_description = './../data/processed_data/features_description_1900_800.json'

# %% [markdown]
# ## FTIR-features (*long-list*)

# %%
dataset = pd.read_csv(path_to_ftir_data, sep=';', index_col=0)

print(dataset.shape)
dataset.head(3)
# Out:
# (75, 207)
#                       $I_{873}$  $I_{1107}$  $I_{1241}$  $I_{1393}$  \
# division_1_size_bulk   0.048208    0.681294    0.455066    0.760582
# division_1_size_5      0.091875    0.606138    0.427988    0.687458
# division_1_size_3      0.110321    0.836176    0.400950    0.696553
#
#                       $I_{1613}$  $I_{1725}$  \
# division_1_size_bulk         1.0    0.423273
# division_1_size_5            1.0    0.384475
# division_1_size_3            1.0    0.368753
#
#                       $\overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                          0.424162
# division_1_size_5                             0.378730
# division_1_size_3                             0.436266
#
#                       $\Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                          3.368423
# division_1_size_5                             3.197934
# division_1_size_3                             3.412752
#
#                       $\overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                           0.426619
# division_1_size_5                              0.378004
# division_1_size_3                              0.429362
#
#                       $\Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                           1.423273
# division_1_size_5                              1.384475
# division_1_size_3                              1.368753
#
#                       $\overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                           0.571735
# division_1_size_5                              0.502368
# division_1_size_3                              0.523513
#
#                       $\Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                           0.760582
# division_1_size_5                              0.687458
# division_1_size_3                              0.696553
#
#                       $\overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                          0.363338
# division_1_size_5                             0.329999
# division_1_size_3                             0.406988
#
#                       $\Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                          1.184569
# division_1_size_5                             1.126001
# division_1_size_3                             1.347446
#
#                       $\overline{I}_{873 \pm 25}$  \
# division_1_size_bulk                     0.047543
# division_1_size_5                        0.093349
# division_1_size_3                        0.113396
#
#                       $\overline{I}_{1107 \pm 25}$  \
# division_1_size_bulk                      0.624379
# division_1_size_5                         0.594059
# division_1_size_3                         0.817537
#
#                       $\overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                      0.447733
# division_1_size_5                         0.424918
# division_1_size_3                         0.401435
#
#                       $\overline{I}_{1393 \pm 25}$  \
# division_1_size_bulk                      0.739415
# division_1_size_5                         0.668322
# division_1_size_3                         0.678474
#
#                       $\overline{I}_{1613 \pm 25}$  \
# division_1_size_bulk                      0.939500
# division_1_size_5                         0.930634
# division_1_size_3                         0.953537
#
#                       $\overline{I}_{1725 \pm 25}$  $\log I_{873}$  \
# division_1_size_bulk                      0.417470       -3.032222
# division_1_size_5                         0.378463       -2.387325
# division_1_size_3                         0.369746       -2.204364
#
#                       $(I_{873})^{-1}$  $\log I_{1107}$  $(I_{1107})^{-1}$  \
# division_1_size_bulk         20.743271        -0.383761           1.467794
# division_1_size_5            10.884335        -0.500648           1.649790
# division_1_size_3             9.064483        -0.178917           1.195921
#
#                       $\log I_{1241}$  $(I_{1241})^{-1}$  $\log I_{1393}$  \
# division_1_size_bulk        -0.787312           2.197482        -0.273672
# division_1_size_5           -0.848660           2.336514        -0.374754
# division_1_size_3           -0.913918           2.494076        -0.361611
#
#                       $(I_{1393})^{-1}$  $\log I_{1613}$  $(I_{1613})^{-1}$  \
# division_1_size_bulk           1.314783              0.0                1.0
# division_1_size_5              1.454634              0.0                1.0
# division_1_size_3              1.435640              0.0                1.0
#
#                       $\log I_{1725}$  $(I_{1725})^{-1}$  \
# division_1_size_bulk        -0.859739           2.362543
# division_1_size_5           -0.955877           2.600952
# division_1_size_3           -0.997629           2.711845
#
#                       $\log \overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                              -0.857641
# division_1_size_5                                 -0.970931
# division_1_size_3                                 -0.829504
#
#                       $(\overline{I}_{1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.357591
# division_1_size_5                                    2.640400
# division_1_size_3                                    2.292181
#
#                       $\log \Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                               1.214445
# division_1_size_5                                  1.162505
# division_1_size_3                                  1.227519
#
#                       $(\Sigma I_{p,\ 1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.296875
# division_1_size_5                                    0.312702
# division_1_size_3                                    0.293019
#
#                       $\log \overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                               -0.851863
# division_1_size_5                                  -0.972851
# division_1_size_3                                  -0.845455
#
#                       $(\overline{I}_{1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  2.344010
# division_1_size_5                                     2.645477
# division_1_size_3                                     2.329038
#
#                       $\log \Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                                0.352959
# division_1_size_5                                   0.325321
# division_1_size_3                                   0.313900
#
#                       $(\Sigma I_{p,\ 1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  0.702606
# division_1_size_5                                     0.722296
# division_1_size_3                                     0.730592
#
#                       $\log \overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                               -0.559080
# division_1_size_5                                  -0.688422
# division_1_size_3                                  -0.647194
#
#                       $(\overline{I}_{1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.749062
# division_1_size_5                                     1.990572
# division_1_size_3                                     1.910173
#
#                       $\log \Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                               -0.273672
# division_1_size_5                                  -0.374754
# division_1_size_3                                  -0.361611
#
#                       $(\Sigma I_{p,\ 1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.314783
# division_1_size_5                                     1.454634
# division_1_size_3                                     1.435640
#
#                       $\log \overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                              -1.012422
# division_1_size_5                                 -1.108665
# division_1_size_3                                 -0.898970
#
#                       $(\overline{I}_{1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.752259
# division_1_size_5                                    3.030309
# division_1_size_3                                    2.457072
#
#                       $\log \Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                               0.169379
# division_1_size_5                                  0.118672
# division_1_size_3                                  0.298211
#
#                       $(\Sigma I_{p,\ 1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.844189
# division_1_size_5                                    0.888099
# division_1_size_3                                    0.742145
#
#                       $\log \overline{I}_{873 \pm 25}$  \
# division_1_size_bulk                         -3.046113
# division_1_size_5                            -2.371406
# division_1_size_3                            -2.176872
#
#                       $(\overline{I}_{873 \pm 25})^{-1}$  \
# division_1_size_bulk                           21.033424
# division_1_size_5                              10.712443
# division_1_size_3                               8.818675
#
#                       $\log \overline{I}_{1107 \pm 25}$  \
# division_1_size_bulk                          -0.470997
# division_1_size_5                             -0.520776
# division_1_size_3                             -0.201459
#
#                       $(\overline{I}_{1107 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.601590
# division_1_size_5                                1.683333
# division_1_size_3                                1.223186
#
#                       $\log \overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                          -0.803558
# division_1_size_5                             -0.855859
# division_1_size_3                             -0.912710
#
#                       $(\overline{I}_{1241 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.233473
# division_1_size_5                                2.353396
# division_1_size_3                                2.491063
#
#                       $\log \overline{I}_{1393 \pm 25}$  \
# division_1_size_bulk                          -0.301897
# division_1_size_5                             -0.402986
# division_1_size_3                             -0.387909
#
#                       $(\overline{I}_{1393 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.352421
# division_1_size_5                                1.496286
# division_1_size_3                                1.473896
#
#                       $\log \overline{I}_{1613 \pm 25}$  \
# division_1_size_bulk                          -0.062408
# division_1_size_5                             -0.071889
# division_1_size_3                             -0.047578
#
#                       $(\overline{I}_{1613 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.064396
# division_1_size_5                                1.074536
# division_1_size_3                                1.048728
#
#                       $\log \overline{I}_{1725 \pm 25}$  \
# division_1_size_bulk                          -0.873542
# division_1_size_5                             -0.971638
# division_1_size_3                             -0.994938
#
#                       $(\overline{I}_{1725 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.395381
# division_1_size_5                                2.642268
# division_1_size_3                                2.704557
#
#                       $\frac{I_{873}}{I_{1107}}$  $\frac{I_{873}}{I_{1241}}$  \
# division_1_size_bulk                    0.070760                    0.105937
# division_1_size_5                       0.151575                    0.214668
# division_1_size_3                       0.131935                    0.275148
#
#                       $\frac{I_{873}}{I_{1393}}$  $\frac{I_{873}}{I_{1613}}$  \
# division_1_size_bulk                    0.063384                    0.048208
# division_1_size_5                       0.133645                    0.091875
# division_1_size_3                       0.158381                    0.110321
#
#                       $\frac{I_{873}}{I_{1725}}$  \
# division_1_size_bulk                    0.113894
# division_1_size_5                       0.238963
# division_1_size_3                       0.299173
#
#                       $\frac{I_{873}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                          0.113656
# division_1_size_5                                             0.242587
# division_1_size_3                                             0.252875
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                          0.014312
# division_1_size_5                                             0.028730
# division_1_size_3                                             0.032326
#
#                       $\frac{I_{873}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.113001
# division_1_size_5                                              0.243054
# division_1_size_3                                              0.256941
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.033872
# division_1_size_5                                              0.066361
# division_1_size_3                                              0.080599
#
#                       $\frac{I_{873}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.084320
# division_1_size_5                                              0.182884
# division_1_size_3                                              0.210732
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.063384
# division_1_size_5                                              0.133645
# division_1_size_3                                              0.158381
#
#                       $\frac{I_{873}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                          0.132682
# division_1_size_5                                             0.278410
# division_1_size_3                                             0.271066
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                          0.040697
# division_1_size_5                                             0.081594
# division_1_size_3                                             0.081874
#
#                       $\frac{I_{873}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                      0.077210
# division_1_size_5                                         0.154656
# division_1_size_3                                         0.134943
#
#                       $\frac{I_{873}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                      0.107672
# division_1_size_5                                         0.216219
# division_1_size_3                                         0.274816
#
#                       $\frac{I_{873}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                      0.065198
# division_1_size_5                                         0.137471
# division_1_size_3                                         0.162601
#
#                       $\frac{I_{873}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                      0.051313
# division_1_size_5                                         0.098723
# division_1_size_3                                         0.115696
#
#                       $\frac{I_{873}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                      0.115477
# division_1_size_5                                         0.242759
# division_1_size_3                                         0.298369
#
#                       $\frac{I_{1107}}{I_{1241}}$  \
# division_1_size_bulk                     1.497132
# division_1_size_5                        1.416250
# division_1_size_3                        2.085485
#
#                       $\frac{I_{1107}}{I_{1393}}$  \
# division_1_size_bulk                     0.895754
# division_1_size_5                        0.881708
# division_1_size_3                        1.200447
#
#                       $\frac{I_{1107}}{I_{1613}}$  \
# division_1_size_bulk                     0.681294
# division_1_size_5                        0.606138
# division_1_size_3                        0.836176
#
#                       $\frac{I_{1107}}{I_{1725}}$  \
# division_1_size_bulk                     1.609587
# division_1_size_5                        1.576535
# division_1_size_3                        2.267579
#
#                       $\frac{I_{1107}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.606214
# division_1_size_5                                              1.600446
# division_1_size_3                                              1.916666
#
#                       $\frac{I_{1107}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.202259
# division_1_size_5                                              0.189540
# division_1_size_3                                              0.245015
#
#                       $\frac{I_{1107}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.596961
# division_1_size_5                                               1.603523
# division_1_size_3                                               1.947485
#
#                       $\frac{I_{1107}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.478681
# division_1_size_5                                               0.437811
# division_1_size_3                                               0.610903
#
#                       $\frac{I_{1107}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.191626
# division_1_size_5                                               1.206561
# division_1_size_3                                               1.597240
#
#                       $\frac{I_{1107}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.895754
# division_1_size_5                                               0.881708
# division_1_size_3                                               1.200447
#
#                       $\frac{I_{1107}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.875098
# division_1_size_5                                              1.836785
# division_1_size_3                                              2.054544
#
#                       $\frac{I_{1107}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.575141
# division_1_size_5                                              0.538310
# division_1_size_3                                              0.620563
#
#                       $\frac{I_{1107}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     14.329951
# division_1_size_5                                         6.493216
# division_1_size_3                                         7.373961
#
#                       $\frac{I_{1107}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.521652
# division_1_size_5                                          1.426482
# division_1_size_3                                          2.082966
#
#                       $\frac{I_{1107}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                       0.921397
# division_1_size_5                                          0.906955
# division_1_size_3                                          1.232436
#
#                       $\frac{I_{1107}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                       0.725167
# division_1_size_5                                          0.651317
# division_1_size_3                                          0.876920
#
#                       $\frac{I_{1107}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.631959
# division_1_size_5                                          1.601578
# division_1_size_3                                          2.261485
#
#                       $\frac{I_{1241}}{I_{1393}}$  \
# division_1_size_bulk                     0.598314
# division_1_size_5                        0.622566
# division_1_size_3                        0.575620
#
#                       $\frac{I_{1241}}{I_{1613}}$  \
# division_1_size_bulk                     0.455066
# division_1_size_5                        0.427988
# division_1_size_3                        0.400950
#
#                       $\frac{I_{1241}}{I_{1725}}$  \
# division_1_size_bulk                     1.075114
# division_1_size_5                        1.113176
# division_1_size_3                        1.087315
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.072861
# division_1_size_5                                              1.130060
# division_1_size_3                                              0.919050
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.135098
# division_1_size_5                                              0.133833
# division_1_size_3                                              0.117486
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.066680
# division_1_size_5                                               1.132232
# division_1_size_3                                               0.933828
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.319732
# division_1_size_5                                               0.309134
# division_1_size_3                                               0.292931
#
#                       $\frac{I_{1241}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.795939
# division_1_size_5                                               0.851941
# division_1_size_3                                               0.765884
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.598314
# division_1_size_5                                               0.622566
# division_1_size_3                                               0.575620
#
#                       $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.252460
# division_1_size_5                                              1.296936
# division_1_size_3                                              0.985163
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.384162
# division_1_size_5                                              0.380096
# division_1_size_3                                              0.297563
#
#                       $\frac{I_{1241}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                      9.571604
# division_1_size_5                                         4.584797
# division_1_size_3                                         3.535849
#
#                       $\frac{I_{1241}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                       0.728830
# division_1_size_5                                          0.720446
# division_1_size_3                                          0.490437
#
#                       $\frac{I_{1241}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                       0.615441
# division_1_size_5                                          0.640392
# division_1_size_3                                          0.590959
#
#                       $\frac{I_{1241}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                       0.484371
# division_1_size_5                                          0.459889
# division_1_size_3                                          0.420487
#
#                       $\frac{I_{1241}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.090057
# division_1_size_5                                          1.130859
# division_1_size_3                                          1.084393
#
#                       $\frac{I_{1393}}{I_{1613}}$  \
# division_1_size_bulk                     0.760582
# division_1_size_5                        0.687458
# division_1_size_3                        0.696553
#
#                       $\frac{I_{1393}}{I_{1725}}$  \
# division_1_size_bulk                     1.796907
# division_1_size_5                        1.788046
# division_1_size_3                        1.888945
#
#                       $\frac{I_{1393}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.793141
# division_1_size_5                                              1.815165
# division_1_size_3                                              1.596626
#
#                       $\frac{I_{1393}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.225798
# division_1_size_5                                              0.214970
# division_1_size_3                                              0.204103
#
#                       $\frac{I_{1393}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.782811
# division_1_size_5                                               1.818655
# division_1_size_3                                               1.622300
#
#                       $\frac{I_{1393}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.534389
# division_1_size_5                                               0.496548
# division_1_size_3                                               0.508897
#
#                       $\frac{I_{1393}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.330305
# division_1_size_5                                               1.368435
# division_1_size_3                                               1.330538
#
#                       $\frac{I_{1393}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                 1.0
# division_1_size_5                                                    1.0
# division_1_size_3                                                    1.0
#
#                       $\frac{I_{1393}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.093317
# division_1_size_5                                              2.083211
# division_1_size_3                                              1.711482
#
#                       $\frac{I_{1393}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.642074
# division_1_size_5                                              0.610531
# division_1_size_3                                              0.516943
#
#                       $\frac{I_{1393}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     15.997634
# division_1_size_5                                         7.364358
# division_1_size_3                                         6.142679
#
#                       $\frac{I_{1393}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                       1.218140
# division_1_size_5                                          1.157221
# division_1_size_3                                          0.852014
#
#                       $\frac{I_{1393}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.698738
# division_1_size_5                                          1.617862
# division_1_size_3                                          1.735159
#
#                       $\frac{I_{1393}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                       0.809560
# division_1_size_5                                          0.738699
# division_1_size_3                                          0.730495
#
#                       $\frac{I_{1393}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.821882
# division_1_size_5                                          1.816449
# division_1_size_3                                          1.883869
#
#                       $\frac{I_{1613}}{I_{1725}}$  \
# division_1_size_bulk                     2.362543
# division_1_size_5                        2.600952
# division_1_size_3                        2.711845
#
#                       $\frac{I_{1613}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           2.357591
# division_1_size_5                                              2.640400
# division_1_size_3                                              2.292181
#
#                       $\frac{I_{1613}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.296875
# division_1_size_5                                              0.312702
# division_1_size_3                                              0.293019
#
#                       $\frac{I_{1613}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            2.344010
# division_1_size_5                                               2.645477
# division_1_size_3                                               2.329038
#
#                       $\frac{I_{1613}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.702606
# division_1_size_5                                               0.722296
# division_1_size_3                                               0.730592
#
#                       $\frac{I_{1613}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.749062
# division_1_size_5                                               1.990572
# division_1_size_3                                               1.910173
#
#                       $\frac{I_{1613}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.314783
# division_1_size_5                                               1.454634
# division_1_size_3                                               1.435640
#
#                       $\frac{I_{1613}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.752259
# division_1_size_5                                              3.030309
# division_1_size_3                                              2.457072
#
#                       $\frac{I_{1613}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.844189
# division_1_size_5                                              0.888099
# division_1_size_3                                              0.742145
#
#                       $\frac{I_{1613}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     21.033424
# division_1_size_5                                        10.712443
# division_1_size_3                                         8.818675
#
#                       $\frac{I_{1613}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                       1.601590
# division_1_size_5                                          1.683333
# division_1_size_3                                          1.223186
#
#                       $\frac{I_{1613}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       2.233473
# division_1_size_5                                          2.353396
# division_1_size_3                                          2.491063
#
#                       $\frac{I_{1613}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                       1.352421
# division_1_size_5                                          1.496286
# division_1_size_3                                          1.473896
#
#                       $\frac{I_{1613}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       2.395381
# division_1_size_5                                          2.642268
# division_1_size_3                                          2.704557
#
#                       $\frac{I_{1725}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           0.997904
# division_1_size_5                                              1.015167
# division_1_size_3                                              0.845248
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.125659
# division_1_size_5                                              0.120226
# division_1_size_3                                              0.108051
#
#                       $\frac{I_{1725}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.992156
# division_1_size_5                                               1.017119
# division_1_size_3                                               0.858839
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.297394
# division_1_size_5                                               0.277704
# division_1_size_3                                               0.269408
#
#                       $\frac{I_{1725}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.740330
# division_1_size_5                                               0.765324
# division_1_size_3                                               0.704381
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.556512
# division_1_size_5                                               0.559270
# division_1_size_3                                               0.529396
#
#                       $\frac{I_{1725}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.164956
# division_1_size_5                                              1.165077
# division_1_size_3                                              0.906052
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.357322
# division_1_size_5                                              0.341451
# division_1_size_3                                              0.273668
#
#                       $\frac{I_{1725}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                      8.902873
# division_1_size_5                                         4.118663
# division_1_size_3                                         3.251910
#
#                       $\frac{I_{1725}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                       0.677909
# division_1_size_5                                          0.647199
# division_1_size_3                                          0.451053
#
#                       $\frac{I_{1725}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       0.945368
# division_1_size_5                                          0.904821
# division_1_size_3                                          0.918586
#
#                       $\frac{I_{1725}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                       0.572443
# division_1_size_5                                          0.575284
# division_1_size_3                                          0.543503
#
#                       $\frac{I_{1725}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                       0.450530
# division_1_size_5                                          0.413132
# division_1_size_3                                          0.386721
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                                                  0.741885
# division_1_size_5                                                                     0.753890
# division_1_size_3                                                                     0.833343
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                                                 1.167403
# division_1_size_5                                                                    1.147670
# division_1_size_3                                                                    1.071937
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                                            8.921573
# division_1_size_5                                                               4.057128
# division_1_size_3                                                               3.847286
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                                             0.679333
# division_1_size_5                                                                0.637529
# division_1_size_3                                                                0.533634
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                             0.947354
# division_1_size_5                                                                0.891303
# division_1_size_3                                                                1.086766
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                             0.573645
# division_1_size_5                                                                0.566689
# division_1_size_3                                                                0.643010
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                             0.451476
# division_1_size_5                                                                0.406959
# division_1_size_3                                                                0.457524
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                             1.016029
# division_1_size_5                                                                1.000707
# division_1_size_3                                                                1.179906
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}800}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                                                  2.366675
# division_1_size_5                                                                     2.309854
# division_1_size_3                                                                     2.493330
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}800}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                                  4.428747
# division_1_size_5                                                                     4.651822
# division_1_size_3                                                                     4.899484
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}800}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                                                 2.843585
# division_1_size_5                                                                    2.840081
# division_1_size_3                                                                    2.532756
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                                                   0.746184
# division_1_size_5                                                                      0.752443
# division_1_size_3                                                                      0.820155
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                                                  1.174167
# division_1_size_5                                                                     1.145468
# division_1_size_3                                                                     1.054973
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                                             8.973264
# division_1_size_5                                                                4.049343
# division_1_size_3                                                                3.786402
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                                              0.683269
# division_1_size_5                                                                 0.636306
# division_1_size_3                                                                 0.525189
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                              0.952843
# division_1_size_5                                                                 0.889592
# division_1_size_3                                                                 1.069567
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                              0.576969
# division_1_size_5                                                                 0.565602
# division_1_size_3                                                                 0.632835
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                              0.454092
# division_1_size_5                                                                 0.406179
# division_1_size_3                                                                 0.450284
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                              1.021916
# division_1_size_5                                                                 0.998787
# division_1_size_3                                                                 1.161234
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}1500}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                                   1.871295
# division_1_size_5                                                                      2.013903
# division_1_size_3                                                                      1.965036
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}1500}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                                                  1.201511
# division_1_size_5                                                                     1.229550
# division_1_size_3                                                                     1.015812
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                                                  1.573562
# division_1_size_5                                                                     1.522331
# division_1_size_3                                                                     1.286309
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                                            12.025543
# division_1_size_5                                                                5.381591
# division_1_size_3                                                                4.616689
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                                              0.915685
# division_1_size_5                                                                 0.845653
# division_1_size_3                                                                 0.640353
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                              1.276955
# division_1_size_5                                                                 1.182272
# division_1_size_3                                                                 1.304103
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                              0.773227
# division_1_size_5                                                                 0.751686
# division_1_size_3                                                                 0.771603
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                              0.608552
# division_1_size_5                                                                 0.539813
# division_1_size_3                                                                 0.549022
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                              1.369523
# division_1_size_5                                                                 1.327392
# division_1_size_3                                                                 1.415870
#
#                       $\frac{\Sigma I_{p,\ 1500\text{–}1300}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                                                  0.642074
# division_1_size_5                                                                     0.610531
# division_1_size_3                                                                     0.516943
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                                            7.642240
# division_1_size_5                                                               3.535099
# division_1_size_3                                                               3.589099
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                                             0.581918
# division_1_size_5                                                                0.555499
# division_1_size_3                                                                0.497823
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                             0.811505
# division_1_size_5                                                                0.776619
# division_1_size_3                                                                1.013834
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                             0.491386
# division_1_size_5                                                                0.493773
# division_1_size_3                                                                0.599859
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                             0.386735
# division_1_size_5                                                                0.354596
# division_1_size_3                                                                0.426820
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                             0.870333
# division_1_size_5                                                                0.871947
# division_1_size_3                                                                1.100724
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                                        0.076145
# division_1_size_5                                                           0.157138
# division_1_size_3                                                           0.138704
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                        0.106187
# division_1_size_5                                                           0.219688
# division_1_size_3                                                           0.282476
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                        0.064299
# division_1_size_5                                                           0.139677
# division_1_size_3                                                           0.167133
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                        0.050605
# division_1_size_5                                                           0.100307
# division_1_size_3                                                           0.118921
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                        0.113884
# division_1_size_5                                                           0.246654
# division_1_size_3                                                           0.306685
#
#                       $\frac{\overline{I}_{1107 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                         1.394535
# division_1_size_5                                                            1.398057
# division_1_size_3                                                            2.036537
#
#                       $\frac{\overline{I}_{1107 \pm 25}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                         0.844424
# division_1_size_5                                                            0.888883
# division_1_size_3                                                            1.204964
#
#                       $\frac{\overline{I}_{1107 \pm 25}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                         0.664587
# division_1_size_5                                                            0.638338
# division_1_size_3                                                            0.857374
#
#                       $\frac{\overline{I}_{1107 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.495626
# division_1_size_5                                                            1.569664
# division_1_size_3                                                            2.211076
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                         0.605524
# division_1_size_5                                                            0.635799
# division_1_size_3                                                            0.591673
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                         0.476565
# division_1_size_5                                                            0.456590
# division_1_size_3                                                            0.420996
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.072491
# division_1_size_5                                                            1.122747
# division_1_size_3                                                            1.085704
#
#                       $\frac{\overline{I}_{1393 \pm 25}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                         0.787030
# division_1_size_5                                                            0.718136
# division_1_size_3                                                            0.711534
#
#                       $\frac{\overline{I}_{1393 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.771179
# division_1_size_5                                                            1.765885
# division_1_size_3                                                            1.834972
#
#                       $\frac{\overline{I}_{1613 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         2.250460
# division_1_size_5                                                            2.458985
# division_1_size_3                                                            2.578894
#
#                       Split Fraction_hue Fraction_grouped_hue  Class
# division_1_size_bulk  Train        $> 0$              $d > 5$      2
# division_1_size_5     Train        $< 5$       $2 < d \leq 5$      1
# division_1_size_3     Train        $< 3$       $2 < d \leq 5$      1

# %% [markdown]
# ## Features description

# %%
with open(path_to_features_description, 'r', encoding='utf-8') as f:
    features_description = json.load(f)

# %% [markdown]
# # Data wrangling

# %% [markdown]
# ## Data wrangling

# %%
dataset_train = dataset.loc[dataset['Split'] == 'Train']

X_train = dataset_train.loc[:, ~dataset_train.columns.isin(['Split', 'Fraction_hue', 'Fraction_grouped_hue', 'Class'])]
y_train = dataset_train['Class']

print(
    f'(*) X_train: {X_train.shape}',
    f'(*) y_train: {y_train.shape}',
    sep='\n'
)
X_train.head(3)
# Out:
# (*) X_train: (56, 203)
# (*) y_train: (56,)
#                       $I_{873}$  $I_{1107}$  $I_{1241}$  $I_{1393}$  \
# division_1_size_bulk   0.048208    0.681294    0.455066    0.760582
# division_1_size_5      0.091875    0.606138    0.427988    0.687458
# division_1_size_3      0.110321    0.836176    0.400950    0.696553
#
#                       $I_{1613}$  $I_{1725}$  \
# division_1_size_bulk         1.0    0.423273
# division_1_size_5            1.0    0.384475
# division_1_size_3            1.0    0.368753
#
#                       $\overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                          0.424162
# division_1_size_5                             0.378730
# division_1_size_3                             0.436266
#
#                       $\Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                          3.368423
# division_1_size_5                             3.197934
# division_1_size_3                             3.412752
#
#                       $\overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                           0.426619
# division_1_size_5                              0.378004
# division_1_size_3                              0.429362
#
#                       $\Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                           1.423273
# division_1_size_5                              1.384475
# division_1_size_3                              1.368753
#
#                       $\overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                           0.571735
# division_1_size_5                              0.502368
# division_1_size_3                              0.523513
#
#                       $\Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                           0.760582
# division_1_size_5                              0.687458
# division_1_size_3                              0.696553
#
#                       $\overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                          0.363338
# division_1_size_5                             0.329999
# division_1_size_3                             0.406988
#
#                       $\Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                          1.184569
# division_1_size_5                             1.126001
# division_1_size_3                             1.347446
#
#                       $\overline{I}_{873 \pm 25}$  \
# division_1_size_bulk                     0.047543
# division_1_size_5                        0.093349
# division_1_size_3                        0.113396
#
#                       $\overline{I}_{1107 \pm 25}$  \
# division_1_size_bulk                      0.624379
# division_1_size_5                         0.594059
# division_1_size_3                         0.817537
#
#                       $\overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                      0.447733
# division_1_size_5                         0.424918
# division_1_size_3                         0.401435
#
#                       $\overline{I}_{1393 \pm 25}$  \
# division_1_size_bulk                      0.739415
# division_1_size_5                         0.668322
# division_1_size_3                         0.678474
#
#                       $\overline{I}_{1613 \pm 25}$  \
# division_1_size_bulk                      0.939500
# division_1_size_5                         0.930634
# division_1_size_3                         0.953537
#
#                       $\overline{I}_{1725 \pm 25}$  $\log I_{873}$  \
# division_1_size_bulk                      0.417470       -3.032222
# division_1_size_5                         0.378463       -2.387325
# division_1_size_3                         0.369746       -2.204364
#
#                       $(I_{873})^{-1}$  $\log I_{1107}$  $(I_{1107})^{-1}$  \
# division_1_size_bulk         20.743271        -0.383761           1.467794
# division_1_size_5            10.884335        -0.500648           1.649790
# division_1_size_3             9.064483        -0.178917           1.195921
#
#                       $\log I_{1241}$  $(I_{1241})^{-1}$  $\log I_{1393}$  \
# division_1_size_bulk        -0.787312           2.197482        -0.273672
# division_1_size_5           -0.848660           2.336514        -0.374754
# division_1_size_3           -0.913918           2.494076        -0.361611
#
#                       $(I_{1393})^{-1}$  $\log I_{1613}$  $(I_{1613})^{-1}$  \
# division_1_size_bulk           1.314783              0.0                1.0
# division_1_size_5              1.454634              0.0                1.0
# division_1_size_3              1.435640              0.0                1.0
#
#                       $\log I_{1725}$  $(I_{1725})^{-1}$  \
# division_1_size_bulk        -0.859739           2.362543
# division_1_size_5           -0.955877           2.600952
# division_1_size_3           -0.997629           2.711845
#
#                       $\log \overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                              -0.857641
# division_1_size_5                                 -0.970931
# division_1_size_3                                 -0.829504
#
#                       $(\overline{I}_{1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.357591
# division_1_size_5                                    2.640400
# division_1_size_3                                    2.292181
#
#                       $\log \Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                               1.214445
# division_1_size_5                                  1.162505
# division_1_size_3                                  1.227519
#
#                       $(\Sigma I_{p,\ 1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.296875
# division_1_size_5                                    0.312702
# division_1_size_3                                    0.293019
#
#                       $\log \overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                               -0.851863
# division_1_size_5                                  -0.972851
# division_1_size_3                                  -0.845455
#
#                       $(\overline{I}_{1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  2.344010
# division_1_size_5                                     2.645477
# division_1_size_3                                     2.329038
#
#                       $\log \Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                                0.352959
# division_1_size_5                                   0.325321
# division_1_size_3                                   0.313900
#
#                       $(\Sigma I_{p,\ 1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  0.702606
# division_1_size_5                                     0.722296
# division_1_size_3                                     0.730592
#
#                       $\log \overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                               -0.559080
# division_1_size_5                                  -0.688422
# division_1_size_3                                  -0.647194
#
#                       $(\overline{I}_{1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.749062
# division_1_size_5                                     1.990572
# division_1_size_3                                     1.910173
#
#                       $\log \Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                               -0.273672
# division_1_size_5                                  -0.374754
# division_1_size_3                                  -0.361611
#
#                       $(\Sigma I_{p,\ 1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.314783
# division_1_size_5                                     1.454634
# division_1_size_3                                     1.435640
#
#                       $\log \overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                              -1.012422
# division_1_size_5                                 -1.108665
# division_1_size_3                                 -0.898970
#
#                       $(\overline{I}_{1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.752259
# division_1_size_5                                    3.030309
# division_1_size_3                                    2.457072
#
#                       $\log \Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                               0.169379
# division_1_size_5                                  0.118672
# division_1_size_3                                  0.298211
#
#                       $(\Sigma I_{p,\ 1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.844189
# division_1_size_5                                    0.888099
# division_1_size_3                                    0.742145
#
#                       $\log \overline{I}_{873 \pm 25}$  \
# division_1_size_bulk                         -3.046113
# division_1_size_5                            -2.371406
# division_1_size_3                            -2.176872
#
#                       $(\overline{I}_{873 \pm 25})^{-1}$  \
# division_1_size_bulk                           21.033424
# division_1_size_5                              10.712443
# division_1_size_3                               8.818675
#
#                       $\log \overline{I}_{1107 \pm 25}$  \
# division_1_size_bulk                          -0.470997
# division_1_size_5                             -0.520776
# division_1_size_3                             -0.201459
#
#                       $(\overline{I}_{1107 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.601590
# division_1_size_5                                1.683333
# division_1_size_3                                1.223186
#
#                       $\log \overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                          -0.803558
# division_1_size_5                             -0.855859
# division_1_size_3                             -0.912710
#
#                       $(\overline{I}_{1241 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.233473
# division_1_size_5                                2.353396
# division_1_size_3                                2.491063
#
#                       $\log \overline{I}_{1393 \pm 25}$  \
# division_1_size_bulk                          -0.301897
# division_1_size_5                             -0.402986
# division_1_size_3                             -0.387909
#
#                       $(\overline{I}_{1393 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.352421
# division_1_size_5                                1.496286
# division_1_size_3                                1.473896
#
#                       $\log \overline{I}_{1613 \pm 25}$  \
# division_1_size_bulk                          -0.062408
# division_1_size_5                             -0.071889
# division_1_size_3                             -0.047578
#
#                       $(\overline{I}_{1613 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.064396
# division_1_size_5                                1.074536
# division_1_size_3                                1.048728
#
#                       $\log \overline{I}_{1725 \pm 25}$  \
# division_1_size_bulk                          -0.873542
# division_1_size_5                             -0.971638
# division_1_size_3                             -0.994938
#
#                       $(\overline{I}_{1725 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.395381
# division_1_size_5                                2.642268
# division_1_size_3                                2.704557
#
#                       $\frac{I_{873}}{I_{1107}}$  $\frac{I_{873}}{I_{1241}}$  \
# division_1_size_bulk                    0.070760                    0.105937
# division_1_size_5                       0.151575                    0.214668
# division_1_size_3                       0.131935                    0.275148
#
#                       $\frac{I_{873}}{I_{1393}}$  $\frac{I_{873}}{I_{1613}}$  \
# division_1_size_bulk                    0.063384                    0.048208
# division_1_size_5                       0.133645                    0.091875
# division_1_size_3                       0.158381                    0.110321
#
#                       $\frac{I_{873}}{I_{1725}}$  \
# division_1_size_bulk                    0.113894
# division_1_size_5                       0.238963
# division_1_size_3                       0.299173
#
#                       $\frac{I_{873}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                          0.113656
# division_1_size_5                                             0.242587
# division_1_size_3                                             0.252875
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                          0.014312
# division_1_size_5                                             0.028730
# division_1_size_3                                             0.032326
#
#                       $\frac{I_{873}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.113001
# division_1_size_5                                              0.243054
# division_1_size_3                                              0.256941
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.033872
# division_1_size_5                                              0.066361
# division_1_size_3                                              0.080599
#
#                       $\frac{I_{873}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.084320
# division_1_size_5                                              0.182884
# division_1_size_3                                              0.210732
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.063384
# division_1_size_5                                              0.133645
# division_1_size_3                                              0.158381
#
#                       $\frac{I_{873}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                          0.132682
# division_1_size_5                                             0.278410
# division_1_size_3                                             0.271066
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                          0.040697
# division_1_size_5                                             0.081594
# division_1_size_3                                             0.081874
#
#                       $\frac{I_{873}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                      0.077210
# division_1_size_5                                         0.154656
# division_1_size_3                                         0.134943
#
#                       $\frac{I_{873}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                      0.107672
# division_1_size_5                                         0.216219
# division_1_size_3                                         0.274816
#
#                       $\frac{I_{873}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                      0.065198
# division_1_size_5                                         0.137471
# division_1_size_3                                         0.162601
#
#                       $\frac{I_{873}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                      0.051313
# division_1_size_5                                         0.098723
# division_1_size_3                                         0.115696
#
#                       $\frac{I_{873}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                      0.115477
# division_1_size_5                                         0.242759
# division_1_size_3                                         0.298369
#
#                       $\frac{I_{1107}}{I_{1241}}$  \
# division_1_size_bulk                     1.497132
# division_1_size_5                        1.416250
# division_1_size_3                        2.085485
#
#                       $\frac{I_{1107}}{I_{1393}}$  \
# division_1_size_bulk                     0.895754
# division_1_size_5                        0.881708
# division_1_size_3                        1.200447
#
#                       $\frac{I_{1107}}{I_{1613}}$  \
# division_1_size_bulk                     0.681294
# division_1_size_5                        0.606138
# division_1_size_3                        0.836176
#
#                       $\frac{I_{1107}}{I_{1725}}$  \
# division_1_size_bulk                     1.609587
# division_1_size_5                        1.576535
# division_1_size_3                        2.267579
#
#                       $\frac{I_{1107}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.606214
# division_1_size_5                                              1.600446
# division_1_size_3                                              1.916666
#
#                       $\frac{I_{1107}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.202259
# division_1_size_5                                              0.189540
# division_1_size_3                                              0.245015
#
#                       $\frac{I_{1107}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.596961
# division_1_size_5                                               1.603523
# division_1_size_3                                               1.947485
#
#                       $\frac{I_{1107}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.478681
# division_1_size_5                                               0.437811
# division_1_size_3                                               0.610903
#
#                       $\frac{I_{1107}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.191626
# division_1_size_5                                               1.206561
# division_1_size_3                                               1.597240
#
#                       $\frac{I_{1107}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.895754
# division_1_size_5                                               0.881708
# division_1_size_3                                               1.200447
#
#                       $\frac{I_{1107}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.875098
# division_1_size_5                                              1.836785
# division_1_size_3                                              2.054544
#
#                       $\frac{I_{1107}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.575141
# division_1_size_5                                              0.538310
# division_1_size_3                                              0.620563
#
#                       $\frac{I_{1107}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     14.329951
# division_1_size_5                                         6.493216
# division_1_size_3                                         7.373961
#
#                       $\frac{I_{1107}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.521652
# division_1_size_5                                          1.426482
# division_1_size_3                                          2.082966
#
#                       $\frac{I_{1107}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                       0.921397
# division_1_size_5                                          0.906955
# division_1_size_3                                          1.232436
#
#                       $\frac{I_{1107}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                       0.725167
# division_1_size_5                                          0.651317
# division_1_size_3                                          0.876920
#
#                       $\frac{I_{1107}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.631959
# division_1_size_5                                          1.601578
# division_1_size_3                                          2.261485
#
#                       $\frac{I_{1241}}{I_{1393}}$  \
# division_1_size_bulk                     0.598314
# division_1_size_5                        0.622566
# division_1_size_3                        0.575620
#
#                       $\frac{I_{1241}}{I_{1613}}$  \
# division_1_size_bulk                     0.455066
# division_1_size_5                        0.427988
# division_1_size_3                        0.400950
#
#                       $\frac{I_{1241}}{I_{1725}}$  \
# division_1_size_bulk                     1.075114
# division_1_size_5                        1.113176
# division_1_size_3                        1.087315
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.072861
# division_1_size_5                                              1.130060
# division_1_size_3                                              0.919050
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.135098
# division_1_size_5                                              0.133833
# division_1_size_3                                              0.117486
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.066680
# division_1_size_5                                               1.132232
# division_1_size_3                                               0.933828
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.319732
# division_1_size_5                                               0.309134
# division_1_size_3                                               0.292931
#
#                       $\frac{I_{1241}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.795939
# division_1_size_5                                               0.851941
# division_1_size_3                                               0.765884
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.598314
# division_1_size_5                                               0.622566
# division_1_size_3                                               0.575620
#
#                       $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.252460
# division_1_size_5                                              1.296936
# division_1_size_3                                              0.985163
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.384162
# division_1_size_5                                              0.380096
# division_1_size_3                                              0.297563
#
#                       $\frac{I_{1241}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                      9.571604
# division_1_size_5                                         4.584797
# division_1_size_3                                         3.535849
#
#                       $\frac{I_{1241}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                       0.728830
# division_1_size_5                                          0.720446
# division_1_size_3                                          0.490437
#
#                       $\frac{I_{1241}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                       0.615441
# division_1_size_5                                          0.640392
# division_1_size_3                                          0.590959
#
#                       $\frac{I_{1241}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                       0.484371
# division_1_size_5                                          0.459889
# division_1_size_3                                          0.420487
#
#                       $\frac{I_{1241}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.090057
# division_1_size_5                                          1.130859
# division_1_size_3                                          1.084393
#
#                       $\frac{I_{1393}}{I_{1613}}$  \
# division_1_size_bulk                     0.760582
# division_1_size_5                        0.687458
# division_1_size_3                        0.696553
#
#                       $\frac{I_{1393}}{I_{1725}}$  \
# division_1_size_bulk                     1.796907
# division_1_size_5                        1.788046
# division_1_size_3                        1.888945
#
#                       $\frac{I_{1393}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.793141
# division_1_size_5                                              1.815165
# division_1_size_3                                              1.596626
#
#                       $\frac{I_{1393}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.225798
# division_1_size_5                                              0.214970
# division_1_size_3                                              0.204103
#
#                       $\frac{I_{1393}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.782811
# division_1_size_5                                               1.818655
# division_1_size_3                                               1.622300
#
#                       $\frac{I_{1393}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.534389
# division_1_size_5                                               0.496548
# division_1_size_3                                               0.508897
#
#                       $\frac{I_{1393}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.330305
# division_1_size_5                                               1.368435
# division_1_size_3                                               1.330538
#
#                       $\frac{I_{1393}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                 1.0
# division_1_size_5                                                    1.0
# division_1_size_3                                                    1.0
#
#                       $\frac{I_{1393}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.093317
# division_1_size_5                                              2.083211
# division_1_size_3                                              1.711482
#
#                       $\frac{I_{1393}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.642074
# division_1_size_5                                              0.610531
# division_1_size_3                                              0.516943
#
#                       $\frac{I_{1393}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     15.997634
# division_1_size_5                                         7.364358
# division_1_size_3                                         6.142679
#
#                       $\frac{I_{1393}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                       1.218140
# division_1_size_5                                          1.157221
# division_1_size_3                                          0.852014
#
#                       $\frac{I_{1393}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.698738
# division_1_size_5                                          1.617862
# division_1_size_3                                          1.735159
#
#                       $\frac{I_{1393}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                       0.809560
# division_1_size_5                                          0.738699
# division_1_size_3                                          0.730495
#
#                       $\frac{I_{1393}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.821882
# division_1_size_5                                          1.816449
# division_1_size_3                                          1.883869
#
#                       $\frac{I_{1613}}{I_{1725}}$  \
# division_1_size_bulk                     2.362543
# division_1_size_5                        2.600952
# division_1_size_3                        2.711845
#
#                       $\frac{I_{1613}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           2.357591
# division_1_size_5                                              2.640400
# division_1_size_3                                              2.292181
#
#                       $\frac{I_{1613}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.296875
# division_1_size_5                                              0.312702
# division_1_size_3                                              0.293019
#
#                       $\frac{I_{1613}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            2.344010
# division_1_size_5                                               2.645477
# division_1_size_3                                               2.329038
#
#                       $\frac{I_{1613}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.702606
# division_1_size_5                                               0.722296
# division_1_size_3                                               0.730592
#
#                       $\frac{I_{1613}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.749062
# division_1_size_5                                               1.990572
# division_1_size_3                                               1.910173
#
#                       $\frac{I_{1613}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.314783
# division_1_size_5                                               1.454634
# division_1_size_3                                               1.435640
#
#                       $\frac{I_{1613}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.752259
# division_1_size_5                                              3.030309
# division_1_size_3                                              2.457072
#
#                       $\frac{I_{1613}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.844189
# division_1_size_5                                              0.888099
# division_1_size_3                                              0.742145
#
#                       $\frac{I_{1613}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     21.033424
# division_1_size_5                                        10.712443
# division_1_size_3                                         8.818675
#
#                       $\frac{I_{1613}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                       1.601590
# division_1_size_5                                          1.683333
# division_1_size_3                                          1.223186
#
#                       $\frac{I_{1613}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       2.233473
# division_1_size_5                                          2.353396
# division_1_size_3                                          2.491063
#
#                       $\frac{I_{1613}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                       1.352421
# division_1_size_5                                          1.496286
# division_1_size_3                                          1.473896
#
#                       $\frac{I_{1613}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       2.395381
# division_1_size_5                                          2.642268
# division_1_size_3                                          2.704557
#
#                       $\frac{I_{1725}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           0.997904
# division_1_size_5                                              1.015167
# division_1_size_3                                              0.845248
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.125659
# division_1_size_5                                              0.120226
# division_1_size_3                                              0.108051
#
#                       $\frac{I_{1725}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.992156
# division_1_size_5                                               1.017119
# division_1_size_3                                               0.858839
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.297394
# division_1_size_5                                               0.277704
# division_1_size_3                                               0.269408
#
#                       $\frac{I_{1725}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.740330
# division_1_size_5                                               0.765324
# division_1_size_3                                               0.704381
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.556512
# division_1_size_5                                               0.559270
# division_1_size_3                                               0.529396
#
#                       $\frac{I_{1725}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.164956
# division_1_size_5                                              1.165077
# division_1_size_3                                              0.906052
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.357322
# division_1_size_5                                              0.341451
# division_1_size_3                                              0.273668
#
#                       $\frac{I_{1725}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                      8.902873
# division_1_size_5                                         4.118663
# division_1_size_3                                         3.251910
#
#                       $\frac{I_{1725}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                       0.677909
# division_1_size_5                                          0.647199
# division_1_size_3                                          0.451053
#
#                       $\frac{I_{1725}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       0.945368
# division_1_size_5                                          0.904821
# division_1_size_3                                          0.918586
#
#                       $\frac{I_{1725}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                       0.572443
# division_1_size_5                                          0.575284
# division_1_size_3                                          0.543503
#
#                       $\frac{I_{1725}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                       0.450530
# division_1_size_5                                          0.413132
# division_1_size_3                                          0.386721
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                                                  0.741885
# division_1_size_5                                                                     0.753890
# division_1_size_3                                                                     0.833343
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                                                 1.167403
# division_1_size_5                                                                    1.147670
# division_1_size_3                                                                    1.071937
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                                            8.921573
# division_1_size_5                                                               4.057128
# division_1_size_3                                                               3.847286
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                                             0.679333
# division_1_size_5                                                                0.637529
# division_1_size_3                                                                0.533634
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                             0.947354
# division_1_size_5                                                                0.891303
# division_1_size_3                                                                1.086766
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                             0.573645
# division_1_size_5                                                                0.566689
# division_1_size_3                                                                0.643010
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                             0.451476
# division_1_size_5                                                                0.406959
# division_1_size_3                                                                0.457524
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                             1.016029
# division_1_size_5                                                                1.000707
# division_1_size_3                                                                1.179906
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}800}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                                                  2.366675
# division_1_size_5                                                                     2.309854
# division_1_size_3                                                                     2.493330
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}800}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                                  4.428747
# division_1_size_5                                                                     4.651822
# division_1_size_3                                                                     4.899484
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}800}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                                                 2.843585
# division_1_size_5                                                                    2.840081
# division_1_size_3                                                                    2.532756
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                                                   0.746184
# division_1_size_5                                                                      0.752443
# division_1_size_3                                                                      0.820155
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                                                  1.174167
# division_1_size_5                                                                     1.145468
# division_1_size_3                                                                     1.054973
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                                             8.973264
# division_1_size_5                                                                4.049343
# division_1_size_3                                                                3.786402
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                                              0.683269
# division_1_size_5                                                                 0.636306
# division_1_size_3                                                                 0.525189
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                              0.952843
# division_1_size_5                                                                 0.889592
# division_1_size_3                                                                 1.069567
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                              0.576969
# division_1_size_5                                                                 0.565602
# division_1_size_3                                                                 0.632835
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                              0.454092
# division_1_size_5                                                                 0.406179
# division_1_size_3                                                                 0.450284
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                              1.021916
# division_1_size_5                                                                 0.998787
# division_1_size_3                                                                 1.161234
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}1500}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                                   1.871295
# division_1_size_5                                                                      2.013903
# division_1_size_3                                                                      1.965036
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}1500}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                                                  1.201511
# division_1_size_5                                                                     1.229550
# division_1_size_3                                                                     1.015812
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                                                  1.573562
# division_1_size_5                                                                     1.522331
# division_1_size_3                                                                     1.286309
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                                            12.025543
# division_1_size_5                                                                5.381591
# division_1_size_3                                                                4.616689
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                                              0.915685
# division_1_size_5                                                                 0.845653
# division_1_size_3                                                                 0.640353
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                              1.276955
# division_1_size_5                                                                 1.182272
# division_1_size_3                                                                 1.304103
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                              0.773227
# division_1_size_5                                                                 0.751686
# division_1_size_3                                                                 0.771603
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                              0.608552
# division_1_size_5                                                                 0.539813
# division_1_size_3                                                                 0.549022
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                              1.369523
# division_1_size_5                                                                 1.327392
# division_1_size_3                                                                 1.415870
#
#                       $\frac{\Sigma I_{p,\ 1500\text{–}1300}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                                                  0.642074
# division_1_size_5                                                                     0.610531
# division_1_size_3                                                                     0.516943
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                                            7.642240
# division_1_size_5                                                               3.535099
# division_1_size_3                                                               3.589099
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                                             0.581918
# division_1_size_5                                                                0.555499
# division_1_size_3                                                                0.497823
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                             0.811505
# division_1_size_5                                                                0.776619
# division_1_size_3                                                                1.013834
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                             0.491386
# division_1_size_5                                                                0.493773
# division_1_size_3                                                                0.599859
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                             0.386735
# division_1_size_5                                                                0.354596
# division_1_size_3                                                                0.426820
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                             0.870333
# division_1_size_5                                                                0.871947
# division_1_size_3                                                                1.100724
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                                        0.076145
# division_1_size_5                                                           0.157138
# division_1_size_3                                                           0.138704
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                        0.106187
# division_1_size_5                                                           0.219688
# division_1_size_3                                                           0.282476
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                        0.064299
# division_1_size_5                                                           0.139677
# division_1_size_3                                                           0.167133
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                        0.050605
# division_1_size_5                                                           0.100307
# division_1_size_3                                                           0.118921
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                        0.113884
# division_1_size_5                                                           0.246654
# division_1_size_3                                                           0.306685
#
#                       $\frac{\overline{I}_{1107 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                         1.394535
# division_1_size_5                                                            1.398057
# division_1_size_3                                                            2.036537
#
#                       $\frac{\overline{I}_{1107 \pm 25}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                         0.844424
# division_1_size_5                                                            0.888883
# division_1_size_3                                                            1.204964
#
#                       $\frac{\overline{I}_{1107 \pm 25}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                         0.664587
# division_1_size_5                                                            0.638338
# division_1_size_3                                                            0.857374
#
#                       $\frac{\overline{I}_{1107 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.495626
# division_1_size_5                                                            1.569664
# division_1_size_3                                                            2.211076
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                         0.605524
# division_1_size_5                                                            0.635799
# division_1_size_3                                                            0.591673
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                         0.476565
# division_1_size_5                                                            0.456590
# division_1_size_3                                                            0.420996
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.072491
# division_1_size_5                                                            1.122747
# division_1_size_3                                                            1.085704
#
#                       $\frac{\overline{I}_{1393 \pm 25}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                         0.787030
# division_1_size_5                                                            0.718136
# division_1_size_3                                                            0.711534
#
#                       $\frac{\overline{I}_{1393 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.771179
# division_1_size_5                                                            1.765885
# division_1_size_3                                                            1.834972
#
#                       $\frac{\overline{I}_{1613 \pm 25}}{\overline{I}_{1725 \pm 25}}$
# division_1_size_bulk                                                         2.250460
# division_1_size_5                                                            2.458985
# division_1_size_3                                                            2.578894

# %%
dataset_test = dataset.loc[dataset['Split'] == 'Test']

X_test = dataset_test.loc[:, ~dataset_test.columns.isin(['Split', 'Fraction_hue', 'Fraction_grouped_hue', 'Class'])]
y_test = dataset_test['Class']

hue_train = dataset_test['Fraction_grouped_hue'].tolist()

print(
    f'(*) X_train: {X_test.shape}',
    f'(*) y_train: {y_test.shape}',
    sep='\n'
)
X_test.head(3)
# Out:
# (*) X_train: (19, 203)
# (*) y_train: (19,)
#                       $I_{873}$  $I_{1107}$  $I_{1241}$  $I_{1393}$  \
# division_1_size_2      0.051659    0.549619    0.365123    0.746028
# division_2_size_2      0.471485    0.926573    0.547706    0.594271
# division_3_size_bulk   0.097737    0.750682    0.780380    0.507825
#
#                       $I_{1613}$  $I_{1725}$  \
# division_1_size_2       0.862042    0.505776
# division_2_size_2       0.715256    0.386647
# division_3_size_bulk    0.278390    0.329510
#
#                       $\overline{I}_{1900\text{–}800}$  \
# division_1_size_2                             0.483747
# division_2_size_2                             0.538366
# division_3_size_bulk                          0.381680
#
#                       $\Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_2                             3.080247
# division_2_size_2                             3.641937
# division_3_size_bulk                          2.744524
#
#                       $\overline{I}_{1900\text{–}1500}$  \
# division_1_size_2                              0.618835
# division_2_size_2                              0.404388
# division_3_size_bulk                           0.161510
#
#                       $\Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_2                              1.367818
# division_2_size_2                              1.101903
# division_3_size_bulk                           0.607901
#
#                       $\overline{I}_{1500\text{–}1300}$  \
# division_1_size_2                              0.620859
# division_2_size_2                              0.509088
# division_3_size_bulk                           0.395469
#
#                       $\Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_2                              0.746028
# division_2_size_2                              0.594271
# division_3_size_bulk                           0.507825
#
#                       $\overline{I}_{1300\text{–}800}$  \
# division_1_size_2                             0.321041
# division_2_size_2                             0.657173
# division_3_size_bulk                          0.552231
#
#                       $\Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_2                             0.966401
# division_2_size_2                             1.945763
# division_3_size_bulk                          1.628799
#
#                       $\overline{I}_{873 \pm 25}$  \
# division_1_size_2                        0.052303
# division_2_size_2                        0.480447
# division_3_size_bulk                     0.100433
#
#                       $\overline{I}_{1107 \pm 25}$  \
# division_1_size_2                         0.549785
# division_2_size_2                         0.927503
# division_3_size_bulk                      0.770813
#
#                       $\overline{I}_{1241 \pm 25}$  \
# division_1_size_2                         0.363182
# division_2_size_2                         0.554685
# division_3_size_bulk                      0.771173
#
#                       $\overline{I}_{1393 \pm 25}$  \
# division_1_size_2                         0.730273
# division_2_size_2                         0.581398
# division_3_size_bulk                      0.496584
#
#                       $\overline{I}_{1613 \pm 25}$  \
# division_1_size_2                         0.870269
# division_2_size_2                         0.712557
# division_3_size_bulk                      0.271598
#
#                       $\overline{I}_{1725 \pm 25}$  $\log I_{873}$  \
# division_1_size_2                         0.523490       -2.963100
# division_2_size_2                         0.388039       -0.751868
# division_3_size_bulk                      0.302098       -2.325471
#
#                       $(I_{873})^{-1}$  $\log I_{1107}$  $(I_{1107})^{-1}$  \
# division_1_size_2            19.357879        -0.598530           1.819442
# division_2_size_2             2.120959        -0.076263           1.079246
# division_3_size_bulk         10.231501        -0.286774           1.332123
#
#                       $\log I_{1241}$  $(I_{1241})^{-1}$  $\log I_{1393}$  \
# division_1_size_2           -1.007520           2.738801        -0.292992
# division_2_size_2           -0.602017           1.825798        -0.520419
# division_3_size_bulk        -0.247975           1.281428        -0.677618
#
#                       $(I_{1393})^{-1}$  $\log I_{1613}$  $(I_{1613})^{-1}$  \
# division_1_size_2              1.340432        -0.148451           1.160036
# division_2_size_2              1.682733        -0.335115           1.398101
# division_3_size_bulk           1.969182        -1.278732           3.592081
#
#                       $\log I_{1725}$  $(I_{1725})^{-1}$  \
# division_1_size_2           -0.681662           1.977161
# division_2_size_2           -0.950244           2.586340
# division_3_size_bulk        -1.110147           3.034805
#
#                       $\log \overline{I}_{1900\text{–}800}$  \
# division_1_size_2                                 -0.726194
# division_2_size_2                                 -0.619217
# division_3_size_bulk                              -0.963173
#
#                       $(\overline{I}_{1900\text{–}800})^{-1}$  \
# division_1_size_2                                    2.067198
# division_2_size_2                                    1.857474
# division_3_size_bulk                                 2.619996
#
#                       $\log \Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_2                                  1.125010
# division_2_size_2                                  1.292516
# division_3_size_bulk                               1.009608
#
#                       $(\Sigma I_{p,\ 1900\text{–}800})^{-1}$  \
# division_1_size_2                                    0.324649
# division_2_size_2                                    0.274579
# division_3_size_bulk                                 0.364362
#
#                       $\log \overline{I}_{1900\text{–}1500}$  \
# division_1_size_2                                  -0.479916
# division_2_size_2                                  -0.905380
# division_3_size_bulk                               -1.823186
#
#                       $(\overline{I}_{1900\text{–}1500})^{-1}$  \
# division_1_size_2                                     1.615939
# division_2_size_2                                     2.472871
# division_3_size_bulk                                  6.191555
#
#                       $\log \Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_2                                   0.313217
# division_2_size_2                                   0.097038
# division_3_size_bulk                               -0.497744
#
#                       $(\Sigma I_{p,\ 1900\text{–}1500})^{-1}$  \
# division_1_size_2                                     0.731091
# division_2_size_2                                     0.907521
# division_3_size_bulk                                  1.645006
#
#                       $\log \overline{I}_{1500\text{–}1300}$  \
# division_1_size_2                                  -0.476651
# division_2_size_2                                  -0.675134
# division_3_size_bulk                               -0.927683
#
#                       $(\overline{I}_{1500\text{–}1300})^{-1}$  \
# division_1_size_2                                     1.610671
# division_2_size_2                                     1.964295
# division_3_size_bulk                                  2.528644
#
#                       $\log \Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_2                                  -0.292992
# division_2_size_2                                  -0.520419
# division_3_size_bulk                               -0.677618
#
#                       $(\Sigma I_{p,\ 1500\text{–}1300})^{-1}$  \
# division_1_size_2                                     1.340432
# division_2_size_2                                     1.682733
# division_3_size_bulk                                  1.969182
#
#                       $\log \overline{I}_{1300\text{–}800}$  \
# division_1_size_2                                 -1.136186
# division_2_size_2                                 -0.419808
# division_3_size_bulk                              -0.593788
#
#                       $(\overline{I}_{1300\text{–}800})^{-1}$  \
# division_1_size_2                                    3.114866
# division_2_size_2                                    1.521669
# division_3_size_bulk                                 1.810835
#
#                       $\log \Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_2                                 -0.034176
# division_2_size_2                                  0.665654
# division_3_size_bulk                               0.487843
#
#                       $(\Sigma I_{p,\ 1300\text{–}800})^{-1}$  \
# division_1_size_2                                    1.034767
# division_2_size_2                                    0.513937
# division_3_size_bulk                                 0.613949
#
#                       $\log \overline{I}_{873 \pm 25}$  \
# division_1_size_2                            -2.950702
# division_2_size_2                            -0.733038
# division_3_size_bulk                         -2.298259
#
#                       $(\overline{I}_{873 \pm 25})^{-1}$  \
# division_1_size_2                              19.119376
# division_2_size_2                               2.081394
# division_3_size_bulk                            9.956837
#
#                       $\log \overline{I}_{1107 \pm 25}$  \
# division_1_size_2                             -0.598229
# division_2_size_2                             -0.075259
# division_3_size_bulk                          -0.260309
#
#                       $(\overline{I}_{1107 \pm 25})^{-1}$  \
# division_1_size_2                                1.818894
# division_2_size_2                                1.078164
# division_3_size_bulk                             1.297331
#
#                       $\log \overline{I}_{1241 \pm 25}$  \
# division_1_size_2                             -1.012852
# division_2_size_2                             -0.589355
# division_3_size_bulk                          -0.259843
#
#                       $(\overline{I}_{1241 \pm 25})^{-1}$  \
# division_1_size_2                                2.753442
# division_2_size_2                                1.802825
# division_3_size_bulk                             1.296726
#
#                       $\log \overline{I}_{1393 \pm 25}$  \
# division_1_size_2                             -0.314337
# division_2_size_2                             -0.542319
# division_3_size_bulk                          -0.700003
#
#                       $(\overline{I}_{1393 \pm 25})^{-1}$  \
# division_1_size_2                                1.369352
# division_2_size_2                                1.719992
# division_3_size_bulk                             2.013759
#
#                       $\log \overline{I}_{1613 \pm 25}$  \
# division_1_size_2                             -0.138953
# division_2_size_2                             -0.338896
# division_3_size_bulk                          -1.303431
#
#                       $(\overline{I}_{1613 \pm 25})^{-1}$  \
# division_1_size_2                                1.149070
# division_2_size_2                                1.403397
# division_3_size_bulk                             3.681909
#
#                       $\log \overline{I}_{1725 \pm 25}$  \
# division_1_size_2                             -0.647237
# division_2_size_2                             -0.946649
# division_3_size_bulk                          -1.197004
#
#                       $(\overline{I}_{1725 \pm 25})^{-1}$  \
# division_1_size_2                                1.910255
# division_2_size_2                                2.577060
# division_3_size_bulk                             3.310185
#
#                       $\frac{I_{873}}{I_{1107}}$  $\frac{I_{873}}{I_{1241}}$  \
# division_1_size_2                       0.093990                    0.141483
# division_2_size_2                       0.508848                    0.860836
# division_3_size_bulk                    0.130198                    0.125243
#
#                       $\frac{I_{873}}{I_{1393}}$  $\frac{I_{873}}{I_{1613}}$  \
# division_1_size_2                       0.069245                    0.059926
# division_2_size_2                       0.793383                    0.659183
# division_3_size_bulk                    0.192463                    0.351081
#
#                       $\frac{I_{873}}{I_{1725}}$  \
# division_1_size_2                       0.102137
# division_2_size_2                       1.219420
# division_3_size_bulk                    0.296614
#
#                       $\frac{I_{873}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_2                                             0.106788
# division_2_size_2                                             0.875771
# division_3_size_bulk                                          0.256071
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_2                                             0.016771
# division_2_size_2                                             0.129460
# division_3_size_bulk                                          0.035612
#
#                       $\frac{I_{873}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_2                                              0.083477
# division_2_size_2                                              1.165921
# division_3_size_bulk                                           0.605146
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_2                                              0.037767
# division_2_size_2                                              0.427882
# division_3_size_bulk                                           0.160779
#
#                       $\frac{I_{873}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_2                                              0.083205
# division_2_size_2                                              0.926136
# division_3_size_bulk                                           0.247143
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_2                                              0.069245
# division_2_size_2                                              0.793383
# division_3_size_bulk                                           0.192463
#
#                       $\frac{I_{873}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_2                                             0.160909
# division_2_size_2                                             0.717444
# division_3_size_bulk                                          0.176986
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_2                                             0.053455
# division_2_size_2                                             0.242314
# division_3_size_bulk                                          0.060006
#
#                       $\frac{I_{873}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_2                                         0.093961
# division_2_size_2                                         0.508338
# division_3_size_bulk                                      0.126798
#
#                       $\frac{I_{873}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_2                                         0.142239
# division_2_size_2                                         0.850004
# division_3_size_bulk                                      0.126739
#
#                       $\frac{I_{873}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_2                                         0.070739
# division_2_size_2                                         0.810950
# division_3_size_bulk                                      0.196819
#
#                       $\frac{I_{873}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_2                                         0.059359
# division_2_size_2                                         0.661681
# division_3_size_bulk                                      0.359860
#
#                       $\frac{I_{873}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_2                                         0.098681
# division_2_size_2                                         1.215045
# division_3_size_bulk                                      0.323529
#
#                       $\frac{I_{1107}}{I_{1241}}$  \
# division_1_size_2                        1.505298
# division_2_size_2                        1.691735
# division_3_size_bulk                     0.961944
#
#                       $\frac{I_{1107}}{I_{1393}}$  \
# division_1_size_2                        0.736727
# division_2_size_2                        1.559175
# division_3_size_bulk                     1.478228
#
#                       $\frac{I_{1107}}{I_{1613}}$  \
# division_1_size_2                        0.637578
# division_2_size_2                        1.295443
# division_3_size_bulk                     2.696509
#
#                       $\frac{I_{1107}}{I_{1725}}$  \
# division_1_size_2                        1.086686
# division_2_size_2                        2.396432
# division_3_size_bulk                     2.278172
#
#                       $\frac{I_{1107}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_2                                              1.136172
# division_2_size_2                                              1.721085
# division_3_size_bulk                                           1.966783
#
#                       $\frac{I_{1107}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_2                                              0.178433
# division_2_size_2                                              0.254418
# division_3_size_bulk                                           0.273520
#
#                       $\frac{I_{1107}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_2                                               0.888151
# division_2_size_2                                               2.291295
# division_3_size_bulk                                            4.647886
#
#                       $\frac{I_{1107}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_2                                               0.401822
# division_2_size_2                                               0.840884
# division_3_size_bulk                                            1.234875
#
#                       $\frac{I_{1107}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_2                                               0.885255
# division_2_size_2                                               1.820063
# division_3_size_bulk                                            1.898207
#
#                       $\frac{I_{1107}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_2                                               0.736727
# division_2_size_2                                               1.559175
# division_3_size_bulk                                            1.478228
#
#                       $\frac{I_{1107}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_2                                              1.711990
# division_2_size_2                                              1.409937
# division_3_size_bulk                                           1.359361
#
#                       $\frac{I_{1107}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_2                                              0.568728
# division_2_size_2                                              0.476200
# division_3_size_bulk                                           0.460881
#
#                       $\frac{I_{1107}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_2                                        10.508375
# division_2_size_2                                         1.928563
# division_3_size_bulk                                      7.474414
#
#                       $\frac{I_{1107}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_2                                          1.513344
# division_2_size_2                                          1.670448
# division_3_size_bulk                                       0.973429
#
#                       $\frac{I_{1107}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_2                                          0.752622
# division_2_size_2                                          1.593698
# division_3_size_bulk                                       1.511692
#
#                       $\frac{I_{1107}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_2                                          0.631551
# division_2_size_2                                          1.300350
# division_3_size_bulk                                       2.763941
#
#                       $\frac{I_{1107}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_2                                          1.049913
# division_2_size_2                                          2.387834
# division_3_size_bulk                                       2.484895
#
#                       $\frac{I_{1241}}{I_{1393}}$  \
# division_1_size_2                        0.489423
# division_2_size_2                        0.921642
# division_3_size_bulk                     1.536709
#
#                       $\frac{I_{1241}}{I_{1613}}$  \
# division_1_size_2                        0.423556
# division_2_size_2                        0.765748
# division_3_size_bulk                     2.803187
#
#                       $\frac{I_{1241}}{I_{1725}}$  \
# division_1_size_2                        0.721907
# division_2_size_2                        1.416553
# division_3_size_bulk                     2.368300
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_2                                              0.754782
# division_2_size_2                                              1.017349
# division_3_size_bulk                                           2.044591
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_2                                              0.118537
# division_2_size_2                                              0.150389
# division_3_size_bulk                                           0.284341
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_2                                               0.590017
# division_2_size_2                                               1.354405
# division_3_size_bulk                                            4.831763
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_2                                               0.266938
# division_2_size_2                                               0.497054
# division_3_size_bulk                                            1.283729
#
#                       $\frac{I_{1241}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_2                                               0.588093
# division_2_size_2                                               1.075856
# division_3_size_bulk                                            1.973303
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_2                                               0.489423
# division_2_size_2                                               0.921642
# division_3_size_bulk                                            1.536709
#
#                       $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_2                                              1.137310
# division_2_size_2                                              0.833427
# division_3_size_bulk                                           1.413139
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_2                                              0.377818
# division_2_size_2                                              0.281486
# division_3_size_bulk                                           0.479114
#
#                       $\frac{I_{1241}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_2                                         6.980929
# division_2_size_2                                         1.139991
# division_3_size_bulk                                      7.770113
#
#                       $\frac{I_{1241}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_2                                          0.664121
# division_2_size_2                                          0.590516
# division_3_size_bulk                                       1.012410
#
#                       $\frac{I_{1241}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_2                                          0.499982
# division_2_size_2                                          0.942049
# division_3_size_bulk                                       1.571496
#
#                       $\frac{I_{1241}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_2                                          0.419552
# division_2_size_2                                          0.768649
# division_3_size_bulk                                       2.873286
#
#                       $\frac{I_{1241}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_2                                          0.697478
# division_2_size_2                                          1.411470
# division_3_size_bulk                                       2.583201
#
#                       $\frac{I_{1393}}{I_{1613}}$  \
# division_1_size_2                        0.865419
# division_2_size_2                        0.830852
# division_3_size_bulk                     1.824149
#
#                       $\frac{I_{1393}}{I_{1725}}$  \
# division_1_size_2                        1.475018
# division_2_size_2                        1.536988
# division_3_size_bulk                     1.541150
#
#                       $\frac{I_{1393}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_2                                              1.542188
# division_2_size_2                                              1.103843
# division_3_size_bulk                                           1.330500
#
#                       $\frac{I_{1393}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_2                                              0.242197
# division_2_size_2                                              0.163175
# division_3_size_bulk                                           0.185032
#
#                       $\frac{I_{1393}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_2                                               1.205536
# division_2_size_2                                               1.469556
# division_3_size_bulk                                            3.144228
#
#                       $\frac{I_{1393}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_2                                               0.545415
# division_2_size_2                                               0.539314
# division_3_size_bulk                                            0.835375
#
#                       $\frac{I_{1393}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_2                                               1.201606
# division_2_size_2                                               1.167325
# division_3_size_bulk                                            1.284109
#
#                       $\frac{I_{1393}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_2                                                    1.0
# division_2_size_2                                                    1.0
# division_3_size_bulk                                                 1.0
#
#                       $\frac{I_{1393}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_2                                              2.323778
# division_2_size_2                                              0.904285
# division_3_size_bulk                                           0.919588
#
#                       $\frac{I_{1393}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_2                                              0.771965
# division_2_size_2                                              0.305418
# division_3_size_bulk                                           0.311779
#
#                       $\frac{I_{1393}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_2                                        14.263592
# division_2_size_2                                         1.236913
# division_3_size_bulk                                      5.056333
#
#                       $\frac{I_{1393}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_2                                          1.356946
# division_2_size_2                                          0.640722
# division_3_size_bulk                                       0.658817
#
#                       $\frac{I_{1393}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_2                                          2.054145
# division_2_size_2                                          1.071367
# division_3_size_bulk                                       0.658510
#
#                       $\frac{I_{1393}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_2                                          0.857238
# division_2_size_2                                          0.833999
# division_3_size_bulk                                       1.869766
#
#                       $\frac{I_{1393}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_2                                          1.425104
# division_2_size_2                                          1.531473
# division_3_size_bulk                                       1.680995
#
#                       $\frac{I_{1613}}{I_{1725}}$  \
# division_1_size_2                        1.704397
# division_2_size_2                        1.849895
# division_3_size_bulk                     0.844860
#
#                       $\frac{I_{1613}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_2                                              1.782013
# division_2_size_2                                              1.328569
# division_3_size_bulk                                           0.729381
#
#                       $\frac{I_{1613}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_2                                              0.279861
# division_2_size_2                                              0.196394
# division_3_size_bulk                                           0.101435
#
#                       $\frac{I_{1613}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_2                                               1.393008
# division_2_size_2                                               1.768735
# division_3_size_bulk                                            1.723668
#
#                       $\frac{I_{1613}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_2                                               0.630232
# division_2_size_2                                               0.649110
# division_3_size_bulk                                            0.457953
#
#                       $\frac{I_{1613}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_2                                               1.388466
# division_2_size_2                                               1.404974
# division_3_size_bulk                                            0.703950
#
#                       $\frac{I_{1613}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_2                                               1.155509
# division_2_size_2                                               1.203584
# division_3_size_bulk                                            0.548201
#
#                       $\frac{I_{1613}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_2                                              2.685147
# division_2_size_2                                              1.088383
# division_3_size_bulk                                           0.504119
#
#                       $\frac{I_{1613}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_2                                              0.892013
# division_2_size_2                                              0.367597
# division_3_size_bulk                                           0.170917
#
#                       $\frac{I_{1613}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_2                                        16.481714
# division_2_size_2                                         1.488729
# division_3_size_bulk                                      2.771885
#
#                       $\frac{I_{1613}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_2                                          1.567964
# division_2_size_2                                          0.771163
# division_3_size_bulk                                       0.361164
#
#                       $\frac{I_{1613}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_2                                          2.373584
# division_2_size_2                                          1.289481
# division_3_size_bulk                                       0.360996
#
#                       $\frac{I_{1613}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_2                                          1.180439
# division_2_size_2                                          1.230234
# division_3_size_bulk                                       0.560611
#
#                       $\frac{I_{1613}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_2                                          1.646721
# division_2_size_2                                          1.843258
# division_3_size_bulk                                       0.921523
#
#                       $\frac{I_{1725}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_2                                              1.045539
# division_2_size_2                                              0.718186
# division_3_size_bulk                                           0.863316
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_2                                              0.164200
# division_2_size_2                                              0.106165
# division_3_size_bulk                                           0.120061
#
#                       $\frac{I_{1725}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_2                                               0.817303
# division_2_size_2                                               0.956128
# division_3_size_bulk                                            2.040182
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_2                                               0.369768
# division_2_size_2                                               0.350890
# division_3_size_bulk                                            0.542047
#
#                       $\frac{I_{1725}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_2                                               0.814638
# division_2_size_2                                               0.759489
# division_3_size_bulk                                            0.833215
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_2                                               0.677958
# division_2_size_2                                               0.650623
# division_3_size_bulk                                            0.648866
#
#                       $\frac{I_{1725}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_2                                              1.575423
# division_2_size_2                                              0.588349
# division_3_size_bulk                                           0.596689
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_2                                              0.523360
# division_2_size_2                                              0.198712
# division_3_size_bulk                                           0.202303
#
#                       $\frac{I_{1725}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_2                                         9.670116
# division_2_size_2                                         0.804764
# division_3_size_bulk                                      3.280882
#
#                       $\frac{I_{1725}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_2                                          0.919952
# division_2_size_2                                          0.416868
# division_3_size_bulk                                       0.427484
#
#                       $\frac{I_{1725}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_2                                          1.392624
# division_2_size_2                                          0.697056
# division_3_size_bulk                                       0.427285
#
#                       $\frac{I_{1725}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_2                                          0.692585
# division_2_size_2                                          0.665029
# division_3_size_bulk                                       0.663555
#
#                       $\frac{I_{1725}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_2                                          0.581172
# division_2_size_2                                          0.542619
# division_3_size_bulk                                       1.213227
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_2                                                                     0.779156
# division_2_size_2                                                                     1.057509
# division_3_size_bulk                                                                  0.965133
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_2                                                                    1.506806
# division_2_size_2                                                                    0.819215
# division_3_size_bulk                                                                 0.691160
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_2                                                               9.248932
# division_2_size_2                                                               1.120551
# division_3_size_bulk                                                            3.800326
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_2                                                                0.879884
# division_2_size_2                                                                0.580446
# division_3_size_bulk                                                             0.495165
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_2                                                                1.331968
# division_2_size_2                                                                0.970579
# division_3_size_bulk                                                             0.494935
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_2                                                                0.662419
# division_2_size_2                                                                0.925984
# division_3_size_bulk                                                             0.768612
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_2                                                                0.555859
# division_2_size_2                                                                0.755541
# division_3_size_bulk                                                             1.405311
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_2                                                                0.924079
# division_2_size_2                                                                1.387401
# division_3_size_bulk                                                             1.263432
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}800}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_2                                                                     2.251942
# division_2_size_2                                                                     3.305135
# division_3_size_bulk                                                                  4.514758
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}800}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_2                                                                     4.128862
# division_2_size_2                                                                     6.128408
# division_3_size_bulk                                                                  5.404467
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}800}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_2                                                                    3.187339
# division_2_size_2                                                                    1.871727
# division_3_size_bulk                                                                 1.684999
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_2                                                                      0.996740
# division_2_size_2                                                                      0.794338
# division_3_size_bulk                                                                   0.408402
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_2                                                                     1.927589
# division_2_size_2                                                                     0.615345
# division_3_size_bulk                                                                  0.292469
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_2                                                               11.831742
# division_2_size_2                                                                0.841691
# division_3_size_bulk                                                             1.608132
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_2                                                                 1.125596
# division_2_size_2                                                                 0.435997
# division_3_size_bulk                                                              0.209532
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_2                                                                 1.703927
# division_2_size_2                                                                 0.729041
# division_3_size_bulk                                                              0.209435
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_2                                                                 0.847403
# division_2_size_2                                                                 0.695544
# division_3_size_bulk                                                              0.325243
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_2                                                                 0.711085
# division_2_size_2                                                                 0.567517
# division_3_size_bulk                                                              0.594666
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_2                                                                 1.182133
# division_2_size_2                                                                 1.042133
# division_3_size_bulk                                                              0.534629
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}1500}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_2                                                                      1.833467
# division_2_size_2                                                                      1.854208
# division_3_size_bulk                                                                   1.197067
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}1500}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_2                                                                     1.415373
# division_2_size_2                                                                     0.566309
# division_3_size_bulk                                                                  0.373220
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_2                                                                     1.933894
# division_2_size_2                                                                     0.774664
# division_3_size_bulk                                                                  0.716129
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_2                                                               11.870445
# division_2_size_2                                                                1.059613
# division_3_size_bulk                                                             3.937619
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_2                                                                 1.129278
# division_2_size_2                                                                 0.548881
# division_3_size_bulk                                                              0.513054
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_2                                                                 1.709500
# division_2_size_2                                                                 0.917797
# division_3_size_bulk                                                              0.512815
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_2                                                                 0.850175
# division_2_size_2                                                                 0.875628
# division_3_size_bulk                                                              0.796379
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_2                                                                 0.713411
# division_2_size_2                                                                 0.714453
# division_3_size_bulk                                                              1.456080
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_2                                                                 1.186000
# division_2_size_2                                                                 1.311952
# division_3_size_bulk                                                              1.309075
#
#                       $\frac{\Sigma I_{p,\ 1500\text{–}1300}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_2                                                                     0.771965
# division_2_size_2                                                                     0.305418
# division_3_size_bulk                                                                  0.311779
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_2                                                               6.138105
# division_2_size_2                                                               1.367836
# division_3_size_bulk                                                            5.498478
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_2                                                                0.583940
# division_2_size_2                                                                0.708540
# division_3_size_bulk                                                             0.716427
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_2                                                                0.883968
# division_2_size_2                                                                1.184768
# division_3_size_bulk                                                             0.716093
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_2                                                                0.439618
# division_2_size_2                                                                1.130332
# division_3_size_bulk                                                             1.112061
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_2                                                                0.368899
# division_2_size_2                                                                0.922275
# division_3_size_bulk                                                             2.033265
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_2                                                                0.613270
# division_2_size_2                                                                1.693575
# division_3_size_bulk                                                             1.827988
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_2                                                           0.095134
# division_2_size_2                                                           0.518001
# division_3_size_bulk                                                        0.130295
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_2                                                           0.144013
# division_2_size_2                                                           0.866162
# division_3_size_bulk                                                        0.130235
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_2                                                           0.071621
# division_2_size_2                                                           0.826365
# division_3_size_bulk                                                        0.202249
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_2                                                           0.060100
# division_2_size_2                                                           0.674258
# division_3_size_bulk                                                        0.369787
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_2                                                           0.099912
# division_2_size_2                                                           1.238142
# division_3_size_bulk                                                        0.332453
#
#                       $\frac{\overline{I}_{1107 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_2                                                            1.513800
# division_2_size_2                                                            1.672125
# division_3_size_bulk                                                         0.999534
#
#                       $\frac{\overline{I}_{1107 \pm 25}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_2                                                            0.752848
# division_2_size_2                                                            1.595298
# division_3_size_bulk                                                         1.552232
#
#                       $\frac{\overline{I}_{1107 \pm 25}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_2                                                            0.631741
# division_2_size_2                                                            1.301655
# division_3_size_bulk                                                         2.838065
#
#                       $\frac{\overline{I}_{1107 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_2                                                            1.050229
# division_2_size_2                                                            2.390231
# division_3_size_bulk                                                         2.551535
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_2                                                            0.497324
# division_2_size_2                                                            0.954054
# division_3_size_bulk                                                         1.552956
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_2                                                            0.417321
# division_2_size_2                                                            0.778444
# division_3_size_bulk                                                         2.839387
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_2                                                            0.693770
# division_2_size_2                                                            1.429457
# division_3_size_bulk                                                         2.552724
#
#                       $\frac{\overline{I}_{1393 \pm 25}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_2                                                            0.839134
# division_2_size_2                                                            0.815933
# division_3_size_bulk                                                         1.828376
#
#                       $\frac{\overline{I}_{1393 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_2                                                            1.395007
# division_2_size_2                                                            1.498298
# division_3_size_bulk                                                         1.643784
#
#                       $\frac{\overline{I}_{1613 \pm 25}}{\overline{I}_{1725 \pm 25}}$
# division_1_size_2                                                            1.662436
# division_2_size_2                                                            1.836301
# division_3_size_bulk                                                         0.899041

# %%
dataset = pd.concat([dataset_train, dataset_test], axis=0)

print(dataset.shape)
dataset.head(3)
# Out:
# (75, 207)
#                       $I_{873}$  $I_{1107}$  $I_{1241}$  $I_{1393}$  \
# division_1_size_bulk   0.048208    0.681294    0.455066    0.760582
# division_1_size_5      0.091875    0.606138    0.427988    0.687458
# division_1_size_3      0.110321    0.836176    0.400950    0.696553
#
#                       $I_{1613}$  $I_{1725}$  \
# division_1_size_bulk         1.0    0.423273
# division_1_size_5            1.0    0.384475
# division_1_size_3            1.0    0.368753
#
#                       $\overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                          0.424162
# division_1_size_5                             0.378730
# division_1_size_3                             0.436266
#
#                       $\Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                          3.368423
# division_1_size_5                             3.197934
# division_1_size_3                             3.412752
#
#                       $\overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                           0.426619
# division_1_size_5                              0.378004
# division_1_size_3                              0.429362
#
#                       $\Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                           1.423273
# division_1_size_5                              1.384475
# division_1_size_3                              1.368753
#
#                       $\overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                           0.571735
# division_1_size_5                              0.502368
# division_1_size_3                              0.523513
#
#                       $\Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                           0.760582
# division_1_size_5                              0.687458
# division_1_size_3                              0.696553
#
#                       $\overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                          0.363338
# division_1_size_5                             0.329999
# division_1_size_3                             0.406988
#
#                       $\Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                          1.184569
# division_1_size_5                             1.126001
# division_1_size_3                             1.347446
#
#                       $\overline{I}_{873 \pm 25}$  \
# division_1_size_bulk                     0.047543
# division_1_size_5                        0.093349
# division_1_size_3                        0.113396
#
#                       $\overline{I}_{1107 \pm 25}$  \
# division_1_size_bulk                      0.624379
# division_1_size_5                         0.594059
# division_1_size_3                         0.817537
#
#                       $\overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                      0.447733
# division_1_size_5                         0.424918
# division_1_size_3                         0.401435
#
#                       $\overline{I}_{1393 \pm 25}$  \
# division_1_size_bulk                      0.739415
# division_1_size_5                         0.668322
# division_1_size_3                         0.678474
#
#                       $\overline{I}_{1613 \pm 25}$  \
# division_1_size_bulk                      0.939500
# division_1_size_5                         0.930634
# division_1_size_3                         0.953537
#
#                       $\overline{I}_{1725 \pm 25}$  $\log I_{873}$  \
# division_1_size_bulk                      0.417470       -3.032222
# division_1_size_5                         0.378463       -2.387325
# division_1_size_3                         0.369746       -2.204364
#
#                       $(I_{873})^{-1}$  $\log I_{1107}$  $(I_{1107})^{-1}$  \
# division_1_size_bulk         20.743271        -0.383761           1.467794
# division_1_size_5            10.884335        -0.500648           1.649790
# division_1_size_3             9.064483        -0.178917           1.195921
#
#                       $\log I_{1241}$  $(I_{1241})^{-1}$  $\log I_{1393}$  \
# division_1_size_bulk        -0.787312           2.197482        -0.273672
# division_1_size_5           -0.848660           2.336514        -0.374754
# division_1_size_3           -0.913918           2.494076        -0.361611
#
#                       $(I_{1393})^{-1}$  $\log I_{1613}$  $(I_{1613})^{-1}$  \
# division_1_size_bulk           1.314783              0.0                1.0
# division_1_size_5              1.454634              0.0                1.0
# division_1_size_3              1.435640              0.0                1.0
#
#                       $\log I_{1725}$  $(I_{1725})^{-1}$  \
# division_1_size_bulk        -0.859739           2.362543
# division_1_size_5           -0.955877           2.600952
# division_1_size_3           -0.997629           2.711845
#
#                       $\log \overline{I}_{1900\text{–}800}$  \
# division_1_size_bulk                              -0.857641
# division_1_size_5                                 -0.970931
# division_1_size_3                                 -0.829504
#
#                       $(\overline{I}_{1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.357591
# division_1_size_5                                    2.640400
# division_1_size_3                                    2.292181
#
#                       $\log \Sigma I_{p,\ 1900\text{–}800}$  \
# division_1_size_bulk                               1.214445
# division_1_size_5                                  1.162505
# division_1_size_3                                  1.227519
#
#                       $(\Sigma I_{p,\ 1900\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.296875
# division_1_size_5                                    0.312702
# division_1_size_3                                    0.293019
#
#                       $\log \overline{I}_{1900\text{–}1500}$  \
# division_1_size_bulk                               -0.851863
# division_1_size_5                                  -0.972851
# division_1_size_3                                  -0.845455
#
#                       $(\overline{I}_{1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  2.344010
# division_1_size_5                                     2.645477
# division_1_size_3                                     2.329038
#
#                       $\log \Sigma I_{p,\ 1900\text{–}1500}$  \
# division_1_size_bulk                                0.352959
# division_1_size_5                                   0.325321
# division_1_size_3                                   0.313900
#
#                       $(\Sigma I_{p,\ 1900\text{–}1500})^{-1}$  \
# division_1_size_bulk                                  0.702606
# division_1_size_5                                     0.722296
# division_1_size_3                                     0.730592
#
#                       $\log \overline{I}_{1500\text{–}1300}$  \
# division_1_size_bulk                               -0.559080
# division_1_size_5                                  -0.688422
# division_1_size_3                                  -0.647194
#
#                       $(\overline{I}_{1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.749062
# division_1_size_5                                     1.990572
# division_1_size_3                                     1.910173
#
#                       $\log \Sigma I_{p,\ 1500\text{–}1300}$  \
# division_1_size_bulk                               -0.273672
# division_1_size_5                                  -0.374754
# division_1_size_3                                  -0.361611
#
#                       $(\Sigma I_{p,\ 1500\text{–}1300})^{-1}$  \
# division_1_size_bulk                                  1.314783
# division_1_size_5                                     1.454634
# division_1_size_3                                     1.435640
#
#                       $\log \overline{I}_{1300\text{–}800}$  \
# division_1_size_bulk                              -1.012422
# division_1_size_5                                 -1.108665
# division_1_size_3                                 -0.898970
#
#                       $(\overline{I}_{1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 2.752259
# division_1_size_5                                    3.030309
# division_1_size_3                                    2.457072
#
#                       $\log \Sigma I_{p,\ 1300\text{–}800}$  \
# division_1_size_bulk                               0.169379
# division_1_size_5                                  0.118672
# division_1_size_3                                  0.298211
#
#                       $(\Sigma I_{p,\ 1300\text{–}800})^{-1}$  \
# division_1_size_bulk                                 0.844189
# division_1_size_5                                    0.888099
# division_1_size_3                                    0.742145
#
#                       $\log \overline{I}_{873 \pm 25}$  \
# division_1_size_bulk                         -3.046113
# division_1_size_5                            -2.371406
# division_1_size_3                            -2.176872
#
#                       $(\overline{I}_{873 \pm 25})^{-1}$  \
# division_1_size_bulk                           21.033424
# division_1_size_5                              10.712443
# division_1_size_3                               8.818675
#
#                       $\log \overline{I}_{1107 \pm 25}$  \
# division_1_size_bulk                          -0.470997
# division_1_size_5                             -0.520776
# division_1_size_3                             -0.201459
#
#                       $(\overline{I}_{1107 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.601590
# division_1_size_5                                1.683333
# division_1_size_3                                1.223186
#
#                       $\log \overline{I}_{1241 \pm 25}$  \
# division_1_size_bulk                          -0.803558
# division_1_size_5                             -0.855859
# division_1_size_3                             -0.912710
#
#                       $(\overline{I}_{1241 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.233473
# division_1_size_5                                2.353396
# division_1_size_3                                2.491063
#
#                       $\log \overline{I}_{1393 \pm 25}$  \
# division_1_size_bulk                          -0.301897
# division_1_size_5                             -0.402986
# division_1_size_3                             -0.387909
#
#                       $(\overline{I}_{1393 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.352421
# division_1_size_5                                1.496286
# division_1_size_3                                1.473896
#
#                       $\log \overline{I}_{1613 \pm 25}$  \
# division_1_size_bulk                          -0.062408
# division_1_size_5                             -0.071889
# division_1_size_3                             -0.047578
#
#                       $(\overline{I}_{1613 \pm 25})^{-1}$  \
# division_1_size_bulk                             1.064396
# division_1_size_5                                1.074536
# division_1_size_3                                1.048728
#
#                       $\log \overline{I}_{1725 \pm 25}$  \
# division_1_size_bulk                          -0.873542
# division_1_size_5                             -0.971638
# division_1_size_3                             -0.994938
#
#                       $(\overline{I}_{1725 \pm 25})^{-1}$  \
# division_1_size_bulk                             2.395381
# division_1_size_5                                2.642268
# division_1_size_3                                2.704557
#
#                       $\frac{I_{873}}{I_{1107}}$  $\frac{I_{873}}{I_{1241}}$  \
# division_1_size_bulk                    0.070760                    0.105937
# division_1_size_5                       0.151575                    0.214668
# division_1_size_3                       0.131935                    0.275148
#
#                       $\frac{I_{873}}{I_{1393}}$  $\frac{I_{873}}{I_{1613}}$  \
# division_1_size_bulk                    0.063384                    0.048208
# division_1_size_5                       0.133645                    0.091875
# division_1_size_3                       0.158381                    0.110321
#
#                       $\frac{I_{873}}{I_{1725}}$  \
# division_1_size_bulk                    0.113894
# division_1_size_5                       0.238963
# division_1_size_3                       0.299173
#
#                       $\frac{I_{873}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                          0.113656
# division_1_size_5                                             0.242587
# division_1_size_3                                             0.252875
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                          0.014312
# division_1_size_5                                             0.028730
# division_1_size_3                                             0.032326
#
#                       $\frac{I_{873}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.113001
# division_1_size_5                                              0.243054
# division_1_size_3                                              0.256941
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                           0.033872
# division_1_size_5                                              0.066361
# division_1_size_3                                              0.080599
#
#                       $\frac{I_{873}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.084320
# division_1_size_5                                              0.182884
# division_1_size_3                                              0.210732
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                           0.063384
# division_1_size_5                                              0.133645
# division_1_size_3                                              0.158381
#
#                       $\frac{I_{873}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                          0.132682
# division_1_size_5                                             0.278410
# division_1_size_3                                             0.271066
#
#                       $\frac{I_{873}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                          0.040697
# division_1_size_5                                             0.081594
# division_1_size_3                                             0.081874
#
#                       $\frac{I_{873}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                      0.077210
# division_1_size_5                                         0.154656
# division_1_size_3                                         0.134943
#
#                       $\frac{I_{873}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                      0.107672
# division_1_size_5                                         0.216219
# division_1_size_3                                         0.274816
#
#                       $\frac{I_{873}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                      0.065198
# division_1_size_5                                         0.137471
# division_1_size_3                                         0.162601
#
#                       $\frac{I_{873}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                      0.051313
# division_1_size_5                                         0.098723
# division_1_size_3                                         0.115696
#
#                       $\frac{I_{873}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                      0.115477
# division_1_size_5                                         0.242759
# division_1_size_3                                         0.298369
#
#                       $\frac{I_{1107}}{I_{1241}}$  \
# division_1_size_bulk                     1.497132
# division_1_size_5                        1.416250
# division_1_size_3                        2.085485
#
#                       $\frac{I_{1107}}{I_{1393}}$  \
# division_1_size_bulk                     0.895754
# division_1_size_5                        0.881708
# division_1_size_3                        1.200447
#
#                       $\frac{I_{1107}}{I_{1613}}$  \
# division_1_size_bulk                     0.681294
# division_1_size_5                        0.606138
# division_1_size_3                        0.836176
#
#                       $\frac{I_{1107}}{I_{1725}}$  \
# division_1_size_bulk                     1.609587
# division_1_size_5                        1.576535
# division_1_size_3                        2.267579
#
#                       $\frac{I_{1107}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.606214
# division_1_size_5                                              1.600446
# division_1_size_3                                              1.916666
#
#                       $\frac{I_{1107}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.202259
# division_1_size_5                                              0.189540
# division_1_size_3                                              0.245015
#
#                       $\frac{I_{1107}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.596961
# division_1_size_5                                               1.603523
# division_1_size_3                                               1.947485
#
#                       $\frac{I_{1107}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.478681
# division_1_size_5                                               0.437811
# division_1_size_3                                               0.610903
#
#                       $\frac{I_{1107}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.191626
# division_1_size_5                                               1.206561
# division_1_size_3                                               1.597240
#
#                       $\frac{I_{1107}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.895754
# division_1_size_5                                               0.881708
# division_1_size_3                                               1.200447
#
#                       $\frac{I_{1107}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.875098
# division_1_size_5                                              1.836785
# division_1_size_3                                              2.054544
#
#                       $\frac{I_{1107}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.575141
# division_1_size_5                                              0.538310
# division_1_size_3                                              0.620563
#
#                       $\frac{I_{1107}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     14.329951
# division_1_size_5                                         6.493216
# division_1_size_3                                         7.373961
#
#                       $\frac{I_{1107}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.521652
# division_1_size_5                                          1.426482
# division_1_size_3                                          2.082966
#
#                       $\frac{I_{1107}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                       0.921397
# division_1_size_5                                          0.906955
# division_1_size_3                                          1.232436
#
#                       $\frac{I_{1107}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                       0.725167
# division_1_size_5                                          0.651317
# division_1_size_3                                          0.876920
#
#                       $\frac{I_{1107}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.631959
# division_1_size_5                                          1.601578
# division_1_size_3                                          2.261485
#
#                       $\frac{I_{1241}}{I_{1393}}$  \
# division_1_size_bulk                     0.598314
# division_1_size_5                        0.622566
# division_1_size_3                        0.575620
#
#                       $\frac{I_{1241}}{I_{1613}}$  \
# division_1_size_bulk                     0.455066
# division_1_size_5                        0.427988
# division_1_size_3                        0.400950
#
#                       $\frac{I_{1241}}{I_{1725}}$  \
# division_1_size_bulk                     1.075114
# division_1_size_5                        1.113176
# division_1_size_3                        1.087315
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.072861
# division_1_size_5                                              1.130060
# division_1_size_3                                              0.919050
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.135098
# division_1_size_5                                              0.133833
# division_1_size_3                                              0.117486
#
#                       $\frac{I_{1241}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.066680
# division_1_size_5                                               1.132232
# division_1_size_3                                               0.933828
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.319732
# division_1_size_5                                               0.309134
# division_1_size_3                                               0.292931
#
#                       $\frac{I_{1241}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.795939
# division_1_size_5                                               0.851941
# division_1_size_3                                               0.765884
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.598314
# division_1_size_5                                               0.622566
# division_1_size_3                                               0.575620
#
#                       $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.252460
# division_1_size_5                                              1.296936
# division_1_size_3                                              0.985163
#
#                       $\frac{I_{1241}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.384162
# division_1_size_5                                              0.380096
# division_1_size_3                                              0.297563
#
#                       $\frac{I_{1241}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                      9.571604
# division_1_size_5                                         4.584797
# division_1_size_3                                         3.535849
#
#                       $\frac{I_{1241}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                       0.728830
# division_1_size_5                                          0.720446
# division_1_size_3                                          0.490437
#
#                       $\frac{I_{1241}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                       0.615441
# division_1_size_5                                          0.640392
# division_1_size_3                                          0.590959
#
#                       $\frac{I_{1241}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                       0.484371
# division_1_size_5                                          0.459889
# division_1_size_3                                          0.420487
#
#                       $\frac{I_{1241}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.090057
# division_1_size_5                                          1.130859
# division_1_size_3                                          1.084393
#
#                       $\frac{I_{1393}}{I_{1613}}$  \
# division_1_size_bulk                     0.760582
# division_1_size_5                        0.687458
# division_1_size_3                        0.696553
#
#                       $\frac{I_{1393}}{I_{1725}}$  \
# division_1_size_bulk                     1.796907
# division_1_size_5                        1.788046
# division_1_size_3                        1.888945
#
#                       $\frac{I_{1393}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           1.793141
# division_1_size_5                                              1.815165
# division_1_size_3                                              1.596626
#
#                       $\frac{I_{1393}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.225798
# division_1_size_5                                              0.214970
# division_1_size_3                                              0.204103
#
#                       $\frac{I_{1393}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            1.782811
# division_1_size_5                                               1.818655
# division_1_size_3                                               1.622300
#
#                       $\frac{I_{1393}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.534389
# division_1_size_5                                               0.496548
# division_1_size_3                                               0.508897
#
#                       $\frac{I_{1393}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.330305
# division_1_size_5                                               1.368435
# division_1_size_3                                               1.330538
#
#                       $\frac{I_{1393}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                 1.0
# division_1_size_5                                                    1.0
# division_1_size_3                                                    1.0
#
#                       $\frac{I_{1393}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.093317
# division_1_size_5                                              2.083211
# division_1_size_3                                              1.711482
#
#                       $\frac{I_{1393}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.642074
# division_1_size_5                                              0.610531
# division_1_size_3                                              0.516943
#
#                       $\frac{I_{1393}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     15.997634
# division_1_size_5                                         7.364358
# division_1_size_3                                         6.142679
#
#                       $\frac{I_{1393}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                       1.218140
# division_1_size_5                                          1.157221
# division_1_size_3                                          0.852014
#
#                       $\frac{I_{1393}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       1.698738
# division_1_size_5                                          1.617862
# division_1_size_3                                          1.735159
#
#                       $\frac{I_{1393}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                       0.809560
# division_1_size_5                                          0.738699
# division_1_size_3                                          0.730495
#
#                       $\frac{I_{1393}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       1.821882
# division_1_size_5                                          1.816449
# division_1_size_3                                          1.883869
#
#                       $\frac{I_{1613}}{I_{1725}}$  \
# division_1_size_bulk                     2.362543
# division_1_size_5                        2.600952
# division_1_size_3                        2.711845
#
#                       $\frac{I_{1613}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           2.357591
# division_1_size_5                                              2.640400
# division_1_size_3                                              2.292181
#
#                       $\frac{I_{1613}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.296875
# division_1_size_5                                              0.312702
# division_1_size_3                                              0.293019
#
#                       $\frac{I_{1613}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            2.344010
# division_1_size_5                                               2.645477
# division_1_size_3                                               2.329038
#
#                       $\frac{I_{1613}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.702606
# division_1_size_5                                               0.722296
# division_1_size_3                                               0.730592
#
#                       $\frac{I_{1613}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.749062
# division_1_size_5                                               1.990572
# division_1_size_3                                               1.910173
#
#                       $\frac{I_{1613}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            1.314783
# division_1_size_5                                               1.454634
# division_1_size_3                                               1.435640
#
#                       $\frac{I_{1613}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           2.752259
# division_1_size_5                                              3.030309
# division_1_size_3                                              2.457072
#
#                       $\frac{I_{1613}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.844189
# division_1_size_5                                              0.888099
# division_1_size_3                                              0.742145
#
#                       $\frac{I_{1613}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                     21.033424
# division_1_size_5                                        10.712443
# division_1_size_3                                         8.818675
#
#                       $\frac{I_{1613}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                       1.601590
# division_1_size_5                                          1.683333
# division_1_size_3                                          1.223186
#
#                       $\frac{I_{1613}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       2.233473
# division_1_size_5                                          2.353396
# division_1_size_3                                          2.491063
#
#                       $\frac{I_{1613}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                       1.352421
# division_1_size_5                                          1.496286
# division_1_size_3                                          1.473896
#
#                       $\frac{I_{1613}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                       2.395381
# division_1_size_5                                          2.642268
# division_1_size_3                                          2.704557
#
#                       $\frac{I_{1725}}{\overline{I}_{1900\text{–}800}}$  \
# division_1_size_bulk                                           0.997904
# division_1_size_5                                              1.015167
# division_1_size_3                                              0.845248
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1900\text{–}800}}$  \
# division_1_size_bulk                                           0.125659
# division_1_size_5                                              0.120226
# division_1_size_3                                              0.108051
#
#                       $\frac{I_{1725}}{\overline{I}_{1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.992156
# division_1_size_5                                               1.017119
# division_1_size_3                                               0.858839
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                            0.297394
# division_1_size_5                                               0.277704
# division_1_size_3                                               0.269408
#
#                       $\frac{I_{1725}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.740330
# division_1_size_5                                               0.765324
# division_1_size_3                                               0.704381
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                            0.556512
# division_1_size_5                                               0.559270
# division_1_size_3                                               0.529396
#
#                       $\frac{I_{1725}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                           1.164956
# division_1_size_5                                              1.165077
# division_1_size_3                                              0.906052
#
#                       $\frac{I_{1725}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                           0.357322
# division_1_size_5                                              0.341451
# division_1_size_3                                              0.273668
#
#                       $\frac{I_{1725}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                      8.902873
# division_1_size_5                                         4.118663
# division_1_size_3                                         3.251910
#
#                       $\frac{I_{1725}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                       0.677909
# division_1_size_5                                          0.647199
# division_1_size_3                                          0.451053
#
#                       $\frac{I_{1725}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                       0.945368
# division_1_size_5                                          0.904821
# division_1_size_3                                          0.918586
#
#                       $\frac{I_{1725}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                       0.572443
# division_1_size_5                                          0.575284
# division_1_size_3                                          0.543503
#
#                       $\frac{I_{1725}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                       0.450530
# division_1_size_5                                          0.413132
# division_1_size_3                                          0.386721
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                                                  0.741885
# division_1_size_5                                                                     0.753890
# division_1_size_3                                                                     0.833343
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                                                 1.167403
# division_1_size_5                                                                    1.147670
# division_1_size_3                                                                    1.071937
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                                            8.921573
# division_1_size_5                                                               4.057128
# division_1_size_3                                                               3.847286
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                                             0.679333
# division_1_size_5                                                                0.637529
# division_1_size_3                                                                0.533634
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                             0.947354
# division_1_size_5                                                                0.891303
# division_1_size_3                                                                1.086766
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                             0.573645
# division_1_size_5                                                                0.566689
# division_1_size_3                                                                0.643010
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                             0.451476
# division_1_size_5                                                                0.406959
# division_1_size_3                                                                0.457524
#
#                       $\frac{\overline{I}_{1900\text{–}800}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                             1.016029
# division_1_size_5                                                                1.000707
# division_1_size_3                                                                1.179906
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}800}}{\Sigma I_{p,\ 1900\text{–}1500}}$  \
# division_1_size_bulk                                                                  2.366675
# division_1_size_5                                                                     2.309854
# division_1_size_3                                                                     2.493330
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}800}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                                  4.428747
# division_1_size_5                                                                     4.651822
# division_1_size_3                                                                     4.899484
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}800}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                                                 2.843585
# division_1_size_5                                                                    2.840081
# division_1_size_3                                                                    2.532756
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1500\text{–}1300}}$  \
# division_1_size_bulk                                                                   0.746184
# division_1_size_5                                                                      0.752443
# division_1_size_3                                                                      0.820155
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                                                  1.174167
# division_1_size_5                                                                     1.145468
# division_1_size_3                                                                     1.054973
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                                             8.973264
# division_1_size_5                                                                4.049343
# division_1_size_3                                                                3.786402
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                                              0.683269
# division_1_size_5                                                                 0.636306
# division_1_size_3                                                                 0.525189
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                              0.952843
# division_1_size_5                                                                 0.889592
# division_1_size_3                                                                 1.069567
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                              0.576969
# division_1_size_5                                                                 0.565602
# division_1_size_3                                                                 0.632835
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                              0.454092
# division_1_size_5                                                                 0.406179
# division_1_size_3                                                                 0.450284
#
#                       $\frac{\overline{I}_{1900\text{–}1500}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                              1.021916
# division_1_size_5                                                                 0.998787
# division_1_size_3                                                                 1.161234
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}1500}}{\Sigma I_{p,\ 1500\text{–}1300}}$  \
# division_1_size_bulk                                                                   1.871295
# division_1_size_5                                                                      2.013903
# division_1_size_3                                                                      1.965036
#
#                       $\frac{\Sigma I_{p,\ 1900\text{–}1500}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                                                  1.201511
# division_1_size_5                                                                     1.229550
# division_1_size_3                                                                     1.015812
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1300\text{–}800}}$  \
# division_1_size_bulk                                                                  1.573562
# division_1_size_5                                                                     1.522331
# division_1_size_3                                                                     1.286309
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                                            12.025543
# division_1_size_5                                                                5.381591
# division_1_size_3                                                                4.616689
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                                              0.915685
# division_1_size_5                                                                 0.845653
# division_1_size_3                                                                 0.640353
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                              1.276955
# division_1_size_5                                                                 1.182272
# division_1_size_3                                                                 1.304103
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                              0.773227
# division_1_size_5                                                                 0.751686
# division_1_size_3                                                                 0.771603
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                              0.608552
# division_1_size_5                                                                 0.539813
# division_1_size_3                                                                 0.549022
#
#                       $\frac{\overline{I}_{1500\text{–}1300}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                              1.369523
# division_1_size_5                                                                 1.327392
# division_1_size_3                                                                 1.415870
#
#                       $\frac{\Sigma I_{p,\ 1500\text{–}1300}}{\Sigma I_{p,\ 1300\text{–}800}}$  \
# division_1_size_bulk                                                                  0.642074
# division_1_size_5                                                                     0.610531
# division_1_size_3                                                                     0.516943
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{873 \pm 25}}$  \
# division_1_size_bulk                                                            7.642240
# division_1_size_5                                                               3.535099
# division_1_size_3                                                               3.589099
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                                             0.581918
# division_1_size_5                                                                0.555499
# division_1_size_3                                                                0.497823
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                             0.811505
# division_1_size_5                                                                0.776619
# division_1_size_3                                                                1.013834
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                             0.491386
# division_1_size_5                                                                0.493773
# division_1_size_3                                                                0.599859
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                             0.386735
# division_1_size_5                                                                0.354596
# division_1_size_3                                                                0.426820
#
#                       $\frac{\overline{I}_{1300\text{–}800}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                             0.870333
# division_1_size_5                                                                0.871947
# division_1_size_3                                                                1.100724
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1107 \pm 25}}$  \
# division_1_size_bulk                                                        0.076145
# division_1_size_5                                                           0.157138
# division_1_size_3                                                           0.138704
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                        0.106187
# division_1_size_5                                                           0.219688
# division_1_size_3                                                           0.282476
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                        0.064299
# division_1_size_5                                                           0.139677
# division_1_size_3                                                           0.167133
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                        0.050605
# division_1_size_5                                                           0.100307
# division_1_size_3                                                           0.118921
#
#                       $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                        0.113884
# division_1_size_5                                                           0.246654
# division_1_size_3                                                           0.306685
#
#                       $\frac{\overline{I}_{1107 \pm 25}}{\overline{I}_{1241 \pm 25}}$  \
# division_1_size_bulk                                                         1.394535
# division_1_size_5                                                            1.398057
# division_1_size_3                                                            2.036537
#
#                       $\frac{\overline{I}_{1107 \pm 25}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                         0.844424
# division_1_size_5                                                            0.888883
# division_1_size_3                                                            1.204964
#
#                       $\frac{\overline{I}_{1107 \pm 25}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                         0.664587
# division_1_size_5                                                            0.638338
# division_1_size_3                                                            0.857374
#
#                       $\frac{\overline{I}_{1107 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.495626
# division_1_size_5                                                            1.569664
# division_1_size_3                                                            2.211076
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1393 \pm 25}}$  \
# division_1_size_bulk                                                         0.605524
# division_1_size_5                                                            0.635799
# division_1_size_3                                                            0.591673
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                         0.476565
# division_1_size_5                                                            0.456590
# division_1_size_3                                                            0.420996
#
#                       $\frac{\overline{I}_{1241 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.072491
# division_1_size_5                                                            1.122747
# division_1_size_3                                                            1.085704
#
#                       $\frac{\overline{I}_{1393 \pm 25}}{\overline{I}_{1613 \pm 25}}$  \
# division_1_size_bulk                                                         0.787030
# division_1_size_5                                                            0.718136
# division_1_size_3                                                            0.711534
#
#                       $\frac{\overline{I}_{1393 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         1.771179
# division_1_size_5                                                            1.765885
# division_1_size_3                                                            1.834972
#
#                       $\frac{\overline{I}_{1613 \pm 25}}{\overline{I}_{1725 \pm 25}}$  \
# division_1_size_bulk                                                         2.250460
# division_1_size_5                                                            2.458985
# division_1_size_3                                                            2.578894
#
#                       Split Fraction_hue Fraction_grouped_hue  Class
# division_1_size_bulk  Train        $> 0$              $d > 5$      2
# division_1_size_5     Train        $< 5$       $2 < d \leq 5$      1
# division_1_size_3     Train        $< 3$       $2 < d \leq 5$      1

# %% [markdown]
# ## Base parameters

# %%
type_color_dict = {
    '$d \leq 2$': '#2166AC',
    '$2 < d \leq 5$': '#67A9CF',
    '$d > 5$': '#B2182B'
}

# %%
groups = list(type_color_dict.keys())

# %%
sns.set_theme()

# %% [markdown]
# ## Dictionary for features mapping to type

# %%
feature_to_types = defaultdict(list)

for feature_type, features in features_description.items():
    for feature in features:
        feature_to_types[feature].append(feature_type)

# %% [markdown]
# ## Dictionary for mapping *class* to *size group*

# %%
class_fraction_group_dict = {
    0: r'$d \leq 2$',
    1: r'$2 < d \leq 5$',
    2: r'$d > 5$'
}

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Target rate analysis

# %% [markdown]
# Mapping hue ~ group:
# * Class 0 — $0< d \leq 2$
# * Class 1 — $2 < d \leq 5$
# * Class 2 — $d > 5$

# %%
fractions_hue_train_df = pd.DataFrame(dataset_train['Fraction_hue'].value_counts()).sort_values(by='Fraction_hue')
fractions_hue_test_df = pd.DataFrame(dataset_test['Fraction_hue'].value_counts()).sort_values(by='Fraction_hue')

display(fractions_hue_train_df.T, fractions_hue_test_df.T)
# Out:
# Fraction_hue  $< 0.2$  $< 0.4$  $< 2$  $< 2.5$  $< 25$  $< 3$  $< 5$  $< 50$  \
# count               6        6      5        6       4      8      8       1
#
# Fraction_hue  $< 70$  $< 75$  $> 0$
# count              3       2      7
# Fraction_hue  $< 0.2$  $< 0.4$  $< 2$  $< 2.5$  $< 25$  $< 3$  $< 4$  $< 5$  \
# count               1        2      3        2       2      2      1      2
#
# Fraction_hue  $< 75$  $> 0$
# count              1      3

# %%
target_rate_train_df = pd.DataFrame(dataset_train['Fraction_grouped_hue'].value_counts()).sort_values(by='Fraction_grouped_hue')
target_rate_test_df = pd.DataFrame(dataset_test['Fraction_grouped_hue'].value_counts()).sort_values(by='Fraction_grouped_hue')

display(target_rate_train_df.T, target_rate_test_df.T)
# Out:
# Fraction_grouped_hue  $2 < d \leq 5$  $d > 5$  $d \leq 2$
# count                             22       17          17
# Fraction_grouped_hue  $2 < d \leq 5$  $d > 5$  $d \leq 2$
# count                              7        6           6

# %% [markdown]
# ### Data wrangling

# %%
train = target_rate_train_df.copy()
test  = target_rate_test_df.copy()

train = train["count"].reset_index()
test  = test["count"].reset_index()
train.columns = ["bin", "count_train"]
test.columns  = ["bin", "count_test"]

bins_order = list(train["bin"])
bins_order += [b for b in test["bin"] if b not in bins_order]

df = (pd.DataFrame({"bin": bins_order})
      .merge(train, on="bin", how="left")
      .merge(test,  on="bin", how="left"))
df[["count_train", "count_test"]] = df[["count_train", "count_test"]].fillna(0).astype(int)

sum_tr, sum_te = df["count_train"].sum(), df["count_test"].sum()
df["freq_train"] = df["count_train"] * 100 / sum_tr if sum_tr else 0
df["freq_test"]  = df["count_test"] * 100  / sum_te if sum_te else 0

# %% [markdown]
# ### Visualization

# %%
fontsize = 14

train_color = "#08519c"
test_color  = "#1f77b4"
edge_color = "white"

# %%
fig, ax = plt.subplots(figsize=(10, 4), dpi=300)

x = np.arange(len(df))

width = 0.35

bars_train = ax.bar(x - width/2, df["freq_train"].values, width=width, label="Train", color=train_color, alpha=0.7, edgecolor=edge_color, linewidth=0.6)
bars_test  = ax.bar(x + width/2, df["freq_test"].values,  width=width, label="Test",  color=test_color, alpha=0.7,  edgecolor=edge_color, linewidth=0.6)

ax.set_xlabel("")
ax.set_ylabel("Relative frequency", fontsize=fontsize, labelpad=5)

ax.set_xticks(x, df["bin"])
ax.tick_params(axis='x', labelsize=fontsize)
ax.tick_params(axis='y', labelsize=fontsize-2)

# ax.yaxis.set_major_formatter(PercentFormatter(1.0))
ax.yaxis.set_major_locator(ticker.MaxNLocator(nbins=10))

# ax.legend(frameon=True, fontsize=fontsize-2, title_fontsize=fontsize, title='Dataset split')
ax.legend(frameon=True, fontsize=fontsize-2)

def annotate(container, values):
    for rect, val in zip(container, values):
        h = rect.get_height()
        ax.annotate(f"{int(val)}",
                    xy=(rect.get_x() + rect.get_width()/2, h),
                    xytext=(0, 0), textcoords="offset points",
                    ha="center", va="bottom", fontsize=fontsize-2, fontweight='normal')

annotate(bars_train, df["count_train"].values)
annotate(bars_test, df["count_test"].values)

plt.tight_layout()

plt.savefig(f"{path_to_save}/target_rate_barplot.svg", dpi=600)

plt.show()

# %% [markdown]
# ## *One-factor (OF)* analysis

# %% [markdown]
# ### *OF*-statictics calculation

# %%
def of_analysis(feature, features_df_train, target_train, features_df_test, target_test, n_bootstrap=50, C=1.0, random_state=42, n_splits=3, cv_shuffle=True):

    def safe_auc(y_true, proba):
        try:
            return roc_auc_score(y_true, proba, multi_class="ovr")
        except ValueError:
            return np.nan

    def fit_logreg_and_auc(X_tr, y_tr, X_te, y_te, C=1.0, rs=42, return_scale=False):
        scaler = StandardScaler().fit(X_tr)
        X_tr_s = scaler.transform(X_tr)
        X_te_s = scaler.transform(X_te)

        clf = OneVsRestClassifier(
            LogisticRegression(
                penalty="l2", C=C, solver="lbfgs", max_iter=10_000, random_state=rs
            )
        )
        clf.fit(X_tr_s, y_tr)

        auc_train = safe_auc(y_tr, clf.predict_proba(X_tr_s))
        auc_test  = safe_auc(y_te, clf.predict_proba(X_te_s))

        if return_scale:
            return auc_train, auc_test, float(scaler.mean_[0]), float(scaler.scale_[0])
        return auc_train, auc_test

    def bootstrap_block(X_source, y_train, X_test_raw, y_test, n_bs, C, rs=42):
        aucs_train, aucs_test = [], []
        for seed in range(n_bs):
            X_bs, y_bs = resample(X_source, y_train, replace=True, random_state=seed)
            a_tr, a_te = fit_logreg_and_auc(X_bs, y_bs, X_test_raw, y_test, C=C, rs=rs)
            aucs_train.append(a_tr)
            aucs_test.append(a_te)
        return np.asarray(aucs_train, float), np.asarray(aucs_test, float)

    def cv_block(X_train_raw, y_train, n_splits, shuffle, rs, C):
        skf = StratifiedKFold(n_splits=n_splits, shuffle=shuffle, random_state=rs)
        oof_scores = []
        for tr_idx, val_idx in skf.split(X_train_raw, y_train):
            X_tr, X_val = X_train_raw[tr_idx], X_train_raw[val_idx]
            y_tr, y_val = y_train[tr_idx], y_train[val_idx]

            scaler = StandardScaler().fit(X_tr)
            X_tr_s  = scaler.transform(X_tr)
            X_val_s = scaler.transform(X_val)

            clf = OneVsRestClassifier(
                LogisticRegression(
                    penalty="l2", C=C, solver="lbfgs", max_iter=10_000, random_state=rs
                )
            )
            clf.fit(X_tr_s, y_tr)
            proba_val = clf.predict_proba(X_val_s)
            oof_scores.append(safe_auc(y_val, proba_val))

        return np.asarray(oof_scores, float)

    def summarize(arr):
        arr = np.asarray(arr, float)
        if arr.size == 0:
            return np.nan, np.nan, np.nan
        return float(np.nanmean(arr)), float(np.nanpercentile(arr, 5)), float(np.nanpercentile(arr, 95))

    rng = np.random.default_rng(random_state)

    X_train_raw = features_df_train[[feature]].values
    y_train     = target_train.values
    X_test_raw  = features_df_test[[feature]].values
    y_test      = target_test.values

    # Глобальные (единственная подгонка на всём трейне)
    auc_global_train, auc_global_test, mean_val, std_val = fit_logreg_and_auc(
        X_train_raw, y_train, X_test_raw, y_test, C=C, rs=random_state, return_scale=True
    )

    # Бутстрэп
    bs_train, bs_test = bootstrap_block(
        X_train_raw, y_train, X_test_raw, y_test, n_bs=n_bootstrap, C=C, rs=random_state
    )
    bs_mean_train, bs_ci5_train, bs_ci95_train = summarize(bs_train)
    bs_mean_test,  bs_ci5_test,  bs_ci95_test  = summarize(bs_test)

    # Нoise baseline (перемешанный train)
    shuffled_train = rng.permutation(X_train_raw.ravel()).reshape(-1, 1)
    noise_train, noise_test = bootstrap_block(
        shuffled_train, y_train, X_test_raw, y_test, n_bs=n_bootstrap, C=C, rs=random_state
    )
    noise_mean_train, noise_ci5_train, noise_ci95_train = summarize(noise_train)
    noise_mean_test,  noise_ci5_test,  noise_ci95_test  = summarize(noise_test)

    # Δ и z-score
    delta_auc_train = bs_mean_train - noise_mean_train
    delta_auc_test  = bs_mean_test  - noise_mean_test
    std_noise_train = np.nanstd(noise_train)
    std_noise_test  = np.nanstd(noise_test)
    z_score_train = (delta_auc_train / std_noise_train) if std_noise_train > 0 else np.nan
    z_score_test  = (delta_auc_test  / std_noise_test)  if std_noise_test  > 0 else np.nan

    # CV-OOF
    cv_scores = cv_block(X_train_raw, y_train, n_splits=n_splits, shuffle=cv_shuffle, rs=random_state, C=C)
    cv_mean_train, cv_ci5_train, cv_ci95_train = summarize(cv_scores)

    return {
        "Feature": feature,
        "$scale-mean$": mean_val,
        "$scale-std$": std_val,
        "$C$": C,

        "$ROC-AUC_{ovr}^{global,train}$": auc_global_train,
        "$ROC-AUC_{ovr}^{global,test}$":  auc_global_test,

        "$ROC-AUC_{ovr}^{BS,train}$": bs_mean_train,
        "$CI_{5\\%}^{BS,train}$":     bs_ci5_train,
        "$CI_{95\\%}^{BS,train}$":    bs_ci95_train,
        "$ROC-AUC_{ovr}^{BS,test}$":  bs_mean_test,
        "$CI_{5\\%}^{BS,test}$":      bs_ci5_test,
        "$CI_{95\\%}^{BS,test}$":     bs_ci95_test,

        "$ROC-AUC_{ovr}^{CV,train}$": cv_mean_train,
        "$CI_{5\\%}^{CV,train}$":     cv_ci5_train,
        "$CI_{95\\%}^{CV,train}$":    cv_ci95_train,
        "$n_{folds}^{CV}$":           int(np.isfinite(cv_scores).sum()),

        "$ROC-AUC_{ovr}^{noise,train}$": noise_mean_train,
        "$CI_{5\\%}^{noise,train}$":     noise_ci5_train,
        "$CI_{95\\%}^{noise,train}$":    noise_ci95_train,
        "$ROC-AUC_{ovr}^{noise,test}$":  noise_mean_test,
        "$CI_{5\\%}^{noise,test}$":      noise_ci5_test,
        "$CI_{95\\%}^{noise,test}$":     noise_ci95_test,

        "$ΔROC-AUC^{train}$": delta_auc_train,
        "$ΔROC-AUC^{test}$":  delta_auc_test,
        "$z-score^{train}$":  z_score_train,
        "$z-score^{test}$":   z_score_test,

        "$n_{valid}^{BS,train}$":      int(np.isfinite(bs_train).sum()),
        "$n_{valid}^{BS,test}$":       int(np.isfinite(bs_test).sum()),
        "$n_{valid}^{noise,train}$":   int(np.isfinite(noise_train).sum()),
        "$n_{valid}^{noise,test}$":    int(np.isfinite(noise_test).sum()),
    }

# %%
# %%time

features_list = X_train.columns.tolist()

with tqdm_joblib(desc="Calculation progress", total=len(features_list)):
    results = Parallel(n_jobs=-1, backend="loky")(
        delayed(of_analysis)(
            feature,
            X_train,
            y_train,
            X_test,
            y_test,
            n_bootstrap=50,
            C=1.0,
        )
        for feature in features_list
    )
# Out:
# Calculation progress:   0%|          | 0/203 [00:00<?, ?it/s]
# CPU times: user 396 ms, sys: 61.5 ms, total: 457 ms
# Wall time: 8.59 s

# %%
of_metrics_df = pd.DataFrame(results).sort_values(
    by=[
        "$CI_{5\%}^{BS,train}$",
        "$ROC-AUC_{ovr}^{BS,train}$",
        "$ROC-AUC_{ovr}^{global,train}$"
    ],
    ascending=[
        False,
        False,
        False
    ]
)
print(of_metrics_df.shape)
of_metrics_df.head(3)
# Out:
# (203, 30)
#                                                             Feature  \
# 104               $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$
# 189  $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1241 \pm 25}}$
# 61                                       $\frac{I_{873}}{I_{1241}}$
#
#      $scale-mean$  $scale-std$  $C$  $ROC-AUC_{ovr}^{global,train}$  \
# 104      1.275469     0.401737  1.0                        0.773973
# 189      0.398869     0.332101  1.0                        0.766134
# 61       0.404977     0.339640  1.0                        0.767860
#
#      $ROC-AUC_{ovr}^{global,test}$  $ROC-AUC_{ovr}^{BS,train}$  \
# 104                       0.707265                    0.773281
# 189                       0.833639                    0.776735
# 61                        0.812882                    0.774925
#
#      $CI_{5\%}^{BS,train}$  $CI_{95\%}^{BS,train}$  $ROC-AUC_{ovr}^{BS,test}$  \
# 104               0.709518                0.840911                   0.683138
# 189               0.708457                0.856457                   0.807540
# 61                0.708431                0.852495                   0.791838
#
#      $CI_{5\%}^{BS,test}$  $CI_{95\%}^{BS,test}$  $ROC-AUC_{ovr}^{CV,train}$  \
# 104              0.646947               0.715201                    0.736574
# 189              0.718666               0.857448                    0.774420
# 61               0.719216               0.836691                    0.771922
#
#      $CI_{5\%}^{CV,train}$  $CI_{95\%}^{CV,train}$  $n_{folds}^{CV}$  \
# 104               0.726893                0.748610                 3
# 189               0.723687                0.824512                 3
# 61                0.730343                0.823077                 3
#
#      $ROC-AUC_{ovr}^{noise,train}$  $CI_{5\%}^{noise,train}$  \
# 104                       0.595109                  0.516264
# 189                       0.585316                  0.508467
# 61                        0.585621                  0.521580
#
#      $CI_{95\%}^{noise,train}$  $ROC-AUC_{ovr}^{noise,test}$  \
# 104                   0.689893                      0.568242
# 189                   0.658768                      0.507045
# 61                    0.655672                      0.506954
#
#      $CI_{5\%}^{noise,test}$  $CI_{95\%}^{noise,test}$  $ΔROC-AUC^{train}$  \
# 104                 0.396490                  0.685195            0.178173
# 189                 0.221917                  0.778083            0.191419
# 61                  0.230769                  0.731731            0.189304
#
#      $ΔROC-AUC^{test}$  $z-score^{train}$  $z-score^{test}$  \
# 104           0.114896           3.406500          1.028953
# 189           0.300495           3.580703          1.661555
# 61            0.284884           3.802740          1.750785
#
#      $n_{valid}^{BS,train}$  $n_{valid}^{BS,test}$  $n_{valid}^{noise,train}$  \
# 104                      50                     50                         50
# 189                      50                     50                         50
# 61                       50                     50                         50
#
#      $n_{valid}^{noise,test}$
# 104                        50
# 189                        50
# 61                         50

# %% [markdown]
# ### *Hard-check* factor selection

# %%
of_features_to_save = (
    of_metrics_df
    .loc[
        (of_metrics_df['$CI_{5\%}^{BS,train}$'] >= 0.60)
        # & (of_metrics_df['$CI_{5\%}^{CV,train}$'] >= 0.55)
        & (of_metrics_df['$ROC-AUC_{ovr}^{global,train}$'] >= 0.60)
    ]['Feature']
).tolist()

print(
    f'Число фичей',
    f'(*) до отбора: {len(of_metrics_df["Feature"].unique())}',
    f'(*) после отбора: {len(of_features_to_save)}',
    f'Доля фичей, прошедших однофакторный отбор: {round(len(of_features_to_save) / len(of_metrics_df["Feature"].unique()) * 100, 2)}%',
    sep='\n'
)
# Out:
# Число фичей
# (*) до отбора: 203
# (*) после отбора: 27
# Доля фичей, прошедших однофакторный отбор: 13.3%

# %%
of_metrics_df = of_metrics_df.loc[of_metrics_df['Feature'].isin(of_features_to_save)]

print(of_metrics_df.shape)
of_metrics_df.head(3)
# Out:
# (27, 30)
#                                                             Feature  \
# 104               $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$
# 189  $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1241 \pm 25}}$
# 61                                       $\frac{I_{873}}{I_{1241}}$
#
#      $scale-mean$  $scale-std$  $C$  $ROC-AUC_{ovr}^{global,train}$  \
# 104      1.275469     0.401737  1.0                        0.773973
# 189      0.398869     0.332101  1.0                        0.766134
# 61       0.404977     0.339640  1.0                        0.767860
#
#      $ROC-AUC_{ovr}^{global,test}$  $ROC-AUC_{ovr}^{BS,train}$  \
# 104                       0.707265                    0.773281
# 189                       0.833639                    0.776735
# 61                        0.812882                    0.774925
#
#      $CI_{5\%}^{BS,train}$  $CI_{95\%}^{BS,train}$  $ROC-AUC_{ovr}^{BS,test}$  \
# 104               0.709518                0.840911                   0.683138
# 189               0.708457                0.856457                   0.807540
# 61                0.708431                0.852495                   0.791838
#
#      $CI_{5\%}^{BS,test}$  $CI_{95\%}^{BS,test}$  $ROC-AUC_{ovr}^{CV,train}$  \
# 104              0.646947               0.715201                    0.736574
# 189              0.718666               0.857448                    0.774420
# 61               0.719216               0.836691                    0.771922
#
#      $CI_{5\%}^{CV,train}$  $CI_{95\%}^{CV,train}$  $n_{folds}^{CV}$  \
# 104               0.726893                0.748610                 3
# 189               0.723687                0.824512                 3
# 61                0.730343                0.823077                 3
#
#      $ROC-AUC_{ovr}^{noise,train}$  $CI_{5\%}^{noise,train}$  \
# 104                       0.595109                  0.516264
# 189                       0.585316                  0.508467
# 61                        0.585621                  0.521580
#
#      $CI_{95\%}^{noise,train}$  $ROC-AUC_{ovr}^{noise,test}$  \
# 104                   0.689893                      0.568242
# 189                   0.658768                      0.507045
# 61                    0.655672                      0.506954
#
#      $CI_{5\%}^{noise,test}$  $CI_{95\%}^{noise,test}$  $ΔROC-AUC^{train}$  \
# 104                 0.396490                  0.685195            0.178173
# 189                 0.221917                  0.778083            0.191419
# 61                  0.230769                  0.731731            0.189304
#
#      $ΔROC-AUC^{test}$  $z-score^{train}$  $z-score^{test}$  \
# 104           0.114896           3.406500          1.028953
# 189           0.300495           3.580703          1.661555
# 61            0.284884           3.802740          1.750785
#
#      $n_{valid}^{BS,train}$  $n_{valid}^{BS,test}$  $n_{valid}^{noise,train}$  \
# 104                      50                     50                         50
# 189                      50                     50                         50
# 61                       50                     50                         50
#
#      $n_{valid}^{noise,test}$
# 104                        50
# 189                        50
# 61                         50

# %% [markdown]
# ### Mapping features with their types

# %%
rows = []

for _, row in of_metrics_df.iterrows():
    feature = row['Feature']
    feature_types = feature_to_types.get(feature, [])

    for feature_type in feature_types:
        row_copy = row.copy()
        row_copy['Feature_Type'] = feature_type
        rows.append(row_copy)

of_metrics_expanded_df = pd.DataFrame(rows)

print(of_metrics_expanded_df.shape)
of_metrics_expanded_df.head(3)
# Out:
# (54, 31)
#                                                             Feature  \
# 104               $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$
# 104               $\frac{I_{1241}}{\overline{I}_{1300\text{–}800}}$
# 189  $\frac{\overline{I}_{873 \pm 25}}{\overline{I}_{1241 \pm 25}}$
#
#      $scale-mean$  $scale-std$  $C$  $ROC-AUC_{ovr}^{global,train}$  \
# 104      1.275469     0.401737  1.0                        0.773973
# 104      1.275469     0.401737  1.0                        0.773973
# 189      0.398869     0.332101  1.0                        0.766134
#
#      $ROC-AUC_{ovr}^{global,test}$  $ROC-AUC_{ovr}^{BS,train}$  \
# 104                       0.707265                    0.773281
# 104                       0.707265                    0.773281
# 189                       0.833639                    0.776735
#
#      $CI_{5\%}^{BS,train}$  $CI_{95\%}^{BS,train}$  $ROC-AUC_{ovr}^{BS,test}$  \
# 104               0.709518                0.840911                   0.683138
# 104               0.709518                0.840911                   0.683138
# 189               0.708457                0.856457                   0.807540
#
#      $CI_{5\%}^{BS,test}$  $CI_{95\%}^{BS,test}$  $ROC-AUC_{ovr}^{CV,train}$  \
# 104              0.646947               0.715201                    0.736574
# 104              0.646947               0.715201                    0.736574
# 189              0.718666               0.857448                    0.774420
#
#      $CI_{5\%}^{CV,train}$  $CI_{95\%}^{CV,train}$  $n_{folds}^{CV}$  \
# 104               0.726893                0.748610                 3
# 104               0.726893                0.748610                 3
# 189               0.723687                0.824512                 3
#
#      $ROC-AUC_{ovr}^{noise,train}$  $CI_{5\%}^{noise,train}$  \
# 104                       0.595109                  0.516264
# 104                       0.595109                  0.516264
# 189                       0.585316                  0.508467
#
#      $CI_{95\%}^{noise,train}$  $ROC-AUC_{ovr}^{noise,test}$  \
# 104                   0.689893                      0.568242
# 104                   0.689893                      0.568242
# 189                   0.658768                      0.507045
#
#      $CI_{5\%}^{noise,test}$  $CI_{95\%}^{noise,test}$  $ΔROC-AUC^{train}$  \
# 104                 0.396490                  0.685195            0.178173
# 104                 0.396490                  0.685195            0.178173
# 189                 0.221917                  0.778083            0.191419
#
#      $ΔROC-AUC^{test}$  $z-score^{train}$  $z-score^{test}$  \
# 104           0.114896           3.406500          1.028953
# 104           0.114896           3.406500          1.028953
# 189           0.300495           3.580703          1.661555
#
#      $n_{valid}^{BS,train}$  $n_{valid}^{BS,test}$  $n_{valid}^{noise,train}$  \
# 104                      50                     50                         50
# 104                      50                     50                         50
# 189                      50                     50                         50
#
#      $n_{valid}^{noise,test}$                            Feature_Type
# 104                        50  engineered_features_intervals_1900_800
# 104                        50                     engineered_features
# 189                        50  engineered_features_intervals_1900_800

# %% [markdown]
# ### Visualization

# %%
train_color = "#08519c"
test_color  = "#1f77b4"

PLOT_STYLE = {
    'TITLE_FONT_SIZE': 18, 'TITLE_FONTSTYLE': 'normal',
    'X_LABEL_FONT_SIZE': 14, 'Y_TICK_LABEL_FONT_SIZE': 14,
    'X_LABELPAD': 8, 'X_NBINS': 8,
    'BAR_HEIGHT': 0.34, 'BAR_ALPHA': 0.7,
    'FIG_DPI': 300, 'SUBPLOT_WIDTH': 6, 'SUBPLOT_HEIGHT': 4.2,
    'TOP_N': 5, 'LEGEND_FONT_SIZE': 12, 'ERR_CAPSIZE': 3, 'ERR_LINEWIDTH': 1.4,
    'HUE_COLORS': {'train': train_color, 'test': test_color}
}

KEYS = {
    'bs_train': "$ROC-AUC_{ovr}^{BS,train}$",     'glob_train': "$ROC-AUC_{ovr}^{global,train}$",
    'bs_test': "$ROC-AUC_{ovr}^{BS,test}$",       'glob_test': "$ROC-AUC_{ovr}^{global,test}$",
    'ci5_train': "$CI_{5\\%}^{BS,train}$",        'ci95_train': "$CI_{95\\%}^{BS,train}$",
    'ci5_test': "$CI_{5\\%}^{BS,test}$",          'ci95_test': "$CI_{95\\%}^{BS,test}$",
    'cv_train': '$ROC-AUC_{ovr}^{CV,train}$',     'ci5_cv_train': '$CI_{5\%}^{CV,train}$',
    'ci95_cv_train': '$CI_{95\%}^{CV,train}$'
}

VISUAL_TYPE_LABELS = {'peaks': 'Peak-based', 'intervals': 'Region-based'}

# %%
def extract_base_and_range(feature_type: str):
    if not isinstance(feature_type, str):
        return None, None

    parts = feature_type.lower().split('_')

    # база (тип)
    if 'peaks' in parts:
        base = 'peaks'
    elif 'intervals' in parts:
        base = 'intervals'
    else:
        base = None

    # диапазон — две последние числовые части
    nums = [p for p in parts if re.fullmatch(r'\d+(?:\.\d+)?', p)]
    rng = None
    if len(nums) >= 2:
        a, b = float(nums[-2]), float(nums[-1])
        hi, lo = (max(a, b), min(a, b))
        def _fmt(x):
            xi = int(round(x))
            return str(xi) if abs(x - xi) < 1e-9 else f"{x:g}"
        rng = f"{_fmt(hi)}–{_fmt(lo)}"

    # валидируем базу по словарю визуальных меток
    if base not in VISUAL_TYPE_LABELS:
        base = None

    return base, rng


def group_sort_key(gr):
    base, rng = gr
    base_order = list(VISUAL_TYPE_LABELS.keys())
    base_idx = base_order.index(base) if base in base_order else len(base_order)

    hi = lo = None
    if isinstance(rng, str):
        m = re.findall(r'\d+(?:\.\d+)?', rng)
        if len(m) >= 2:
            a, b = float(m[0]), float(m[1])
            hi, lo = (max(a, b), min(a, b))

    # hi -> сортируем по убыванию (поэтому минус), lo -> по возрастанию
    return (base_idx, -(hi if hi is not None else -1e9), (lo if lo is not None else 1e9))


def panel_title_from_group(gr):
    base, rng = gr
    base_label = VISUAL_TYPE_LABELS.get(base, base or "")
    return f"{base_label} | {rng} cm$^{{-1}}$" if rng else base_label


def build_plot_df(subset: pd.DataFrame, top_n: int = 5):
    rows = []
    for _, row in subset.iterrows():
        feat = row.get('Feature')
        if pd.isna(feat):
            continue

        for split in ('train', 'test'):
            mean_col_bs = KEYS[f'bs_{split}']
            mean_col_glob = KEYS[f'glob_{split}']
            ci5_col = KEYS[f'ci5_{split}']
            ci95_col = KEYS[f'ci95_{split}']

            mean = row.get(mean_col_bs)
            ci5  = row.get(ci5_col)
            ci95 = row.get(ci95_col)

            # если bootstrap-метрик нет — используем global без ошибок
            if pd.isna(mean):
                mean = row.get(mean_col_glob)
                ci5, ci95 = np.nan, np.nan

            if pd.isna(mean):
                continue

            err_left  = float(mean - ci5)  if (ci5  is not None and not pd.isna(ci5))  else 0.0
            err_right = float(ci95 - mean) if (ci95 is not None and not pd.isna(ci95)) else 0.0

            rows.append({
                'Feature': feat,
                'Split': split,
                'mean': float(mean),
                'err_left': err_left,
                'err_right': err_right
            })

    plot_df = pd.DataFrame(rows)
    if plot_df.empty:
        return plot_df, []

    order_feats = (
        plot_df.groupby('Feature')['mean']
        .mean()
        .sort_values(ascending=False)
        .head(top_n)
        .index.tolist()
    )
    plot_df = plot_df[plot_df['Feature'].isin(order_feats)].copy()
    return plot_df, order_feats

# %%
tmp = of_metrics_expanded_df.copy()

tmp[['viz_base','viz_range']] = tmp['Feature_Type'].apply(lambda s: pd.Series(extract_base_and_range(s)))
tmp = tmp[tmp['viz_base'].isin(VISUAL_TYPE_LABELS) & tmp['viz_range'].notna()]

present_groups = sorted(tmp[['viz_base','viz_range']].drop_duplicates().itertuples(index=False, name=None), key=group_sort_key)

# %%
# --- layout ---
n = len(present_groups)
ncols = 2 if n > 1 else 1
nrows = math.ceil(n / ncols)
fig, axes = plt.subplots(nrows=nrows, ncols=ncols,
                         figsize=(ncols*PLOT_STYLE['SUBPLOT_WIDTH'], nrows*PLOT_STYLE['SUBPLOT_HEIGHT']),
                         dpi=PLOT_STYLE['FIG_DPI'])
axes = np.atleast_1d(axes).ravel()

# --- panels ---
for i, g in enumerate(present_groups):
    ax = axes[i]
    base, rng = g
    subset = tmp[(tmp['viz_base']==base) & (tmp['viz_range']==rng)].copy()
    plot_df, order_feats = build_plot_df(subset, PLOT_STYLE['TOP_N'])
    if plot_df.empty:
        ax.set_title(panel_title_from_group(g), fontsize=PLOT_STYLE['TITLE_FONT_SIZE'],
                     fontstyle=PLOT_STYLE['TITLE_FONTSTYLE'])
        ax.text(0.5,0.5,'no data',ha='center',va='center',fontsize=12,alpha=0.7)
        ax.set_axis_off()
        continue

    plot_df['Feature'] = pd.Categorical(plot_df['Feature'], categories=order_feats, ordered=True)
    y0 = np.arange(len(order_feats)); off = PLOT_STYLE['BAR_HEIGHT']/2

    for split, sign in (('train',-1),('test',+1)):
        sub = plot_df[plot_df['Split']==split].sort_values('Feature')
        y = y0 + sign*off
        xerr = np.vstack([sub['err_left'].to_numpy(), sub['err_right'].to_numpy()])
        ax.barh(y, sub['mean'], height=PLOT_STYLE['BAR_HEIGHT'], alpha=PLOT_STYLE['BAR_ALPHA'],
                label=split.capitalize(), color=PLOT_STYLE['HUE_COLORS'][split],
                xerr=xerr, error_kw={'capsize':PLOT_STYLE['ERR_CAPSIZE'], 'lw':PLOT_STYLE['ERR_LINEWIDTH']})

    ax.set_yticks(y0, labels=order_feats, fontsize=PLOT_STYLE['Y_TICK_LABEL_FONT_SIZE'])
    ax.invert_yaxis()
    ax.set_xlabel('$ROC\\!-\\!AUC_{ovr}$', fontsize=PLOT_STYLE['X_LABEL_FONT_SIZE'],
                  labelpad=PLOT_STYLE['X_LABELPAD'])
    ax.set_xlim(0,1)
    ax.set_title(panel_title_from_group(g), fontsize=PLOT_STYLE['TITLE_FONT_SIZE'],
                 fontstyle=PLOT_STYLE['TITLE_FONTSTYLE'])
    ax.xaxis.set_major_locator(ticker.MaxNLocator(nbins=PLOT_STYLE['X_NBINS']))
    ax.legend(loc='upper left', fontsize=PLOT_STYLE['LEGEND_FONT_SIZE'], frameon=True)

# hide unused axes
for j in range(len(present_groups), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()

plt.savefig(f'{path_to_save}/roc_auc_barplots.svg', dpi=600)

plt.show()

# %% [markdown]
# ## *Multi-factor* analysis

# %% [markdown]
# ### Functions for processing & config-parameters

# %% [markdown]
# #### Forward selection

# %%
def forward_selection_bootstrap(
    X_train: pd.DataFrame,
    y_train: pd.Series | np.ndarray,
    X_test: pd.DataFrame,
    y_test: pd.Series | np.ndarray,
    candidate_features: list[str],
    scoring: str = "roc_auc_ovr",          # 'roc_auc_ovr' | 'pr_auc'
    min_uplift: float | None = None,
    max_features: int | None = None,
    n_bootstrap: int = 50,
    n_jobs: int = -1,
    use_tqdm: bool = True,
    uplift_type: str = "mean",             # 'mean' | 'low' | 'high' — USED ONLY WHEN selection_mode='bootstrap'
    return_ci: bool = True,                # kept for compatibility; CI is always calculated in bootstrap mode
    random_state: int = 42,
    selection_mode: str = "bootstrap",     # 'bootstrap' | 'train'
):
    rng = np.random.RandomState(random_state)

    # convert targets to arrays/indices
    y_tr = np.asarray(y_train).ravel() if isinstance(y_train, (pd.Series, pd.DataFrame)) else np.asarray(y_train).ravel()
    y_te = np.asarray(y_test).ravel() if isinstance(y_test, (pd.Series, pd.DataFrame)) else np.asarray(y_test).ravel()

    # fix the set of classes (important for PR AUC / aligning probability column order)
    classes = np.unique(np.concatenate([y_tr, y_te]))

    def _score_metric(y_true, proba):
        try:
            if scoring == "roc_auc_ovr":
                return roc_auc_score(y_true, proba, multi_class="ovr", labels=classes)
            elif scoring == "pr_auc":
                y_bin = label_binarize(y_true, classes=classes)
                return average_precision_score(y_bin, proba, average="macro")
            else:
                raise ValueError(f"Unsupported metric: {scoring}")
        except Exception:
            return np.nan

    # Общий пайплайн обучение→прогноз→метрика
    def _fit_and_score(Xtr, ytr, Xte, seed):
        est = Pipeline([
            ("scaler", StandardScaler()),
            ("clf", OneVsRestClassifier(
                LogisticRegression(
                    penalty="l2",
                    C=1.0,
                    solver="lbfgs",
                    max_iter=10_000,
                    random_state=seed
                ),
                n_jobs=None
            ))
        ])
        est.fit(Xtr, ytr)
        proba_tr = est.predict_proba(Xtr)
        proba_te = est.predict_proba(Xte)
        if hasattr(est, "classes_"):
            order = [int(np.where(est.classes_ == c)[0][0]) for c in classes]
            proba_tr = proba_tr[:, order]
            proba_te = proba_te[:, order]
        train_metric = _score_metric(ytr, proba_tr)
        test_metric  = _score_metric(y_te, proba_te)
        return train_metric, test_metric

    selected: list[str] = []
    best_train_score = -np.inf
    history: list[dict] = []
    remain = list(candidate_features)

    # --- режим 1: bootstrap (как было) ---
    def bootstrap_scores(feature_set: list[str]):
        Xtr = X_train[feature_set].values
        Xte = X_test[feature_set].values

        def single_bootstrap(seed: int):
            idx = resample(np.arange(len(y_tr)), replace=True, random_state=seed)
            X_bs = Xtr[idx]
            y_bs = y_tr[idx]
            if np.unique(y_bs).size < 2:
                return np.nan, np.nan
            try:
                return _fit_and_score(X_bs, y_bs, Xte, seed)
            except Exception:
                return np.nan, np.nan

        seeds = rng.randint(0, 10**9, size=n_bootstrap)
        pairs = Parallel(n_jobs=n_jobs)(
            delayed(single_bootstrap)(int(s)) for s in seeds
        )
        pairs = np.asarray(pairs, dtype=float)
        train_scores = pairs[:, 0]
        test_scores  = pairs[:, 1]

        def _agg(x):
            return (np.nanmean(x), np.nanpercentile(x, 5), np.nanpercentile(x, 95))

        tr_mean, tr_low, tr_high = _agg(train_scores)
        te_mean, te_low, te_high = _agg(test_scores)
        return (tr_mean, tr_low, tr_high), (te_mean, te_low, te_high)

    # --- режим 2: plain train (без бутстрапа) ---
    def plain_train_scores(feature_set: list[str]):
        Xtr = X_train[feature_set].values
        Xte = X_test[feature_set].values
        try:
            tr, te = _fit_and_score(Xtr, y_tr, Xte, random_state)
        except Exception:
            tr, te = np.nan, np.nan
        # совместимость с полями *_mean/low/high
        return (tr, tr, tr), (te, te, te)

    step = 0
    while remain:
        step += 1
        iterator = tqdm(remain, desc=f"Step {step}") if use_tqdm else remain

        if selection_mode not in ("bootstrap", "train"):
            raise ValueError("selection_mode must be 'bootstrap' or 'train'")

        scorer = bootstrap_scores if selection_mode == "bootstrap" else plain_train_scores

        results = Parallel(n_jobs=n_jobs)(
            delayed(scorer)(selected + [feat]) for feat in iterator
        )

        candidates_info = []
        for feat, ((tr_m, tr_l, tr_h), (te_m, te_l, te_h)) in zip(remain, results):
            candidates_info.append({
                "feature":   feat,
                "train_mean": float(tr_m),
                "train_low":  float(tr_l),
                "train_high": float(tr_h),
                "test_mean":  float(te_m),
                "test_low":   float(te_l),
                "test_high":  float(te_h),
            })

        # ключ выбора
        if selection_mode == "bootstrap":
            if uplift_type == "mean":
                key = "train_mean"
            elif uplift_type == "low":
                key = "train_low"
            elif uplift_type == "high":
                key = "train_high"
            else:
                raise ValueError("uplift_type must be one of: 'mean', 'low', 'high'")
        else:
            # в train-режиме берем train_mean (он же = low = high)
            key = "train_mean"

        best_candidate = max(candidates_info, key=lambda x: (x[key], -np.inf if np.isnan(x[key]) else 0))

        uplift = best_candidate[key] - best_train_score
        if (min_uplift is not None) and (uplift < min_uplift):
            break

        selected.append(best_candidate["feature"])
        remain.remove(best_candidate["feature"])
        best_train_score = best_candidate[key]

        history.append({
            "feature":     best_candidate["feature"],
            "train_mean":  best_candidate["train_mean"],
            "train_low":   best_candidate["train_low"],
            "train_high":  best_candidate["train_high"],
            "test_mean":   best_candidate["test_mean"],
            "test_low":    best_candidate["test_low"],
            "test_high":   best_candidate["test_high"],
            "uplift_train": float(uplift),
            "n_selected":  len(selected),
            "selection_mode": selection_mode,   # NEW: для прозрачности в логе
        })

        if (max_features is not None) and (len(selected) >= max_features):
            break

    return selected, history

# %% [markdown]
# #### *Metric-uplift* line plot

# %%
def plot_cumulative_score_line_bootstrap(
    selection_log,
    ax=None,
    show_ci=True,
    show_test=True,
    annotate=True,
):
    # Prepare data
    df_log = pd.DataFrame(selection_log).copy()
    if df_log.empty:
        raise ValueError("selection_log is empty.")

    # Backward compatibility with old keys
    if {"score_mean", "score_low", "score_high"}.issubset(df_log.columns):
        df_log["train_mean"] = df_log["score_mean"]
        df_log["train_low"]  = df_log["score_low"]
        df_log["train_high"] = df_log["score_high"]

    req_train = {"train_mean", "train_low", "train_high"}
    if not req_train.issubset(df_log.columns):
        missing = req_train - set(df_log.columns)
        raise ValueError(f"Missing train columns: {missing}")

    df_log["Step"] = np.arange(1, len(df_log) + 1)

    created_fig = False
    if ax is None:
        fig, ax = plt.subplots(figsize=(max(6, len(df_log) * 1.2), 5), dpi=150)
        created_fig = True

    # Style from PLOT_STYLE (direct access)
    title           = PLOT_STYLE["TITLE"]
    title_fs        = PLOT_STYLE["TITLE_FONT_SIZE"]
    title_fs_style  = PLOT_STYLE["TITLE_FONTSTYLE"]
    x_label         = PLOT_STYLE["X_LABEL"]
    x_label_fs      = PLOT_STYLE["X_LABEL_FONT_SIZE"]
    x_labelpad      = PLOT_STYLE["X_LABELPAD"]
    y_label         = PLOT_STYLE["Y_LABEL"]
    y_label_fs      = PLOT_STYLE["Y_LABEL_FONT_SIZE"]
    y_labelpad      = PLOT_STYLE["Y_LABELPAD"]
    x_tick_fs       = PLOT_STYLE["X_TICK_LABEL_FONT_SIZE"]
    y_tick_fs       = PLOT_STYLE["Y_TICK_LABEL_FONT_SIZE"]
    metric_value_fs = PLOT_STYLE["METRIC_VALUE_FONT_SIZE"]

    # Fixed colors
    train_color = "#08519c"
    test_color  = "#1f77b4"

    # Train line
    line_train, = ax.plot(
        df_log["Step"],
        df_log["train_mean"],
        marker="o",
        linewidth=2,
        alpha=0.7,
        linestyle="-",
        label="Train",
        color=train_color,
    )
    if show_ci:
        ax.fill_between(
            df_log["Step"],
            df_log["train_low"],
            df_log["train_high"],
            alpha=0.20,
            color=train_color,
        )

    # Test line (nominal)
    line_test = None
    if show_test and {"test_mean","test_low","test_high"}.issubset(df_log.columns):
        line_test, = ax.plot(
            df_log["Step"],
            df_log["test_mean"],
            marker="s",
            linewidth=2,
            alpha=0.7,
            linestyle="-",
            label="Test",
            color=test_color,
        )
        if show_ci:
            ax.fill_between(
                df_log["Step"],
                df_log["test_low"],
                df_log["test_high"],
                alpha=0.20,
                color=test_color,
            )

    # Point annotations
    if annotate:
        for _, row in df_log.iterrows():
            ax.text(
                row["Step"],
                row["train_mean"] + 0.005,
                f'{row["train_mean"]:.3f}',
                ha="center",
                va="bottom",
                fontsize=metric_value_fs,
                color='black',
            )
        if line_test is not None:
            for _, row in df_log.iterrows():
                ax.text(
                    row["Step"],
                    row["test_mean"] - 0.020,
                    f'{row["test_mean"]:.3f}',
                    ha="center",
                    va="bottom",
                    fontsize=metric_value_fs,
                    color='black',
                )

    # Axes formatting
    ax.set_title(title, fontsize=title_fs, fontstyle=title_fs_style)
    ax.set_xlabel(x_label, fontsize=x_label_fs, labelpad=x_labelpad)
    ax.set_ylabel(y_label, fontsize=y_label_fs, labelpad=y_labelpad)
    ax.tick_params(axis="x", labelsize=x_tick_fs)
    ax.tick_params(axis="y", labelsize=y_tick_fs)

    # Exactly 10 ticks on Y
    ax.yaxis.set_major_locator(ticker.MaxNLocator(10))

    # Steps and labels
    ax.set_xticks(df_log["Step"])
    if "feature" in df_log.columns:
        ax.set_xticklabels(df_log["feature"], rotation=0)

    # Legend with only two line entries
    handles = [line_train] + ([line_test] if line_test is not None else [])
    labels = ["Train"] + (["Test"] if line_test is not None else [])
    ax.legend(handles, labels, loc="upper left", frameon=True)

    # Y limits padding
    y_candidates = [df_log["train_low"], df_log["train_high"], df_log["train_mean"]]
    if line_test is not None:
        y_candidates += [df_log["test_low"], df_log["test_high"], df_log["test_mean"]]
    y_min = np.nanmin([c.min() for c in y_candidates])
    y_max = np.nanmax([c.max() for c in y_candidates])
    if np.isfinite(y_min) and np.isfinite(y_max):
        pad = (y_max - y_min) * 0.06 if y_max > y_min else 0.02
        ax.set_ylim(y_min - pad, y_max + pad)

    if created_fig:
        plt.tight_layout()
        plt.show()

    return ax

# %% [markdown]
# ### Feature selection

# %%
candidate_features = []

for feature in of_features_to_save:
    feature_types_lst = feature_to_types[feature]
    for feature_type in feature_types_lst:
        candidate_features.append(feature)

print(f'Число фичей для многофакторного анализа: {len(candidate_features)}')
# Out:
# Число фичей для многофакторного анализа: 54

# %%
# %%time

selected_feats, selection_log = forward_selection_bootstrap(
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    candidate_features=candidate_features,
    scoring='roc_auc_ovr',
    min_uplift=0.005,
    max_features=5,
    n_bootstrap=50,
    uplift_type='low',  # 'mean', 'low', 'high'
    n_jobs=-1
)
# Out:
# Step 1:   0%|          | 0/54 [00:00<?, ?it/s]
# Step 2:   0%|          | 0/53 [00:00<?, ?it/s]
# Step 3:   0%|          | 0/52 [00:00<?, ?it/s]
# Step 4:   0%|          | 0/51 [00:00<?, ?it/s]
# Step 5:   0%|          | 0/50 [00:00<?, ?it/s]
# CPU times: user 427 ms, sys: 74.1 ms, total: 501 ms
# Wall time: 8.53 s

# %%
PLOT_STYLE = {
    'TITLE': '',
    'TITLE_FONT_SIZE': 12,
    'TITLE_FONTSTYLE': 'normal',
    'X_LABEL': '',
    'Y_LABEL': '$ROC-AUC_{ovr}$',
    'X_LABEL_FONT_SIZE': 12,
    'Y_LABEL_FONT_SIZE': 12,
    'X_TICK_LABEL_FONT_SIZE': 16,
    'Y_TICK_LABEL_FONT_SIZE': 10,
    'X_LABELPAD': 10,
    'Y_LABELPAD': 10,
    'METRIC_VALUE_FONT_SIZE': 8,
    'Y_NBINS': 10
}

# %%
fig, ax = plt.subplots(figsize=(8, 4), dpi=300)

plot_cumulative_score_line_bootstrap(
    selection_log=selection_log,
    ax=ax,
    show_ci=True
)

plt.tight_layout()
plt.savefig(f'{path_to_save}/fs_uplift_lineplot_bootstrap.svg', dpi=600)
plt.show()
